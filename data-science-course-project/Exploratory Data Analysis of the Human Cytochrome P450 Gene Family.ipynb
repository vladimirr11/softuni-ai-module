# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from nltk.corpus import stopwords

# %%
plt.style.use('seaborn')

# %% [markdown]
# # Exploratory Data Analysis of the Human Cytochrome P450 Gene Family

# %% [markdown]
# ### Author: Vladimir Stoev

# %% [markdown]
# ### Abstract

# %% [markdown]
# In recent years pharmacogenomics has become the cornerstone in elucidating the intrinsic interplay between individual's genetic makeup and the commonly prescribed drugs. Moreover, the promise of pharmacogenomics is that it will accelerate the movement to the so appreciated precision medicine while escaping 'one-drug-fits-all' paradigm. Conceptually, pharmacogenomics integrate in itself the study of genes and their function at genome-wide level - genomics, and the study of drug action - pharmacology. In turn, the two main areas of pharmacology - pharmacokinetics PKs, and pharmacodynamics PDs, focus on the factors that infuence the drug metabolism in the body - PKs level, and factors associated with the drug target(s) - PDs level. The subject of exploration in this project - the human Cytochrome P450 gene family, accounts for the metabolism of nearly 3/4 of all prescribed drugs. The main topics of examination throughout the project will be the genetic variability amongst the Cytochrome P450 genes, analysis of the drugs and their adverse effects associated with these genetic variants, as well as _tf-idf_ analysis of the phenotypic characteristics of the variants. The data used in the project is collected from the primary source of pharmacogenomic information - The Pharmacogenomics Knowledge Base (PharmGKB).

# %% [markdown]
# ### I. Introduction to Pharmacogenomics

# %% [markdown]
# The  completion  of  the  Human  Genome  Project (HGP) in April 2003 yielded a permanent  foundation  for  biological  research  and  launched a new era in biomedicine. The goal of the HGP was to create a reference human genome sequence covering nearly the entire genome  with  an  error  rate  of  ~1 in 10,000 bases. In fact, the final sequence covers   99%   of   the   euchromatic   genome   with  fewer  than  350  gaps  and  has  an  error  rate  of  ~1  in  100,000  bases. One important consequence of the completion of the HGP was the emergence of new fields in biomedecine and molecular biology known informely as $omics$. Genomics, transcriptomics, proteomics, metabolomics, and epigenomics are only a small fraction of the many disciplines that arose with the HGP. The related suffix -ome is used to address the objects of study of these fields, such as the genome, proteome or metabolome, respectively.
#
# This project will deal with one particular omics science, namely pharmacogenomics. Pharmacogenomics is the study of how genes affect an individual's response to drugs. This new field of study combine in itself pharmacology (the study of drugs, and how they interact with the living organism) and genomics (the study of genes and their functions). Pharmacogenomics analyzes the genetic variants amongst individuals and how these variants affect drug action at pharmacokinetics PK level (absorbsion, distribution, metabolism, and excretion of the drugs) and pharmacodynamics PD level (the interaction between the drug and the biological target). The term pharmacogenomics is often used interchangeably with pharmacogenetics. Although both terms relate to drug response based on genetic influences, pharmacogenetics focuses on single drug-gene interactions, whereas pharmacogenomics encompasses a more genome-wide association approach, incorporating genomics and epigenetics while dealing with the effects of multiple genes on drug response.
#
# The field of pharmacogenomics aims to define those common genetic factors that contribute to variable serious adverse drug reactions ADRs, their underlying genetic mechanisms, and ultimately to implement genetic testing to improve drug efficacy and reduce toxicity. Furthermore, an understanding of the genetic basis of variable drug response can be used as a tool to expand the use of existing drugs to new indications and to develop new drugs. Well recognised examples of
# genetically determined variability in drug response often involve single DNA variants common in a population and associated with relatively large effect sizes and clearly definable metaboliser phenotypes. As a result, the implementation of pharmacogenomic information into the clinical practice can eventually lead up to the so welcomed model of precision medicine. That is the approach of customzable healtcare by means of which medical decisions, treatments, or products are being tailored to a subgroup of patients, insted of using the model 'one-drug-fits-all'. However, several barriers are identified and need to be overcomed to routinely use pharmacogenomic variant data in improving drug prescribing and treatment. Of course, the central issue, again, is the cost - diagnostics do not come cheap, plus, the pharmaceutical industry do not have interests in manufacturing 'orphan' drugs, from which only small sub-groups of patients could have betefits. Moreover, some of the world’s first truly individualised cancer treatments utilizing genetically modified CAR-T cells (CAR-T stands for chimeric antigen t-cell receptor), despite having achieved impressive results in rare and advanced cancers, could be serious burden for reimbursement from private and public payers, due to eye-watering cost upwards of $400,000 per patient, per trietment.
#
# Despite the cost-related drawbacks, the field of pharmacogenomics is decisively heading to implementing the model of precision medicine in the clinic by continuously generating huge amounts of genetic data in connection with the different drug response. These data, by no means, should be left unanalyzed, and that is the moment when the power of artificial intelligence comes into play. Tumor detection in large medical images datasets, high-content screening (HCS) in drug discovery, and disease risk prediction using genetic variant data, are only a few examples of use cases for AI in precision medicine.
#
# Within the reach of this project will be analysis of data collceted from the Pharmacogenomics Knowledge Base (PharmGKB). PharmGKB is a publicly available, online knowledgebase responsible for the aggregation, curation, and integration of knowledge regarding the impact of human genetic variation on drug response. The main objectives of the analysis will be examination of some of the most common pharmacogenes implicated in the differential drug response, as well as exploration of their variants and associated drugs. The analysis of the data will end with natural language processing NLP of the variant-associated clinical phenotypes of the Cytochrome P450 gene family.

# %% [markdown]
# ### II. Exploration of the Genetic Variability in the Cytochrome P450 Gene Family

# %% [markdown]
# Two conceptual pathways describe an organism’s response to drug exposure. Pharmacokinetics defines variability in the processes (absorption, distribution, metabolism, and elimination) modulating delivery of drug and active metabolites to and removal from their site or sites of action. Pharmacodynamics describes variability in drug action that is not attributable to variable drug concentrations, which can reflect variability in the interaction of active drug with its effector molecules or other mechanisms such as variability in disease mechanisms.
#
# The earliest examples of pharmacogenetic variability involved variability in pharmacodynamic processes. During and after World War 2, the first instances of genetically determined adverse drug reactions (ADRs) were described, including haemolytic anaemia in African-American soldiers with glucose-6-phosphate dehydrogenase (G6PD) deficiency exposed to antimalarials drugs, and prolonged paralysis following treatment with the muscle relaxant succinylcholine in patients with pseudocholinesterase deficiency. With the development of robust methods to measure concentrations of drugs and their metabolites in plasma and other sites came the ability to define patients who are pharmacokinetic outliers in whom unusually high or
# low plasma concentrations were associated with variable efficacy or ADRs. This in turn led to studies defining
# variants in key drug metabolising or transport genes as the basis for these responses. To date, the majority of variability to drug response is described in genes involved in pharmacokinetic processes, the most prevalent of which encode for drug-metabolizing enzymes part of the Cytochrome P450 (CYP) gene family.
#
# Cytochromes P450 (CYPs) is a superfamily of enzymes containing heme as a cofactor that function as monooxygenases. The term "P450" is derived from the spectrophotometric peak at the wavelength of the absorption maximum of the enzyme (450 nm) when it is in the reduced state and complexed with carbon monoxide. The Human Genome Project has identified 57 human genes coding for the various cytochrome P450 enzymes. Human CYPs are primarily membrane-associated proteins located either in the inner membrane of mitochondria or in the endoplasmic reticulum of cells. Cytochrome P450 enzymes are present in most tissues of the body, but are most concentrated in hepatocytes, the cells of the liver, where is the primary station of xenobiotics metabolism.
#
# CYPs metabolize thousands of endogenous and exogenous chemicals. While some CYPs metabolize only one (or a very few) substrates, such as CYP19 (aromatase), others may metabolize multiple substrates. From a clinical perspective, the most commonly tested CYPs include: CYP2D6, CYP2C19, CYP2C9, CYP3A4 and CYP3A5. These genes account for the metabolism of approximately 70-90% of currently available prescription drugs.
#
# Now, when we got acquainted with the field of pharmacogenomics and the subject of analysis of this project - CYP genes, let's do some data science.
#
# As it was mentioned earlier, the data analyzed in this project is obtained from PharmGKB. PharmGKB has many different types of PGx-related information (PGx stands for pharmacogenomics or pharmacogenetics), including genetic variants (single-nucleotide polymorphisms (SNPs) and haplotypes, as well as some copy number variations (CNVs) and indels), genes, drugs, phenotypes (diseases and side effects) and PubMed IDs (PMIDs).
#
# We will begin our exploratary data analysis with loading our first dataset. It contains information about clinical annotations, manually created by the PharmGKB curators, and provide evidence-rated, genotype-based summary about particular pharmacogenetic variant-drug pairs.
#
# Let's now read this dataset.

# %%
clinical_annotation_metadata = pd.read_table('Data/clinical_ann_metadata.tsv')

# %%
clinical_annotation_metadata
# Out:
#       Clinical Annotation ID     Location  \
# 0                  981755803   rs75527207
# 1                 1449311190    rs4149056
# 2                 1449191690  rs141033578
# 3                 1449191746   rs78769542
# 4                  981204774    rs1799971
# ...                      ...          ...
# 4553              1451212540   rs62103056
# 4554              1451217440   rs12979860
# 4555              1451217520   rs12979860
# 4556              1451217540   rs12979860
# 4557              1451217560   rs12979860
#
#                                          Gene Level of Evidence  \
# 0                                CFTR (PA109)                1A
# 1                       SLCO1B1 (PA134865839)                 3
# 2                                CFTR (PA109)                1A
# 3                                CFTR (PA109)                1A
# 4                             OPRM1 (PA31945)                 3
# ...                                       ...               ...
# 4553                                      NaN                 3
# 4554  IFNL3 (PA134952671);IFNL4 (PA166049147)                 3
# 4555  IFNL3 (PA134952671);IFNL4 (PA166049147)                 3
# 4556  IFNL3 (PA134952671);IFNL4 (PA166049147)                 3
# 4557  IFNL3 (PA134952671);IFNL4 (PA166049147)                 3
#
#      Clinical Annotation Types            Genotype-Phenotype IDs  \
# 0                     Efficacy  1450043467;1450043468;1450043469
# 1                       Dosage  1449311192;1449311193;1449311194
# 2                     Efficacy  1449191692;1449191693;1449191694
# 3                     Efficacy  1449191748;1449191749;1449191750
# 4                     Efficacy     982037129;982037130;982037131
# ...                        ...                               ...
# 4553                  Efficacy  1451212542;1451212543;1451212544
# 4554                  Efficacy  1451217442;1451217443;1451217444
# 4555                  Efficacy  1451217522;1451217523;1451217524
# 4556                       NaN  1451217542;1451217543;1451217544
# 4557                  Efficacy  1451217562;1451217563;1451217564
#
#                                         Annotation Text  \
# 0     AA:Ivacaftor is indicated in cystic fibrosis p...
# 1     CC:Patients with the CC genotype and Precursor...
# 2     CC:Patients with the CC genotype (do not have ...
# 3     AA:Patients with the AA genotype (two copies o...
# 4     AA:Patients with AA genotype may have an incre...
# ...                                                 ...
# 4553  AA:Patients with the AA genotype with malaria ...
# 4554  CC:Patients with hepatitis B and the CC genoty...
# 4555  CC:Patients with the CC genotype may have an i...
# 4556  CC:Patients with a HCV genotype I infection an...
# 4557  CC:Patients with the CC genotype may have an i...
#
#                                 Variant Annotations IDs  \
# 0     981755665;981755678;982006840;982009991;104373...
# 1                                            1449311153
# 2                                            1449191113
# 3                                            1449191063
# 4                         655386751;655386750;655385584
# ...                                                 ...
# 4553                                         1451212190
# 4554                   1448631931;1450810253;1449713162
# 4555                                         1449190317
# 4556                                981352209;981352215
# 4557                                         1447951883
#
#                                     Variant Annotations  \
# 0     Genotypes AA + AG  are associated with  respon...
# 1     Genotypes CC + CT  is associated with  decreas...
# 2     Allele T  is associated with  activity of CFTR...
# 3     Allele A  is associated with  activity of CFTR...
# 4     Genotype GG  is associated with  increased lik...
# ...                                                 ...
# 4553  Allele A  is associated with  increased likeli...
# 4554  Genotype TT  is associated with  increased lik...
# 4555  Genotype CC  is associated with  increased sus...
# 4556  Genotype CC  is associated with  increased sus...
# 4557  Genotype CC  is associated with  increased res...
#
#                                                   PMIDs  Evidence Count  \
# 0     19846789;21083385;22047557;22293084;22942289;2...              29
# 1                                              29683944               1
# 2                                              23891399               1
# 3                                              23891399               1
# 4                                     15007373;17224915               3
# ...                                                 ...             ...
# 4553                                           32433338               1
# 4554                         28453395;30016335;31201901               3
# 4555                                           29534310               1
# 4556                                           22438096               2
# 4557                                           26334898               1
#
#                                       Related Chemicals  \
# 0                               ivacaftor (PA165950341)
# 1     mercaptopurine (PA450379);methotrexate (PA450428)
# 2                               ivacaftor (PA165950341)
# 3                               ivacaftor (PA165950341)
# 4     Drugs used in nicotine dependence (PA164712720...
# ...                                                 ...
# 4553                          tafenoquine (PA166115580)
# 4554                peginterferon alfa-2a (PA164749390)
# 4555                           sofosbuvir (PA166122593)
# 4556                             interferons (PA451999)
# 4557                             interferons (PA451999)
#
#                                        Related Diseases  \
# 0                            Cystic Fibrosis (PA443829)
# 1     Precursor Cell Lymphoblastic Leukemia-Lymphoma...
# 2                            Cystic Fibrosis (PA443829)
# 3                            Cystic Fibrosis (PA443829)
# 4                       Tobacco Use Disorder (PA445876)
# ...                                                 ...
# 4553                                 Malaria (PA444859)
# 4554                    Hepatitis B, Chronic (PA446862)
# 4555                    Hepatitis C, Chronic (PA446863)
# 4556                             Hepatitis C (PA444445)
# 4557                             Hepatitis C (PA444445)
#
#                                  Biogeographical Groups Chromosome
# 0                                      Mixed Population       chr7
# 1                                          Near Eastern      chr12
# 2     Not applicable - study was carried out in FRT ...       chr7
# 3     Not applicable - study was carried out in FRT ...       chr7
# 4                                              European       chr6
# ...                                                 ...        ...
# 4553                                   Mixed Population      chr18
# 4554                                   Mixed Population      chr19
# 4555                                            Unknown      chr19
# 4556                                         East Asian      chr19
# 4557                                           European      chr19
#
# [4558 rows x 15 columns]

# %% [markdown]
# Ok, we got our dataset, now let's verify the dimensionality of our DataFrame.

# %%
clinical_annotation_metadata.shape
# Out:
# (4558, 15)

# %% [markdown]
# 15 coulmns with 4558 records each, ok. Now, it is a good idea to explore these columns and their associated data types.

# %%
clinical_annotation_metadata.dtypes
# Out:
# Clinical Annotation ID        int64
# Location                     object
# Gene                         object
# Level of Evidence            object
# Clinical Annotation Types    object
# Genotype-Phenotype IDs       object
# Annotation Text              object
# Variant Annotations IDs      object
# Variant Annotations          object
# PMIDs                        object
# Evidence Count                int64
# Related Chemicals            object
# Related Diseases             object
# Biogeographical Groups       object
# Chromosome                   object
# dtype: object

# %% [markdown]
# We can see that 13 out of 15 columns are with dtype object, which means that they are with mixed types of data. The columns `Clinical Annotation ID` and `Evidence Count` are dtype int64. The column Clinical Annotation contains unique PharmGKB ID number for each variant - drug annotation, while the column Evidence Count holds information for the number of supporting PubMed IDs (PMIDs). That is the number of times this variant - drug pair appeared in PubMed.
#
# Now, let's explore the other columns with `dtype: object` and find out what information is stored there.
#
# First, we can take random sample from our dataset.

# %%
clinical_annotation_metadata.sample(20)
# Out:
#       Clinical Annotation ID            Location                   Gene  \
# 1309               655386310            rs870995       PIK3CA (PA33308)
# 3176              1444673197          rs13207351        VEGFA (PA37302)
# 626               1183491333              rs4673         CYBA (PA27075)
# 3763              1448264356   HLA-DRB1*04:03:01     HLA-DRB1 (PA35072)
# 3559              1447982761         rs745746329         CYP2D6 (PA128)
# 886               1449167200          rs12302749    SPSB2 (PA142670872)
# 1545               655384979           rs2842030         RGS4 (PA34375)
# 456               1043880792              rs5443           GNB3 (PA176)
# 3771              1448423436          rs12436663    PRORP (PA134879499)
# 1800              1449004522          rs73594404                    NaN
# 2383              1450375758           rs9366772        HLA-C (PA35057)
# 1600               655385352           rs3892097         CYP2D6 (PA128)
# 2981              1444667549           rs3129294     HLA-DPB2 (PA35065)
# 4080              1448099149           rs2032582          ABCB1 (PA267)
# 3323              1448605577      HLA-B*35:05:01        HLA-B (PA35056)
# 2121              1183704339           rs6977820                    NaN
# 3993              1448104131             rs14158           LDLR (PA227)
# 3394              1448602385          rs11124945  PLEKHH2 (PA134912826)
# 432               1183701224      HLA-A*31:01:02        HLA-A (PA35055)
# 1901              1450811379  CYP2B6*1, CYP2B6*6         CYP2B6 (PA123)
#
#      Level of Evidence Clinical Annotation Types  \
# 1309                 4                    Dosage
# 3176                 3                  Efficacy
# 626                  3                     Other
# 3763                 3              Toxicity/ADR
# 3559                 4             Metabolism/PK
# 886                  4                  Efficacy
# 1545                 4                  Efficacy
# 456                  3                  Efficacy
# 3771                 3                  Efficacy
# 1800                 3              Toxicity/ADR
# 2383                 4                  Efficacy
# 1600                 3                  Efficacy
# 2981                 3              Toxicity/ADR
# 4080                 3                  Efficacy
# 3323                 3              Toxicity/ADR
# 2121                2B              Toxicity/ADR
# 3993                 3                  Efficacy
# 3394                 3              Toxicity/ADR
# 432                 1A              Toxicity/ADR
# 1901                 3                  Efficacy
#
#                 Genotype-Phenotype IDs  \
# 1309     655386311;655386312;655386313
# 3176  1444673204;1444673205;1444673206
# 626   1183491350;1183491351;1183491352
# 3763                        1448264358
# 3559  1447982765;1447982764;1447982763
# 886   1449167207;1449167208;1449167209
# 1545     655384982;655384981;655384980
# 456   1183615553;1183615554;1183615555
# 3771  1448423438;1448423439;1448423440
# 1800  1449004524;1449004525;1449004526
# 2383  1450375760;1450375761;1450375762
# 1600     982030643;982030644;982030645
# 2981  1444667551;1444667552;1444667553
# 4080  1448099151;1448099152;1448099153
# 3323                        1448605579
# 2121  1183704344;1183704345;1183704346
# 3993  1448104138;1448104139;1448104140
# 3394  1448602387;1448602388;1448602389
# 432                         1450376317
# 1901  1450811384;1450811385;1450811386
#
#                                         Annotation Text  \
# 1309  AA:Patients with the AA genotype may have decr...
# 3176  AA:Patients with the AA genotype and breast ca...
# 626   AA:Patients with the AA genotype and Hyperchol...
# 3763  *04:03:01:Patients with one or two copies of t...
# 3559  CC:Patients with the CC genotype may have incr...
# 886   CC:Patients with the CC genotype and Attention...
# 1545  GG:Patients with the GG genotype is associated...
# 456   CC:Patients with the CC genotype and essential...
# 3771  AA:Patients with the AA genotype and asthma ma...
# 1800  AA:Patients with nasopharyngeal cancer and the...
# 2383  AA:Patients with the AA genotype may have an i...
# 1600  CC:Patients with CC genotype may have lower pl...
# 2981  AA:Patients with asthma and the AA genotype ma...
# 4080  AA:Patients with the AA genotype and bone frac...
# 3323  *35:05:01:Patients with one or two copies of t...
# 2121  CC:Patients with the CC genotype may have decr...
# 3993  AA:Patients with the AA genotype who are co-in...
# 3394  AA:Patients with hypertension and the AA genot...
# 432   *31:01:02:Patients with one or two copies of t...
# 1901  *1/*1:Patients with the *1/*1 genotype may be ...
#
#                                 Variant Annotations IDs  \
# 1309                                          699638956
# 3176                                         1184512103
# 626                                           982045376
# 3763                                         1448264230
# 3559                                         1447958868
# 886                                          1449166009
# 1545                                          608431255
# 456                       982044907;982044939;982044965
# 3771                                         1448423402
# 1800                              1448821255;1449004423
# 2383                                         1450375653
# 1600                                          769181593
# 2981                                         1185003204
# 4080                                         1184467504
# 3323                                         1448605559
# 2121                                          827704156
# 3993                              1444706762;1444706772
# 3394                                         1448602371
# 432   981482109;992282434;993813998;993944301;118370...
# 1901                              1446765775;1450811368
#
#                                     Variant Annotations  \
# 1309  Allele C  is associated with  increased cleara...
# 3176  Genotype GG  is associated with  decreased pro...
# 626   Genotypes AA + AG  are associated with  increa...
# 3763  HLA-DRB1 *04:03:01  is associated with  increa...
# 3559  Allele T  is associated with  decreased cleara...
# 886   Allele C  is associated with  increased respon...
# 1545  Genotype GG  is associated with  increased res...
# 456   Genotype CC  is associated with  increased res...
# 3771  Genotype AA  is associated with  decreased res...
# 1800  Genotypes AA + AG  are associated with  increa...
# 2383  Allele A  is associated with  increased respon...
# 1600  Allele T  is associated with  increased plasma...
# 2981  Allele C  is associated with  increased risk o...
# 4080  Allele A  is associated with  increased likeli...
# 3323  HLA-B *35:05:01  is associated with  increased...
# 2121  Genotypes CT + TT  are associated with  increa...
# 3993  Genotype GG  is associated with  increased res...
# 3394  Allele G  is associated with  decreased risk o...
# 432   HLA-A *31:01:02 is associated with increased r...
# 1901  CYP2B6 *6  is not associated with  response to...
#
#                                                   PMIDs  Evidence Count  \
# 1309                                           20157331               1
# 3176                                           24061601               1
# 626                                            15936011               1
# 3763                                           27666425               1
# 3559                                           26310775               1
# 886                                            29382897               1
# 1545                                           17588543               1
# 456                                            20235788               3
# 3771                                           25963335               1
# 1800                                           28814798               2
# 2383                                           30924126               1
# 1600                                           19037197               1
# 2981                                           25372592               1
# 4080                                           24624916               1
# 3323                                           28323125               1
# 2121                                           21826085               1
# 3993                                           21572301               2
# 3394                                           27670767               1
# 432   21149285;21428769;21917426;22211527;22348435;2...              27
# 1901                                  17223085;26153084               2
#
#                                       Related Chemicals  \
# 1309                               docetaxel (PA449383)
# 3176                               docetaxel (PA449383)
# 626                              simvastatin (PA451363)
# 3763                           oxcarbazepine (PA450732)
# 3559  bufuralol (PA166110256);dextromethorphan (PA44...
# 886                          methylphenidate (PA450464)
# 1545                             risperidone (PA451257)
# 456                                 atenolol (PA448499)
# 3771                                zileuton (PA451955)
# 1800  Platinum compounds (PA164713176);radiotherapy ...
# 2383                             allopurinol (PA448320)
# 1600                              metoprolol (PA450480)
# 2981                                 aspirin (PA448497)
# 4080                                tramadol (PA451735)
# 3323                             minocycline (PA450519)
# 2121                          antipsychotics (PA452233)
# 3993  peginterferon alfa-2a (PA164749390);peginterfe...
# 3394           atenolol (PA448499);verapamil (PA451868)
# 432                            carbamazepine (PA448785)
# 1901                               bupropion (PA448687)
#
#                                        Related Diseases  \
# 1309          Carcinoma, Non-Small-Cell Lung (PA443622)
# 3176                        Breast Neoplasms (PA443560)
# 626                     Hypercholesterolemia (PA444516)
# 3763                                Epilepsy (PA444065)
# 3559                                                NaN
# 886   Attention Deficit Disorder with Hyperactivity ...
# 1545                           Schizophrenia (PA447216)
# 456                   Essential hypertension (PA447288)
# 3771                                  Asthma (PA443450)
# 1800  Anemia (PA443340);Dermatitis (PA443875);Leukop...
# 2383                                                NaN
# 1600                                                NaN
# 2981  aspirin-induced asthma (PA131285571);Asthma (P...
# 4080                         Fractures, Bone (PA444222)
# 3323            drug-induced liver injury (PA166119041)
# 2121  Schizophrenia (PA447216);tardive dyskinesia (P...
# 3993  Hepatitis C, Chronic (PA446863);HIV Infections...
# 3394  Diabetes Mellitus (PA443886);Hypertension (PA4...
# 432   Drug Hypersensitivity (PA443936);drug reaction...
# 1901                    Tobacco Use Disorder (PA445876)
#
#      Biogeographical Groups Chromosome
# 1309               European       chr3
# 3176                Unknown       chr6
# 626                 Unknown      chr16
# 3763             East Asian        NaN
# 3559                Unknown      chr22
# 886        Mixed Population      chr12
# 1545               European       chr1
# 456        Mixed Population      chr12
# 3771                Unknown      chr14
# 1800             East Asian      chr16
# 2383       Mixed Population       chr6
# 1600               European      chr22
# 2981             East Asian       chr6
# 4080             East Asian       chr7
# 3323               European        NaN
# 2121             East Asian       chr7
# 3993               European      chr19
# 3394       Mixed Population       chr2
# 432        Mixed Population        NaN
# 1901       Mixed Population        NaN

# %% [markdown]
# We can see that many of the columns hold more than one record. For instance, the `Gene` column has rows with more than one gene, while the column `Location` holds more than one variant for those genes. The same applies for the rest of the columns with dtype object.
#
# Let's explore these columns more thoroughly.

# %%
clinical_annotation_metadata['Location'].sample(20)
# Out:
# 1417              rs6028945
# 2217      HLA-DRB1*14:01:01
# 3110              rs1045642
# 4437              rs1799971
# 26                rs1045642
# 1821              rs2298881
# 1082         HLA-B*15:02:01
# 331               rs1801020
# 4072               rs846664
# 3161             rs12595985
# 1629                rs20417
# 1884              rs1042028
# 1591             rs17731538
# 1580              rs1487278
# 4540    UGT1A1*1, UGT1A1*28
# 2179              rs3732219
# 2364              rs1801252
# 1731              rs1045642
# 2405                 rs7294
# 2800                 rs6295
# Name: Location, dtype: object

# %% [markdown]
# The column `Location` comprises of the most precise variant location available troughout NCBI database.   Pharmacogeneticists adopted a star nomenclature (eg, CYP2C19\*2) to describe variants in genes (sometimes termed pharmacogenes) underlying variability in drug response. Some star alleles can include more than one variant (eg, TPMT\*3A designates an allele defined by the presence of two single-nucleotide polymorphisms SNPs), and distinguishing this allele from those carrying only one of the SNPs can be challenging. Although the star nomenclature persists, as the understanding of the numbers of variants in important pharmacogenes increases, attempts are being made to reconcile the notation with alternate variant nomenclature, such as the conventional "rs" designation which comes from RefSNPs (rs) ID number from dbSNP database.
#
# We will have particular interest in this column, and we will explore it further, but before we do that, let's first pay attention to another attractive column for our analysis - the `Level Of Evidence` column.

# %%
clinical_annotation_metadata['Level of Evidence'].sort_values().unique()
# Out:
# array(['1A', '1B', '2A', '2B', '3', '4'], dtype=object)

# %% [markdown]
# Clinical annotations combine all variant annotations that discuss the same variant - drug phenotype association and bring them together into a single written summary of the association. Each clinical annotation is also given a level of evidence, providing a measure of confidence in the association. The level of evidence for a clinical annotation is manually assessed, and is based on criteria such as the number of studies finding positive versus negative results, p-values and study sizes.
#
# As we can see from the unique values of the column `Level of Evidence`, each clinical annotation has an "Evidence Strength", which ranks the level of evidence in the literature curated by PharmGKB for that association. The "strenght" of evidence is in ascending order, with 1A and 1B providing the most significant level of evidence.
#
# In the column `Clinical Annotation Types` are placed tags for the type of study.

# %%
clinical_annotation_metadata['Clinical Annotation Types'].unique()
# Out:
# array(['Efficacy', 'Dosage', 'Toxicity/ADR', 'Metabolism/PK', 'Other',
#        'Efficacy;Toxicity/ADR', 'Efficacy;Metabolism/PK',
#        'Dosage;Efficacy', nan, 'Efficacy;Toxicity/ADR;Metabolism/PK',
#        'Dosage;Metabolism/PK', 'Dosage;Toxicity/ADR',
#        'Toxicity/ADR;Metabolism/PK', 'Dosage;Efficacy;Toxicity/ADR',
#        'Dosage;Other', 'Toxicity/ADR;Other',
#        'Dosage;Efficacy;Metabolism/PK',
#        'Dosage;Toxicity/ADR;Metabolism/PK'], dtype=object)

# %% [markdown]
# The above column will not be of interest to us, in contrast to the column `Genotype-Phenotype IDs`, which contains unique ID numbers, which we will use later on in our analysis.

# %%
clinical_annotation_metadata['Genotype-Phenotype IDs'].head(10)
# Out:
# 0                     1450043467;1450043468;1450043469
# 1                     1449311192;1449311193;1449311194
# 2                     1449191692;1449191693;1449191694
# 3                     1449191748;1449191749;1449191750
# 4                        982037129;982037130;982037131
# 5                     1446905293;1446905294;1446905295
# 6                     1449566381;1449566382;1449566383
# 7    1449166659;1449166660;1449166661;1449166662;14...
# 8                     1449155609;1449155610;1449155611
# 9                     1449155656;1449155657;1449155658
# Name: Genotype-Phenotype IDs, dtype: object

# %% [markdown]
# As we can see, each record in the column is made up of several ID numbers, which we will have to separate as individual records. But, again, leter in the analysis.
#
# The column `Annotation Text` contains written summary of the clinical annotation for each genotype.

# %%
clinical_annotation_metadata['Annotation Text'].sample(10)
# Out:
# 1470    AA:Patients with the AA genotype and breast ca...
# 862     CC:Patients with the CC genotype may have decr...
# 816     AA:Patients with the AA genotype and hypertens...
# 4036    GG:Patients with the GG genotype and type 2 di...
# 1858    AA:Patients with the AA genotype may have a de...
# 955     CC:Patients with the CC genotype and Attention...
# 4538    *1/*1:Women with the UGT1A1*1/*1 genotype and ...
# 3411    AA:Patients with the AA genotype and cancer ma...
# 3686    GG:Patients with the GG genotype and decompens...
# 1339    CC:Patients with the CC genotype and Rheumatoi...
# Name: Annotation Text, dtype: object

# %%
clinical_annotation_metadata['Annotation Text'][2856]
# Out:
# "CC:Patients with the CC genotype and major depression may have decreased response to citalopram and escitalopram as compared to patients with the GG genotype. Other genetic and clinical factors may also influence a patient's response to citalopram and escitalopram.; CG:Patients with the CG genotype and major depression may have increased response to citalopram and escitalopram as compared to patients with the CC genotype or may have decreased response to citalopram and escitalopram as compared to patients with the GG genotype. Other genetic and clinical factors may also influence a patient's response to citalopram and escitalopram.; GG:Patients with the GG genotype and major depression may have increased response to citalopram and escitalopram as compared to patients with the CC genotype. Other genetic and clinical factors may also influence a patient's response to citalopram and escitalopram."

# %% [markdown]
# The column `Variant Annotation` represents summaries describing how a particular genetic polymophism is associated with a drug response, as reported in a single publication. Examples of drug responses include adverse drug reactions, changes in drug efficacy and alterations in how quickly or slowly a drug is metabolized.

# %%
clinical_annotation_metadata['Variant Annotations'].sample(10)
# Out:
# 1662    Allele C  is associated with  decreased expres...
# 55      Allele G  is associated with  decreased sulfat...
# 801     Genotype GG  is associated with  increased res...
# 1211    Genotypes CC + CT  is associated with  increas...
# 2255    Genotype AA  is associated with  increased abs...
# 4290    CYP3A4 *1B  is associated with  decreased clea...
# 4318    Allele G  is associated with  increased risk o...
# 3357    Genotype CC  is associated with  increased con...
# 867     CYP2C19 *2/*2 + *3/*3 is associated with decre...
# 4052    Allele T  is associated with  increased respon...
# Name: Variant Annotations, dtype: object

# %%
clinical_annotation_metadata['Variant Annotations'][2856]
# Out:
# 'Allele G  is associated with  increased response to citalopram and escitalopram in people with Depressive Disorder, Major as compared to allele C.'

# %% [markdown]
# The columns `Related Chemicals` and `Biogeographical Groups` will be important part of our analysis in this section.
#
# `Related Chemicals` stores information about drug(s) associated with the variant(s) in the annotation.

# %%
clinical_annotation_metadata['Related Chemicals'].unique()
# Out:
# array(['ivacaftor (PA165950341)',
#        'mercaptopurine (PA450379);methotrexate (PA450428)',
#        'Drugs used in nicotine dependence (PA164712720);nicotine (PA450626)',
#        'atorvastatin (PA448500);hmg coa reductase inhibitors (PA133950441);rosuvastatin (PA134308647)',
#        'hydrochlorothiazide (PA449899)', 'risperidone (PA451257)',
#        'ustekinumab (PA166048654)',
#        'Tumor necrosis factor alpha (TNF-alpha) inhibitors (PA164713366)',
#        'Tumor necrosis factor alpha (TNF-alpha) inhibitors (PA164713366);ustekinumab (PA166048654)',
#        'nevirapine (PA450616)', 'lumacaftor (PA166114483)',
#        'capecitabine (PA448771)', 'warfarin (PA451906)',
#        'hmg coa reductase inhibitors (PA133950441)',
#        'Platinum compounds (PA164713176)', 'bupropion (PA448687)',
#        'quetiapine (PA451201)', 'nicotine (PA450626)',
#        'fentanyl (PA449599)',
#        'bupropion (PA448687);Drugs used in nicotine dependence (PA164712720);nicotine (PA450626);varenicline (PA164781343)',
#        'carboplatin (PA448803);docetaxel (PA449383);trastuzumab (PA451743)',
#        'cocaine (PA449072)', 'pitavastatin (PA142650384)',
#        'pioglitazone (PA450970)',
#        'cyclophosphamide (PA449165);doxorubicin (PA449412);fluorouracil (PA128406956)',
#        'valproic acid (PA451846)',
#        'clomipramine (PA449048);nefazodone (PA450603);paroxetine (PA450801);venlafaxine (PA451866)',
#        'methotrexate (PA450428)', 'phenytoin (PA450947)',
#        'Antiinflammatory agents, non-steroids (PA164712462);celecoxib (PA448871);diclofenac (PA449293)',
#        'acetaminophen (PA448015)', 'morphine (PA450550)',
#        'tapentadol (PA166179720)',
#        'o-desmethyltramadol (PA166131379);tramadol (PA451735)',
#        'stavudine (PA451494)',
#        'cisplatin (PA449014);pemetrexed (PA10810)',
#        'cisplatin (PA449014);gemcitabine (PA449748)',
#        'lumefantrine (PA165111722)', 'escitalopram (PA10074)',
#        'opioids (PA452618)', 'methylphenidate (PA450464)',
#        'duloxetine (PA10066)', 'allopurinol (PA448320)',
#        'ethanol (PA448073)', 'heroin (PA452619)',
#        'ceftriaxone (PA448866)', 'lansoprazole (PA450180)',
#        'atenolol (PA448499)',
#        'buprenorphine (PA448685);fentanyl (PA449599);tramadol (PA451735)',
#        'migalastat (PA166182881)',
#        'azathioprine (PA448515);mercaptopurine (PA450379)',
#        'mephenytoin (PA450373)', 'acetaldehyde (PA166186245)',
#        'tacrolimus (PA451578)',
#        'capecitabine (PA448771);fluorouracil (PA128406956);leucovorin (PA450198);tegafur (PA452620)',
#        'fluorouracil (PA128406956);leucovorin (PA450198);oxaliplatin (PA131285527)',
#        'amiodarone (PA448383)',
#        'Drugs For Treatment Of Tuberculosis (PA164712708)',
#        'desmethylnaproxen (PA166163690)', 'cisplatin (PA449014)',
#        'hydroxyurea (PA449942)', 'lithium (PA450243)',
#        'acenocoumarol (PA452632)', 'clopidogrel (PA449053)',
#        'paroxetine (PA450801)', 'aspirin (PA448497)',
#        'Ace Inhibitors, Plain (PA164712308)',
#        'Alkylating Agents (PA164712331);cisplatin (PA449014)',
#        'antipsychotics (PA452233)', 'nortriptyline (PA450657)',
#        'cyclophosphamide (PA449165);doxorubicin (PA449412)',
#        'lovastatin (PA450272)', 'fluvastatin (PA449688)',
#        'venlafaxine (PA451866)', 'atorvastatin (PA448500)',
#        'oxycodone (PA450741)', 'irinotecan (PA450085)',
#        'metformin (PA450395)', 'imatinib (PA10804)',
#        'Antiinflammatory agents, non-steroids (PA164712462)',
#        'carboplatin (PA448803);cisplatin (PA449014);fluorouracil (PA128406956)',
#        'benazepril (PA448561);imidapril (PA452640)',
#        'talinolol (PA146123005)', 'antiepileptics (PA143485705)',
#        'corticosteroids (PA10832)', 'fluvoxamine (PA449690)',
#        'heroin (PA452619);methamphetamine (PA450403)',
#        'phenobarbital (PA450911)',
#        'antidepressants (PA452229);Selective serotonin reuptake inhibitors (PA164713257);venlafaxine (PA451866)',
#        'Drugs used in nicotine dependence (PA164712720);nicotine (PA450626);varenicline (PA164781343)',
#        'bupropion (PA448687);nicotine (PA450626)',
#        'spironolactone (PA451483)', 'bucindolol (PA165945764)',
#        'mycophenolate mofetil (PA450566)',
#        'atorvastatin (PA448500);quinapril (PA451205)',
#        'thalidomide (PA451644)', 'pravastatin (PA451089)',
#        'simvastatin (PA451363)', 'Dabigatran (PA165110351)',
#        'gemcitabine (PA449748)',
#        'anthracyclines and related substances (PA130620651)',
#        'pantoprazole (PA450774)', 'codeine (PA449088)',
#        'dapsone (PA449211)',
#        'cytarabine (PA449177);fludarabine (PA449655);gemtuzumab ozogamicin (PA164749431);idarubicin (PA449961)',
#        'infliximab (PA452639);Tumor necrosis factor alpha (TNF-alpha) inhibitors (PA164713366)',
#        'sirolimus (PA451365)', 'didanosine (PA449301)',
#        'SN-38 (PA165110775)', 'lopinavir (PA450264)',
#        'amodiaquine (PA448404);pyrimethamine (PA451193);sulfadoxine (PA451540)',
#        'clozapine (PA449061)', 'sulfamethoxazole (PA451544)',
#        'benazepril (PA448561)',
#        'bevacizumab (PA130232992);ranibizumab (PA164746012)',
#        'captopril (PA448780)', 'disulfiram (PA449376)',
#        'enalapril (PA449456)', 'flunisolide (PA449661)',
#        'docetaxel (PA449383);gemcitabine (PA449748);paclitaxel (PA450761);Platinum compounds (PA164713176);vinorelbine (PA451881)',
#        'olanzapine (PA450688)',
#        'hmg coa reductase inhibitors (PA133950441);simvastatin (PA451363)',
#        'cisplatin (PA449014);irinotecan (PA450085)',
#        'peginterferon alfa-2b (PA164784024);ribavirin (PA451241)',
#        'aspirin (PA448497);clopidogrel (PA449053)',
#        'citalopram (PA449015);fluoxetine (PA449673);paroxetine (PA450801);sertraline (PA451333)',
#        'tolterodine (PA164746757)',
#        'antiepileptics (PA143485705);carbamazepine (PA448785);lamotrigine (PA450164);oxcarbazepine (PA450732);phenytoin (PA450947);topiramate (PA451728)',
#        'carboplatin (PA448803);cisplatin (PA449014)',
#        'cladribine (PA449027);cytarabine (PA449177)',
#        'fluorouracil (PA128406956)',
#        'corticosteroids (PA10832);salmeterol (PA451300)',
#        'adalimumab (PA10004);etanercept (PA449515);infliximab (PA452639);Tumor necrosis factor alpha (TNF-alpha) inhibitors (PA164713366)',
#        'isoniazid (PA450112)',
#        'amitriptyline (PA448385);citalopram (PA449015);paroxetine (PA450801);venlafaxine (PA451866)',
#        'methadone (PA450401)', 'desipramine (PA449233)',
#        'bevacizumab (PA130232992);fluorouracil (PA128406956);irinotecan (PA450085);leucovorin (PA450198)',
#        'atorvastatin (PA448500);lovastatin (PA450272);simvastatin (PA451363)',
#        'antidepressants (PA452229)', 'dobutamine (PA449381)',
#        'adalimumab (PA10004);etanercept (PA449515);infliximab (PA452639)',
#        'fenofibrate (PA449594)', 'rituximab (PA451261)',
#        'bumetanide (PA448682);furosemide (PA449719);torasemide (PA451733)',
#        'zuclopenthixol (PA452629)',
#        'antidepressants (PA452229);citalopram (PA449015);fluvoxamine (PA449690);paroxetine (PA450801);sertraline (PA451333);venlafaxine (PA451866)',
#        'antidepressants (PA452229);citalopram (PA449015);fluoxetine (PA449673);mirtazapine (PA450522);paroxetine (PA450801);Selective serotonin reuptake inhibitors (PA164713257);venlafaxine (PA451866)',
#        'trimipramine (PA451791)', 'Enzymes (PA164712734)',
#        'candesartan (PA448765)', 'pitrakinra (PA165983754)',
#        'timolol (PA451690)', 'icotinib (PA166114460)',
#        'cyclosporine (PA449167)', 'indinavir (PA449977)',
#        'pimozide (PA450965)', 'propranolol (PA451145)',
#        'Bisphosphonates (PA164712563)', 'debrisoquine (PA452616)',
#        'thioridazine (PA451666)',
#        'cisplatin (PA449014);cyclophosphamide (PA449165)',
#        'cisplatin (PA449014);cyclophosphamide (PA449165);doxorubicin (PA449412);methotrexate (PA450428);vincristine (PA451879)',
#        'clomipramine (PA449048)', 'amitriptyline (PA448385)',
#        'buprenorphine (PA448685);fentanyl (PA449599);meperidine (PA450369);morphine (PA450550);opioids (PA452618);pentazocine (PA164744326)',
#        'calcein (PA132595336);lopinavir (PA450264)',
#        'atenolol (PA448499);irbesartan (PA450084)',
#        'mirtazapine (PA450522)',
#        'carboplatin (PA448803);docetaxel (PA449383);paclitaxel (PA450761)',
#        'salbutamol (PA448068)', 'rabeprazole (PA451216)',
#        'fluorouracil (PA128406956);oxaliplatin (PA131285527)',
#        'capecitabine (PA448771);fluorouracil (PA128406956)',
#        'repaglinide (PA451234)', 'methylene blue (PA450457)',
#        'prasugrel (PA154410481)', 'omeprazole (PA450704)',
#        'atomoxetine (PA134688071)',
#        'lamivudine (PA450163);lopinavir (PA450264);ritonavir (PA451260);zidovudine (PA451954)',
#        'clozapine (PA449061);olanzapine (PA450688)',
#        'losartan (PA450268)',
#        'boceprevir (PA165948902);peginterferon alfa-2b (PA164784024);ribavirin (PA451241)',
#        'tamoxifen (PA451581)', 'ranibizumab (PA164746012)',
#        'sipoglitazar (PA166114434)',
#        'lithium (PA450243);valproic acid (PA451846)',
#        'fluindione (PA165980614)',
#        'antidepressants (PA452229);citalopram (PA449015);escitalopram (PA10074);fluoxetine (PA449673);paroxetine (PA450801)',
#        'calcium (PA164712582)',
#        'citalopram (PA449015);escitalopram (PA10074)',
#        'doxepin (PA449409)', 'zidovudine (PA451954)',
#        'carboplatin (PA448803);paclitaxel (PA450761)',
#        'diuretics (PA151249535);hydrochlorothiazide (PA449899)',
#        'glibenclamide (PA449782)', 'citalopram (PA449015)',
#        'antipsychotics (PA452233);chlorpromazine (PA448964);fluphenazine (PA449676);thioridazine (PA451666);trifluoperazine (PA451771)',
#        'sorafenib (PA7000)', 'efavirenz (PA449441)',
#        'hormonal contraceptives for systemic use (PA452637)',
#        'mitotane (PA164746157)',
#        'amlodipine (PA448388);chlorthalidone (PA448970);lisinopril (PA450242)',
#        'lisinopril (PA450242)', 'lamotrigine (PA450164)',
#        'diazepam (PA449283)', 'carbamazepine (PA448785)',
#        'carvedilol (PA448817)', 'nifedipine (PA450631)',
#        'methacholine (PA165958382)',
#        'Drugs used in alcohol dependence (PA164712718)',
#        'cisplatin (PA449014);fluorouracil (PA128406956);oxaliplatin (PA131285527)',
#        'zonisamide (PA451978)',
#        'interferons (PA451999);peginterferon alfa-2a (PA164749390);peginterferon alfa-2b (PA164784024);ribavirin (PA451241)',
#        'calcium channel blockers (PA10407);nitrendipine (PA146096020)',
#        'artesunate (PA165111697);primaquine (PA451103);pyrimethamine (PA451193);sulfadoxine (PA451540)',
#        'bleomycin (PA448645);cisplatin (PA449014);etoposide (PA449552)',
#        'Drugs For Treatment Of Tuberculosis (PA164712708);ethambutol (PA164784021);isoniazid (PA450112);pyrazinamide (PA451182);rifampin (PA451250);streptomycin (PA451512)',
#        'erythromycin (PA449493)', 'oxaliplatin (PA131285527)',
#        'somatropin recombinant (PA451446)',
#        'cyclosporine (PA449167);mycophenolate mofetil (PA450566)',
#        'folic acid (PA449692);methotrexate (PA450428)',
#        'rosuvastatin (PA134308647)', 'azathioprine (PA448515)',
#        'diuretics (PA151249535)', 'imipramine (PA449969)',
#        'amitriptyline (PA448385);antidepressants (PA452229);clomipramine (PA449048);desipramine (PA449233);doxepin (PA449409);imipramine (PA449969);nortriptyline (PA450657);trimipramine (PA451791)',
#        'tramadol (PA451735)', 'flecainide (PA449646)',
#        'raloxifene (PA451221);tamoxifen (PA451581)',
#        'Alkylating Agents (PA164712331);anthracyclines and related substances (PA130620651);fluorouracil (PA128406956);Platinum compounds (PA164713176)',
#        'cangrelor (PA165945763)', 'ondansetron (PA450705)',
#        'folic acid (PA449692);vitamin b-complex, plain (PA10505)',
#        'citalopram (PA449015);escitalopram (PA10074);fluoxetine (PA449673);fluvoxamine (PA449690);paroxetine (PA450801);sertraline (PA451333)',
#        'fluoxetine (PA449673)',
#        'amitriptyline (PA448385);citalopram (PA449015);fluoxetine (PA449673);paroxetine (PA450801);sertraline (PA451333);venlafaxine (PA451866)',
#        'sulfamethoxazole (PA451544);trimethoprim (PA451788)',
#        'amlodipine (PA448388)',
#        'paclitaxel (PA450761);Platinum compounds (PA164713176)',
#        'memantine (PA10364)',
#        'anthracyclines and related substances (PA130620651);taxanes (PA150481189)',
#        'antineoplastic agents (PA452621)',
#        'lansoprazole (PA450180);omeprazole (PA450704);rabeprazole (PA451216)',
#        'Selective serotonin reuptake inhibitors (PA164713257)',
#        'diltiazem (PA449334)', 'midazolam (PA450496)',
#        'verapamil (PA451868)', 'acetylcholine (PA448031)',
#        'sunitinib (PA162372840)',
#        'fluvoxamine (PA449690);milnacipran (PA164752812);paroxetine (PA450801)',
#        'aripiprazole (PA10026);clozapine (PA449061);haloperidol (PA449841);olanzapine (PA450688);quetiapine (PA451201);risperidone (PA451257)',
#        'dexmedetomidine (PA449256)',
#        'cetuximab (PA10040);panitumumab (PA162373091)',
#        'capecitabine (PA448771);docetaxel (PA449383)',
#        'iloperidone (PA161199368)', 'haloperidol (PA449841)',
#        'l-tryptophan (PA10323)', 'esomeprazole (PA10075)',
#        'Thiazides, plain (PA164713347)', 'zoledronate (PA10235)',
#        'etanercept (PA449515);infliximab (PA452639);Tumor necrosis factor alpha (TNF-alpha) inhibitors (PA164713366)',
#        'nitroprusside (PA451406)',
#        'sulfonamides, urea derivatives (PA10390)',
#        'cyclosporine (PA449167);mycophenolate mofetil (PA450566);sirolimus (PA451365);tacrolimus (PA451578)',
#        'atorvastatin (PA448500);pravastatin (PA451089);simvastatin (PA451363)',
#        'sertraline (PA451333)', 'aripiprazole (PA10026)',
#        'propafenone (PA451131)',
#        'irinotecan (PA450085);raltitrexed (PA131625240)',
#        '3,4-methylenedioxymethamphetamine (PA131887008)',
#        'interferon beta-1a (PA450037);interferon beta-1b (PA450039)',
#        'digoxin (PA449319)', 'docetaxel (PA449383)',
#        'abacavir (PA448004)', 'cerivastatin (PA448897)',
#        'Drugs For Treatment Of Tuberculosis (PA164712708);isoniazid (PA450112)',
#        'methamphetamine (PA450403)',
#        'antidepressants (PA452229);benzodiazepine derivatives (PA10402);mirtazapine (PA450522);Selective serotonin reuptake inhibitors (PA164713257)',
#        'clomipramine (PA449048);lithium (PA450243);nefazodone (PA450603);paroxetine (PA450801);venlafaxine (PA451866)',
#        'antidepressants (PA452229);citalopram (PA449015);paroxetine (PA450801)',
#        'chlorthalidone (PA448970);lisinopril (PA450242)',
#        'amphetamine (PA448408)',
#        'simvastatin (PA451363);warfarin (PA451906)',
#        'dolasetron (PA449390);granisetron (PA449809)',
#        'carbamazepine (PA448785);phenytoin (PA450947);valproic acid (PA451846)',
#        'fentanyl (PA449599);morphine (PA450550);opioids (PA452618);oxycodone (PA450741)',
#        'antiepileptics (PA143485705);carbamazepine (PA448785);phenobarbital (PA450911);phenytoin (PA450947);valproic acid (PA451846)',
#        'carbamazepine (PA448785);oxcarbazepine (PA450732)',
#        'irbesartan (PA450084)', 'rasburicase (PA10176)',
#        'clomipramine (PA449048);liothyronine (PA164778866);lithium (PA450243);nefazodone (PA450603);venlafaxine (PA451866)',
#        'amisulpride (PA162565877);antipsychotics (PA452233);olanzapine (PA450688);quetiapine (PA451201);risperidone (PA451257)',
#        'cytarabine (PA449177)',
#        'mycophenolate mofetil (PA450566);mycophenolic acid (PA164748728)',
#        'ABT-751 (PA166104276)',
#        'atenolol (PA448499);verapamil (PA451868)',
#        'bortezomib (PA10252);dexamethasone (PA449247);melphalan (PA450354);prednisone (PA451100)',
#        'gemcitabine (PA449748);Platinum compounds (PA164713176)',
#        'benazepril (PA448561);perindopril (PA450877)',
#        'aspirin (PA448497);Beta Blocking Agents (PA164712535);clopidogrel (PA449053);hmg coa reductase inhibitors (PA133950441)',
#        'escitalopram (PA10074);nortriptyline (PA450657)',
#        'clonidine (PA449051)', 'everolimus (PA164746311)',
#        'codeine (PA449088);dextromethorphan (PA449273);n-desmethyltamoxifen (PA166127651)',
#        'Antithyroid Preparations (PA164712499)',
#        'desflurane (PA164749136);enflurane (PA449461);halothane (PA449845);isoflurane (PA450106);methoxyflurane (PA450434);sevoflurane (PA451341);succinylcholine (PA451522);volatile anesthetics (PA166131630)',
#        'cetuximab (PA10040)', 'heroin (PA452619);opioids (PA452618)',
#        'cyclophosphamide (PA449165);epirubicin (PA449476);fluorouracil (PA128406956)',
#        'caffeine (PA448710)', 'tropisetron (PA161925594)',
#        'amisulpride (PA162565877);aripiprazole (PA10026);clozapine (PA449061);lithium (PA450243);mirtazapine (PA450522);olanzapine (PA450688);paliperidone (PA163518919);quetiapine (PA451201);risperidone (PA451257);valproic acid (PA451846)',
#        'tenofovir (PA10204)', 'Drugs Used In Diabetes (PA164712711)',
#        'prochlorperazine (PA451114)', 'dolutegravir (PA166114961)',
#        'Platinum compounds (PA164713176);radiotherapy (PA166122986)',
#        'bupropion (PA448687);nicotine (PA450626);varenicline (PA164781343)',
#        'isoniazid (PA450112);phenytoin (PA450947)',
#        'nimodipine (PA450633)',
#        'highly active antiretroviral therapy (haart) (PA166177229)',
#        'l-methylfolate (PA166182939);Vitamin B-complex, Incl. Combinations (PA164713398)',
#        'varenicline (PA164781343)',
#        'ivacaftor (PA165950341);tezacaftor (PA166175754)',
#        'oxcarbazepine (PA450732)', 'deferasirox (PA164760843)',
#        'Opioid anesthetics (PA164712948);Other general anesthetics (PA164713083);volatile anesthetics (PA166131630)',
#        'etanercept (PA449515)', 'sibutramine (PA451344)',
#        'azathioprine (PA448515);mercaptopurine (PA450379);thioguanine (PA451663)',
#        'modafinil (PA450530)',
#        'desflurane (PA164749136);enflurane (PA449461);halothane (PA449845);isoflurane (PA450106);methoxyflurane (PA450434);sevoflurane (PA451341);succinylcholine (PA451522)',
#        'oxazepam (PA450731)', 'ibuprofen (PA449957)',
#        'naltrexone (PA450588)', 'vancomycin (PA451850)',
#        'alfentanil (PA448084)', 'sufentanil (PA451527)',
#        'acetaminophen (PA448015);ibuprofen (PA449957);loxoprofen (PA166049180);salicylamide (PA165958416)',
#        'atazanavir (PA10251)', 'tolbutamide (PA451718)',
#        'mexiletine (PA450488)', 'levodopa (PA450213)',
#        'HMG CoA reductase inhibitors, other combinations (PA164712781)',
#        'dexamethasone (PA449247);lenalidomide (PA162363968)',
#        'cotinine (PA166114414);nicotine (PA450626)',
#        'cocaine (PA449072);heroin (PA452619)', 'apixaban (PA166163740)',
#        'aripiprazole (PA10026);haloperidol (PA449841);levomepromazine (PA134687942);quetiapine (PA451201);risperidone (PA451257)',
#        'acenocoumarol (PA452632);warfarin (PA451906)',
#        'Vitamin K (PA164713404)',
#        'cocaine (PA449072);ethanol (PA448073);nicotine (PA450626)',
#        'atorvastatin (PA448500);hmg coa reductase inhibitors (PA133950441);pravastatin (PA451089);simvastatin (PA451363)',
#        'antipsychotics (PA452233);clozapine (PA449061);olanzapine (PA450688)',
#        'antipsychotics (PA452233);clozapine (PA449061);olanzapine (PA450688);risperidone (PA451257)',
#        'Antihypertensives And Diuretics In Combination (PA164712446)',
#        'efavirenz (PA449441);nelfinavir (PA450606)',
#        'antidepressants (PA452229);desipramine (PA449233);fluoxetine (PA449673)',
#        'antiepileptics (PA143485705);carbamazepine (PA448785);oxcarbazepine (PA450732)',
#        'paclitaxel (PA450761)',
#        'doxorubicin (PA449412);idarubicin (PA449961)',
#        'doxorubicin (PA449412)', 'etoposide (PA449552)',
#        'fexofenadine (PA449621)',
#        'doxorubicin (PA449412);doxorubicinol (PA165291922)',
#        'docetaxel (PA449383);thalidomide (PA451644)',
#        'Analgesics (PA164712362)',
#        'cisplatin (PA449014);oxaliplatin (PA131285527);platinum (PA150595617);Platinum compounds (PA164713176)',
#        'carboplatin (PA448803);cisplatin (PA449014);oxaliplatin (PA131285527);platinum (PA150595617);Platinum compounds (PA164713176)',
#        'cisplatin (PA449014);platinum (PA150595617);Platinum compounds (PA164713176)',
#        'antidepressants (PA452229);citalopram (PA449015);fluoxetine (PA449673)',
#        'alendronate (PA448082);Bisphosphonates (PA164712563);calcium (PA164712582);clodronate (PA10239);etidronic acid (PA449548);raloxifene (PA451221)',
#        'clodronate (PA10239)',
#        'Bisphosphonates (PA164712563);clodronate (PA10239);etidronic acid (PA449548);risedronate (PA451255);tiludronate (PA451688)',
#        'salbutamol (PA448068);selective beta-2-adrenoreceptor agonists (PA134687887)',
#        'cyclophosphamide (PA449165)',
#        'cyclophosphamide (PA449165);doxorubicin (PA449412);fluorouracil (PA128406956);methotrexate (PA450428)',
#        'antipsychotics (PA452233);risperidone (PA451257)',
#        'nemonapride (PA151186253)', 'nitrous oxide (PA450645)',
#        'prednisone (PA451100);tacrolimus (PA451578)',
#        'antipsychotics (PA452233);aripiprazole (PA10026);bromperidol (PA165282097);chlorpromazine (PA448964);clozapine (PA449061);nemonapride (PA151186253);olanzapine (PA450688);risperidone (PA451257)',
#        'antidepressants (PA452229);mirtazapine (PA450522);venlafaxine (PA451866)',
#        'citalopram (PA449015);fluoxetine (PA449673)',
#        'sumatriptan (PA451566)',
#        'amitriptyline (PA448385);antidepressants (PA452229);citalopram (PA449015);fluvoxamine (PA449690);paroxetine (PA450801);sertraline (PA451333);venlafaxine (PA451866)',
#        'amitriptyline (PA448385);antidepressants (PA452229);citalopram (PA449015);paroxetine (PA450801);venlafaxine (PA451866)',
#        'amodiaquine (PA448404)',
#        'azathioprine (PA448515);purine analogues (PA452634)',
#        'Platinum compounds (PA164713176);taxanes (PA150481189)',
#        'oxaliplatin (PA131285527);Platinum compounds (PA164713176)',
#        'erlotinib (PA134687924)',
#        'topoisomerase I inhibitors (PA150481186)',
#        'geldanamycin (PA152031327)', 'Alkylating Agents (PA164712331)',
#        'gefitinib (PA131301952)', 'bisantrene (PA146096021)',
#        'calcein (PA132595336)', 'forskolin (PA146096022)',
#        'prazosin (PA451093)', 'vinblastine (PA451877)',
#        'perindopril (PA450877)',
#        'antidepressants (PA452229);citalopram (PA449015)',
#        'daunorubicin (PA449212)',
#        'antidepressants (PA452229);citalopram (PA449015);clomipramine (PA449048);lithium (PA450243);nefazodone (PA450603);paroxetine (PA450801);venlafaxine (PA451866)',
#        'Bisphosphonates (PA164712563);pamidronate (PA450767);zoledronate (PA10235)',
#        'antipsychotics (PA452233);olanzapine (PA450688);perphenazine (PA450882);quetiapine (PA451201);ziprasidone (PA451974)',
#        'hmg coa reductase inhibitors (PA133950441);pravastatin (PA451089);simvastatin (PA451363)',
#        'atorvastatin (PA448500);fluvastatin (PA449688);hmg coa reductase inhibitors (PA133950441);lovastatin (PA450272);pravastatin (PA451089);simvastatin (PA451363)',
#        'atorvastatin (PA448500);pravastatin (PA451089)',
#        'propofol (PA451141)', 'rosiglitazone (PA451283)',
#        'rofecoxib (PA451268)', 'sildenafil (PA451346)',
#        'troglitazone (PA451799)',
#        'amlodipine (PA448388);chlorthalidone (PA448970)',
#        'antidepressants (PA452229);fluvoxamine (PA449690);paroxetine (PA450801);Selective serotonin reuptake inhibitors (PA164713257);sertraline (PA451333)',
#        'Beta Blocking Agents (PA164712535)',
#        'selective beta-2-adrenoreceptor agonists (PA134687887)',
#        'muraglitazar (PA162356187)',
#        'Antivirals for treatment of HIV infections, combinations (PA164712505);ritonavir (PA451260)',
#        'lansoprazole (PA450180);tacrolimus (PA451578)',
#        'leflunomide (PA450192)', 'Measles vaccines (PA164712887)',
#        'montelukast (PA450546)',
#        'olanzapine (PA450688);risperidone (PA451257)',
#        'antipsychotics (PA452233);olanzapine (PA450688);risperidone (PA451257)',
#        'olanzapine (PA450688);perphenazine (PA450882)',
#        'trastuzumab (PA451743)', 'pramipexole (PA164742949)',
#        'rifampin (PA451250)', 'ritonavir (PA451260)',
#        'salbutamol (PA448068);salmeterol (PA451300)',
#        'thiotepa (PA451668)',
#        'mirtazapine (PA450522);venlafaxine (PA451866)',
#        'methadone (PA450401);morphine (PA450550);opioids (PA452618);oxycodone (PA450741);remifentanil (PA451232);sufentanil (PA451527);tramadol (PA451735)',
#        'naloxone (PA450586)', 'nateglinide (PA450600)',
#        'metoprolol (PA450480)', 'levetiracetam (PA450206)',
#        'letrozole (PA450196)',
#        'chlorproguanil (PA165857067);dapsone (PA449211)',
#        'cisplatin (PA449014);Platinum compounds (PA164713176)',
#        'conjugated estrogens (PA164754789);medroxyprogesterone (PA450344)',
#        'atenolol (PA448499);Beta Blocking Agents (PA164712535);bucindolol (PA165945764);carvedilol (PA448817);metoprolol (PA450480)',
#        'interferon alfa-2a, recombinant (PA164779048);peginterferon alfa-2b (PA164784024)',
#        'conjugated estrogens (PA164754789)',
#        'amoxicillin (PA448406);clavulanate (PA164742987)',
#        'capecitabine (PA448771);fluorouracil (PA128406956);Pyrimidine analogues (PA164713220);tegafur (PA452620)',
#        'coumarin (PA134521193)',
#        'Antihypertensives (PA164712445);Antihypertensives And Diuretics In Combination (PA164712446);diuretics (PA151249535)',
#        'egfr inhibitors (PA153561371)',
#        'capecitabine (PA448771);fluorouracil (PA128406956);Pyrimidine analogues (PA164713220);s 1 (combination) (PA166115442)',
#        'methotrexate (PA450428);pemetrexed (PA10810);raltitrexed (PA131625240)',
#        'celecoxib (PA448871)',
#        'cisplatin (PA449014);fluorouracil (PA128406956);mitoxantrone (PA450526)',
#        'interferon alfa-2b, recombinant (PA164783990);ribavirin (PA451241)',
#        'carboplatin (PA448803);gefitinib (PA131301952);paclitaxel (PA450761)',
#        'carboplatin (PA448803);docetaxel (PA449383);erlotinib (PA134687924);gemcitabine (PA449748);paclitaxel (PA450761)',
#        'dexamethasone (PA449247);doxorubicin (PA449412);vincristine (PA451879)',
#        'rhodamine 123 (PA165110729)',
#        'erlotinib (PA134687924);gefitinib (PA131301952)',
#        'acenocoumarol (PA452632);phenprocoumon (PA450921)',
#        'antiepileptics (PA143485705);carbamazepine (PA448785)',
#        'metformin (PA450395);sulfonamides, urea derivatives (PA10390)',
#        'furosemide (PA449719);spironolactone (PA451483)',
#        'cisplatin (PA449014);fluorouracil (PA128406956)',
#        'dicloxacillin (PA164749649)',
#        'capecitabine (PA448771);fluorouracil (PA128406956);leucovorin (PA450198);oxaliplatin (PA131285527)',
#        'atorvastatin (PA448500);rifampin (PA451250)',
#        'mercaptopurine (PA450379)',
#        'bevacizumab (PA130232992);carboplatin (PA448803);cisplatin (PA449014);cyanocobalamin (PA451892);folic acid (PA449692);pemetrexed (PA10810)',
#        'cyclophosphamide (PA449165);epirubicin (PA449476)',
#        'carbamazepine (PA448785);clobazam (PA10888);ethosuximide (PA449533);lamotrigine (PA450164);levetiracetam (PA450206);oxcarbazepine (PA450732);valproic acid (PA451846)',
#        'cyclosporine (PA449167);tacrolimus (PA451578)',
#        'sirolimus (PA451365);temsirolimus (PA164746890)',
#        'fluorouracil (PA128406956);Platinum compounds (PA164713176);radiotherapy (PA166122986)',
#        'bevacizumab (PA130232992)', 'heparin (PA449855)',
#        'idarubicin (PA449961)',
#        'antidepressants (PA452229);antipsychotics (PA452233);benzodiazepine derivatives (PA10402);opioids (PA452618);Sympathomimetics (PA164713301)',
#        'aripiprazole (PA10026);risperidone (PA451257)',
#        'aspirin (PA448497);prasugrel (PA154410481)',
#        'n-desmethyltamoxifen (PA166127651)', 'disopyramide (PA449373)',
#        'quinidine (PA451209)',
#        'acenocoumarol (PA452632);phenprocoumon (PA450921);warfarin (PA451906)',
#        'buprenorphine (PA448685);methadone (PA450401)',
#        'chlorothiazide (PA448953);hydrochlorothiazide (PA449899)',
#        'thioguanine (PA451663)', 'simvastatin acid (PA166129446)',
#        'caffeine (PA448710);chlorocresol (PA166122627)',
#        'glibenclamide (PA449782);gliclazide (PA10892);glimepiride (PA449761);glipizide (PA449762);gliquidone (PA164744895);sulfonamides, urea derivatives (PA10390)',
#        'donepezil (PA449394)', 'glatiramer acetate (PA449760)',
#        'oseltamivir (PA450721)',
#        'adefovir dipivoxil (PA10005);cidofovir (PA448997);tenofovir (PA10204)',
#        'adefovir dipivoxil (PA10005)',
#        'ethambutol (PA164784021);isoniazid (PA450112);pyrazinamide (PA451182);rifampin (PA451250)',
#        'hydrocodone (PA449900)',
#        '(R)-methadone (PA166178312);(S)-EDDP (PA166177606);methadone (PA450401)',
#        'dapoxetine (PA166151992)',
#        'granisetron (PA449809);palonosetron (PA10352)',
#        'propofol (PA451141);remifentanil (PA451232)',
#        'budesonide (PA448681);corticosteroids (PA10832);fluticasone propionate (PA449686);fluticasone/salmeterol (PA165290926);triamcinolone (PA451749)',
#        'budesonide (PA448681);flunisolide (PA449661);fluticasone propionate (PA449686);glucocorticoids (PA452347);nedocromil (PA450601);triamcinolone (PA451749)',
#        'peginterferon alfa-2a (PA164749390);peginterferon alfa-2b (PA164784024);ribavirin (PA451241)',
#        'diuretics (PA151249535);hydrochlorothiazide (PA449899);Thiazides, plain (PA164713347)',
#        'amphetamine (PA448408);cannabinoids (PA131890620);cocaine (PA449072);opioids (PA452618)',
#        'cannabinoids (PA131890620)',
#        'remifentanil (PA451232);sevoflurane (PA451341)',
#        'nitrofurantoin (PA450640)', 'phenazopyridine (PA164746899)',
#        'adalimumab (PA10004);infliximab (PA452639)',
#        'etoposide (PA449552);Platinum compounds (PA164713176)',
#        'anastrozole (PA448432)',
#        'olanzapine (PA450688);quetiapine (PA451201);risperidone (PA451257)',
#        'mefloquine (PA450348)',
#        'flecainide (PA449646);mexiletine (PA450488)',
#        'methoxsalen (PA450433)',
#        'anastrozole (PA448432);letrozole (PA450196)',
#        'sulfadoxine (PA451540)', 'sulfametopyrazine (PA164747038)',
#        'phenprocoumon (PA450921)',
#        'boceprevir (PA165948902);peginterferon alfa-2a (PA164749390);peginterferon alfa-2b (PA164784024);ribavirin (PA451241);simeprevir (PA166122590);telaprevir (PA165958354)',
#        'peginterferon alfa-2a (PA164749390);peginterferon alfa-2b (PA164784024);ribavirin (PA451241);telaprevir (PA165958354)',
#        'antidepressants (PA452229);antiepileptics (PA143485705);Beta Blocking Agents (PA164712535);calcium channel blockers (PA10407)',
#        'radiotherapy (PA166122986)',
#        'atorvastatin (PA448500);simvastatin (PA451363)',
#        'asparaginase (PA448492);cyclophosphamide (PA449165);cytarabine (PA449177);daunorubicin (PA449212);dexamethasone (PA449247);doxorubicin (PA449412);leucovorin (PA450198);mercaptopurine (PA450379);methotrexate (PA450428);pegaspargase (PA164760860);prednisone (PA451100);thioguanine (PA451663);vincristine (PA451879)',
#        'sulfasalazine (PA451547)',
#        'carboplatin (PA448803);cyclophosphamide (PA449165);thiotepa (PA451668)',
#        'sulfamethoxazole (PA451544);sulfamethoxazole / trimethoprim (PA10715);trimethoprim (PA451788)',
#        'eculizumab (PA164776637)', 'voriconazole (PA10233)',
#        'exemestane (PA449563)', 'vitamin e (PA451900)',
#        'cytarabine (PA449177);idarubicin (PA449961)',
#        'hydralazine (PA449894)',
#        'azathioprine (PA448515);mercaptopurine (PA450379);purine analogues (PA452634);thioguanine (PA451663)',
#        'mercaptopurine (PA450379);thioguanine (PA451663)',
#        'gemcitabine (PA449748);paclitaxel (PA450761)',
#        'succinylcholine (PA451522)', 'platinum (PA150595617)',
#        'carboplatin (PA448803);cisplatin (PA449014);docetaxel (PA449383);erlotinib (PA134687924);gefitinib (PA131301952);paclitaxel (PA450761)',
#        'dimercaprol (PA165958406)', 'ciprofloxacin (PA449009)',
#        'chloroquine (PA448948)', 'chloramphenicol (PA448927)',
#        'ketorolac (PA450150)',
#        'ivacaftor (PA165950341);lumacaftor (PA166114483)',
#        'dextromethorphan (PA449273)',
#        'dasatinib (PA162372878);imatinib (PA10804);nilotinib (PA165958345)',
#        'interferons (PA451999);ribavirin (PA451241)',
#        'capecitabine (PA448771);radiotherapy (PA166122986)',
#        'anthracyclines and related substances (PA130620651);cyclophosphamide (PA449165);doxorubicin (PA449412);epirubicin (PA449476);fluorouracil (PA128406956);methotrexate (PA450428);oxaliplatin (PA131285527);Platinum compounds (PA164713176)',
#        'clozapine (PA449061);olanzapine (PA450688);risperidone (PA451257)',
#        'Antihypertensives (PA164712445);Beta Blocking Agents (PA164712535)',
#        'cyclophosphamide (PA449165);docetaxel (PA449383)',
#        'peginterferon alfa-2a (PA164749390);peginterferon alfa-2b (PA164784024);ribavirin (PA451241);simeprevir (PA166122590)',
#        'epirubicin (PA449476);fluorouracil (PA128406956);oxaliplatin (PA131285527)',
#        'tocilizumab (PA165292659)', 'isoproterenol (PA450121)',
#        'salvianolic acid b (PA166128370)', 'pemetrexed (PA10810)',
#        'rocuronium (PA164754992)',
#        'doxorubicin (PA449412);methotrexate (PA450428);prednisolone (PA451096);vincristine (PA451879)',
#        'Analgesics (PA164712362);Antiinflammatory agents, non-steroids (PA164712462);Ergot alkaloids (PA164712741);opioids (PA452618);sumatriptan (PA451566)',
#        'topiramate (PA451728);zonisamide (PA451978)',
#        'atorvastatin (PA448500);Bisphosphonates (PA164712563)',
#        'atenolol (PA448499);bisoprolol (PA448641)',
#        'trandolapril (PA451737);verapamil (PA451868)',
#        'melphalan (PA450354)', 'buprenorphine (PA448685)',
#        'peginterferon alfa-2a (PA164749390);ribavirin (PA451241)',
#        'carbimazole (PA164742970);methimazole (PA450422);propylthiouracil (PA451156)',
#        'maprotiline (PA450322);opipramol (PA144614922)',
#        'ketamine (PA450144)', 'asparaginase (PA448492)',
#        'carboplatin (PA448803);taxanes (PA150481189)',
#        'dextroamphetamine (PA449269);methylphenidate (PA450464)',
#        'direct acting antivirals (PA166179660);sofosbuvir (PA166122593)',
#        'ledipasvir (PA166128166);sofosbuvir (PA166122593)',
#        'hdl cholesterol (PA166129559);letrozole (PA450196);triglycerides (PA451776)',
#        'dasatinib (PA162372878);imatinib (PA10804)',
#        'fluvoxamine (PA449690);paroxetine (PA450801)',
#        'bilirubin (PA166123346)',
#        'cisplatin (PA449014);oxaliplatin (PA131285527)',
#        'peginterferon alfa-2a (PA164749390);peginterferon alfa-2b (PA164784024)',
#        'Farglitazar (PA165815771);glibenclamide (PA449782)',
#        'calcium channel blockers (PA10407)',
#        'desloratadine (PA164776964);mizolastine (PA166129535)',
#        'exemestane (PA449563);letrozole (PA450196)',
#        'donepezil (PA449394);galantamine (PA449726);rivastigmine (PA451262)',
#        'galantamine (PA449726)',
#        'follitropin beta (PA449693);thyrotropin alfa (PA164746560);urofollitropin (PA451835)',
#        'daclatasvir (PA166128167);peginterferon alfa-2a (PA164749390);peginterferon alfa-2b (PA164784024);ribavirin (PA451241)',
#        'dalcetrapib (PA166131581)', 'pazopanib (PA165291492)',
#        'tiotropium (PA164769056)', 'busulfan (PA448691)',
#        'hmg coa reductase inhibitors (PA133950441);letrozole (PA450196)',
#        'cyclophosphamide (PA449165);epirubicin (PA449476);paclitaxel (PA450761)',
#        'bleomycin (PA448645);cyclophosphamide (PA449165);doxorubicin (PA449412);prednisone (PA451100);rituximab (PA451261);vincristine (PA451879);vindesine (PA10232)',
#        'infliximab (PA452639)', 'Antihypertensives (PA164712445)',
#        'Hepatitis vaccines (PA164712789)', 'latanoprost (PA164774763)',
#        'docetaxel (PA449383);epirubicin (PA449476)',
#        'rivastigmine (PA451262)', 'telmisartan (PA451605)',
#        'silibinin (PA166129539)', 'amisulpride (PA162565877)',
#        'hydralazine / isosorbide dinitrate (PA166176017)',
#        'entacapone (PA164748726)', 'daptomycin (PA164768820)',
#        'interferon alfa-2a, recombinant (PA164779048);interferon alfa-2b, recombinant (PA164783990);ribavirin (PA451241)',
#        'cyclosporine (PA449167);sirolimus (PA451365);tacrolimus (PA451578)',
#        'clobazam (PA10888)',
#        'anastrozole (PA448432);exemestane (PA449563)',
#        'acamprosate (PA10344)',
#        'interferon alfa-2a, recombinant (PA164779048);ribavirin (PA451241)',
#        'topiramate (PA451728)', 'pegloticase (PA165963961)',
#        'ticlopidine (PA451686)', 'cavosonstat (PA166163226)',
#        'debrisoquine (PA452616);dextromethorphan (PA449273)',
#        'methylphenobarbital (PA450374)', 'olmesartan (PA164742950)',
#        'amikacin (PA164744372);aminoglycoside antibacterials (PA452167);gentamicin (PA449753);kanamycin (PA450137);neomycin (PA450608);streptomycin (PA451512);tobramycin (PA451704)',
#        'cetuximab (PA10040);irinotecan (PA450085);panitumumab (PA162373091)',
#        'omeprazole (PA450704);pantoprazole (PA450774)',
#        'enalapril (PA449456);imidapril (PA452640);lisinopril (PA450242)',
#        'vincristine (PA451879)', 'Influenza vaccines (PA164712830)',
#        'irinotecan (PA450085);oxaliplatin (PA131285527);s 1 (combination) (PA166115442)',
#        'vardenafil (PA10229)', 'lapatinib (PA152241907)',
#        'deferiprone (PA166118041)',
#        'bleomycin (PA448645);dacarbazine (PA449197);doxorubicin (PA449412);vinblastine (PA451877)',
#        'debrisoquine (PA452616);sparteine (PA452610)',
#        'vortioxetine (PA166122595)',
#        'olanzapine (PA450688);quetiapine (PA451201);risperidone (PA451257);ziprasidone (PA451974)',
#        'methazolamide (PA450413)', 'acetazolamide (PA448018)',
#        'diclofenac (PA449293)', 'mianserin (PA134687937)',
#        'methylprednisolone (PA450466);prednisolone (PA451096)',
#        'estradiol (PA449503)', 'lorazepam (PA450267)',
#        'atrasentan (PA143414738)',
#        'debrisoquine (PA452616);dextromethorphan (PA449273);metoprolol (PA450480)',
#        'atazanavir (PA10251);ritonavir (PA451260)',
#        'fluticasone propionate (PA449686);montelukast (PA450546)',
#        'amisulpride (PA162565877);aripiprazole (PA10026);clozapine (PA449061);haloperidol (PA449841);olanzapine (PA450688);paliperidone (PA163518919);quetiapine (PA451201);risperidone (PA451257);ziprasidone (PA451974)',
#        'etravirine (PA166014703)', 'antithymocyte globulin (PA164743704)',
#        'Pertussis vaccines (PA164713160)',
#        'bevacizumab (PA130232992);pegaptanib (PA164771236);ranibizumab (PA164746012)',
#        'bevacizumab (PA130232992);capecitabine (PA448771);fluorouracil (PA128406956);irinotecan (PA450085);leucovorin (PA450198);oxaliplatin (PA131285527)',
#        'adrenergics, inhalants (PA10405)',
#        'carboplatin (PA448803);lonafarnib (PA166129466);paclitaxel (PA450761)',
#        'Opium alkaloids and derivatives (PA164712950)',
#        'fluorouracil (PA128406956);irinotecan (PA450085);leucovorin (PA450198)',
#        'acetaminophen (PA448015);aspirin (PA448497);diclofenac (PA449293);propionic acid derivatives (PA451140);Pyrazolones (PA164713217)',
#        'carisoprodol (PA448809)',
#        'debrisoquine (PA452616);dextromethorphan (PA449273);sparteine (PA452610)',
#        'XK469 (PA166114484)',
#        'Ace Inhibitors, Plain (PA164712308);Angiotensin II Antagonists (PA164712372);Beta Blocking Agents (PA164712535);digoxin (PA449319);diuretics (PA151249535);spironolactone (PA451483)',
#        'sparteine (PA452610)', 'itopride (PA152432599)',
#        'flucloxacillin (PA164781042)',
#        'insulin recombinant (PA164744571);zinc acetate (PA451961)',
#        'adalimumab (PA10004)',
#        'ephedrine (PA449466);phenylephrine (PA450935)',
#        'deleobuvir (PA166128130);faldaprevir (PA166128132)',
#        'cotinine (PA166114414)', 'alendronate (PA448082)',
#        'trichloroethylene (PA166115521)', 'thiazolidinediones (PA452631)',
#        'liraglutide (PA165958364)',
#        'Antiinflammatory agents, non-steroids (PA164712462);aspirin (PA448497)',
#        'interferons (PA451999)',
#        'allopurinol (PA448320);febuxostat (PA165958521)',
#        'granisetron (PA449809)', 'rivaroxaban (PA165958360)',
#        'sulindac (PA451565)', 'minocycline (PA450519)',
#        'asparaginase (PA448492);cyclophosphamide (PA449165);daunorubicin (PA449212);prednisolone (PA451096);vincristine (PA451879)',
#        'cladribine (PA449027);fluorouracil (PA128406956);gemcitabine (PA449748)',
#        'catecholamines (PA133822447)', 'sulfinpyrazone (PA451550)',
#        'bupropion (PA448687);Drugs used in nicotine dependence (PA164712720)',
#        'cytarabine (PA449177);daunorubicin (PA449212);etoposide (PA449552);mitoxantrone (PA450526)',
#        'valganciclovir (PA10227)', 'Antibiotics (PA164712406)',
#        'atenolol (PA448499);hydrochlorothiazide (PA449899)',
#        'phenazepam (PA166180939)', 'tipifarnib (PA165110778)',
#        'nelfinavir (PA450606)', 'ataluren (PA166151864)',
#        'antipsychotics (PA452233);aripiprazole (PA10026);risperidone (PA451257)',
#        'flupirtine (PA166152829)',
#        'Antivirals for treatment of HIV infections, combinations (PA164712505);Drugs For Treatment Of Tuberculosis (PA164712708)',
#        'ticagrelor (PA165374673)',
#        'isoniazid (PA450112);rifampin (PA451250)',
#        'axitinib (PA164924493);sorafenib (PA7000)',
#        'folic acid (PA449692)', 'cysteamine (PA449171)',
#        'cyclophosphamide (PA449165);cytarabine (PA449177);daunorubicin (PA449212);dexamethasone (PA449247);doxorubicin (PA449412);methotrexate (PA450428);pegaspargase (PA164760860);prednisone (PA451100);thioguanine (PA451663);vincristine (PA451879)',
#        'interferon beta-1a (PA450037)', 'regadenoson (PA166129536)',
#        'ramipril (PA451223)',
#        'bevacizumab (PA130232992);pemetrexed (PA10810)',
#        'cetuximab (PA10040);irinotecan (PA450085);leucovorin (PA450198);tegafur (PA452620)',
#        'asparaginase (PA448492);dexamethasone (PA449247);methotrexate (PA450428)',
#        'capecitabine (PA448771);oxaliplatin (PA131285527)',
#        'cyclophosphamide (PA449165);docetaxel (PA449383);doxorubicin (PA449412);epirubicin (PA449476);fluorouracil (PA128406956)',
#        'capecitabine (PA448771);fluorouracil (PA128406956);tegafur (PA452620)',
#        'cyclophosphamide (PA449165);dexamethasone (PA449247);lenalidomide (PA162363968);thalidomide (PA451644)',
#        'lenalidomide (PA162363968);thalidomide (PA451644)',
#        'acetylcysteine (PA448033)',
#        'bufuralol (PA166110256);dextromethorphan (PA449273)',
#        'imiquimod (PA449972)', 'quinapril (PA451205)',
#        'fluvastatin (PA449688);simvastatin (PA451363)',
#        'pravastatin (PA451089);simvastatin (PA451363)',
#        'tegafur (PA452620)', 'zafirlukast (PA451949)',
#        'atenolol (PA448499);metoprolol (PA450480)',
#        'photodynamic therapy (PA165984462)', 'tolperisone (PA166152940)',
#        'Dipeptidyl peptidase 4 (DPP-4) inhibitors (PA164712689)',
#        'triamcinolone (PA451749)',
#        'fentanyl (PA449599);propofol (PA451141);remifentanil (PA451232);sevoflurane (PA451341)',
#        'atorvastatin (PA448500);fluvastatin (PA449688);hmg coa reductase inhibitors (PA133950441);pravastatin (PA451089);rosuvastatin (PA134308647);simvastatin (PA451363)',
#        'ivacaftor / lumacaftor (PA166152935)', 'testosterone (PA451627)',
#        'curcumin (PA151958596);ivacaftor (PA165950341)',
#        'endoxifen (PA166124478)', 'brivaracetam (PA166153491)',
#        'clindamycin (PA449035)', 'milnacipran (PA164752812)',
#        'carboplatin (PA448803);cisplatin (PA449014);gemcitabine (PA449748)',
#        'furosemide (PA449719)',
#        'carboplatin (PA448803);cisplatin (PA449014);docetaxel (PA449383);paclitaxel (PA450761)',
#        'nitrendipine (PA146096020)',
#        'acetaminophen (PA448015);tramadol (PA451735)',
#        'catecholamines (PA133822447);metformin (PA450395)',
#        'cyclosporine (PA449167);dicloxacillin (PA164749649)',
#        'Dihydropyridine derivatives (PA164712688)',
#        'cefotaxime (PA448852)', 'zileuton (PA451955)',
#        'amiodarone (PA448383);Antibiotics (PA164712406);antipsychotics (PA452233);diuretics (PA151249535);quinidine (PA451209);sotalol (PA451457)',
#        'fluoxetine (PA449673);sertraline (PA451333)',
#        'carboplatin (PA448803);cisplatin (PA449014);docetaxel (PA449383);gemcitabine (PA449748);paclitaxel (PA450761)',
#        'cyclophosphamide (PA449165);cytarabine (PA449177);daunorubicin (PA449212);mercaptopurine (PA450379);methotrexate (PA450428);prednisone (PA451100);vincristine (PA451879)',
#        'berberine (PA165860812);coptisine (PA166153416)',
#        'terbutaline (PA451616)',
#        'cyclophosphamide (PA449165);fluorouracil (PA128406956);methotrexate (PA450428)',
#        'bevacizumab (PA130232992);capecitabine (PA448771);cetuximab (PA10040);oxaliplatin (PA131285527)',
#        'mycophenolic acid (PA164748728)',
#        'Drugs For Treatment Of Tuberculosis (PA164712708);rifampin (PA451250)',
#        'amiloride (PA448368);spironolactone (PA451483)',
#        'peginterferon alfa-2b (PA164784024);protease inhibitors (PA451159);ribavirin (PA451241)',
#        'difluorodeoxyuridine (PA166131569)', 'raloxifene (PA451221)',
#        'cyclophosphamide (PA449165);doxorubicin (PA449412);prednisone (PA451100);rituximab (PA451261);vincristine (PA451879)',
#        'angiotensin II (PA166109554)', 'topotecan (PA451729)',
#        'rasagiline (PA164764584)', 'telaprevir (PA165958354)',
#        'sitagliptin (PA164748978);vildagliptin (PA165958346)',
#        'bisoprolol (PA448641)',
#        'amantadine (PA448360);Anticholinergics (PA164712420);Dopamine agonists (PA164712697);levodopa (PA450213);selegiline (PA451316)',
#        'nicotine (PA450626);Opium alkaloids and derivatives (PA164712950)',
#        'adalimumab (PA10004);certolizumab pegol (PA165107055);etanercept (PA449515);glucocorticoids (PA452347);infliximab (PA452639);methotrexate (PA450428)',
#        'cyclosporine (PA449167);mycophenolic acid (PA164748728)',
#        'busulfan (PA448691);cyclophosphamide (PA449165)',
#        'ritodrine (PA451258)',
#        'efavirenz (PA449441);lopinavir (PA450264);Nucleoside and nucleotide reverse transcriptase inhibitors (PA164712943);ritonavir (PA451260)',
#        'succinylcholine (PA451522);volatile anesthetics (PA166131630)',
#        'dexamethasone (PA449247)',
#        'chlorpromazine (PA448964);clozapine (PA449061);haloperidol (PA449841);olanzapine (PA450688);quetiapine (PA451201);risperidone (PA451257);trifluoperazine (PA451771)',
#        'tipiracil hydrochloride (PA166171170);trifluridine (PA451775)',
#        'sofosbuvir (PA166122593);velpatasvir (PA166163415);voxilaprevir (PA166171182)',
#        'atazanavir (PA10251);lopinavir (PA450264);ritonavir (PA451260);tenofovir (PA10204)',
#        'dimethyl fumarate (PA166152838)', 'tianeptine (PA166186040)',
#        'anastrozole (PA448432);exemestane (PA449563);letrozole (PA450196)',
#        'alemtuzumab (PA164783958);chlorambucil (PA448926);cyclophosphamide (PA449165);fludarabine (PA449655);prednisone (PA451100);rituximab (PA451261);vincristine (PA451879)',
#        'gemtuzumab ozogamicin (PA164749431)',
#        'peginterferon alfa-2b (PA164784024)',
#        'docetaxel (PA449383);doxorubicin (PA449412)',
#        'abiraterone (PA166123407);prednisolone (PA451096)',
#        'anastrozole (PA448432);cyclophosphamide (PA449165);docetaxel (PA449383);doxorubicin (PA449412);epirubicin (PA449476);exemestane (PA449563);fluorouracil (PA128406956);paclitaxel (PA450761);radiotherapy (PA166122986);tamoxifen (PA451581)',
#        'agomelatine (PA165958363)',
#        'bevacizumab (PA130232992);capecitabine (PA448771);oxaliplatin (PA131285527)',
#        'carbamazepine (PA448785);phenobarbital (PA450911);phenytoin (PA450947);valproic acid (PA451846)',
#        'flurbiprofen (PA449683)', 'glucocorticoids (PA452347)',
#        'aspirin (PA448497);clopidogrel (PA449053);prasugrel (PA154410481)',
#        'capecitabine (PA448771);fluorouracil (PA128406956);s 1 (combination) (PA166115442)',
#        'carbocisteine (PA166184060)', 'l-phenylalanine (PA450931)',
#        'atenolol (PA448499);hydrochlorothiazide (PA449899);metoprolol (PA450480)',
#        'tenoxicam (PA131890625)',
#        'cytarabine (PA449177);daunorubicin (PA449212);dexrazoxane (PA449259);idarubicin (PA449961)',
#        'piroxicam (PA450985)', 'lornoxicam (PA165958395)',
#        'meloxicam (PA450353)', 'cilostazol (PA164746334)',
#        'maraviroc (PA164768835)', 'dextropropoxyphene (PA166183939)',
#        'acetaldehyde (PA166186245);ethanol (PA448073)',
#        'botulinum toxin type a (PA164754825)', 'letermovir (PA166184379)',
#        'Vitamin K1 (PA166197681)', 'amprenavir (PA448422)',
#        'cannabinoids (PA131890620);cocaine (PA449072);ethanol (PA448073);nicotine (PA450626);opioids (PA452618)',
#        'docetaxel (PA449383);FEC100 (PA166185677);gemcitabine (PA449748);trastuzumab (PA451743);zoledronate (PA10235)',
#        'remifentanil (PA451232)',
#        'phenobarbital (PA450911);phenytoin (PA450947)',
#        'Beta blocking agents, selective (PA164712547)',
#        'artemether (PA165111698)', 'budesonide (PA448681)',
#        'carboplatin (PA448803);gemcitabine (PA449748)',
#        'tenofovir disoproxil fumarate (PA166201941)',
#        'temozolomide (PA451609)', 'creatine (PA164778930)',
#        'desloratadine (PA164776964)', 'lurasidone (PA166129557)',
#        'progesterone (PA451123)',
#        'morphine (PA450550);nortriptyline (PA450657)',
#        'dexlansoprazole (PA166110257)', 'dipyrone (PA166128206)',
#        'indomethacin (PA449982)', 'naproxen (PA450595)',
#        'alprazolam (PA448333)', 'fesoterodine (PA165958376)',
#        'ethylmorphine (PA166210801)', 'dihydrocodeine (PA166176885)',
#        'metronidazole (PA450484)', 'tranilast (PA131890628)',
#        'nilotinib (PA165958345)',
#        'ketoprofen (PA450149);tramadol (PA451735)',
#        'atazanavir / ritonavir (PA166182624)',
#        'tafenoquine (PA166115580)', 'peginterferon alfa-2a (PA164749390)',
#        'sofosbuvir (PA166122593)'], dtype=object)

# %% [markdown]
# Again, this column has multiple values (drugs) per record.
#
# If the variant - drug association was found in one particular race, it is designated in the column `Biogeographical Groups`.

# %%
clinical_annotation_metadata['Biogeographical Groups'].sort_values().unique()
# Out:
# array(['African American/Afro-Caribbean', 'American',
#        'Central/South Asian', 'East Asian', 'European', 'In vitro',
#        'Latino', 'Mixed Population', 'NCI-60 cell lines', 'Near Eastern',
#        'Not applicable - in vitro study with FRT cells',
#        'Not applicable - study was carried out in FRT cells',
#        'Not applicable - study was carried out in PBE cells', 'Oceanian',
#        'Sub-Saharan African', 'Unknown', 'cell lines', 'in vitro', nan],
#       dtype=object)

# %% [markdown]
# Now, after we got acquainted with our first dataset, let's see if there is some missing values in it.

# %%
clinical_annotation_metadata.isnull().any()
# Out:
# Clinical Annotation ID       False
# Location                     False
# Gene                          True
# Level of Evidence            False
# Clinical Annotation Types     True
# Genotype-Phenotype IDs       False
# Annotation Text              False
# Variant Annotations IDs      False
# Variant Annotations          False
# PMIDs                        False
# Evidence Count               False
# Related Chemicals            False
# Related Diseases              True
# Biogeographical Groups        True
# Chromosome                    True
# dtype: bool

# %% [markdown]
# We will use the columns `Gene` and `Biogeographical Groups` in our analysis, and since there exists missing values, we will have to substitute them or discard them.
#
# But first, let's see which are those records without values in the column `Gene`.

# %%
clinical_annotation_metadata[clinical_annotation_metadata['Gene'].isnull()]
# Out:
#       Clinical Annotation ID    Location Gene Level of Evidence  \
# 6                 1449566379  rs11065987  NaN                 3
# 23                1450815166   rs7395555  NaN                 3
# 46                 981237670   rs1799853  NaN                 3
# 83                1449167568   rs1061115  NaN                 4
# 84                1449168307   rs4437856  NaN                 4
# ...                      ...         ...  ...               ...
# 4508              1451151478  rs56722963  NaN                 3
# 4510              1451151500   rs6589386  NaN                 3
# 4511              1451151490   rs1783835  NaN                 3
# 4513              1451151512   rs8008020  NaN                 3
# 4553              1451212540  rs62103056  NaN                 3
#
#      Clinical Annotation Types            Genotype-Phenotype IDs  \
# 6                     Efficacy  1449566381;1449566382;1449566383
# 23                    Efficacy  1450815168;1450815169;1450815170
# 46       Efficacy;Toxicity/ADR  1448615596;1448615597;1448615598
# 83                    Efficacy  1449167580;1449167581;1449167582
# 84                    Efficacy  1449168309;1449168310;1449168311
# ...                        ...                               ...
# 4508              Toxicity/ADR  1451151480;1451151481;1451151482
# 4510              Toxicity/ADR  1451151502;1451151503;1451151504
# 4511              Toxicity/ADR  1451151492;1451151493;1451151494
# 4513              Toxicity/ADR  1451151514;1451151515;1451151516
# 4553                  Efficacy  1451212542;1451212543;1451212544
#
#                                         Annotation Text  \
# 6     AA:Patients with the AA genotype and hypertens...
# 23    CC:Patients with schizophrenia and the CC geno...
# 46    CC:Patients with the CC genotype and Epilepsy ...
# 83    AA:Patients with the AA genotype and Attention...
# 84    AA:Patients with the AA genotype may have a de...
# ...                                                 ...
# 4508  CC:Patients with the CC genotype may be at an ...
# 4510  CC:Patients with the CC genotype may be at an ...
# 4511  AA:Patients with the AA genotype may be at a d...
# 4513  CC:Patients with the CC genotype may be at a d...
# 4553  AA:Patients with the AA genotype with malaria ...
#
#                                 Variant Annotations IDs  \
# 6                                            1449566369
# 23                                           1450815030
# 46    769250046;769248925;769248937;769259087;769250...
# 83                                           1449166351
# 84                                           1449168118
# ...                                                 ...
# 4508                                         1451149858
# 4510                                         1451149880
# 4511                                         1451149900
# 4513                                         1451149947
# 4553                                         1451212190
#
#                                     Variant Annotations  \
# 6     Genotypes AA + AG  is associated with  increas...
# 23    Allele C  is associated with  increased respon...
# 46    Genotype TT  is associated with  increased lik...
# 83    Allele G  is associated with  increased respon...
# 84    Allele A  is associated with  decreased respon...
# ...                                                 ...
# 4508  Allele T  is associated with  decreased risk o...
# 4510  Allele T  is associated with  decreased risk o...
# 4511  Allele A  is associated with  decreased risk o...
# 4513  Allele T  is associated with  increased risk o...
# 4553  Allele A  is associated with  increased likeli...
#
#                                                   PMIDs  Evidence Count  \
# 6                                              29925376               1
# 23                                             23241943               1
# 46    10901705;15805193;16815679;19617466;21068649;2...               9
# 83                                             29382897               1
# 84                                             29407288               1
# ...                                                 ...             ...
# 4508                                           32451486               1
# 4510                                           32451486               1
# 4511                                           32451486               1
# 4513                                           32451486               1
# 4553                                           32433338               1
#
#                    Related Chemicals  \
# 6     hydrochlorothiazide (PA449899)
# 23            risperidone (PA451257)
# 46              phenytoin (PA450947)
# 83        methylphenidate (PA450464)
# 84              duloxetine (PA10066)
# ...                              ...
# 4508              ethanol (PA448073)
# 4510              ethanol (PA448073)
# 4511              ethanol (PA448073)
# 4513              ethanol (PA448073)
# 4553       tafenoquine (PA166115580)
#
#                                        Related Diseases  \
# 6                               Hypertension (PA444552)
# 23                             Schizophrenia (PA447216)
# 46                                  Epilepsy (PA444065)
# 83    Attention Deficit Disorder with Hyperactivity ...
# 84                Depressive Disorder, Major (PA447321)
# ...                                                 ...
# 4508                              Alcoholism (PA443309)
# 4510                              Alcoholism (PA443309)
# 4511                              Alcoholism (PA443309)
# 4513                              Alcoholism (PA443309)
# 4553                                 Malaria (PA444859)
#
#      Biogeographical Groups Chromosome
# 6                  European      chr12
# 23         Mixed Population      chr11
# 46         Mixed Population      chr10
# 83         Mixed Population      chr10
# 84                 European       chr1
# ...                     ...        ...
# 4508               European      chr10
# 4510               European      chr11
# 4511               European      chr11
# 4513               European      chr14
# 4553       Mixed Population      chr18
#
# [227 rows x 15 columns]

# %% [markdown]
# 227 rows. It is quite a lot. We will use this column to filter out our genes of interest (CYP genes), but before that we will have to render all those records which are made up of more than one gene to hold exactly one gene, not more. In order to do that, we will have to write a function that splits the values and expand the DataFrame so that the new DataFrame has only one gene per rocord. In order that function to work, we will have to fill up all those missing values.
#
# Let's do that.

# %%
# fill up the missing values in `gene` column

clinical_annotation_metadata['Gene'] = clinical_annotation_metadata['Gene'].fillna('missing')

# %% [markdown]
# Let's now verify if there has left any `NaN` values in our `Gene` column.

# %%
clinical_annotation_metadata['Gene'].isnull().any()
# Out:
# False

# %% [markdown]
# `False`, excellently.
#
# Now, let's taka a random sample from our `Gene` column, with say, 50 records, to verify that there are records with multiple values (genes) per record.

# %%
clinical_annotation_metadata['Gene'].sample(50)
# Out:
# 2579                                VEGFA (PA37302)
# 4105                                HLA-B (PA35056)
# 4150                                        missing
# 120                                 ERCC2 (PA27848)
# 3380                                  ABCB1 (PA267)
# 4525                                 CYP2D6 (PA128)
# 4438                                   COMT (PA117)
# 1793                                GSTP1 (PA29028)
# 3449                               CHRNA5 (PA26491)
# 3115                                 CYP2B6 (PA123)
# 2144                                   ESR1 (PA156)
# 4513                                        missing
# 1740                                  ABCB1 (PA267)
# 3948                 CYP3A (PA27114);CYP3A4 (PA130)
# 4084                                  NR1I3 (PA391)
# 1807                                        missing
# 1963                 ABCC8 (PA24395);KCNJ11 (PA217)
# 617                               NEUROD1 (PA31564)
# 3572    ADORA2A (PA24584);ADORA2A-AS1 (PA165378332)
# 1588                                  ABCC1 (PA244)
# 1714                          GALNT14 (PA134920089)
# 3174                                   COMT (PA117)
# 2565                               CXCL10 (PA35568)
# 111                            NUDT15 (PA134963132)
# 2580                              UGT2B10 (PA37186)
# 1190                                 RYR1 (PA34896)
# 1756                                  MTHFR (PA245)
# 581                  UGT1A (PA37173);UGT1A9 (PA419)
# 4190                               UGT1A8 (PA37183)
# 2350                                 CYP3A4 (PA130)
# 254                                    AGTR1 (PA43)
# 1950                                 CYP2C8 (PA125)
# 3436                            ANKK1 (PA134872551)
# 4253                                 CYP2D6 (PA128)
# 684                                 VEGFA (PA37302)
# 1672              ENOSF1 (PA134897613);TYMS (PA359)
# 3125                                 DLG5 (PA27360)
# 3058                           ENOSF1 (PA134897613)
# 2973                             HLA-DPB1 (PA35064)
# 1782                                  XRCC1 (PA369)
# 1347                                   NOS3 (PA254)
# 3623                                   RRM1 (PA298)
# 3987                                   TPMT (PA356)
# 2644                            ZMAT4 (PA142670525)
# 3675                                 CHRNB2 (PA115)
# 1637                                 DRD3 (PA27479)
# 1831                               CYP1A2 (PA27093)
# 349                                 PRKCA (PA33759)
# 2971                                 CYP2D6 (PA128)
# 3850                           ERICH3 (PA142672422)
# Name: Gene, dtype: object

# %% [markdown]
# There exists multiple values per record.
#
# Now, that we could do is to separate those values and expand our DataFrame so that each gene to be set as distinct record.
#
# In order to do that, will have to write a function that recieves as parameters - a DataFrame, and column to split on, and a separator which will be used to split the column's values. The function will return an expanded DataFrame with one value per record.
#
# Let's define that function.

# %%
def explode_string(dataframe, column, separator):
    """
    Split the values of a column and expand so the new DataFrame has one split value per row.
    """
    string = dataframe[column]
    index = np.arange(len(string)).repeat(string.str.count(separator) + 1)
    
    return dataframe.iloc[index].assign(**{column: separator.join(string).split(separator)}).reset_index(drop = True)

# %% [markdown]
# Now, let's use this function to split all rows with muliple genes in them.

# %%
explode_string(clinical_annotation_metadata, 'Gene', ';')
# Out:
#       Clinical Annotation ID     Location                   Gene  \
# 0                  981755803   rs75527207           CFTR (PA109)
# 1                 1449311190    rs4149056  SLCO1B1 (PA134865839)
# 2                 1449191690  rs141033578           CFTR (PA109)
# 3                 1449191746   rs78769542           CFTR (PA109)
# 4                  981204774    rs1799971        OPRM1 (PA31945)
# ...                      ...          ...                    ...
# 4689              1451217520   rs12979860    IFNL4 (PA166049147)
# 4690              1451217540   rs12979860    IFNL3 (PA134952671)
# 4691              1451217540   rs12979860    IFNL4 (PA166049147)
# 4692              1451217560   rs12979860    IFNL3 (PA134952671)
# 4693              1451217560   rs12979860    IFNL4 (PA166049147)
#
#      Level of Evidence Clinical Annotation Types  \
# 0                   1A                  Efficacy
# 1                    3                    Dosage
# 2                   1A                  Efficacy
# 3                   1A                  Efficacy
# 4                    3                  Efficacy
# ...                ...                       ...
# 4689                 3                  Efficacy
# 4690                 3                       NaN
# 4691                 3                       NaN
# 4692                 3                  Efficacy
# 4693                 3                  Efficacy
#
#                 Genotype-Phenotype IDs  \
# 0     1450043467;1450043468;1450043469
# 1     1449311192;1449311193;1449311194
# 2     1449191692;1449191693;1449191694
# 3     1449191748;1449191749;1449191750
# 4        982037129;982037130;982037131
# ...                                ...
# 4689  1451217522;1451217523;1451217524
# 4690  1451217542;1451217543;1451217544
# 4691  1451217542;1451217543;1451217544
# 4692  1451217562;1451217563;1451217564
# 4693  1451217562;1451217563;1451217564
#
#                                         Annotation Text  \
# 0     AA:Ivacaftor is indicated in cystic fibrosis p...
# 1     CC:Patients with the CC genotype and Precursor...
# 2     CC:Patients with the CC genotype (do not have ...
# 3     AA:Patients with the AA genotype (two copies o...
# 4     AA:Patients with AA genotype may have an incre...
# ...                                                 ...
# 4689  CC:Patients with the CC genotype may have an i...
# 4690  CC:Patients with a HCV genotype I infection an...
# 4691  CC:Patients with a HCV genotype I infection an...
# 4692  CC:Patients with the CC genotype may have an i...
# 4693  CC:Patients with the CC genotype may have an i...
#
#                                 Variant Annotations IDs  \
# 0     981755665;981755678;982006840;982009991;104373...
# 1                                            1449311153
# 2                                            1449191113
# 3                                            1449191063
# 4                         655386751;655386750;655385584
# ...                                                 ...
# 4689                                         1449190317
# 4690                                981352209;981352215
# 4691                                981352209;981352215
# 4692                                         1447951883
# 4693                                         1447951883
#
#                                     Variant Annotations  \
# 0     Genotypes AA + AG  are associated with  respon...
# 1     Genotypes CC + CT  is associated with  decreas...
# 2     Allele T  is associated with  activity of CFTR...
# 3     Allele A  is associated with  activity of CFTR...
# 4     Genotype GG  is associated with  increased lik...
# ...                                                 ...
# 4689  Genotype CC  is associated with  increased sus...
# 4690  Genotype CC  is associated with  increased sus...
# 4691  Genotype CC  is associated with  increased sus...
# 4692  Genotype CC  is associated with  increased res...
# 4693  Genotype CC  is associated with  increased res...
#
#                                                   PMIDs  Evidence Count  \
# 0     19846789;21083385;22047557;22293084;22942289;2...              29
# 1                                              29683944               1
# 2                                              23891399               1
# 3                                              23891399               1
# 4                                     15007373;17224915               3
# ...                                                 ...             ...
# 4689                                           29534310               1
# 4690                                           22438096               2
# 4691                                           22438096               2
# 4692                                           26334898               1
# 4693                                           26334898               1
#
#                                       Related Chemicals  \
# 0                               ivacaftor (PA165950341)
# 1     mercaptopurine (PA450379);methotrexate (PA450428)
# 2                               ivacaftor (PA165950341)
# 3                               ivacaftor (PA165950341)
# 4     Drugs used in nicotine dependence (PA164712720...
# ...                                                 ...
# 4689                           sofosbuvir (PA166122593)
# 4690                             interferons (PA451999)
# 4691                             interferons (PA451999)
# 4692                             interferons (PA451999)
# 4693                             interferons (PA451999)
#
#                                        Related Diseases  \
# 0                            Cystic Fibrosis (PA443829)
# 1     Precursor Cell Lymphoblastic Leukemia-Lymphoma...
# 2                            Cystic Fibrosis (PA443829)
# 3                            Cystic Fibrosis (PA443829)
# 4                       Tobacco Use Disorder (PA445876)
# ...                                                 ...
# 4689                    Hepatitis C, Chronic (PA446863)
# 4690                             Hepatitis C (PA444445)
# 4691                             Hepatitis C (PA444445)
# 4692                             Hepatitis C (PA444445)
# 4693                             Hepatitis C (PA444445)
#
#                                  Biogeographical Groups Chromosome
# 0                                      Mixed Population       chr7
# 1                                          Near Eastern      chr12
# 2     Not applicable - study was carried out in FRT ...       chr7
# 3     Not applicable - study was carried out in FRT ...       chr7
# 4                                              European       chr6
# ...                                                 ...        ...
# 4689                                            Unknown      chr19
# 4690                                         East Asian      chr19
# 4691                                         East Asian      chr19
# 4692                                           European      chr19
# 4693                                           European      chr19
#
# [4694 rows x 15 columns]

# %% [markdown]
# As we can see, the dimensionality of our DataFrame increased from 4558 rows, initially, to 4694 after we splited the values.
#
# Now, let's overwrite our `clinical_annotation_metadata` variable with the expanded dataset.

# %%
clinical_annotation_metadata = explode_string(clinical_annotation_metadata, 'Gene', ';')

# %% [markdown]
# We may take out a random sample from our new `Gene` column to verify if there has left records with multiple genes.

# %%
clinical_annotation_metadata['Gene'].sample(50)
# Out:
# 1637            ABCC1 (PA244)
# 3284           THBD (PA36496)
# 2648            MTHFR (PA245)
# 4260           CYP2B6 (PA123)
# 3717           CYP3A4 (PA130)
# 93                    missing
# 4125            ABCB1 (PA267)
# 2475         FCGR3A (PA28065)
# 1484            ABCB1 (PA267)
# 4380     VKORC1 (PA133787052)
# 4328          PLIN1 (PA33409)
# 2840          HTR1B (PA29549)
# 3768          HLA-B (PA35056)
# 1302            ABCB1 (PA267)
# 3602         CHRNA5 (PA26491)
# 3505           TJP1 (PA36532)
# 2842         CELSR2 (PA26394)
# 4253          SLC22A1 (PA329)
# 1214          SCN4A (PA35006)
# 4611            ADRA2A (PA35)
# 1532    SLCO1B1 (PA134865839)
# 951           SLC31A1 (PA118)
# 1616          CRHR2 (PA26875)
# 3872       HLA-DRB1 (PA35072)
# 215                CDA (PA98)
# 2843           CYP3A5 (PA131)
# 1587            HTR2C (PA194)
# 51            SULT1A3 (PA344)
# 4005             ESR1 (PA156)
# 4280           UGT1A1 (PA420)
# 2149        ALDH1A1 (PA24692)
# 3050          SLIT1 (PA35938)
# 1703        ADORA2A (PA24584)
# 3574          AMPD1 (PA24776)
# 432            CYP2B6 (PA123)
# 966              IRS1 (PA203)
# 3357           PTGER3 (PA288)
# 2266           ADH7 (PA24577)
# 509        SCAP (PA162402461)
# 1897            ABCG2 (PA390)
# 3730      HCG22 (PA134876212)
# 392             ABCB1 (PA267)
# 2703        SLC30A9 (PA25909)
# 1658            ABCB1 (PA267)
# 1733             COMT (PA117)
# 4537            ABCB1 (PA267)
# 4497          OPRD1 (PA31942)
# 845           OPRM1 (PA31945)
# 1275         CYP1A2 (PA27093)
# 2241             CFTR (PA109)
# Name: Gene, dtype: object

# %% [markdown]
# Everything looks all right.
#
# We can even verify it more precisely.

# %%
clinical_annotation_metadata['Gene'].str.contains(';').any()
# Out:
# False

# %% [markdown]
# Let's find out how many unique genes contains our `Gene` column.

# %%
len(clinical_annotation_metadata['Gene'].unique())
# Out:
# 1026

# %% [markdown]
# 1026 genes annotated in PharmGKB. Interestingly, approximately 5 % of all human genes are implicated in one or another way in drug metabolism, or are targets for drugs.
#
# Now, because to all genes are assigned unique PharmGKB ID numbers beginnig with 'PA' and some digits after that, which honestly is a quite annoying, we will discard them, to make the column more tidy and well-looking.

# %%
# remove everything after the white space in `gene` column

clinical_annotation_metadata['Gene'] = clinical_annotation_metadata['Gene'].str.split(' ').str[0]

# %%
clinical_annotation_metadata['Gene'].sample(20)
# Out:
# 3197      NR1I2
# 3240      ABCC5
# 1364     CD3EAP
# 4234      NR1I2
# 4321      IFNL3
# 3404      ABCB1
# 3949    missing
# 1235     CYP2C8
# 1864     UGT1A8
# 4598       NAT2
# 4506     UGT2B7
# 4642    missing
# 4169      CTLA4
# 3700     CYP2C9
# 1742     UGT1A1
# 1198        ATM
# 2420       RYR1
# 1645     CYP2D6
# 2681       IL1B
# 878      SACM1L
# Name: Gene, dtype: object

# %% [markdown]
# That looks better.
#
# Now, let's verify how many Cytochrome P450 genes are there in our dataset.

# %%
clinical_annotation_metadata[clinical_annotation_metadata['Gene'].str.contains('CYP')]
# Out:
#       Clinical Annotation ID  \
# 7                 1448999716
# 39                1449718265
# 49                 981238437
# 72                1449718242
# 82                1449005041
# ...                      ...
# 4667              1451161878
# 4671              1451163460
# 4677              1451208240
# 4679              1451208340
# 4680              1451207862
#
#                                                Location     Gene  \
# 7     CYP2D6*1, CYP2D6*10, CYP2D6*87, CYP2D6*88, CYP...   CYP2D6
# 39                                           rs12248560  CYP2C19
# 49                                            rs1057910   CYP2C9
# 72                                            rs1056836   CYP1B1
# 82                                             rs776746    CYP3A
# ...                                                 ...      ...
# 4667                                 CYP2B6*1, CYP2B6*6   CYP2B6
# 4671           CYP2A6*17, CYP2A6*1A, CYP2A6*2, CYP2A6*9   CYP2A6
# 4677                                CYP2D6*1, CYP2D6*10   CYP2D6
# 4679  CYP2D6*1, CYP2D6*10, CYP2D6*17, CYP2D6*2, CYP2...   CYP2D6
# 4680                                 CYP3A5*1, CYP3A5*3   CYP3A5
#
#      Level of Evidence Clinical Annotation Types  \
# 7                    4             Metabolism/PK
# 39                   3              Toxicity/ADR
# 49                  2A              Toxicity/ADR
# 72                   3              Toxicity/ADR
# 82                   3             Metabolism/PK
# ...                ...                       ...
# 4667                 4                    Dosage
# 4671                 3             Metabolism/PK
# 4677                 3                    Dosage
# 4679                 3              Toxicity/ADR
# 4680                 3             Metabolism/PK
#
#                                  Genotype-Phenotype IDs  \
# 7     1449166659;1449166660;1449166661;1449166662;14...
# 39                     1449718267;1449718268;1449718269
# 49                        981238438;981238439;981238440
# 72                     1449718244;1449718245;1449718246
# 82                     1449005043;1449005044;1449005045
# ...                                                 ...
# 4667                              1451161920;1451161921
# 4671        1451163462;1451163463;1451163464;1451163465
# 4677                              1451208242;1451208243
# 4679  1451208361;1451208362;1451208363;1451208364;14...
# 4680                              1451207868;1451207869
#
#                                         Annotation Text  \
# 7     *1:Patients with the CYP2D6*1 allele may have ...
# 39    CC:Patients with the CC genotype and breast ca...
# 49    AA:Patients with the AA genotype who are treat...
# 72    CC:Patients with the CC genotype and breast ca...
# 82    CC:Pregnant patients infected with malaria and...
# ...                                                 ...
# 4667  *1:Patients with opioid dependence and carryin...
# 4671  *1A:Patients with two copies of the *1A allele...
# 4677  *1:Patients carrying the *1 allele in combinat...
# 4679  *1:Patients carrying the *1 allele in combinat...
# 4680  *1:Patients carrying the *1 allele in combinat...
#
#      Variant Annotations IDs  \
# 7                 1447959180
# 39                1449718012
# 49       827826832;827826844
# 72                1449718142
# 82     1449003493;1449003659
# ...                      ...
# 4667              1451161493
# 4671   1449576398;1451162952
# 4677              1451208192
# 4679              1451208260
# 4680              1451207780
#
#                                     Variant Annotations              PMIDs  \
# 7     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...           26544071
# 39    Genotype CC  is associated with  increased ris...           29507678
# 49    Allele C  is associated with  increased risk o...  14707031;17681167
# 72    Genotype CC  is associated with  increased ris...           29507678
# 82    Allele C  is associated with  increased concen...           28673292
# ...                                                 ...                ...
# 4667  CYP2B6 *6/*6  is associated with  decreased do...           21589866
# 4671  CYP2A6 *17  is not associated with  clearance ...  27417511;30706508
# 4677  CYP2D6 *10/*10  is associated with  increased ...           25825958
# 4679  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...           25989235
# 4680  CYP3A5 *1/*1  is associated with  decreased ex...           32564268
#
#       Evidence Count                                  Related Chemicals  \
# 7                  1                             risperidone (PA451257)
# 39                 1  cyclophosphamide (PA449165);doxorubicin (PA449...
# 49                 2  Antiinflammatory agents, non-steroids (PA16471...
# 72                 1  cyclophosphamide (PA449165);doxorubicin (PA449...
# 82                 2                         lumefantrine (PA165111722)
# ...              ...                                                ...
# 4667               1                               methadone (PA450401)
# 4671               2                           metronidazole (PA450484)
# 4677               1                                fentanyl (PA449599)
# 4679               1          ketoprofen (PA450149);tramadol (PA451735)
# 4680               1                           Dabigatran (PA165110351)
#
#                          Related Diseases Biogeographical Groups Chromosome
# 7                                     NaN                Unknown        NaN
# 39            Breast Neoplasms (PA443560)                Unknown      chr10
# 49                                    NaN                Unknown      chr10
# 72            Breast Neoplasms (PA443560)                Unknown       chr2
# 82                     Malaria (PA444859)    Sub-Saharan African       chr7
# ...                                   ...                    ...        ...
# 4667  Opioid-Related Disorders (PA445043)               European        NaN
# 4671                                  NaN       Mixed Population        NaN
# 4677                                  NaN                Unknown        NaN
# 4679                                  NaN               European        NaN
# 4680                                  NaN       Mixed Population        NaN
#
# [612 rows x 15 columns]

# %% [markdown]
# 612 records contain information about CYP genes.
#
# We will save this filtered DataFrame in a new variable.

# %%
cyps = clinical_annotation_metadata[clinical_annotation_metadata['Gene'].str.contains('CYP')]

# %% [markdown]
# Let's see which are these CYP genes.

# %%
cyps['Gene'].unique()
# Out:
# array(['CYP2D6', 'CYP2C19', 'CYP2C9', 'CYP1B1', 'CYP3A', 'CYP3A5',
#        'CYP3A4', 'CYP11B2', 'CYP1A2', 'CYP2B6', 'CYP2E1', 'CYP2A6',
#        'CYP2C8', 'CYP1A1', 'CYP2F1', 'CYP7A1', 'CYP4A11', 'CYP3A7',
#        'CYP2J2', 'CYP4F2', 'CYP2A13', 'CYP4B1', 'CYP27B1', 'CYP24A1',
#        'CYP19A1', 'CYP3A43', 'ACYP2', 'CYP2R1', 'CYP4F11'], dtype=object)

# %%
len(cyps['Gene'].unique())
# Out:
# 29

# %% [markdown]
# We have clinical annotations for 29 CYPs genes in our dataset.
#
# Now, we can group by the column `Gene`, and check how many records per each CYP gene we have.

# %%
cyps.groupby('Gene').size().sort_values(ascending = False)
# Out:
# Gene
# CYP2D6     109
# CYP2C19     84
# CYP2C9      74
# CYP3A4      68
# CYP3A5      63
# CYP2B6      57
# CYP2A6      27
# CYP1A2      26
# CYP2C8      24
# CYP19A1     16
# CYP4F2      12
# CYP3A        9
# CYP2E1       8
# CYP1A1       6
# CYP1B1       5
# CYP24A1      5
# CYP27B1      3
# CYP3A43      2
# CYP4A11      2
# CYP11B2      2
# CYP2A13      2
# CYP7A1       1
# CYP2F1       1
# CYP2J2       1
# CYP2R1       1
# CYP3A7       1
# CYP4B1       1
# CYP4F11      1
# ACYP2        1
# dtype: int64

# %% [markdown]
# The first 5 genes - CYP2D6, CYP2C19, CYP2C9, CYP3A4 and CYP3A5, are in fact, the genes that are involved in the metabolism of nearly 3/4 of all prescribed drugs.
#
# Now, we can display this count, which basically represent the number of variant - drug annotation for each CYP gene in our DataFrame. This number account for the relative importance of each CYP gene as regarded to scientific interest.
#
# We can show this count as a horizontal bar chart for better presentation of the figures.
#
# Let's display that.

# %%
# group on the column `gene`
cyps_grouped_by_gene = cyps.groupby('Gene').size().sort_values()

# display the figure
plt.figure(figsize = (9, 8))
plt.barh(cyps_grouped_by_gene.index, cyps_grouped_by_gene)
plt.title('Comparison of CYP genes\' frequencies', fontsize = 13)
plt.xlabel('Number of appearance', fontsize = 12)
plt.show()

# %% [markdown]
# As we can see from our bar chart, the first 6 CYP genes are nearly twice more represented from the rest of CYPs, i.e there are more variant - drug annotations in the literature for them.
#
# Now, let's filter out these 6 most common CYPs and make them main subject of our subsequent analysis.

# %%
most_common_genes = 'CYP2D6|CYP2C19|CYP2C9|CYP3A4\Z|CYP3A5|CYP2B6'

# %%
cyps_most_common_genes = clinical_annotation_metadata[clinical_annotation_metadata['Gene'].str.contains(most_common_genes)]

# %%
cyps_most_common_genes
# Out:
#       Clinical Annotation ID  \
# 7                 1448999716
# 39                1449718265
# 49                 981238437
# 83                1449005041
# 85                1449005047
# ...                      ...
# 4663              1451155020
# 4667              1451161878
# 4677              1451208240
# 4679              1451208340
# 4680              1451207862
#
#                                                Location     Gene  \
# 7     CYP2D6*1, CYP2D6*10, CYP2D6*87, CYP2D6*88, CYP...   CYP2D6
# 39                                           rs12248560  CYP2C19
# 49                                            rs1057910   CYP2C9
# 83                                             rs776746   CYP3A5
# 85                                            rs2740574   CYP3A4
# ...                                                 ...      ...
# 4663  CYP2D6*1, CYP2D6*10, CYP2D6*17, CYP2D6*1xN, CY...   CYP2D6
# 4667                                 CYP2B6*1, CYP2B6*6   CYP2B6
# 4677                                CYP2D6*1, CYP2D6*10   CYP2D6
# 4679  CYP2D6*1, CYP2D6*10, CYP2D6*17, CYP2D6*2, CYP2...   CYP2D6
# 4680                                 CYP3A5*1, CYP3A5*3   CYP3A5
#
#      Level of Evidence Clinical Annotation Types  \
# 7                    4             Metabolism/PK
# 39                   3              Toxicity/ADR
# 49                  2A              Toxicity/ADR
# 83                   3             Metabolism/PK
# 85                   3    Efficacy;Metabolism/PK
# ...                ...                       ...
# 4663                2A             Metabolism/PK
# 4667                 4                    Dosage
# 4677                 3                    Dosage
# 4679                 3              Toxicity/ADR
# 4680                 3             Metabolism/PK
#
#                                  Genotype-Phenotype IDs  \
# 7     1449166659;1449166660;1449166661;1449166662;14...
# 39                     1449718267;1449718268;1449718269
# 49                        981238438;981238439;981238440
# 83                     1449005043;1449005044;1449005045
# 85                     1449005049;1449005050;1449005051
# ...                                                 ...
# 4663  1451208441;1451208442;1451208443;1451208444;14...
# 4667                              1451161920;1451161921
# 4677                              1451208242;1451208243
# 4679  1451208361;1451208362;1451208363;1451208364;14...
# 4680                              1451207868;1451207869
#
#                                         Annotation Text  \
# 7     *1:Patients with the CYP2D6*1 allele may have ...
# 39    CC:Patients with the CC genotype and breast ca...
# 49    AA:Patients with the AA genotype who are treat...
# 83    CC:Pregnant patients infected with malaria and...
# 85    CC:Pregnant patients with malaria and the CC g...
# ...                                                 ...
# 4663  *1:Patients carrying the *1 allele in addition...
# 4667  *1:Patients with opioid dependence and carryin...
# 4677  *1:Patients carrying the *1 allele in combinat...
# 4679  *1:Patients carrying the *1 allele in combinat...
# 4680  *1:Patients carrying the *1 allele in combinat...
#
#                                 Variant Annotations IDs  \
# 7                                            1447959180
# 39                                           1449718012
# 49                                  827826832;827826844
# 83                                1449003493;1449003659
# 85                                1449003545;1449003637
# ...                                                 ...
# 4663  1183684640;1183684653;1183684657;1183684661;14...
# 4667                                         1451161493
# 4677                                         1451208192
# 4679                                         1451208260
# 4680                                         1451207780
#
#                                     Variant Annotations  \
# 7     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...
# 39    Genotype CC  is associated with  increased ris...
# 49    Allele C  is associated with  increased risk o...
# 83    Allele C  is associated with  increased concen...
# 85    Allele C  is associated with  increased concen...
# ...                                                 ...
# 4663  CYP2D6 ultra-metabolizer genotype is associate...
# 4667  CYP2B6 *6/*6  is associated with  decreased do...
# 4677  CYP2D6 *10/*10  is associated with  increased ...
# 4679  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...
# 4680  CYP3A5 *1/*1  is associated with  decreased ex...
#
#                                                   PMIDs  Evidence Count  \
# 7                                              26544071               1
# 39                                             29507678               1
# 49                                    14707031;17681167               2
# 83                                             28673292               2
# 85                                             28673292               2
# ...                                                 ...             ...
# 4663  12191703;12893130;14624403;15906019;16368820;1...              34
# 4667                                           21589866               1
# 4677                                           25825958               1
# 4679                                           25989235               1
# 4680                                           32564268               1
#
#                                       Related Chemicals  \
# 7                                risperidone (PA451257)
# 39    cyclophosphamide (PA449165);doxorubicin (PA449...
# 49    Antiinflammatory agents, non-steroids (PA16471...
# 83                           lumefantrine (PA165111722)
# 85                           lumefantrine (PA165111722)
# ...                                                 ...
# 4663                                tramadol (PA451735)
# 4667                               methadone (PA450401)
# 4677                                fentanyl (PA449599)
# 4679          ketoprofen (PA450149);tramadol (PA451735)
# 4680                           Dabigatran (PA165110351)
#
#                          Related Diseases Biogeographical Groups Chromosome
# 7                                     NaN                Unknown        NaN
# 39            Breast Neoplasms (PA443560)                Unknown      chr10
# 49                                    NaN                Unknown      chr10
# 83                     Malaria (PA444859)    Sub-Saharan African       chr7
# 85                     Malaria (PA444859)    Sub-Saharan African       chr7
# ...                                   ...                    ...        ...
# 4663                                  NaN       Mixed Population        NaN
# 4667  Opioid-Related Disorders (PA445043)               European        NaN
# 4677                                  NaN                Unknown        NaN
# 4679                                  NaN               European        NaN
# 4680                                  NaN       Mixed Population        NaN
#
# [455 rows x 15 columns]

# %% [markdown]
# Our current working DataFrame has reduced to 455 records.
#
# Now, we will have to tidy up another important column for our analysis, that is the `Location` column. We saw that there is stored information about the variants associated with particular drug. However, this column also contain more than one value (gene variant) per row, that we should split in a similar fashion as we did with the column `Gene`.
#
# Before we do that, let's take a random sample from this column.

# %%
cyps_most_common_genes['Location'].sample(20)
# Out:
# 586                                            rs12782374
# 770                                              rs776746
# 522     CYP2D6*1, CYP2D6*10, CYP2D6*1xN, CYP2D6*2, CYP...
# 587                                            rs12721655
# 1708                                            rs4244285
# 2991                                             rs776746
# 3741                                            rs4646437
# 2204                                           rs41303343
# 2010                                  CYP3A4*1, CYP3A4*22
# 4662    CYP2D6*1, CYP2D6*1xN, CYP2D6*2xN, CYP2D6*3, CY...
# 2696                                            rs1065852
# 3648                                            rs8192719
# 3708                                  CYP3A4*1, CYP3A4*22
# 3250                                 CYP2C19*1, CYP2C19*2
# 619                                             rs2246709
# 1644                                            rs5030655
# 4658           CYP2D6*1, CYP2D6*1xN, CYP2D6*2, CYP2D6*2xN
# 1852               CYP3A5*1, CYP3A5*3, CYP3A5*6, CYP3A5*7
# 2118    CYP2D6*1, CYP2D6*10, CYP2D6*87, CYP2D6*88, CYP...
# 790     CYP2D6*1, CYP2D6*10, CYP2D6*87, CYP2D6*88, CYP...
# Name: Location, dtype: object

# %% [markdown]
# As we can see nearly all records contain multiple variants. That basically means that the action of certain drug(s) can be infuenced by many alleles of one gene in a similar fashion.
#
# Now, let's split out these variants and render them as individual records. For that purpose, we will have to use again our `explode_string` function. We will store the expanded DataFrame in new variable.

# %%
cyps_most_common = explode_string(cyps_most_common_genes, 'Location', ',')

# %%
cyps_most_common
# Out:
#       Clinical Annotation ID    Location    Gene Level of Evidence  \
# 0                 1448999716    CYP2D6*1  CYP2D6                 4
# 1                 1448999716   CYP2D6*10  CYP2D6                 4
# 2                 1448999716   CYP2D6*87  CYP2D6                 4
# 3                 1448999716   CYP2D6*88  CYP2D6                 4
# 4                 1448999716   CYP2D6*89  CYP2D6                 4
# ...                      ...         ...     ...               ...
# 1258              1451208340    CYP2D6*5  CYP2D6                 3
# 1259              1451208340    CYP2D6*6  CYP2D6                 3
# 1260              1451208340    CYP2D6*9  CYP2D6                 3
# 1261              1451207862    CYP3A5*1  CYP3A5                 3
# 1262              1451207862    CYP3A5*3  CYP3A5                 3
#
#      Clinical Annotation Types  \
# 0                Metabolism/PK
# 1                Metabolism/PK
# 2                Metabolism/PK
# 3                Metabolism/PK
# 4                Metabolism/PK
# ...                        ...
# 1258              Toxicity/ADR
# 1259              Toxicity/ADR
# 1260              Toxicity/ADR
# 1261             Metabolism/PK
# 1262             Metabolism/PK
#
#                                  Genotype-Phenotype IDs  \
# 0     1449166659;1449166660;1449166661;1449166662;14...
# 1     1449166659;1449166660;1449166661;1449166662;14...
# 2     1449166659;1449166660;1449166661;1449166662;14...
# 3     1449166659;1449166660;1449166661;1449166662;14...
# 4     1449166659;1449166660;1449166661;1449166662;14...
# ...                                                 ...
# 1258  1451208361;1451208362;1451208363;1451208364;14...
# 1259  1451208361;1451208362;1451208363;1451208364;14...
# 1260  1451208361;1451208362;1451208363;1451208364;14...
# 1261                              1451207868;1451207869
# 1262                              1451207868;1451207869
#
#                                         Annotation Text  \
# 0     *1:Patients with the CYP2D6*1 allele may have ...
# 1     *1:Patients with the CYP2D6*1 allele may have ...
# 2     *1:Patients with the CYP2D6*1 allele may have ...
# 3     *1:Patients with the CYP2D6*1 allele may have ...
# 4     *1:Patients with the CYP2D6*1 allele may have ...
# ...                                                 ...
# 1258  *1:Patients carrying the *1 allele in combinat...
# 1259  *1:Patients carrying the *1 allele in combinat...
# 1260  *1:Patients carrying the *1 allele in combinat...
# 1261  *1:Patients carrying the *1 allele in combinat...
# 1262  *1:Patients carrying the *1 allele in combinat...
#
#      Variant Annotations IDs  \
# 0                 1447959180
# 1                 1447959180
# 2                 1447959180
# 3                 1447959180
# 4                 1447959180
# ...                      ...
# 1258              1451208260
# 1259              1451208260
# 1260              1451208260
# 1261              1451207780
# 1262              1451207780
#
#                                     Variant Annotations     PMIDs  \
# 0     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 1     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 2     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 3     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 4     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# ...                                                 ...       ...
# 1258  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...  25989235
# 1259  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...  25989235
# 1260  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...  25989235
# 1261  CYP3A5 *1/*1  is associated with  decreased ex...  32564268
# 1262  CYP3A5 *1/*1  is associated with  decreased ex...  32564268
#
#       Evidence Count                          Related Chemicals  \
# 0                  1                     risperidone (PA451257)
# 1                  1                     risperidone (PA451257)
# 2                  1                     risperidone (PA451257)
# 3                  1                     risperidone (PA451257)
# 4                  1                     risperidone (PA451257)
# ...              ...                                        ...
# 1258               1  ketoprofen (PA450149);tramadol (PA451735)
# 1259               1  ketoprofen (PA450149);tramadol (PA451735)
# 1260               1  ketoprofen (PA450149);tramadol (PA451735)
# 1261               1                   Dabigatran (PA165110351)
# 1262               1                   Dabigatran (PA165110351)
#
#      Related Diseases Biogeographical Groups Chromosome
# 0                 NaN                Unknown        NaN
# 1                 NaN                Unknown        NaN
# 2                 NaN                Unknown        NaN
# 3                 NaN                Unknown        NaN
# 4                 NaN                Unknown        NaN
# ...               ...                    ...        ...
# 1258              NaN               European        NaN
# 1259              NaN               European        NaN
# 1260              NaN               European        NaN
# 1261              NaN       Mixed Population        NaN
# 1262              NaN       Mixed Population        NaN
#
# [1263 rows x 15 columns]

# %% [markdown]
# Our new DataFrame expanded to 1263 records.
#
# Now, we can check how many unique variants are there in the column `Location`.

# %%
cyps_most_common['Location'].nunique()
# Out:
# 248

# %% [markdown]
# We can do it better. We can see for each of the selected CYP gene, which are those unique variants associated with it.

# %%
for gene, gene_variant_data in cyps_most_common.groupby('Gene')['Location']:
    print('=========================')
    print(f'Gene: {gene}')
    print('=========================')
    print(gene_variant_data.unique())
# Out:
# =========================
# Gene: CYP2B6
# =========================
# ['rs3211371' 'CYP2B6*1' ' CYP2B6*5' ' CYP2B6*4' ' CYP2B6*6' ' CYP2B6*7'
#  'rs3745274' 'rs12721655' 'rs2279343' 'rs8192709' 'rs8109525' 'rs28399499'
#  'rs2279345' 'rs12721646' 'rs7254579' 'rs4802101' 'rs4803419' 'rs58425034'
#  ' CYP2B6*18' ' CYP2B6*2' ' CYP2B6*22' 'rs35303484' 'rs2054675'
#  'rs3786547' 'CYP2B6*27' ' CYP2B6*28' 'rs8192719' 'rs36118214']
# =========================
# Gene: CYP2C19
# =========================
# ['rs12248560' 'rs11188072' 'CYP2C19*1' ' CYP2C19*17' ' CYP2C19*2'
#  ' CYP2C19*3' 'rs145119820' 'rs61311738' 'rs1187513719' 'rs4244285'
#  ' CYP2C19*4' ' CYP2C19*5' ' CYP2C19*6' ' CYP2C19*8' 'rs28399504'
#  'rs11568732' 'rs4986893' 'rs144928727' ' CYP2C19*10' ' CYP2C19*11'
#  ' CYP2C19*13' ' CYP2C19*14' ' CYP2C19*15' ' CYP2C19*16' ' CYP2C19*18'
#  ' CYP2C19*19' ' CYP2C19*22' ' CYP2C19*23' ' CYP2C19*24' ' CYP2C19*25'
#  ' CYP2C19*26' ' CYP2C19*9' ' CYP2C19*7' 'rs12768009' ' CYP2C19*28'
#  'rs3814637']
# =========================
# Gene: CYP2C9
# =========================
# ['rs1057910' 'CYP2C9*1' ' CYP2C9*3' 'rs1799853' ' CYP2C9*2' 'rs1934969'
#  'rs9332096' 'rs4917639' 'rs12782374' 'rs56165452' 'rs10509680'
#  'rs7089580' 'rs9332131' 'rs28371686' 'rs28371685' 'rs4086116' 'rs9332239'
#  ' CYP2C9*13' ' CYP2C9*14' ' CYP2C9*16' ' CYP2C9*19' ' CYP2C9*27'
#  ' CYP2C9*29' ' CYP2C9*31' ' CYP2C9*33' ' CYP2C9*36' ' CYP2C9*37'
#  ' CYP2C9*39' ' CYP2C9*40' ' CYP2C9*41' ' CYP2C9*42' ' CYP2C9*43'
#  ' CYP2C9*45' ' CYP2C9*47' ' CYP2C9*49' ' CYP2C9*50' ' CYP2C9*51'
#  ' CYP2C9*52' ' CYP2C9*53' ' CYP2C9*54' ' CYP2C9*55' ' CYP2C9*56'
#  ' CYP2C9*8' 'rs71486745' ' CYP2C9*59' ' CYP2C9*6' 'rs544027339'
#  'rs1029359343' 'rs72558187' 'rs4918758' ' CYP2C9*5' 'rs7900194'
#  ' CYP2C9*11' 'rs780801862']
# =========================
# Gene: CYP2D6
# =========================
# ['CYP2D6*1' ' CYP2D6*10' ' CYP2D6*87' ' CYP2D6*88' ' CYP2D6*89'
#  ' CYP2D6*90' ' CYP2D6*91' ' CYP2D6*93' ' CYP2D6*94' ' CYP2D6*95'
#  ' CYP2D6*97' ' CYP2D6*98' 'rs5030655' ' CYP2D6*2xN' ' CYP2D6*3'
#  ' CYP2D6*4' ' CYP2D6*5' ' CYP2D6*6' 'CYP2D6*10' ' CYP2D6*2' ' CYP2D6*17'
#  ' CYP2D6*1xN' ' CYP2D6*40' ' CYP2D6*41' 'rs1080985' 'rs3892097'
#  ' CYP2D6*21' ' CYP2D6*36' 'rs1065852' ' CYP2D6*14' ' CYP2D6*24'
#  ' CYP2D6*92' ' CYP2D6*96' ' CYP2D6*114' ' CYP2D6*12' ' CYP2D6*18'
#  ' CYP2D6*22' ' CYP2D6*23' ' CYP2D6*25' ' CYP2D6*26' ' CYP2D6*27'
#  ' CYP2D6*28' ' CYP2D6*29' ' CYP2D6*30' ' CYP2D6*31' ' CYP2D6*32'
#  ' CYP2D6*33' ' CYP2D6*37' ' CYP2D6*43' ' CYP2D6*45' ' CYP2D6*46'
#  ' CYP2D6*47' ' CYP2D6*49' ' CYP2D6*50' ' CYP2D6*51' ' CYP2D6*52'
#  ' CYP2D6*54' ' CYP2D6*55' ' CYP2D6*57' ' CYP2D6*61' ' CYP2D6*62'
#  ' CYP2D6*63' ' CYP2D6*64' ' CYP2D6*65' ' CYP2D6*7' ' CYP2D6*70'
#  ' CYP2D6*71' ' CYP2D6*9' ' CYP2D6*100' ' CYP2D6*101' ' CYP2D6*13'
#  ' CYP2D6*69' ' CYP2D6*38' ' CYP2D6*15' ' CYP2D6*8' 'rs28360521'
#  'CYP2D6*20' ' CYP2D6*44' ' CYP2D6*42' ' CYP2D6*4xN' ' CYP2D6*56'
#  ' CYP2D6*11' ' CYP2D6*59' 'rs76088846' 'rs750996195' 'rs745746329'
#  'rs28371706' 'rs777560972' 'rs367543000' 'rs567606867' 'rs371793722'
#  'rs138417770' ' CYP2D6*35' ' CYP2D6*39' ' CYP2D6*48' ' CYP2D6*53'
#  ' CYP2D6*72' ' CYP2D6*75']
# =========================
# Gene: CYP3A4
# =========================
# ['rs2740574' 'rs2242480' 'rs28371759' 'CYP3A4*1' ' CYP3A4*1G' 'rs35599367'
#  ' CYP3A4*4' 'rs2246709' ' CYP3A4*1B' ' CYP3A4*18B' ' CYP3A4*20'
#  'rs12721627' 'rs4987161' 'CYP3A4*1A' ' CYP3A4*22' ' CYP3A4*3' ' CYP3A4*8'
#  'rs4646437' 'rs4986910' 'rs3735451' 'rs4646440' 'rs56324128']
# =========================
# Gene: CYP3A5
# =========================
# ['rs776746' 'CYP3A5*1' ' CYP3A5*3' 'rs10264272' 'rs41303343' ' CYP3A5*6'
#  ' CYP3A5*7' 'rs17161788' 'rs15524' 'rs4646450']

# %% [markdown]
# We can even plot the number of the unique variants for each CYP gene.
#
# For that purpose, we will create a simple bar chart.

# %%
plt.figure(figsize = (8, 6))

for gene, gene_variant_data in cyps_most_common.groupby('Gene'):
    plt.bar(gene, gene_variant_data['Location'].nunique())

plt.title('Number of unique variants per gene', fontsize = 13)
plt.ylabel('Counts', fontsize = 12)
plt.show()

# %% [markdown]
# We can see that the gene CYP2D6 has most variants associated with different drugs.
#
# Now, it is interesting to see how spread out are these CYP variants amongst the distinct racial groups.
#
# In order to find out that, we can group jointly on the columns `Gene` and `Biogeographical Groups`, and then we can use the column `Location` to perform the actual aggregation only on the unique variants for each gene, and for each racial group.
#
# Let's do that.

# %%
cyps_most_common.groupby(['Gene', 'Biogeographical Groups'], as_index = False).agg({'Location': pd.Series.nunique})
# Out:
#        Gene           Biogeographical Groups  Location
# 0    CYP2B6  African American/Afro-Caribbean         1
# 1    CYP2B6                       East Asian         7
# 2    CYP2B6                         European         7
# 3    CYP2B6                 Mixed Population        16
# 4    CYP2B6              Sub-Saharan African         2
# 5    CYP2B6                          Unknown        10
# 6   CYP2C19                       East Asian         6
# 7   CYP2C19                         European         8
# 8   CYP2C19                 Mixed Population        16
# 9   CYP2C19              Sub-Saharan African         2
# 10  CYP2C19                          Unknown        28
# 11   CYP2C9  African American/Afro-Caribbean         2
# 12   CYP2C9                       East Asian         9
# 13   CYP2C9                         European         9
# 14   CYP2C9                           Latino         4
# 15   CYP2C9                 Mixed Population        18
# 16   CYP2C9              Sub-Saharan African         1
# 17   CYP2C9                          Unknown        35
# 18   CYP2C9                         in vitro         1
# 19   CYP2D6  African American/Afro-Caribbean         8
# 20   CYP2D6              Central/South Asian         1
# 21   CYP2D6                       East Asian        11
# 22   CYP2D6                         European        17
# 23   CYP2D6                 Mixed Population        40
# 24   CYP2D6              Sub-Saharan African         1
# 25   CYP2D6                          Unknown        79
# 26   CYP3A4  African American/Afro-Caribbean         2
# 27   CYP3A4                       East Asian        10
# 28   CYP3A4                         European         8
# 29   CYP3A4                 Mixed Population        10
# 30   CYP3A4                     Near Eastern         1
# 31   CYP3A4              Sub-Saharan African         1
# 32   CYP3A4                          Unknown        10
# 33   CYP3A4                         in vitro         1
# 34   CYP3A5                       East Asian         4
# 35   CYP3A5                         European         3
# 36   CYP3A5                           Latino         1
# 37   CYP3A5                 Mixed Population         7
# 38   CYP3A5              Sub-Saharan African         3
# 39   CYP3A5                          Unknown         5

# %% [markdown]
# Since we used the parametar `as_index = False`, we obtained a nice DataFrame with three columns, insted of getting `pd.Series` with `MultiIndex`.
#
# Now, let's first save this new dataframe in a new variable.

# %%
gene_biogeo_group_association = cyps_most_common.groupby(['Gene', 'Biogeographical Groups'], as_index = False).agg({'Location': pd.Series.nunique})

# %% [markdown]
# At first glance, we can see that some of the CYP genes are poorly represented in some of the racial groups. Moreover, some of the CYP genes are not presented, at all, in other groups. We can explore that further if we use this new DataFrame and group on `Biogeographical groups` and aggregate on `Location`.

# %%
gene_biogeo_group_association.groupby('Biogeographical Groups')['Location'].size().sort_values(ascending = False)
# Out:
# Biogeographical Groups
# Unknown                            6
# Sub-Saharan African                6
# Mixed Population                   6
# European                           6
# East Asian                         6
# African American/Afro-Caribbean    4
# in vitro                           2
# Latino                             2
# Near Eastern                       1
# Central/South Asian                1
# Name: Location, dtype: int64

# %% [markdown]
# As we can see `Near Eastern` and `Central/South Asian` are presented with only one CYP gene, while `Latino` is presented with two CYP genes. On the other hand, we have `in vitro` group, which does not provide any useful information about the racial spread of the CYP genes, while the group `African American/Afro-Caribbean` is presented with four CYP genes, though each of these four genes is represented with only one or two variants. For these reasons, we will exclude all these groups that are not fully represented for each of the CYP genes of interest, and our further analysis will not rely on them.
#
# The remaining groups `East Asian`, `European`, `Mixed Population`, and `Unknown` are fully represented for each of the six CYP genes, although only `East Asian` and `European` can be seen as distinct biogeographical groups which is not very reaviling about the true spread of the varians geographically. However, that is our data and we must act in accordance with it.
#
# Now, we can filter out these fully represented groups and visualize them as a grouped bar chart.
#
# First, let's create a variable with the groups we will use to filter our `gene_biogeo_group_association` DataFrame.

# %%
biogeo_groups = 'East Asian|Europea|Mixed Population|Unknown'

# %%
# filter the biogeographical groups of interest

gene_biogeo_group_association[gene_biogeo_group_association['Biogeographical Groups'].str.contains(biogeo_groups)].reset_index(drop = True)
# Out:
#        Gene Biogeographical Groups  Location
# 0    CYP2B6             East Asian         7
# 1    CYP2B6               European         7
# 2    CYP2B6       Mixed Population        16
# 3    CYP2B6                Unknown        10
# 4   CYP2C19             East Asian         6
# 5   CYP2C19               European         8
# 6   CYP2C19       Mixed Population        16
# 7   CYP2C19                Unknown        28
# 8    CYP2C9             East Asian         9
# 9    CYP2C9               European         9
# 10   CYP2C9       Mixed Population        18
# 11   CYP2C9                Unknown        35
# 12   CYP2D6             East Asian        11
# 13   CYP2D6               European        17
# 14   CYP2D6       Mixed Population        40
# 15   CYP2D6                Unknown        79
# 16   CYP3A4             East Asian        10
# 17   CYP3A4               European         8
# 18   CYP3A4       Mixed Population        10
# 19   CYP3A4                Unknown        10
# 20   CYP3A5             East Asian         4
# 21   CYP3A5               European         3
# 22   CYP3A5       Mixed Population         7
# 23   CYP3A5                Unknown         5

# %% [markdown]
# As we can see each of the six CYP genes is associated with all four selected biogeographical groups and has intiger representing the number of unique CYP variants per each group.
#
# Now, we can save this DataFrame in a new variable.

# %%
cyps_biogeo_groups = gene_biogeo_group_association[gene_biogeo_group_association['Biogeographical Groups'].str.contains(biogeo_groups)].reset_index(drop = True)

# %% [markdown]
# Since we will display a grouped bar chart it is a good idea to take out the data for each CYP gene in separate variable. We will work more easily with them.

# %%
# assigning each CYP gene data to new variables

cyp2b6 = cyps_biogeo_groups.loc[cyps_biogeo_groups.Gene.str.contains('CYP2B6')]
cyp2c19 = cyps_biogeo_groups.loc[cyps_biogeo_groups.Gene.str.contains('CYP2C19')]
cyp2c9 = cyps_biogeo_groups.loc[cyps_biogeo_groups.Gene.str.contains('CYP2C9')]
cyp2d6 = cyps_biogeo_groups.loc[cyps_biogeo_groups.Gene.str.contains('CYP2D6')]
cyp3a4 = cyps_biogeo_groups.loc[cyps_biogeo_groups.Gene.str.contains('CYP3A4')]
cyp3a5 = cyps_biogeo_groups.loc[cyps_biogeo_groups.Gene.str.contains('CYP3A5')]

# %% [markdown]
# Now, after we got our new variables, let's display a horizontally grouped bar chart representing the biogeographical spread of the selected CYPs genes in terms of the number of variants for each gene in each biogeographical group.

# %%
# create the figure, assign a figure title
plt.figure(figsize = (11, 7.5))
figure_title = 'Comparison of the numbers of unique CYP gene variants between biogeographical groups'

# the height of the bars
height = 0.14

# set the location, width, and height of the bars
cyp2b6_plot = plt.barh(np.arange(len(cyp2b6.Location)), cyp2b6.Location, height = height, alpha = 0.9, edgecolor = 'white', label = 'CYP2B6')
cyp2c19_plot = plt.barh([p + height for p in np.arange(len(cyp2c19.Location))], cyp2c19.Location, height = height, alpha = 0.9, edgecolor = 'white', label = 'CYP2C19')
cyp2c9_plot = plt.barh([p + height * 2 for p in np.arange(len(cyp2c9.Location))], cyp2c9.Location, height = height, alpha = 0.9, edgecolor = 'white', label = 'CYP2C9')
cyp2d6_plot = plt.barh([p + height * 3 for p in np.arange(len(cyp2d6.Location))], cyp2d6.Location, height = height, alpha = 0.9, edgecolor = 'white', label = 'CYP2D6')
cyp3a4_plot = plt.barh([p + height * 4 for p in np.arange(len(cyp3a4.Location))], cyp3a4.Location, height = height, alpha = 0.9, edgecolor = 'white', label = 'CYP3A4')
cyp3a5_plot = plt.barh([p + height * 5 for p in np.arange(len(cyp3a5.Location))], cyp3a5.Location, height = height, alpha = 0.9, edgecolor = 'white', label = 'CYP3A5')

# set the arrangement of x-, and yticks
plt.xticks(np.arange(0, 101, 20), fontsize = 12)
plt.yticks([p + 2.5 * height for p in range(len(cyp2b6.Location))], (cyp2c9['Biogeographical Groups'].tolist()), fontsize = 12)

# add title, x-, and ylabels, xlim
plt.title(figure_title, fontsize = 14, pad = 16)
plt.xlabel('Count', fontsize = 13, labelpad = 10)
plt.ylabel('Biogeographical groups', fontsize = 13, labelpad = 20)
plt.xlim(0, 100)

def autolabel(cyps):
    """
    Attach a text label aside each bar in *cyps*, displaying its width.
    """
    for cyp in cyps:
        width = cyp.get_width()
        plt.text(x = cyp.get_width() + 2.5, 
                 y = cyp.get_y() + 0.5 * cyp.get_height(),
                 s = '%d' % int(width), 
                 ha = 'center', 
                 va = 'center',
                 fontsize = 10.5)
    
autolabel(cyp2b6_plot)
autolabel(cyp2c19_plot)
autolabel(cyp2c9_plot)
autolabel(cyp2d6_plot)
autolabel(cyp3a4_plot)
autolabel(cyp3a5_plot)

# display the figure
plt.legend(loc = 'best', fontsize = 12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Now, after we got visual presentation for the number of CYP variants amongst the groups, we can form a hypoteses to test if the number of different CYP variants is spread out equally in the distinct biogeographical groups (i.e., the group means are the same) or there is statistically significant difference in the spread amongst the groups.
#
# In order to find out that we will perform one-way ANOVA. The one-way ANOVA tests the null hypothesis that two or more groups have the same population mean. The test has important assumptions that must be satisfied in order for the associated p-value to be valid, such as each sample to come from normal distribution, and the population standard deviations of the groups to be equal. We do not know if these assumption are satisfied, because our data is scarce, and we do not know anything more about the populations where our samples come from. However, this must not be an issue to perform the test, although we may observe some loss of power of the associated p-value.
#
# Before we run the test, let's first compose a dictionary with keys - our selected CYP genes, and values - the number of CYP variants for each of the biogreographical groups.

# %%
gene_variant_groups = {gene: variant.tolist() for gene, variant in cyps_biogeo_groups.groupby('Gene')['Location']}

# %% [markdown]
# Let's see these key - value pairs.

# %%
gene_variant_groups
# Out:
# {'CYP2B6': [7, 7, 16, 10],
#  'CYP2C19': [6, 8, 16, 28],
#  'CYP2C9': [9, 9, 18, 35],
#  'CYP2D6': [11, 17, 40, 79],
#  'CYP3A4': [10, 8, 10, 10],
#  'CYP3A5': [4, 3, 7, 5]}

# %% [markdown]
# Now, we can run one-way ANOVA by passing the dictionary values (for the number of biogeographical spread of the CYP variants) as separate arguments to the `scipy.stats` method `f_oneway`. We will get the corresponding p-value calculated from F-statistics which works 'under the hood' of the test.
#
# Before we do that, let's first form our hypotheses.
#
# * $H_0$: CYP gene variants are equally distributed amongs the biogeographical groups (the means of the groups are equall).
# * $H_1$: CYP gene variants are not equally distributed amongs the groups. Some of the CYP genes are more spread out (have more variants) in given biogeographical group(s).
# * $\alpha_c = 0,05$

# %%
print(f'p-value:', st.f_oneway(*gene_variant_groups.values()).pvalue)
# Out:
# p-value: 0.06804418313404897

# %% [markdown]
# We got p-value - 0.068 (6.8%) which is higher than our $\alpha_c$, therefore we can not reject the null hypothesis ($H_0$) at significance level 0.05 (5%).

# %% [markdown]
# ### III. Analysis of the Drugs Associated with the Cytochrome P450 Gene Family

# %% [markdown]
# In this section, our analysis will be directed towards exploration of the drugs associated with the genetic variants of CYPs.
#
# We will begin this analysis with taking out a random sample from the column `Related Chemicals`, where are stored the drugs associated with each variant.

# %%
cyps_most_common['Related Chemicals'].sample(25)
# Out:
# 1071                            tolterodine (PA164746757)
# 1259            ketoprofen (PA450149);tramadol (PA451735)
# 770                               debrisoquine (PA452616)
# 855                                  sparteine (PA452610)
# 129                             atomoxetine (PA134688071)
# 551                                  methadone (PA450401)
# 1158                               dipyrone (PA166128206)
# 263                                mirtazapine (PA450522)
# 275                                risperidone (PA451257)
# 1081                             lornoxicam (PA165958395)
# 407                             tropisetron (PA161925594)
# 430                               cyclosporine (PA449167)
# 509                    n-desmethyltamoxifen (PA166127651)
# 640                                  donepezil (PA449394)
# 1040    bufuralol (PA166110256);dextromethorphan (PA44...
# 443     aripiprazole (PA10026);haloperidol (PA449841);...
# 1145                                 efavirenz (PA449441)
# 888                              carbamazepine (PA448785)
# 507                                 metoprolol (PA450480)
# 1128                                nimodipine (PA450633)
# 202                              nortriptyline (PA450657)
# 868                                clopidogrel (PA449053)
# 1218                                  tramadol (PA451735)
# 151                                 paroxetine (PA450801)
# 293                                aripiprazole (PA10026)
# Name: Related Chemicals, dtype: object

# %% [markdown]
# At a glimpse, this column, likewise the columns `Gene` and `Location`, holds more than one value (drug in this case) per record. Therefore, it needs to be tidied up a bit. Similarly to the columns `Gene` and `Location`, we will split up those rows which holds multiple drugs, and will make from them separate records. Subsequently, we will remove those ID numbers in the brackets.
#
# First, let's use our `explode_string` function to separate those rows that hold multiple values, and store the recieved DataFrame in a new variable.

# %%
cyps_related_chemicals = explode_string(cyps_most_common, 'Related Chemicals', ';')

# %%
cyps_related_chemicals
# Out:
#       Clinical Annotation ID    Location    Gene Level of Evidence  \
# 0                 1448999716    CYP2D6*1  CYP2D6                 4
# 1                 1448999716   CYP2D6*10  CYP2D6                 4
# 2                 1448999716   CYP2D6*87  CYP2D6                 4
# 3                 1448999716   CYP2D6*88  CYP2D6                 4
# 4                 1448999716   CYP2D6*89  CYP2D6                 4
# ...                      ...         ...     ...               ...
# 1443              1451208340    CYP2D6*6  CYP2D6                 3
# 1444              1451208340    CYP2D6*9  CYP2D6                 3
# 1445              1451208340    CYP2D6*9  CYP2D6                 3
# 1446              1451207862    CYP3A5*1  CYP3A5                 3
# 1447              1451207862    CYP3A5*3  CYP3A5                 3
#
#      Clinical Annotation Types  \
# 0                Metabolism/PK
# 1                Metabolism/PK
# 2                Metabolism/PK
# 3                Metabolism/PK
# 4                Metabolism/PK
# ...                        ...
# 1443              Toxicity/ADR
# 1444              Toxicity/ADR
# 1445              Toxicity/ADR
# 1446             Metabolism/PK
# 1447             Metabolism/PK
#
#                                  Genotype-Phenotype IDs  \
# 0     1449166659;1449166660;1449166661;1449166662;14...
# 1     1449166659;1449166660;1449166661;1449166662;14...
# 2     1449166659;1449166660;1449166661;1449166662;14...
# 3     1449166659;1449166660;1449166661;1449166662;14...
# 4     1449166659;1449166660;1449166661;1449166662;14...
# ...                                                 ...
# 1443  1451208361;1451208362;1451208363;1451208364;14...
# 1444  1451208361;1451208362;1451208363;1451208364;14...
# 1445  1451208361;1451208362;1451208363;1451208364;14...
# 1446                              1451207868;1451207869
# 1447                              1451207868;1451207869
#
#                                         Annotation Text  \
# 0     *1:Patients with the CYP2D6*1 allele may have ...
# 1     *1:Patients with the CYP2D6*1 allele may have ...
# 2     *1:Patients with the CYP2D6*1 allele may have ...
# 3     *1:Patients with the CYP2D6*1 allele may have ...
# 4     *1:Patients with the CYP2D6*1 allele may have ...
# ...                                                 ...
# 1443  *1:Patients carrying the *1 allele in combinat...
# 1444  *1:Patients carrying the *1 allele in combinat...
# 1445  *1:Patients carrying the *1 allele in combinat...
# 1446  *1:Patients carrying the *1 allele in combinat...
# 1447  *1:Patients carrying the *1 allele in combinat...
#
#      Variant Annotations IDs  \
# 0                 1447959180
# 1                 1447959180
# 2                 1447959180
# 3                 1447959180
# 4                 1447959180
# ...                      ...
# 1443              1451208260
# 1444              1451208260
# 1445              1451208260
# 1446              1451207780
# 1447              1451207780
#
#                                     Variant Annotations     PMIDs  \
# 0     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 1     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 2     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 3     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 4     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# ...                                                 ...       ...
# 1443  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...  25989235
# 1444  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...  25989235
# 1445  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...  25989235
# 1446  CYP3A5 *1/*1  is associated with  decreased ex...  32564268
# 1447  CYP3A5 *1/*1  is associated with  decreased ex...  32564268
#
#       Evidence Count         Related Chemicals Related Diseases  \
# 0                  1    risperidone (PA451257)              NaN
# 1                  1    risperidone (PA451257)              NaN
# 2                  1    risperidone (PA451257)              NaN
# 3                  1    risperidone (PA451257)              NaN
# 4                  1    risperidone (PA451257)              NaN
# ...              ...                       ...              ...
# 1443               1       tramadol (PA451735)              NaN
# 1444               1     ketoprofen (PA450149)              NaN
# 1445               1       tramadol (PA451735)              NaN
# 1446               1  Dabigatran (PA165110351)              NaN
# 1447               1  Dabigatran (PA165110351)              NaN
#
#      Biogeographical Groups Chromosome
# 0                   Unknown        NaN
# 1                   Unknown        NaN
# 2                   Unknown        NaN
# 3                   Unknown        NaN
# 4                   Unknown        NaN
# ...                     ...        ...
# 1443               European        NaN
# 1444               European        NaN
# 1445               European        NaN
# 1446       Mixed Population        NaN
# 1447       Mixed Population        NaN
#
# [1448 rows x 15 columns]

# %% [markdown]
# Now, let's strip off the ID numbers in the brackets.

# %%
cyps_related_chemicals['Related Chemicals'] = cyps_related_chemicals['Related Chemicals'].str.split(' ').str[0]

# %%
cyps_related_chemicals['Related Chemicals']
# Out:
# 0       risperidone
# 1       risperidone
# 2       risperidone
# 3       risperidone
# 4       risperidone
#            ...
# 1443       tramadol
# 1444     ketoprofen
# 1445       tramadol
# 1446     Dabigatran
# 1447     Dabigatran
# Name: Related Chemicals, Length: 1448, dtype: object

# %% [markdown]
# Our column looks much more better now.
#
# We can verify how many unique drugs are associated with the different CYP variants.

# %%
cyps_related_chemicals['Related Chemicals'].nunique()
# Out:
# 171

# %% [markdown]
# We can now group on the column `Related Chemicals` and aggregate on the column `Location` in order to see how many unique genetic variants are associated with given drug.

# %%
related_chemicals_cyp_variants = cyps_related_chemicals.groupby('Related Chemicals')['Location'].nunique()

# %%
related_chemicals_cyp_variants.sort_values(ascending = False)
# Out:
# Related Chemicals
# dextromethorphan        62
# bufuralol               46
# n-desmethyltamoxifen    42
# phenytoin               38
# clopidogrel             32
#                         ..
# erythromycin             1
# etoposide                1
# etravirine               1
# iloperidone              1
# indinavir                1
# Name: Location, Length: 171, dtype: int64

# %% [markdown]
# We can plot the count of the variants for each drug as horizontal bar chart for better presentation.

# %%
plt.figure(figsize = (8.5, 7.5))

plt.barh(related_chemicals_cyp_variants.sort_values().index[-25:], 
         related_chemicals_cyp_variants.sort_values()[-25:])

plt.title('Number of associated variants per drug', fontsize = 13)
plt.xlabel('Count')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %% [markdown]
# That plot looks nice, however, in our analysis we will not be interested in exploring the association drug - variant, but rather in exploring just the opposite - for a given genetic variant - which are those drugs linked to it.
#
# In order to find out that, we must perform the last grouping in reverse order.
#
# Let's do that.

# %%
cyps_related_chemicals.groupby('Location')['Related Chemicals'].nunique().nlargest(25)
# Out:
# Location
# CYP2D6*1       62
#  CYP2D6*4      49
#  CYP2D6*5      38
#  CYP2D6*10     36
#  CYP2D6*3      34
#  CYP2C19*2     32
# CYP2C19*1      32
#  CYP2D6*6      25
#  CYP2D6*1xN    23
#  CYP2D6*2      22
#  CYP2C19*3     21
# rs776746       21
#  CYP2C9*3      20
# CYP2C9*1       20
#  CYP3A5*3      19
# CYP3A5*1       19
#  CYP2D6*41     18
# rs2740574      17
# rs3892097      17
#  CYP2D6*2xN    16
# CYP2B6*1       14
# CYP3A4*1       14
#  CYP2B6*6      13
#  CYP2C19*17    13
#  CYP2C9*2      13
# Name: Related Chemicals, dtype: int64

# %% [markdown]
# We can see from the Series we got, which are those variants with most drugs linked to them. We can also see that some of the variants begin with white space, which is annoying, so we will strip them off.

# %%
cyps_related_chemicals['Location'] = cyps_related_chemicals['Location'].str.strip()

# %% [markdown]
# We can now do something else. We will use the column `Level of Evidence` to access those variant - drug pairs which have level of evidence '1A' or '1B'. Thus, we will filter out the variant - drug pairs with the most significant level of evidence in the literature.
#
# Let's do that filtering.

# %%
# filter variant-drug pairs with level of evince 1A and 1B and display the number of drugs per each genetic variant

cyps_related_chemicals[cyps_related_chemicals['Level of Evidence'].str.contains('1')].groupby('Location')['Related Chemicals'].nunique().nlargest(25)
# Out:
# Location
# CYP2D6*1      12
# CYP2D6*3      10
# CYP2D6*4      10
# CYP2D6*5      10
# CYP2C9*1       8
# CYP2C9*3       8
# CYP2D6*1xN     8
# CYP2D6*2xN     8
# CYP2D6*6       8
# rs3892097      8
# CYP2C9*2       7
# CYP2D6*10      7
# CYP2D6*2       7
# CYP2C19*1      6
# CYP2C19*2      6
# CYP2C19*3      6
# CYP2C19*17     4
# CYP2C19*4      3
# rs1057910      3
# CYP2C9*13      2
# CYP2D6*17      2
# CYP2D6*41      2
# rs4244285      2
# CYP2B6*1       1
# CYP2B6*6       1
# Name: Related Chemicals, dtype: int64

# %% [markdown]
# Now, let's save the filtered DataFrame in new variable.

# %%
cyps_related_chemicals_level_1 = cyps_related_chemicals[cyps_related_chemicals['Level of Evidence'].str.contains('1')].groupby('Location')

# %% [markdown]
# From now on, our analysis will be heading to accessing those drugs associated with the most numerously represented variant - CYP2D6\*1.
#
# Before we acquire these drugs, let's print all drugs associated with CYP variants which are ranked as Level 1, according to the curators of PharmGKB.

# %%
for cyp_variant, data in cyps_related_chemicals_level_1:
    print('===============================')
    print(f'Variant: {cyp_variant}')
    print('===============================')
    print(f'Related Chemicals:')
    print(data['Related Chemicals'].unique(), end = '\n\n')
# Out:
# ===============================
# Variant: CYP2B6*1
# ===============================
# Related Chemicals:
# ['efavirenz']
#
# ===============================
# Variant: CYP2B6*6
# ===============================
# Related Chemicals:
# ['efavirenz']
#
# ===============================
# Variant: CYP2C19*1
# ===============================
# Related Chemicals:
# ['clopidogrel' 'sertraline' 'citalopram' 'escitalopram' 'amitriptyline'
#  'voriconazole']
#
# ===============================
# Variant: CYP2C19*17
# ===============================
# Related Chemicals:
# ['citalopram' 'escitalopram' 'amitriptyline' 'voriconazole']
#
# ===============================
# Variant: CYP2C19*2
# ===============================
# Related Chemicals:
# ['clopidogrel' 'sertraline' 'citalopram' 'escitalopram' 'amitriptyline'
#  'voriconazole']
#
# ===============================
# Variant: CYP2C19*3
# ===============================
# Related Chemicals:
# ['clopidogrel' 'sertraline' 'citalopram' 'escitalopram' 'amitriptyline'
#  'voriconazole']
#
# ===============================
# Variant: CYP2C19*4
# ===============================
# Related Chemicals:
# ['clopidogrel' 'citalopram' 'escitalopram']
#
# ===============================
# Variant: CYP2C19*5
# ===============================
# Related Chemicals:
# ['clopidogrel']
#
# ===============================
# Variant: CYP2C19*6
# ===============================
# Related Chemicals:
# ['clopidogrel']
#
# ===============================
# Variant: CYP2C19*8
# ===============================
# Related Chemicals:
# ['clopidogrel']
#
# ===============================
# Variant: CYP2C9*1
# ===============================
# Related Chemicals:
# ['phenytoin' 'flurbiprofen' 'tenoxicam' 'piroxicam' 'lornoxicam'
#  'meloxicam' 'ibuprofen' 'warfarin']
#
# ===============================
# Variant: CYP2C9*11
# ===============================
# Related Chemicals:
# ['warfarin']
#
# ===============================
# Variant: CYP2C9*13
# ===============================
# Related Chemicals:
# ['lornoxicam' 'meloxicam']
#
# ===============================
# Variant: CYP2C9*2
# ===============================
# Related Chemicals:
# ['phenytoin' 'flurbiprofen' 'tenoxicam' 'piroxicam' 'meloxicam'
#  'ibuprofen' 'warfarin']
#
# ===============================
# Variant: CYP2C9*29
# ===============================
# Related Chemicals:
# ['flurbiprofen']
#
# ===============================
# Variant: CYP2C9*3
# ===============================
# Related Chemicals:
# ['phenytoin' 'flurbiprofen' 'tenoxicam' 'piroxicam' 'lornoxicam'
#  'meloxicam' 'ibuprofen' 'warfarin']
#
# ===============================
# Variant: CYP2C9*5
# ===============================
# Related Chemicals:
# ['warfarin']
#
# ===============================
# Variant: CYP2C9*6
# ===============================
# Related Chemicals:
# ['warfarin']
#
# ===============================
# Variant: CYP2D6*1
# ===============================
# Related Chemicals:
# ['fluvoxamine' 'codeine' 'amitriptyline' 'atomoxetine' 'doxepin'
#  'paroxetine' 'trimipramine' 'nortriptyline' 'ondansetron' 'tropisetron'
#  'clomipramine' 'tramadol']
#
# ===============================
# Variant: CYP2D6*10
# ===============================
# Related Chemicals:
# ['fluvoxamine' 'codeine' 'amitriptyline' 'atomoxetine' 'paroxetine'
#  'nortriptyline' 'tramadol']
#
# ===============================
# Variant: CYP2D6*17
# ===============================
# Related Chemicals:
# ['codeine' 'tramadol']
#
# ===============================
# Variant: CYP2D6*1xN
# ===============================
# Related Chemicals:
# ['codeine' 'amitriptyline' 'doxepin' 'paroxetine' 'nortriptyline'
#  'ondansetron' 'tropisetron' 'clomipramine']
#
# ===============================
# Variant: CYP2D6*2
# ===============================
# Related Chemicals:
# ['codeine' 'amitriptyline' 'atomoxetine' 'doxepin' 'paroxetine'
#  'nortriptyline' 'clomipramine']
#
# ===============================
# Variant: CYP2D6*2xN
# ===============================
# Related Chemicals:
# ['codeine' 'amitriptyline' 'doxepin' 'paroxetine' 'trimipramine'
#  'nortriptyline' 'tropisetron' 'clomipramine']
#
# ===============================
# Variant: CYP2D6*3
# ===============================
# Related Chemicals:
# ['fluvoxamine' 'codeine' 'amitriptyline' 'atomoxetine' 'doxepin'
#  'paroxetine' 'trimipramine' 'nortriptyline' 'clomipramine' 'tramadol']
#
# ===============================
# Variant: CYP2D6*4
# ===============================
# Related Chemicals:
# ['fluvoxamine' 'codeine' 'amitriptyline' 'atomoxetine' 'doxepin'
#  'paroxetine' 'trimipramine' 'nortriptyline' 'clomipramine' 'tramadol']
#
# ===============================
# Variant: CYP2D6*40
# ===============================
# Related Chemicals:
# ['codeine']
#
# ===============================
# Variant: CYP2D6*41
# ===============================
# Related Chemicals:
# ['codeine' 'amitriptyline']
#
# ===============================
# Variant: CYP2D6*5
# ===============================
# Related Chemicals:
# ['fluvoxamine' 'codeine' 'amitriptyline' 'atomoxetine' 'doxepin'
#  'paroxetine' 'trimipramine' 'nortriptyline' 'clomipramine' 'tramadol']
#
# ===============================
# Variant: CYP2D6*6
# ===============================
# Related Chemicals:
# ['fluvoxamine' 'codeine' 'amitriptyline' 'paroxetine' 'trimipramine'
#  'nortriptyline' 'clomipramine' 'tramadol']
#
# ===============================
# Variant: CYP3A5*1
# ===============================
# Related Chemicals:
# ['tacrolimus']
#
# ===============================
# Variant: CYP3A5*3
# ===============================
# Related Chemicals:
# ['tacrolimus']
#
# ===============================
# Variant: CYP3A5*6
# ===============================
# Related Chemicals:
# ['tacrolimus']
#
# ===============================
# Variant: CYP3A5*7
# ===============================
# Related Chemicals:
# ['tacrolimus']
#
# ===============================
# Variant: rs1057910
# ===============================
# Related Chemicals:
# ['phenytoin' 'warfarin' 'celecoxib']
#
# ===============================
# Variant: rs12248560
# ===============================
# Related Chemicals:
# ['clopidogrel']
#
# ===============================
# Variant: rs1799853
# ===============================
# Related Chemicals:
# ['warfarin']
#
# ===============================
# Variant: rs28371685
# ===============================
# Related Chemicals:
# ['warfarin']
#
# ===============================
# Variant: rs28371686
# ===============================
# Related Chemicals:
# ['warfarin']
#
# ===============================
# Variant: rs28399499
# ===============================
# Related Chemicals:
# ['efavirenz']
#
# ===============================
# Variant: rs28399504
# ===============================
# Related Chemicals:
# ['clopidogrel']
#
# ===============================
# Variant: rs3745274
# ===============================
# Related Chemicals:
# ['efavirenz']
#
# ===============================
# Variant: rs3892097
# ===============================
# Related Chemicals:
# ['amitriptyline' 'antidepressants' 'clomipramine' 'desipramine' 'doxepin'
#  'imipramine' 'nortriptyline' 'trimipramine']
#
# ===============================
# Variant: rs4244285
# ===============================
# Related Chemicals:
# ['amitriptyline' 'clopidogrel']
#
# ===============================
# Variant: rs4986893
# ===============================
# Related Chemicals:
# ['clopidogrel']
#
# ===============================
# Variant: rs7900194
# ===============================
# Related Chemicals:
# ['warfarin']
#
# ===============================
# Variant: rs9332131
# ===============================
# Related Chemicals:
# ['warfarin']

# %% [markdown]
# Now, let's access the drugs associated with CYP2D6\*1.
#
# For that purpose, we will create an empty list and will iterate over our grouped obeject - `cyps_related_chemicals_level_1` to access and extract the drugs linked to CYP2D6\*1.

# %%
related_chemicals = []

for cyp_variant, data in cyps_related_chemicals_level_1:
    if cyp_variant == 'CYP2D6*1':
        related_chemicals.append(data['Related Chemicals'].unique())

# %% [markdown]
# Let's see what we got.

# %%
related_chemicals
# Out:
# [array(['fluvoxamine', 'codeine', 'amitriptyline', 'atomoxetine',
#         'doxepin', 'paroxetine', 'trimipramine', 'nortriptyline',
#         'ondansetron', 'tropisetron', 'clomipramine', 'tramadol'],
#        dtype=object)]

# %% [markdown]
# It seems that everything is all right, however, if we think a little about what we did, we will realize that we created a empty list, then we iterated over our grouped object and appended a whole list of related drugs to our empty list, so we basically got a list of list.
#
# Our aim from now on will be to make a named `pd.Series` object, which we will use to join to other dataset, from which we will evaluate the adverse reactions of the drugs associated with CYP2D6\*1.
#
# In order to do that, we first have to flatten our variable `related_chemicals`. We can do that in two ways. In the much more complicated way we may iterate in a nested for loop throughout the variable in order to access and extract the drugs and make a `pd.Series` from them. In the much easier way, we may just pick up the first element, and use it to create a `pd.Series`.
#
# Let's do this the easy way.

# %%
cyp2d6_related_chemicals = pd.Series(related_chemicals[0], name = 'CYP2D6*1')

# %%
cyp2d6_related_chemicals
# Out:
# 0       fluvoxamine
# 1           codeine
# 2     amitriptyline
# 3       atomoxetine
# 4           doxepin
# 5        paroxetine
# 6      trimipramine
# 7     nortriptyline
# 8       ondansetron
# 9       tropisetron
# 10     clomipramine
# 11         tramadol
# Name: CYP2D6*1, dtype: object

# %% [markdown]
# As we mentioned, we will use this named Series object to join to other dataset.
#
# This new dataset holds infromation about the adverse drug reactions of thousand of drugs.
#
# The dataset is retrieved from related projects to PharmGKB and it is stored in the Stanford digital repository.
#
# Let's now read this dataset.

# %%
off_sides = pd.read_table('Data/3003377s-offsides.tsv')

# %%
off_sides
# Out:
#            stitch_id                    drug   umls_id  \
# 0       CID000000076  dehydroepiandrosterone  C0000737
# 1       CID000000076  dehydroepiandrosterone  C0001622
# 2       CID000000076  dehydroepiandrosterone  C0001623
# 3       CID000000076  dehydroepiandrosterone  C0002792
# 4       CID000000076  dehydroepiandrosterone  C0002940
# ...              ...                     ...       ...
# 438796  CID011980859       bleomycin sulfate  C1869066
# 438797  CID011980859       bleomycin sulfate  C2242529
# 438798  CID011980859       bleomycin sulfate  C2363744
# 438799  CID011980859       bleomycin sulfate  C2363799
# 438800  CID011980859       bleomycin sulfate  C2363825
#
#                                                     event         rr  \
# 0                                          abdominal pain   2.250000
# 1                                         hyperadrenalism  11.000000
# 2                                   adrenal insufficiency   2.200000
# 3                                   anaphylactic reaction   2.588235
# 4                                                aneurysm   7.333333
# ...                                                   ...        ...
# 438796                                 hypovolaemic shock   5.076923
# 438797                               stem cell transplant   4.400000
# 438798  epstein-barr virus associated lymphoproliferat...   3.000000
# 438799                         oxygen saturation abnormal   7.333333
# 438800                                    lymphadenectomy   5.500000
#
#           log2rr  t_statistic        pvalue  observed  expected  \
# 0       1.169925     6.537095  6.156712e-07         9  4.000000
# 1       3.459432     4.782699  1.644408e-03         2  0.181818
# 2       1.137504     4.315199  9.884952e-03         2  0.909091
# 3       1.371969     4.590918  3.355380e-03         4  1.545455
# 4       2.874469     4.598374  3.399457e-03         2  0.272727
# ...          ...          ...           ...       ...       ...
# 438796  2.343954     6.976299  1.337393e-07         6  1.181818
# 438797  2.137504    11.800431  3.370766e-18        16  3.636364
# 438798  1.584963     4.665783  3.752785e-03         3  1.000000
# 438799  2.874469     5.551510  9.547621e-05         2  0.272727
# 438800  2.459432     6.413229  1.894213e-06         4  0.727273
#
#         bg_correction  sider  future_aers  medeffect
# 0            0.002849      0            0          0
# 1            0.000041      0            0          0
# 2            0.002491      0            0          0
# 3            0.000503      0            0          0
# 4            0.000135      0            0          0
# ...               ...    ...          ...        ...
# 438796       0.000338      0            0          0
# 438797       0.001934      0            0          0
# 438798       0.000629      0            0          0
# 438799       0.000037      0            0          0
# 438800       0.000192      0            0          0
#
# [438801 rows x 14 columns]

# %% [markdown]
# First, we can verify the dimensionality of our new DataFrame.

# %%
off_sides.shape
# Out:
# (438801, 14)

# %% [markdown]
# Now, let's see the dtypes of the columns.

# %%
off_sides.dtypes
# Out:
# stitch_id         object
# drug              object
# umls_id           object
# event             object
# rr               float64
# log2rr           float64
# t_statistic      float64
# pvalue           float64
# observed           int64
# expected         float64
# bg_correction    float64
# sider              int64
# future_aers        int64
# medeffect          int64
# dtype: object

# %% [markdown]
# From this dataset we will use the column `drug` to merge and, at the same time, to filter the dataset with our CYP2D6\*1 associated drugs. Subsequently, we will use the column `rr` to evaluate the relative risk of the adverse events associated with each drug.
#
# Before we do that, let's check out how many unique drugs are listed in this dataset.

# %%
off_sides['drug'].nunique()
# Out:
# 1332

# %% [markdown]
# This dataset holds information about the adverse reactions for 1332 drugs, which is slightly above the half of all approved small molecule drugs (2637).
#
# Now, let's do the merge.

# %%
# merge sorted Series object with off_sides DataFrame

cyp2d6_drugs_off_sides = pd.merge(left = cyp2d6_related_chemicals.sort_values(), 
                                  right = off_sides, 
                                  left_on = 'CYP2D6*1', 
                                  right_on = 'drug', 
                                  how = 'left')

# %%
cyp2d6_drugs_off_sides
# Out:
#            CYP2D6*1     stitch_id           drug   umls_id  \
# 0     amitriptyline  CID000002160  amitriptyline  C0000735
# 1     amitriptyline  CID000002160  amitriptyline  C0000737
# 2     amitriptyline  CID000002160  amitriptyline  C0000833
# 3     amitriptyline  CID000002160  amitriptyline  C0001261
# 4     amitriptyline  CID000002160  amitriptyline  C0001418
# ...             ...           ...            ...       ...
# 6358    tropisetron  CID000005595    tropisetron  C1621958
# 6359    tropisetron  CID000005595    tropisetron  C1869066
# 6360    tropisetron  CID000005595    tropisetron  C1963916
# 6361    tropisetron  CID000005595    tropisetron  C2242544
# 6362    tropisetron  CID000005595    tropisetron  C2609419
#
#                                         event         rr    log2rr  \
# 0                          abdominal neoplasm  11.000000  3.459432
# 1                              abdominal pain   1.833333  0.874469
# 2                                     abscess   3.333333  1.736966
# 3                               actinomycosis   4.583333  2.196397
# 4                              adenocarcinoma   2.693878  1.429684
# ...                                       ...        ...       ...
# 6358                  glioblastoma multiforme   2.750000  1.459432
# 6359                       hypovolaemic shock   5.500000  2.459432
# 6360                         neuropathic pain  11.000000  3.459432
# 6361  congenital tricuspid valve incompetence   2.933333  1.552541
# 6362                   bronchoalveolar lavage   5.076923  2.343954
#
#       t_statistic        pvalue  observed   expected  bg_correction  sider  \
# 0        5.088161  1.317479e-03         2   0.181818       0.000096      0
# 1       10.385167  4.839023e-15        37  20.181818       0.000862      0
# 2        8.213117  4.727203e-10        10   3.000000       0.000191      0
# 3        5.582193  1.514727e-04         5   1.090909       0.000272      0
# 4        7.073039  1.355906e-07        12   4.454545       0.005190      0
# ...           ...           ...       ...        ...            ...    ...
# 6358     4.561288  3.853288e-03         4   1.454545       0.001671      0
# 6359     5.260516  2.226400e-04         4   0.727273       0.000371      0
# 6360     5.795204  2.271312e-05         3   0.272727       0.000081      0
# 6361     4.119299  2.097746e-02         4   1.363636       0.000136      0
# 6362     7.715834  2.434348e-09         6   1.181818       0.000864      0
#
#       future_aers  medeffect
# 0               0          0
# 1               1          1
# 2               0          0
# 3               0          0
# 4               0          0
# ...           ...        ...
# 6358            0          0
# 6359            0          0
# 6360            0          0
# 6361            0          0
# 6362            0          0
#
# [6363 rows x 15 columns]

# %% [markdown]
# First, we can see that we reduced the number of rows from 438801, initially, to 6363 after the merging.
#
# Now, as we will use the column `rr` to evaluate the relative risk for all adverse reactions associated with each CYP2D6\*1 associated drug, we can explore more thoroughly this column as displaying descriptive statistics for the values stored in it.

# %%
cyp2d6_drugs_off_sides[['rr']].describe()
# Out:
#                 rr
# count  6363.000000
# mean      6.219879
# std       3.356025
# min       0.018108
# 25%       3.000000
# 50%       6.000000
# 75%       9.166667
# max      11.000000

# %% [markdown]
# We can see that the rr-values range in the interval 0.02 to 11 with a mean around 6.
#
# But what does that rr mean?
#
# $rr$ stands for relative risk or risk ration and it is used in the statistical analysis of data collected from randomized  controlled  trials (RCTs), cohort studies, or case-control studies to estimate the strength of the association between treatments (or risk factors), and outcomes. It represent the ratio of the probability of an outcome to be expressed in an exposed group to the probability of an outcome to be expressed in an unexposed group. In simple words, $rr$ measures the association between the exposure and the outcome. It is computed as $I_e / I_u$, where $I_e$ is the incidence in the exposed group, and $I_u$ is the incidence in the unexposed group. $rr$ is almost invariably expressed as a ratio to denominator 1 rather than as a percentage.
#
# Values of $rr$ can be interpreted as follows:
#
# * $rr$ = 1 means that exposure does not affect the outcome
#
# * $rr$ < 1 means that the risk of the outcome is decreased by the exposure
#
# * $rr$ > 1 means that the risk of the outcome is increased by the exposure
#
# Let's provide for example hypothetical RCT in which 76 depressed patients were randomly assigned to receive either  venlafaxine (n = 40) or placebo (n = 36) for 8 weeks. During the trial, new-onset sexual dysfunction was identified in 8 patients treated with venlafaxine and in 3 patients treated with placebo. In order to assess the relative risk, we first have to assess the absolute risk of the event. The  absolute  risk  of  an  event  is  estimated  as  the  number  of  individuals  who  actually  experience  the  event  divided  by  the  total number of individuals exposed to the risk of that event. This figure is usually expressed as a percentage. In our example, because 40 patients took venlafaxine and because 8 of them developed sexual dysfunction, the absolute risk of sexual dysfunction with venlafaxine is 8/40, or 20.0%. Similarly, the absolute risk of developing sexual dysfunction with placebo is 3/36, or 8.3%. We can now calculate the relative risk by simply dividing 20/8.3 which is equal to 2.40.
#
# Now, after we got an idea what is $rr$, we can plot histograms using these values in order to find out their respective distributions for each drug. Generally, the column `log2rr` it could also be used, because it stores a logarithm to the base 2 of the $rr$ values. However, there is no significant difference in the distributions, as excluding the scale, so we will stick to `rr`.
#
# Before plotting the histograms, let's see how many associated adverse reactions are there for each drug.

# %%
cyp2d6_drugs_off_sides.groupby('drug')['rr'].size()
# Out:
# drug
# amitriptyline     535
# atomoxetine       651
# clomipramine      418
# codeine           616
# doxepin           882
# fluvoxamine       304
# nortriptyline    1111
# ondansetron       371
# paroxetine        689
# tramadol          425
# trimipramine      214
# tropisetron       147
# Name: rr, dtype: int64

# %% [markdown]
# We can see that the number of adverse reaction for each drug is different. We will plot histograms for each drug using all values (we will not subsample them), however, we will 'hardcore' the y-axis to some constant to make the scale equal for each plot in order to get better visual presentation for the distributions (and the unequal sample sizes) of the drugs. In addition, we will print the skewness for each distribution because all of them are asymmetrical.
#
# Let's do these plots.

# %%
for drug, drug_data in cyp2d6_drugs_off_sides.groupby('drug'):
    plt.hist(drug_data['rr'], bins = 40, alpha = 0.9)
    plt.axvline(drug_data['rr'].mean(), c = 'y')
    plt.title(f'Distribution of {drug}\'s rr-values', fontsize = 13)
    plt.ylim(0, 70)
    plt.xlim(0, 10.5)
    plt.xlabel('$rr$-values')
    plt.ylabel('Frequency')
    plt.show()
    print(f'The skewness of the distribution of {drug}:', st.skew(drug_data['rr']))
# Out:
# The skewness of the distribution of amitriptyline: 0.9731476571555219
# The skewness of the distribution of atomoxetine: 0.026408867303526352
# The skewness of the distribution of clomipramine: -0.2156616258763904
# The skewness of the distribution of codeine: -0.08822413939641047
# The skewness of the distribution of doxepin: -0.544624559571815
# The skewness of the distribution of fluvoxamine: 0.5562778576447736
# The skewness of the distribution of nortriptyline: -0.3198670116717572
# The skewness of the distribution of ondansetron: 1.1012939654037304
# The skewness of the distribution of paroxetine: 0.8639784912001205
# The skewness of the distribution of tramadol: 0.6615557268103734
# The skewness of the distribution of trimipramine: 0.7539854420839388
# The skewness of the distribution of tropisetron: 0.913339101493153

# %% [markdown]
# Looking at these plots, we can not find some central tendency or something resembling a Gaussian distribution. The shape of the most ditributions is asymmetrical with moderate to high skewness. Only for those distributions with skewness value between -0.5 and 0.5 we can say that they are simetrical (nortriptyline, codeine, atomoxetine, and clomipramine).
#
# Interestingly, many distributions have the most values in the bins scoping the interval from 10 to 11. As we already explained, the rr-values represent the probability of occurance of adverse drug reaction, where higher values indicate greatter probability of observing the reaction. Therefore, we may conclude that in these bins are placed the most characteristic adverse drug reactions for each drug. It is interesting to be seen which are these characteristic drug reaction, however, before we do that let's do another plot, this time box plot, since this is the other way do display the distributions of continuous variables. We can show the distributions on one plot, which in our case with 12 distributions is easier for interpretation.
#
# Let's make this plot.

# %%
# specifies the style of the fliers
green_diamond = dict(markerfacecolor = 'y', marker='D')

# set the labels
labels = [drug_name for drug_name, _ in cyp2d6_drugs_off_sides.groupby('drug')]

plt.figure(figsize = (10, 7.5))
plt.boxplot([drug_data['rr'] for _, drug_data in cyp2d6_drugs_off_sides.groupby('drug')],
            flierprops = green_diamond)

plt.title('Distribution of the rr-values per drug', fontsize = 13, pad = 16)
plt.xticks(np.arange(1, 13, step = 1), labels = labels, rotation = 40, fontsize = 12)
plt.show()

# %% [markdown]
# Now, as we said, we may display all those characteristic adverse reactions for each drug.

# %%
for drug, drug_data in cyp2d6_drugs_off_sides[cyp2d6_drugs_off_sides['rr'] >= 10].groupby('drug'):
    print('========================================================')
    print(drug)
    print('========================================================')
    print(drug_data['event'])
# Out:
# ========================================================
# amitriptyline
# ========================================================
# 0                  abdominal neoplasm
# 5                 adjustment disorder
# 43     central venous catheterisation
# 84                       episcleritis
# 89                   felty's syndrome
#                     ...
# 488            infusion site bruising
# 490                infusion site rash
# 497      cardiovascular insufficiency
# 501       bowel movement irregularity
# 522            injection site dryness
# Name: event, Length: 63, dtype: object
# ========================================================
# atomoxetine
# ========================================================
# 537                          abdominal mass
# 540                           adenoidectomy
# 541                                 adenoma
# 557             beckwith-wiedemann syndrome
# 559                              human bite
#                        ...
# 1170                           renal injury
# 1174    aspartate aminotransferase abnormal
# 1177              psychiatric investigation
# 1180                         vascular graft
# 1184               cholestatic liver injury
# Name: event, Length: 218, dtype: object
# ========================================================
# clomipramine
# ========================================================
# 1186                  habitual abortion
# 1187                         acanthosis
# 1190                             mutism
# 1197                       appendectomy
# 1201              bacteroides infection
#                      ...
# 1590             mechanical ventilation
# 1595    dopamine dysregulation syndrome
# 1598               anorectal discomfort
# 1599                 hypotonia neonatal
# 1600         oxygen saturation abnormal
# Name: event, Length: 140, dtype: object
# ========================================================
# codeine
# ========================================================
# 1605                      achlorhydria
# 1607            renal tubular acidosis
# 1608           acinetobacter infection
# 1610               allergic alveolitis
# 1621               Arthritis infective
#                      ...
# 2199                device dislocation
# 2206         cd4 lymphocytes increased
# 2207             pleural decortication
# 2213    haemorrhagic erosive gastritis
# 2215                     social phobia
# Name: event, Length: 191, dtype: object
# ========================================================
# doxepin
# ========================================================
# 2226         adjustment disorder
# 2227                 agoraphobia
# 2229       respiratory alkalosis
# 2249     benign colonic neoplasm
# 2251                 bereavement
#                   ...
# 3085    superinfection bacterial
# 3092            vasoconstriction
# 3095       pulmonary air leakage
# 3097             lymphadenectomy
# 3098            optic neuropathy
# Name: event, Length: 237, dtype: object
# ========================================================
# fluvoxamine
# ========================================================
# 3126                              corneal abrasion
# 3140                                  epiglottitis
# 3141                              Erythema nodosum
# 3159                           hyperparathyroidism
# 3178                            Aseptic meningitis
# 3182                                    calcinosis
# 3196                            pseudobulbar palsy
# 3202                  schizophrenia, paranoid type
# 3222                           skin depigmentation
# 3232                                  macrocytosis
# 3233                               hyperchloraemia
# 3234                                      marasmus
# 3237                       atrophic vulvovaginitis
# 3241                   encephalopathy hypertensive
# 3243                               kidney fibrosis
# 3246            high density lipoprotein decreased
# 3253                     parathyroid tumour benign
# 3257                             aspiration breast
# 3259                             limb malformation
# 3265                     pupillary reflex impaired
# 3277                          duodenal perforation
# 3280                                 skin swelling
# 3281                pregnancy induced hypertension
# 3283                              breast haematoma
# 3300                 drug interaction potentiation
# 3309                     neutrophil count abnormal
# 3310                       basophil count abnormal
# 3312                        breast disorder female
# 3315                        oesophageal dilatation
# 3318                               pharyngeal mass
# 3319                              subdural hygroma
# 3324                   biopsy lymph gland abnormal
# 3331                       intentional self-injury
# 3332                         renal tubular atrophy
# 3334                           urine sodium normal
# 3335                     eosinophil count abnormal
# 3341              prothrombin time ratio decreased
# 3342          blood alkaline phosphatase decreased
# 3344                bilirubin conjugated increased
# 3351                       endometrial hypertrophy
# 3352                          oestradiol decreased
# 3360                        infusion site erythema
# 3369                            bile duct stenosis
# 3372                        infusion site swelling
# 3374          red cell distribution width abnormal
# 3375                            blood ph increased
# 3376                        carotid pulse abnormal
# 3377                     post procedural bile leak
# 3380                     abdominal cavity drainage
# 3383    antipsychotic drug level above therapeutic
# 3384    antipsychotic drug level below therapeutic
# 3391                            biopsy endometrium
# 3400              gastrointestinal sounds abnormal
# Name: event, dtype: object
# ========================================================
# nortriptyline
# ========================================================
# 3409                 apert's syndrome
# 3410                       Acromegaly
# 3420                              als
# 3426         coarctation of the aorta
# 3430                       apicectomy
#                     ...
# 4506               hypotonia neonatal
# 4508    acquired protein s deficiency
# 4512                 optic neuropathy
# 4513                 breast operation
# 4514            spinal cord operation
# Name: event, Length: 248, dtype: object
# ========================================================
# ondansetron
# ========================================================
# 4549                                       adhesiolysis
# 4590                               enteritis infectious
# 4647                                metastases to ovary
# 4684                                   hypermagnesaemia
# 4695                                  vitreous disorder
# 4696                              subacute endocarditis
# 4707                               eye muscle operation
# 4722                                          adnexitis
# 4727                        chronic respiratory failure
# 4728                           subendocardial ischaemia
# 4732                       mesenteric artery thrombosis
# 4735                                     metamorphopsia
# 4741                             pneumothorax traumatic
# 4747                             vascular calcification
# 4748                            capillary leak syndrome
# 4749                                      legal problem
# 4751                                      wound abscess
# 4752                                      masked facies
# 4761                    gastroenteritis cryptosporidial
# 4763                              implant site reaction
# 4781                            opportunistic infection
# 4782                                 submandibular mass
# 4797                        pulmonary vascular disorder
# 4802                                      sleep attacks
# 4815                                    peritonsillitis
# 4816                                 blood homocysteine
# 4817                   postoperative wound complication
# 4818                                      wound closure
# 4824                                 intestinal fistula
# 4828                             vascular insufficiency
# 4834                                 catheter site pain
# 4835                             infusion site swelling
# 4838                             enterobacter pneumonia
# 4839           alpha haemolytic streptococcal infection
# 4841                              vulvovaginal pruritus
# 4843                            vocal cord inflammation
# 4854             urinary tract infection staphylococcal
# 4858                               catheter bacteraemia
# 4860                     incisional hernia, obstructive
# 4865    labelled drug-drug interaction medication error
# 4873                          cd8 lymphocytes decreased
# 4876                                  procedural nausea
# 4877                                procedural vomiting
# 4878                                        muscle mass
# 4880                                 hyperosmolar state
# 4883                                       drug therapy
# Name: event, dtype: object
# ========================================================
# paroxetine
# ========================================================
# 4891    multiple congenital abnormalities
# 4940                       cerebral palsy
# 4972              intervertebral discitis
# 4986        oedema due to cardiac disease
# 4997                 female sterilisation
#                       ...
# 5548                               anoxia
# 5552                     device occlusion
# 5563                      elbow operation
# 5564               mechanical ventilation
# 5569            quality of life decreased
# Name: event, Length: 87, dtype: object
# ========================================================
# tramadol
# ========================================================
# 5598                 cerebral atherosclerosis
# 5610                              acne cystic
# 5618                          senile dementia
# 5637                            epicondylitis
# 5685                 mucopolysaccharidosis ii
# 5686                        myasthenia gravis
# 5692                                neoplasia
# 5757                            vulval oedema
# 5774                    soft tissue infection
# 5778       central nervous system stimulation
# 5801                                frostbite
# 5806                         tendon operation
# 5807                   tendon sheath incision
# 5810                                 dandruff
# 5819              alcohol withdrawal syndrome
# 5823                             ovarian mass
# 5827                          vulval erythema
# 5832                                  xerosis
# 5840                         reflux gastritis
# 5843                           radicular pain
# 5844                  adenocarcinoma pancreas
# 5847              pancreatic duct obstruction
# 5848     metastases to gastrointestinal tract
# 5849                           ilium fracture
# 5852                hepatic artery thrombosis
# 5855                       gingival operation
# 5862                      blood urea abnormal
# 5864                 pain threshold decreased
# 5868                  varicose vein operation
# 5874                             oral surgery
# 5877                           skin fragility
# 5884                    fracture displacement
# 5885                         accident at work
# 5897                     diagnostic procedure
# 5906                     blood thromboplastin
# 5909              blood aldosterone increased
# 5911                      somatoform disorder
# 5917                         blood creatinine
# 5925    coagulation factor ix level decreased
# 5936                     stomatocytes present
# 5938                       bursitis infective
# 5942                                 subileus
# 5943               mitral valve calcification
# 5952                        candida pneumonia
# 5953                                apheresis
# 5968                    bone callus excessive
# 5970                        adnexa uteri mass
# 5972               pacemaker generated rhythm
# 5975                   post procedural nausea
# 5976                            mass excision
# 5977                          wound treatment
# 5984                               onychalgia
# 5986                calcific deposits removal
# 5992                      procedural vomiting
# 5993                         cytotoxic oedema
# 5997                         neuropathic pain
# Name: event, dtype: object
# ========================================================
# trimipramine
# ========================================================
# 6016                                        brain abscess
# 6017                                              bulimia
# 6022                                    brain compression
# 6033                            electroconvulsive therapy
# 6034                                        enterocolitis
# 6041                        internal fixation of fracture
# 6042                                           hemiplegia
# 6045                                  portal hypertension
# 6054                                 meningeal irritation
# 6055                                   mental retardation
# 6063                                       pneumoconiosis
# 6066                                                  PMs
# 6097                                      Benign Neoplasm
# 6099                                        toe deformity
# 6114                           cerebral venous thrombosis
# 6127                                             hyposmia
# 6128                                    oculogyric crisis
# 6134                                            grimacing
# 6136                                   pulmonary necrosis
# 6141                                             lividity
# 6142                              capillary leak syndrome
# 6147                             neonatal cardiac failure
# 6148                                 neonatal hypotension
# 6168                                  somatoform disorder
# 6169                   high density lipoprotein increased
# 6175    mental disorder due to a general medical condi...
# 6179                               renal failure neonatal
# 6180          antidepressant drug level above therapeutic
# 6184                                  nail bed tenderness
# 6186                                 post procedural pain
# 6192         electrocardiogram repolarisation abnormality
# 6193                         cardiac stress test abnormal
# 6194                                 sleep study abnormal
# 6195                                           gaze palsy
# 6199           antipsychotic drug level above therapeutic
# 6200                        ischaemic cerebral infarction
# 6206                           cystic fibrosis pancreatic
# 6207                                           onychalgia
# Name: event, dtype: object
# ========================================================
# tropisetron
# ========================================================
# 6228                  Cholangitis sclerosing
# 6233                           tooth deposit
# 6244                  angle closure glaucoma
# 6263                              amyotrophy
# 6275                                priapism
# 6280                         endotoxic shock
# 6283    staphylococcal scalded skin syndrome
# 6308                serum ferritin increased
# 6309                         nikolsky's sign
# 6312                    autonomic neuropathy
# 6315                       axonal neuropathy
# 6326      gamma-glutamyltransferase abnormal
# 6327                             fat atrophy
# 6332                       arterial disorder
# 6338                     peripheral embolism
# 6345                hepatic artery occlusion
# 6348                    cytomegalovirus test
# 6352                              troponin t
# 6355                  perinephric collection
# 6357                       dilatation atrial
# 6360                        neuropathic pain
# Name: event, dtype: object

# %% [markdown]
# We can now direct towards testing some hypotheses about the distibutions of our drugs. However, before we do that, let's explore more closely what types of drugs we have deal with.
#
# In our list of 12 drugs, 7 of them are classified as tricyclic antidepressants (amitriptyline, atomoxetine, clomipramine, doxepin, nortriptyline, paroxetine, trimipramine). Fluvoxamine belongs to the group of the selective serotonin reuptake inhibitors (SSRI), which are more modern class of antidepressants with fewer adverse drug reactions, which can also be seen from the data we have. Both codeine and tramadol belong to the group of opioid analgesics and are used to treat moderate to moderately severe pain. The last two drugs - ondansetron and tropisetron belong to the group of the so called setrons or 5-HT$_3$ antagonists. These are a class of drugs that act as antiemetics, and are considered the gold standard in controlling the nausea and vomiting produced by cancer chemotherapy.
#
# To sum up, we have 3 classes of drugs - antidepressants, opiod analgestics, and setrons. All of them have continuous distribution of the dependant variable - `rr`. Therefore, we may use independant samples $t$ test to compare the means of the drugs in each of these 3 classes.
#
# An independant samples $t$ test is a statistical hypothesis test that is used to analyze two samples means. The null hypothesis ($H_0$) and alternative hypothesis ($H_1$) of the test can be expressed as follows:
#
# * $H_0$: µ1 = µ2 - the two population means are equal
#
# * $H_1$: µ1 ≠ µ2 - the two population means are not equal
#
# Since we have 3 classes, we will approach the testing as follows:
#
# First, we will draw out the rr-values for each drug from the setrons and opioid classes in separate variables.
#
# Next, we will compare the means of the samples in every class. For the classes of the setrons and opioid analgestics that will be easy as there are only two drugs in each class. For the antidepressants class we will use a for loop to iterate over the drugs, and will test each drug to each other in the class.
#
# Let's walk through this.
#
# First, we will define a function that extracts the rr-values.

# %%
def extract_rr(dataframe, drug):
    """
    Extract the rr-values for a drug. 
    """
    drug_column = 'drug'
    rr_column = 'rr'
    rr_values = [rr_value for rr_value, _ in dataframe[dataframe[drug_column] == drug].groupby(rr_column)]
    
    return rr_values

# %% [markdown]
# We can now use this function to extract the rr-values for tropisetron and ondansetron.

# %%
tropisetron = extract_rr(cyp2d6_drugs_off_sides, 'tropisetron')
ondansetron = extract_rr(cyp2d6_drugs_off_sides, 'ondansetron')

# %% [markdown]
# Now, we can use the `scipy.stats` method `ttest_ind` to test if the means of the setrons - tropisetron and ondansetrons are equal ($H_0$) or not ($H_1$).
#
# * $\alpha_c$ = 0,05

# %%
print(f'p-value:', st.ttest_ind(tropisetron, ondansetron).pvalue)
# Out:
# p-value: 0.021191854545595183

# %% [markdown]
# We got p-value - 0.021 (2.1%) which is lower than our $\alpha_c$, therefore we can reject the null hypothesis ($H_0$) at significance level 0.05 (5%).
#
# Now, let's test the opioid class.
#
# First, we must take out the values for codeine and tramadol, repectively.

# %%
codeine = extract_rr(cyp2d6_drugs_off_sides, 'codeine')
tramadol = extract_rr(cyp2d6_drugs_off_sides, 'tramadol')

# %% [markdown]
# Our hypotheses are the same for the opioid class. $\alpha_c$ = 0,05

# %%
print(f'p-value:', st.ttest_ind(codeine, tramadol).pvalue)
# Out:
# p-value: 3.8495082084287395e-23

# %% [markdown]
# The p-value we got is far below our $\alpha_c$, so we can reject the null hypothesis ($H_0$) at significance level 0.05 (5%).
#
# Now, for the antidepressants class we will approach the testing similarly as we did with the ANOVA test. First, we will create a dictionary with the rr-values of each antidepressant, then as we said we will iterate over the the drugs (the keys of the dictionary) and will test each drug to each other.
#
# Hypotheses - $H_0$: the two population means are equal, $H_1$: the two population means are not equal. $\alpha_c$ = 0,05.

# %%
antidepressants = ['amitriptyline', 'atomoxetine', 'clomipramine', 'doxepin',
                   'fluvoxamine', 'nortriptyline', 'paroxetine', 'trimipramine']

# %%
antidepressants_rr = {drug: drug_data['rr'].tolist() for drug, drug_data in cyp2d6_drugs_off_sides.groupby('drug') \
                      if drug in antidepressants}

# %%
for drug_one in antidepressants_rr.keys():
    for drug_two in antidepressants_rr.keys():
        print(f'{drug_one} vs. {drug_two}:', st.ttest_ind(antidepressants_rr[drug_one], antidepressants_rr[drug_two]).pvalue)
# Out:
# amitriptyline vs. amitriptyline: 1.0
# amitriptyline vs. atomoxetine: 3.2668060023441185e-16
# amitriptyline vs. clomipramine: 2.48402641102786e-26
# amitriptyline vs. doxepin: 1.2545101523859028e-65
# amitriptyline vs. fluvoxamine: 0.00020107266320709444
# amitriptyline vs. nortriptyline: 7.427907242407256e-35
# amitriptyline vs. paroxetine: 0.08845557026727853
# amitriptyline vs. trimipramine: 0.0453813342841976
# atomoxetine vs. amitriptyline: 3.2668060023441185e-16
# atomoxetine vs. atomoxetine: 1.0
# atomoxetine vs. clomipramine: 0.009708678810274091
# atomoxetine vs. doxepin: 2.79580947074336e-11
# atomoxetine vs. fluvoxamine: 0.0007758570734328315
# atomoxetine vs. nortriptyline: 0.01857271597381732
# atomoxetine vs. paroxetine: 1.7613855828591648e-13
# atomoxetine vs. trimipramine: 5.2946268484779416e-05
# clomipramine vs. amitriptyline: 2.48402641102786e-26
# clomipramine vs. atomoxetine: 0.009708678810274091
# clomipramine vs. clomipramine: 1.0
# clomipramine vs. doxepin: 0.0030574140966364276
# clomipramine vs. fluvoxamine: 1.4862699610285522e-08
# clomipramine vs. nortriptyline: 0.29186885989753464
# clomipramine vs. paroxetine: 2.6715388536276685e-23
# clomipramine vs. trimipramine: 7.271143800155249e-10
# doxepin vs. amitriptyline: 1.2545101523859028e-65
# doxepin vs. atomoxetine: 2.79580947074336e-11
# doxepin vs. clomipramine: 0.0030574140966364276
# doxepin vs. doxepin: 1.0
# doxepin vs. fluvoxamine: 6.2772708442601125e-24
# doxepin vs. nortriptyline: 9.579458854184395e-08
# doxepin vs. paroxetine: 4.176812617111562e-62
# doxepin vs. trimipramine: 5.3117978508066035e-25
# fluvoxamine vs. amitriptyline: 0.00020107266320709444
# fluvoxamine vs. atomoxetine: 0.0007758570734328315
# fluvoxamine vs. clomipramine: 1.4862699610285522e-08
# fluvoxamine vs. doxepin: 6.2772708442601125e-24
# fluvoxamine vs. fluvoxamine: 1.0
# fluvoxamine vs. nortriptyline: 1.936180552790462e-09
# fluvoxamine vs. paroxetine: 0.011413662470913282
# fluvoxamine vs. trimipramine: 0.2561819149983931
# nortriptyline vs. amitriptyline: 7.427907242407256e-35
# nortriptyline vs. atomoxetine: 0.01857271597381732
# nortriptyline vs. clomipramine: 0.29186885989753464
# nortriptyline vs. doxepin: 9.579458854184395e-08
# nortriptyline vs. fluvoxamine: 1.936180552790462e-09
# nortriptyline vs. nortriptyline: 1.0
# nortriptyline vs. paroxetine: 3.122617330906231e-31
# nortriptyline vs. trimipramine: 5.805653146894483e-11
# paroxetine vs. amitriptyline: 0.08845557026727853
# paroxetine vs. atomoxetine: 1.7613855828591648e-13
# paroxetine vs. clomipramine: 2.6715388536276685e-23
# paroxetine vs. doxepin: 4.176812617111562e-62
# paroxetine vs. fluvoxamine: 0.011413662470913282
# paroxetine vs. nortriptyline: 3.122617330906231e-31
# paroxetine vs. paroxetine: 1.0
# paroxetine vs. trimipramine: 0.3926541559505651
# trimipramine vs. amitriptyline: 0.0453813342841976
# trimipramine vs. atomoxetine: 5.2946268484779416e-05
# trimipramine vs. clomipramine: 7.271143800155249e-10
# trimipramine vs. doxepin: 5.3117978508066035e-25
# trimipramine vs. fluvoxamine: 0.2561819149983931
# trimipramine vs. nortriptyline: 5.805653146894483e-11
# trimipramine vs. paroxetine: 0.3926541559505651
# trimipramine vs. trimipramine: 1.0

# %% [markdown]
# As we got many p-values we will not interpret all of them, we will only say that there are some that are below our $\alpha_c$, hence we can reject the null hypothesis for them at significance level 0.05 (5%).

# %% [markdown]
# ### IV.  TF-IDF Analysis of the Cytochrome P450 Associated Clinical Phenotypes

# %% [markdown]
# So far in this project we have dealt with exploratary data analysis coupled with hypotheses testing. In this section, we will deviate from this approach and will focus more on text analysis. For that purpose we will use one particular numerical statistics named ___tf-idf___. The term _tf-idf_ stands for _term frequency-inverse document frequency_. This is a technique intended to reflect how import a word is to a document in a collection of documents called text corpus. It is often used as a weighting factor in searches of information retrieval and text mining. The goal of using _tf-idf_ is to scale down the impact of words (terms) that occur very frequently in a given corpus and that are hence empirically less informative than terms that occur in a small fraction of the corpus.
#
# In our case the corpus will be the clinical phenotypes of all pharmacogenes deposited in PharmGKB. These phenotypes are housed in separate dataset available through the PharmGKB website.
#
# In a nutshell, our work from now on will be related with loading that dataset, accessing the clinical phenotypes associated with the Cytochrome P450 genes, extracting all other phenotypes, scoring the realative importance of the words in CYPs associated phenotypes and the rest of phenotypes using _tf-idf_ , and comparing these scores to find out those words that are unique for the CYPs associated phenotypes.
#
# After we pictured our successive work, let's start out with reading this clinical phenotypes' dataset.

# %%
clinical_phenotypes = pd.read_table('Data/clinical_ann.tsv')

# %%
clinical_phenotypes
# Out:
#        Genotype-Phenotype ID Genotype  \
# 0                 1447963976       CC
# 1                 1447963993       AA
# 2                 1448106268       AA
# 3                 1449170173       AA
# 4                 1450823787       AA
# ...                      ...      ...
# 14139             1451218400       *2
# 14140             1451218401       *3
# 14141             1451218263       *1
# 14142             1451218264       *3
# 14143             1451218265      *13
#
#                                       Clinical Phenotype
# 0      Patients with genotype CC may have decreased l...
# 1      Male patients with the AA genotype and specifi...
# 2      Patients with the AA genotype and multiple scl...
# 3      Patients with the AA genotype and who are trea...
# 4      Patients with the AA genotype may be at an inc...
# ...                                                  ...
# 14139  Patients carrying the *2 allele in combination...
# 14140  Patients carrying the *3 allele in combination...
# 14141  Patients carrying the *1 allele in combination...
# 14142  Patients carrying the *3 allele in combination...
# 14143  Patients carrying the *13 allele in combinatio...
#
# [14144 rows x 3 columns]

# %% [markdown]
# As we can see this dataset contains 3 columns, the first of which holds unique ID number for each genotype - phenotype association. The second column is the very genotype, while in the third column is housed the phenotype information for each genotype.
#
# Now, we have to access the phenotypes information for the CYP genes. We can do that by using the variable `cyps` where are stored the genotype - phenotype ID numbers for each CYP gene.
#
# Let's recall what holds this variable.

# %%
cyps
# Out:
#       Clinical Annotation ID  \
# 7                 1448999716
# 39                1449718265
# 49                 981238437
# 72                1449718242
# 82                1449005041
# ...                      ...
# 4667              1451161878
# 4671              1451163460
# 4677              1451208240
# 4679              1451208340
# 4680              1451207862
#
#                                                Location     Gene  \
# 7     CYP2D6*1, CYP2D6*10, CYP2D6*87, CYP2D6*88, CYP...   CYP2D6
# 39                                           rs12248560  CYP2C19
# 49                                            rs1057910   CYP2C9
# 72                                            rs1056836   CYP1B1
# 82                                             rs776746    CYP3A
# ...                                                 ...      ...
# 4667                                 CYP2B6*1, CYP2B6*6   CYP2B6
# 4671           CYP2A6*17, CYP2A6*1A, CYP2A6*2, CYP2A6*9   CYP2A6
# 4677                                CYP2D6*1, CYP2D6*10   CYP2D6
# 4679  CYP2D6*1, CYP2D6*10, CYP2D6*17, CYP2D6*2, CYP2...   CYP2D6
# 4680                                 CYP3A5*1, CYP3A5*3   CYP3A5
#
#      Level of Evidence Clinical Annotation Types  \
# 7                    4             Metabolism/PK
# 39                   3              Toxicity/ADR
# 49                  2A              Toxicity/ADR
# 72                   3              Toxicity/ADR
# 82                   3             Metabolism/PK
# ...                ...                       ...
# 4667                 4                    Dosage
# 4671                 3             Metabolism/PK
# 4677                 3                    Dosage
# 4679                 3              Toxicity/ADR
# 4680                 3             Metabolism/PK
#
#                                  Genotype-Phenotype IDs  \
# 7     1449166659;1449166660;1449166661;1449166662;14...
# 39                     1449718267;1449718268;1449718269
# 49                        981238438;981238439;981238440
# 72                     1449718244;1449718245;1449718246
# 82                     1449005043;1449005044;1449005045
# ...                                                 ...
# 4667                              1451161920;1451161921
# 4671        1451163462;1451163463;1451163464;1451163465
# 4677                              1451208242;1451208243
# 4679  1451208361;1451208362;1451208363;1451208364;14...
# 4680                              1451207868;1451207869
#
#                                         Annotation Text  \
# 7     *1:Patients with the CYP2D6*1 allele may have ...
# 39    CC:Patients with the CC genotype and breast ca...
# 49    AA:Patients with the AA genotype who are treat...
# 72    CC:Patients with the CC genotype and breast ca...
# 82    CC:Pregnant patients infected with malaria and...
# ...                                                 ...
# 4667  *1:Patients with opioid dependence and carryin...
# 4671  *1A:Patients with two copies of the *1A allele...
# 4677  *1:Patients carrying the *1 allele in combinat...
# 4679  *1:Patients carrying the *1 allele in combinat...
# 4680  *1:Patients carrying the *1 allele in combinat...
#
#      Variant Annotations IDs  \
# 7                 1447959180
# 39                1449718012
# 49       827826832;827826844
# 72                1449718142
# 82     1449003493;1449003659
# ...                      ...
# 4667              1451161493
# 4671   1449576398;1451162952
# 4677              1451208192
# 4679              1451208260
# 4680              1451207780
#
#                                     Variant Annotations              PMIDs  \
# 7     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...           26544071
# 39    Genotype CC  is associated with  increased ris...           29507678
# 49    Allele C  is associated with  increased risk o...  14707031;17681167
# 72    Genotype CC  is associated with  increased ris...           29507678
# 82    Allele C  is associated with  increased concen...           28673292
# ...                                                 ...                ...
# 4667  CYP2B6 *6/*6  is associated with  decreased do...           21589866
# 4671  CYP2A6 *17  is not associated with  clearance ...  27417511;30706508
# 4677  CYP2D6 *10/*10  is associated with  increased ...           25825958
# 4679  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...           25989235
# 4680  CYP3A5 *1/*1  is associated with  decreased ex...           32564268
#
#       Evidence Count                                  Related Chemicals  \
# 7                  1                             risperidone (PA451257)
# 39                 1  cyclophosphamide (PA449165);doxorubicin (PA449...
# 49                 2  Antiinflammatory agents, non-steroids (PA16471...
# 72                 1  cyclophosphamide (PA449165);doxorubicin (PA449...
# 82                 2                         lumefantrine (PA165111722)
# ...              ...                                                ...
# 4667               1                               methadone (PA450401)
# 4671               2                           metronidazole (PA450484)
# 4677               1                                fentanyl (PA449599)
# 4679               1          ketoprofen (PA450149);tramadol (PA451735)
# 4680               1                           Dabigatran (PA165110351)
#
#                          Related Diseases Biogeographical Groups Chromosome
# 7                                     NaN                Unknown        NaN
# 39            Breast Neoplasms (PA443560)                Unknown      chr10
# 49                                    NaN                Unknown      chr10
# 72            Breast Neoplasms (PA443560)                Unknown       chr2
# 82                     Malaria (PA444859)    Sub-Saharan African       chr7
# ...                                   ...                    ...        ...
# 4667  Opioid-Related Disorders (PA445043)               European        NaN
# 4671                                  NaN       Mixed Population        NaN
# 4677                                  NaN                Unknown        NaN
# 4679                                  NaN               European        NaN
# 4680                                  NaN       Mixed Population        NaN
#
# [612 rows x 15 columns]

# %% [markdown]
# The unique ID numbers are stored in the column `Genotype-Phenotype IDs`. As we can see this column houses information about multiple CYP variants (genotypes) in its records, so we will have to split these values as separate rows.
#
# Let's use the `explode_string` function to do that.

# %%
explode_string(cyps, 'Genotype-Phenotype IDs', ';')
# Out:
#       Clinical Annotation ID  \
# 0                 1448999716
# 1                 1448999716
# 2                 1448999716
# 3                 1448999716
# 4                 1448999716
# ...                      ...
# 2344              1451208340
# 2345              1451208340
# 2346              1451208340
# 2347              1451207862
# 2348              1451207862
#
#                                                Location    Gene  \
# 0     CYP2D6*1, CYP2D6*10, CYP2D6*87, CYP2D6*88, CYP...  CYP2D6
# 1     CYP2D6*1, CYP2D6*10, CYP2D6*87, CYP2D6*88, CYP...  CYP2D6
# 2     CYP2D6*1, CYP2D6*10, CYP2D6*87, CYP2D6*88, CYP...  CYP2D6
# 3     CYP2D6*1, CYP2D6*10, CYP2D6*87, CYP2D6*88, CYP...  CYP2D6
# 4     CYP2D6*1, CYP2D6*10, CYP2D6*87, CYP2D6*88, CYP...  CYP2D6
# ...                                                 ...     ...
# 2344  CYP2D6*1, CYP2D6*10, CYP2D6*17, CYP2D6*2, CYP2...  CYP2D6
# 2345  CYP2D6*1, CYP2D6*10, CYP2D6*17, CYP2D6*2, CYP2...  CYP2D6
# 2346  CYP2D6*1, CYP2D6*10, CYP2D6*17, CYP2D6*2, CYP2...  CYP2D6
# 2347                                 CYP3A5*1, CYP3A5*3  CYP3A5
# 2348                                 CYP3A5*1, CYP3A5*3  CYP3A5
#
#      Level of Evidence Clinical Annotation Types Genotype-Phenotype IDs  \
# 0                    4             Metabolism/PK             1449166659
# 1                    4             Metabolism/PK             1449166660
# 2                    4             Metabolism/PK             1449166661
# 3                    4             Metabolism/PK             1449166662
# 4                    4             Metabolism/PK             1449166663
# ...                ...                       ...                    ...
# 2344                 3              Toxicity/ADR             1451208368
# 2345                 3              Toxicity/ADR             1451208369
# 2346                 3              Toxicity/ADR             1451208370
# 2347                 3             Metabolism/PK             1451207868
# 2348                 3             Metabolism/PK             1451207869
#
#                                         Annotation Text  \
# 0     *1:Patients with the CYP2D6*1 allele may have ...
# 1     *1:Patients with the CYP2D6*1 allele may have ...
# 2     *1:Patients with the CYP2D6*1 allele may have ...
# 3     *1:Patients with the CYP2D6*1 allele may have ...
# 4     *1:Patients with the CYP2D6*1 allele may have ...
# ...                                                 ...
# 2344  *1:Patients carrying the *1 allele in combinat...
# 2345  *1:Patients carrying the *1 allele in combinat...
# 2346  *1:Patients carrying the *1 allele in combinat...
# 2347  *1:Patients carrying the *1 allele in combinat...
# 2348  *1:Patients carrying the *1 allele in combinat...
#
#      Variant Annotations IDs  \
# 0                 1447959180
# 1                 1447959180
# 2                 1447959180
# 3                 1447959180
# 4                 1447959180
# ...                      ...
# 2344              1451208260
# 2345              1451208260
# 2346              1451208260
# 2347              1451207780
# 2348              1451207780
#
#                                     Variant Annotations     PMIDs  \
# 0     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 1     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 2     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 3     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# 4     CYP2D6 *2 + *10 + *87 + *88 + *89 + *90 + *91 ...  26544071
# ...                                                 ...       ...
# 2344  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...  25989235
# 2345  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...  25989235
# 2346  CYP2D6 *1/*3 + *1/*4 + *1/*5 + *1/*6 + *4/*41 ...  25989235
# 2347  CYP3A5 *1/*1  is associated with  decreased ex...  32564268
# 2348  CYP3A5 *1/*1  is associated with  decreased ex...  32564268
#
#       Evidence Count                          Related Chemicals  \
# 0                  1                     risperidone (PA451257)
# 1                  1                     risperidone (PA451257)
# 2                  1                     risperidone (PA451257)
# 3                  1                     risperidone (PA451257)
# 4                  1                     risperidone (PA451257)
# ...              ...                                        ...
# 2344               1  ketoprofen (PA450149);tramadol (PA451735)
# 2345               1  ketoprofen (PA450149);tramadol (PA451735)
# 2346               1  ketoprofen (PA450149);tramadol (PA451735)
# 2347               1                   Dabigatran (PA165110351)
# 2348               1                   Dabigatran (PA165110351)
#
#      Related Diseases Biogeographical Groups Chromosome
# 0                 NaN                Unknown        NaN
# 1                 NaN                Unknown        NaN
# 2                 NaN                Unknown        NaN
# 3                 NaN                Unknown        NaN
# 4                 NaN                Unknown        NaN
# ...               ...                    ...        ...
# 2344              NaN               European        NaN
# 2345              NaN               European        NaN
# 2346              NaN               European        NaN
# 2347              NaN       Mixed Population        NaN
# 2348              NaN       Mixed Population        NaN
#
# [2349 rows x 15 columns]

# %% [markdown]
# Now, let's save the resulting DataFrame in a new variable.

# %%
cyps_clinical_phenotypes = explode_string(cyps, 'Genotype-Phenotype IDs', ';')

# %% [markdown]
# If we verify the dtype of the new column `Genotype-Phenotype IDs` it will be dtype object, since in the original dataset there was stored information about multiple genotype - phenotype IDs.
#
# We will use this column to merge to the `clinical_phenotypes` dataset, to select the phenotype information about the CYPs. In order to do that, we first have to cast the dtype of the column `Genotype-Phenotype IDs` to intiger.
#
# But first, let's verify the dtype of the original column.

# %%
cyps_clinical_phenotypes['Genotype-Phenotype IDs']
# Out:
# 0       1449166659
# 1       1449166660
# 2       1449166661
# 3       1449166662
# 4       1449166663
#            ...
# 2344    1451208368
# 2345    1451208369
# 2346    1451208370
# 2347    1451207868
# 2348    1451207869
# Name: Genotype-Phenotype IDs, Length: 2349, dtype: object

# %% [markdown]
# dtype: object.
#
# Let's now do the casting.

# %%
cyps_clinical_phenotypes['Genotype-Phenotype IDs'] = cyps_clinical_phenotypes['Genotype-Phenotype IDs'].astype(int)

# %% [markdown]
# Now, we can do the merging.

# %%
# merge the `clinical_phenotypes` dataset with the selected CYPs on the specified columns

merged_cyps_clinical_phenotypes = pd.merge(clinical_phenotypes, cyps_clinical_phenotypes, 
         left_on = 'Genotype-Phenotype ID', 
         right_on = 'Genotype-Phenotype IDs',
         how = 'inner')

# %% [markdown]
# Since we aim to access the information concerning CYPs phenotypes which is stored in our new merged dataset - `merged_cyps_clinical_phenotypes` in the column `Clinical Phenotype`, we will save that column in a new variable, which we will use later to extract the unique words for the CYPs phenotypes.

# %%
cyps_phenotypes = merged_cyps_clinical_phenotypes['Clinical Phenotype']

# %%
cyps_phenotypes
# Out:
# 0       Patients with the GG genotype may have increas...
# 1       Patients with the GG genotype may have increas...
# 2       Patients with the CC genotype may have decreas...
# 3       Patients with the CT genotype may have decreas...
# 4       Patients with the TT genotype may have increas...
#                               ...
# 2344    Patients carrying the *2 allele in combination...
# 2345    Patients carrying the *3 allele in combination...
# 2346    Patients carrying the *1 allele in combination...
# 2347    Patients carrying the *3 allele in combination...
# 2348    Patients carrying the *13 allele in combinatio...
# Name: Clinical Phenotype, Length: 2349, dtype: object

# %% [markdown]
# 2349 records related to distinct CYP genotypes (variants).
#
# Now, it is a good idea to clarify something important about the phenotype annotations. First, they are mannualy created from the PharmGKB curators; and second, they represent concise, structered text for the clinical annotation of the given genotype. This means that the annotations are very similar to each other in terms of text (words used).
#
# But, let's not being wordy and prove the validity of this by taking out 2 annotations and look at their lexical set of words.

# %%
cyps_phenotypes[2]
# Out:
# 'Patients with the CC genotype may have decreased but not non-existent risk for osteonecrosis of the jaw in response to bisphosphonates as compared to patients with the TT genotype. Other genetic and clinical factors may also influence adverse responses to bisphosphonates.'

# %%
cyps_phenotypes[4]
# Out:
# 'Patients with the TT genotype may have increased risk for osteonecrosis of the jaw in response to bisphosphonates as compared to patients with the CC or CT genotype. Other genetic and clinical factors may also influence adverse responses to bisphosphonates.'

# %% [markdown]
# As we can see both annotations are with very close set of words. That means that there are words that are characteristics for each annotation. In fact, our aim in this sections is to explore exactly this. Which are those words that are specific for the CYPs phenotypes, and are not present in the rest of the annotations.
#
# Now, we will focus on extracting these words; first - associated with CYPs phenotypes; and second - associated with the rest of the annotations.
#
# In order to do that, we will have to define a function that perform this task. This finction will accept as a parametar
# `pd.Series`, and will return all words from that Series. This function will also filter out all semantically meaningless 'stop words'.
#
# Let's define that function.

# %%
def extract_words(pd_series):
    """
    Extract all words from a pd.Series object.
    """
    # extract all strings from pd.Series object 
    all_words = [word for word in ' '.join(pd_series.str.lower().tolist()).split() if word.isalpha()]
    
    # assign stopwords
    stop_words = set(stopwords.words('english'))
    
    # remove stopwords 
    list_of_words = [word for word in all_words if word not in stop_words]
    
    return list_of_words

# %% [markdown]
# Now, after we obtained our function, let's use it to get all words for the CYPs annotations.

# %%
words_cyps = extract_words(cyps_phenotypes)

# %%
words_cyps[:100]
# Out:
# ['patients',
#  'gg',
#  'genotype',
#  'may',
#  'increased',
#  'metabolism',
#  'paclitaxel',
#  'compared',
#  'patients',
#  'cc',
#  'cg',
#  'genetic',
#  'clinical',
#  'factors',
#  'may',
#  'also',
#  'influence',
#  'paclitaxel',
#  'patients',
#  'gg',
#  'genotype',
#  'may',
#  'increased',
#  'metabolism',
#  'paclitaxel',
#  'compared',
#  'patients',
#  'cc',
#  'cg',
#  'genetic',
#  'clinical',
#  'factors',
#  'may',
#  'also',
#  'influence',
#  'paclitaxel',
#  'patients',
#  'cc',
#  'genotype',
#  'may',
#  'decreased',
#  'risk',
#  'osteonecrosis',
#  'jaw',
#  'response',
#  'bisphosphonates',
#  'compared',
#  'patients',
#  'tt',
#  'genetic',
#  'clinical',
#  'factors',
#  'may',
#  'also',
#  'influence',
#  'adverse',
#  'responses',
#  'patients',
#  'ct',
#  'genotype',
#  'may',
#  'decreased',
#  'risk',
#  'osteonecrosis',
#  'jaw',
#  'response',
#  'bisphosphonates',
#  'compared',
#  'patients',
#  'tt',
#  'genetic',
#  'clinical',
#  'factors',
#  'may',
#  'also',
#  'influence',
#  'adverse',
#  'responses',
#  'patients',
#  'tt',
#  'genotype',
#  'may',
#  'increased',
#  'risk',
#  'osteonecrosis',
#  'jaw',
#  'response',
#  'bisphosphonates',
#  'compared',
#  'patients',
#  'cc',
#  'ct',
#  'genetic',
#  'clinical',
#  'factors',
#  'may',
#  'also',
#  'influence',
#  'adverse',
#  'responses']

# %%
len(words_cyps)
# Out:
# 59467

# %% [markdown]
# We can see which are the words for the CYPs, and how many they are.
#
# The next step is to extract the words associated with the rest of the annotations.
#
# This will be a litle bit tricky exercise, because we have already assigned a bunch of variables, and now we will have to reassign some of them to fulfill this our intention. With so many variables, we can easily get entangled, however we are detirmined to do that.
#
# In short, we will have to use the CYPs filtered DataFrame - `merged_cyps_clinical_phenotypes`, and to set the column `Genotype-Phenotype ID` as the index of the DataFrame, since later on we will use these indices to filter out the `clinical_phenotypes` dataset, in order to exclude all records related to CYPs genotypes.
#
# Let's see this sequence of steps in action.
#
# First, let's set the `Genotype-Phenotype ID` as our index column.

# %%
merged_cyps_clinical_phenotypes.set_index('Genotype-Phenotype ID', inplace = True)

# %% [markdown]
# We can now convince that the column `Genotype-Phenotype ID` is our index column.

# %%
merged_cyps_clinical_phenotypes
# Out:
#                       Genotype  \
# Genotype-Phenotype ID
# 655384596                   GG
# 655384596                   GG
# 655384601                   CC
# 655384600                   CT
# 655384599                   TT
# ...                        ...
# 1451218400                  *2
# 1451218401                  *3
# 1451218263                  *1
# 1451218264                  *3
# 1451218265                 *13
#
#                                                       Clinical Phenotype  \
# Genotype-Phenotype ID
# 655384596              Patients with the GG genotype may have increas...
# 655384596              Patients with the GG genotype may have increas...
# 655384601              Patients with the CC genotype may have decreas...
# 655384600              Patients with the CT genotype may have decreas...
# 655384599              Patients with the TT genotype may have increas...
# ...                                                                  ...
# 1451218400             Patients carrying the *2 allele in combination...
# 1451218401             Patients carrying the *3 allele in combination...
# 1451218263             Patients carrying the *1 allele in combination...
# 1451218264             Patients carrying the *3 allele in combination...
# 1451218265             Patients carrying the *13 allele in combinatio...
#
#                        Clinical Annotation ID                       Location  \
# Genotype-Phenotype ID
# 655384596                           655384592                     rs12721627
# 655384596                           655384592                     rs12721627
# 655384601                           655384597                      rs1934951
# 655384600                           655384597                      rs1934951
# 655384599                           655384597                      rs1934951
# ...                                       ...                            ...
# 1451218400                         1451092460   CYP2C9*1, CYP2C9*2, CYP2C9*3
# 1451218401                         1451092460   CYP2C9*1, CYP2C9*2, CYP2C9*3
# 1451218263                         1183703296  CYP2C9*1, CYP2C9*13, CYP2C9*3
# 1451218264                         1183703296  CYP2C9*1, CYP2C9*13, CYP2C9*3
# 1451218265                         1183703296  CYP2C9*1, CYP2C9*13, CYP2C9*3
#
#                          Gene Level of Evidence Clinical Annotation Types  \
# Genotype-Phenotype ID
# 655384596               CYP3A                 3                    Dosage
# 655384596              CYP3A4                 3                    Dosage
# 655384601              CYP2C8                 3              Toxicity/ADR
# 655384600              CYP2C8                 3              Toxicity/ADR
# 655384599              CYP2C8                 3              Toxicity/ADR
# ...                       ...               ...                       ...
# 1451218400             CYP2C9                1A             Metabolism/PK
# 1451218401             CYP2C9                1A             Metabolism/PK
# 1451218263             CYP2C9                1A             Metabolism/PK
# 1451218264             CYP2C9                1A             Metabolism/PK
# 1451218265             CYP2C9                1A             Metabolism/PK
#
#                        Genotype-Phenotype IDs  \
# Genotype-Phenotype ID
# 655384596                           655384596
# 655384596                           655384596
# 655384601                           655384601
# 655384600                           655384600
# 655384599                           655384599
# ...                                       ...
# 1451218400                         1451218400
# 1451218401                         1451218401
# 1451218263                         1451218263
# 1451218264                         1451218264
# 1451218265                         1451218265
#
#                                                          Annotation Text  \
# Genotype-Phenotype ID
# 655384596              CC:Patients with the CC genotype may have decr...
# 655384596              CC:Patients with the CC genotype may have decr...
# 655384601              CC:Patients with the CC genotype may have decr...
# 655384600              CC:Patients with the CC genotype may have decr...
# 655384599              CC:Patients with the CC genotype may have decr...
# ...                                                                  ...
# 1451218400             *1:Patients carrying the *1 allele in combinat...
# 1451218401             *1:Patients carrying the *1 allele in combinat...
# 1451218263             *1:Patients carrying the *1 allele in combinat...
# 1451218264             *1:Patients carrying the *1 allele in combinat...
# 1451218265             *1:Patients carrying the *1 allele in combinat...
#
#                                                  Variant Annotations IDs  \
# Genotype-Phenotype ID
# 655384596                                                      655387863
# 655384596                                                      655387863
# 655384601                                            699638940;827863672
# 655384600                                            699638940;827863672
# 655384599                                            699638940;827863672
# ...                                                                  ...
# 1451218400                              1183702710;1183702721;1183702730
# 1451218401                              1183702710;1183702721;1183702730
# 1451218263             1183703229;1183703238;1183703250;1183703257;11...
# 1451218264             1183703229;1183703238;1183703250;1183703257;11...
# 1451218265             1183703229;1183703238;1183703250;1183703257;11...
#
#                                                      Variant Annotations  \
# Genotype-Phenotype ID
# 655384596              Allele C  is associated with  decreased metabo...
# 655384596              Allele C  is associated with  decreased metabo...
# 655384601              Genotype TT  is associated with  increased ris...
# 655384600              Genotype TT  is associated with  increased ris...
# 655384599              Genotype TT  is associated with  increased ris...
# ...                                                                  ...
# 1451218400             CYP2C9 *3  is associated with  increased AUC a...
# 1451218401             CYP2C9 *3  is associated with  increased AUC a...
# 1451218263             CYP2C9 *1/*3  is associated with  decreased me...
# 1451218264             CYP2C9 *1/*3  is associated with  decreased me...
# 1451218265             CYP2C9 *1/*3  is associated with  decreased me...
#
#                                    PMIDs  Evidence Count  \
# Genotype-Phenotype ID
# 655384596                       16890579               1
# 655384596                       16890579               1
# 655384601              18594024;21151627               2
# 655384600              18594024;21151627               2
# 655384599              18594024;21151627               2
# ...                                  ...             ...
# 1451218400             15229460;18992346               3
# 1451218401             15229460;18992346               3
# 1451218263             15764711;16182270               5
# 1451218264             15764711;16182270               5
# 1451218265             15764711;16182270               5
#
#                                                        Related Chemicals  \
# Genotype-Phenotype ID
# 655384596                                          paclitaxel (PA450761)
# 655384596                                          paclitaxel (PA450761)
# 655384601              Bisphosphonates (PA164712563);pamidronate (PA4...
# 655384600              Bisphosphonates (PA164712563);pamidronate (PA4...
# 655384599              Bisphosphonates (PA164712563);pamidronate (PA4...
# ...                                                                  ...
# 1451218400                                       tenoxicam (PA131890625)
# 1451218401                                       tenoxicam (PA131890625)
# 1451218263                                      lornoxicam (PA165958395)
# 1451218264                                      lornoxicam (PA165958395)
# 1451218265                                      lornoxicam (PA165958395)
#
#                                                         Related Diseases  \
# Genotype-Phenotype ID
# 655384596              Carcinoma, Non-Small-Cell Lung (PA443622);Neop...
# 655384596              Carcinoma, Non-Small-Cell Lung (PA443622);Neop...
# 655384601              Multiple Myeloma (PA444985);Osteonecrosis (PA4...
# 655384600              Multiple Myeloma (PA444985);Osteonecrosis (PA4...
# 655384599              Multiple Myeloma (PA444985);Osteonecrosis (PA4...
# ...                                                                  ...
# 1451218400                                                           NaN
# 1451218401                                                           NaN
# 1451218263                                                           NaN
# 1451218264                                                           NaN
# 1451218265                                                           NaN
#
#                       Biogeographical Groups Chromosome
# Genotype-Phenotype ID
# 655384596                         East Asian       chr7
# 655384596                         East Asian       chr7
# 655384601                           European      chr10
# 655384600                           European      chr10
# 655384599                           European      chr10
# ...                                      ...        ...
# 1451218400                           Unknown        NaN
# 1451218401                           Unknown        NaN
# 1451218263                        East Asian        NaN
# 1451218264                        East Asian        NaN
# 1451218265                        East Asian        NaN
#
# [2349 rows x 17 columns]

# %% [markdown]
# Now, we will have to do the same with the `clinical_phenotypes` DataFrame.
#
# We will again set the column `Genotype-Phenotype ID` as our index column.
#
# Let's do it.

# %%
clinical_phenotypes.set_index('Genotype-Phenotype ID', inplace = True)

# %%
clinical_phenotypes
# Out:
#                       Genotype  \
# Genotype-Phenotype ID
# 1447963976                  CC
# 1447963993                  AA
# 1448106268                  AA
# 1449170173                  AA
# 1450823787                  AA
# ...                        ...
# 1451218400                  *2
# 1451218401                  *3
# 1451218263                  *1
# 1451218264                  *3
# 1451218265                 *13
#
#                                                       Clinical Phenotype
# Genotype-Phenotype ID
# 1447963976             Patients with genotype CC may have decreased l...
# 1447963993             Male patients with the AA genotype and specifi...
# 1448106268             Patients with the AA genotype and multiple scl...
# 1449170173             Patients with the AA genotype and who are trea...
# 1450823787             Patients with the AA genotype may be at an inc...
# ...                                                                  ...
# 1451218400             Patients carrying the *2 allele in combination...
# 1451218401             Patients carrying the *3 allele in combination...
# 1451218263             Patients carrying the *1 allele in combination...
# 1451218264             Patients carrying the *3 allele in combination...
# 1451218265             Patients carrying the *13 allele in combinatio...
#
# [14144 rows x 2 columns]

# %% [markdown]
# We got this new reassinged DataFrame.
#
# We can now do the filtering of the `clinical_phenotypes` DataFrame, with the indices of our CYPs filtered `merged_cyps_clinical_phenotypes` DataFrame, in order to extract the rest of the annotations.

# %%
# exclude all records that are not present in CYPs DataFrame, based on indices

clinical_phenotypes[~clinical_phenotypes.index.isin(merged_cyps_clinical_phenotypes.index)]
# Out:
#                       Genotype  \
# Genotype-Phenotype ID
# 1447963976                  CC
# 1447963993                  AA
# 1448106268                  AA
# 1449170173                  AA
# 1450823787                  AA
# ...                        ...
# 1451217563                  CT
# 1451217564                  TT
# 1451217581                  AA
# 1451217582                  AG
# 1451217583                  GG
#
#                                                       Clinical Phenotype
# Genotype-Phenotype ID
# 1447963976             Patients with genotype CC may have decreased l...
# 1447963993             Male patients with the AA genotype and specifi...
# 1448106268             Patients with the AA genotype and multiple scl...
# 1449170173             Patients with the AA genotype and who are trea...
# 1450823787             Patients with the AA genotype may be at an inc...
# ...                                                                  ...
# 1451217563             Patients with the CT genotype may have a decre...
# 1451217564             Patients with the TT genotype may have a decre...
# 1451217581             Patients with the AA genotype may require a lo...
# 1451217582             Patients with the AG genotype may require a lo...
# 1451217583             Patients with the GG genotype may require a hi...
#
# [11822 rows x 2 columns]

# %% [markdown]
# We can see the resulting filtered DataFrame.
#
# Let's save it in a new variable.

# %%
clinical_phenotypes_without_cyps = clinical_phenotypes[~clinical_phenotypes.index.isin(merged_cyps_clinical_phenotypes.index)]

# %% [markdown]
# Now, after we obtained that new filtered DataFrame, we can save the column `Clinical Phenotype` in a new variable, and subsequently to use this variable to extract the words that are not associated with CYPs phenotypes.
#
# Let's do that.

# %%
phenotypes_without_cyps = clinical_phenotypes_without_cyps['Clinical Phenotype']

# %%
phenotypes_without_cyps
# Out:
# Genotype-Phenotype ID
# 1447963976    Patients with genotype CC may have decreased l...
# 1447963993    Male patients with the AA genotype and specifi...
# 1448106268    Patients with the AA genotype and multiple scl...
# 1449170173    Patients with the AA genotype and who are trea...
# 1450823787    Patients with the AA genotype may be at an inc...
#                                     ...
# 1451217563    Patients with the CT genotype may have a decre...
# 1451217564    Patients with the TT genotype may have a decre...
# 1451217581    Patients with the AA genotype may require a lo...
# 1451217582    Patients with the AG genotype may require a lo...
# 1451217583    Patients with the GG genotype may require a hi...
# Name: Clinical Phenotype, Length: 11822, dtype: object

# %% [markdown]
# Now, let's use our `extract_words` function to get these words.

# %%
words_phenotypes_without_cyps = extract_words(phenotypes_without_cyps)

# %% [markdown]
# Let's see these words, and how many they are.

# %%
words_phenotypes_without_cyps[:100]
# Out:
# ['patients',
#  'genotype',
#  'cc',
#  'may',
#  'decreased',
#  'likelihood',
#  'drug',
#  'resistance',
#  'treated',
#  'antiepileptics',
#  'carbamazepine',
#  'people',
#  'epilepsy',
#  'compared',
#  'patients',
#  'genotype',
#  'contradictory',
#  'findings',
#  'genotype',
#  'cc',
#  'associated',
#  'dose',
#  'genetic',
#  'clinical',
#  'factors',
#  'may',
#  'also',
#  'influence',
#  'response',
#  'male',
#  'patients',
#  'aa',
#  'genotype',
#  'specifically',
#  'epilepsy',
#  'syndrome',
#  'may',
#  'decreased',
#  'risk',
#  'resistance',
#  'antiepileptic',
#  'treatment',
#  'compared',
#  'patients',
#  'gg',
#  'one',
#  'study',
#  'found',
#  'association',
#  'variant',
#  'resistance',
#  'antiepileptic',
#  'genetic',
#  'clinical',
#  'factors',
#  'may',
#  'also',
#  'influence',
#  'resistance',
#  'patients',
#  'aa',
#  'genotype',
#  'multiple',
#  'sclerosis',
#  'may',
#  'increased',
#  'response',
#  'treatment',
#  'compared',
#  'patients',
#  'gg',
#  'genetic',
#  'clinical',
#  'factors',
#  'may',
#  'also',
#  'influence',
#  'response',
#  'patients',
#  'aa',
#  'genotype',
#  'treated',
#  'allopurinol',
#  'may',
#  'increased',
#  'risk',
#  'developing',
#  'dress',
#  'syndrome',
#  'syndrome',
#  'compared',
#  'patients',
#  'gg',
#  'please',
#  'aa',
#  'ag',
#  'genotypes',
#  'found',
#  'high',
#  'linkage']

# %%
len(words_phenotypes_without_cyps)
# Out:
# 288085

# %% [markdown]
# 288085, ok.
#
# Now, we will do something alse.
#
# Since our _tf-idf_ analysis will rely on all words in the corpus (all phenotype annotations in our original dataset - `clinical_phenotypes`), we will have to union both list of words and make a new set of words that is unique for the entire dataset. Then, we will use this set of unique words to count the occurence of each word in the 'CYPs-related' and 'not-CYPs-related' documents.
#
# Fortunately, we can easily do that union by using the python set method `union`.
#
# Let's see what it is all about.

# %%
unique_words = set(words_cyps).union(set(words_phenotypes_without_cyps))

# %% [markdown]
# Let's see which are these unique words, and how many they are.

# %%
len(unique_words)
# Out:
# 2620

# %% [markdown]
# We have 2620 unique words in the entire corpus.
#
# Now, we are approaching to the actual part of our _tf-idf_ analysis. Due to that, we must shed a bit more light on the computational part of the analysis.
#
# First of all, _tf-idf_ is calculated by multipyling two different metrics: $tf-idf_{t,d, D} = tf_{t,d} \cdot idf_{t, D}$ - where $t$ denotes the terms; $d$ denotes each document; $D$ denotes the collection of documents (corpus). Each of these matrics is calculated as follows:
#
# * __The term frequency__ of a word in a document - that is the number of times a word appears in a document divded by the total number of words in the document. Every document has its own term frequency.
#
# $$tf_{t,d} = \dfrac{n_{t,d}}{{\sum_n}{n_{t,d}}}$$
#
# * __The inverse document frequency__ of the word across a set of documents. This means, how common or rare a word is in the corpus. The closer it is to 0, the more common a word is. This metric can be calculated by taking the total number of documents, dividing it by the number of documents that contain a word, and calculating the logarithm.
#
# $$idf_t = log\dfrac{N}{df_t}$$
#
# Now, in order to compute _tf-idf_ we must first count the occurance of each unique word in our 'CYPs-related' and 'not-CYPs-related' documents. We can do that counting by making a dictionary with keys - the unique words in the corpus; and
# then by iterating over each document we can count the appearance of each unique word and assign these numbers as values of the dictionary.
#
# But let's not be verbose and see this in action. We will first count the words in the 'CYPs-related' document.

# %%
number_of_words_cyps = dict.fromkeys(unique_words, 0)
for word in words_cyps:
    number_of_words_cyps[word] += 1

# %% [markdown]
# We can now see the count of each unique word in our 'CYPs-related' document.

# %%
#number_of_words_cyps

# %% [markdown]
# Let's now do the same exercise for the 'not-CYPs-related' document.

# %%
number_of_words_phenotypes_without_cyps = dict.fromkeys(unique_words, 0)
for word in words_phenotypes_without_cyps:
    number_of_words_phenotypes_without_cyps[word] += 1

# %%
number_of_words_phenotypes_without_cyps
# Out:
# {'dolutegravir': 3,
#  'excerice': 0,
#  'normalized': 6,
#  'increases': 15,
#  'velpatasvir': 3,
#  'methylene': 9,
#  'recommended': 1,
#  'propionic': 9,
#  'extreme': 6,
#  'cilostazol': 0,
#  'drink': 3,
#  'separate': 17,
#  'consumption': 37,
#  'propofol': 9,
#  'perphanazine': 3,
#  'arteriosclerosis': 3,
#  'clarithromycin': 0,
#  'quinidine': 6,
#  'diabetes': 264,
#  'constipation': 12,
#  'reinforcement': 3,
#  'thalidomide': 78,
#  'atrasentan': 6,
#  'adalimumab': 21,
#  'dry': 3,
#  'discovery': 24,
#  'atrial': 18,
#  'hdl': 30,
#  'pharmacological': 18,
#  'insensitive': 3,
#  'e': 0,
#  'fatal': 5,
#  'entecavir': 3,
#  'leukopenia': 103,
#  'remission': 104,
#  'cystic': 309,
#  'record': 0,
#  'insulin': 9,
#  'fluorescently': 9,
#  'schizoaffective': 14,
#  'adjust': 0,
#  'hypertriglyceridemia': 40,
#  'eosinophilia': 4,
#  'hydrocodone': 3,
#  'offered': 0,
#  'measure': 3,
#  'comparing': 12,
#  'withdrawn': 3,
#  'dosing': 1,
#  'metronomic': 3,
#  'tumours': 3,
#  'representing': 56,
#  'behaviors': 15,
#  'etanercept': 33,
#  'analogs': 3,
#  'hours': 6,
#  'antiepileptic': 30,
#  'myasthenia': 3,
#  'replicated': 38,
#  'tipiracil': 12,
#  'second': 22,
#  'success': 6,
#  'cohorts': 15,
#  'dipyrone': 5,
#  'wt': 0,
#  'remained': 3,
#  'letermovir': 9,
#  'position': 10,
#  'hyperbilirubinemia': 86,
#  'distinguished': 12,
#  'list': 203,
#  'severity': 550,
#  'acitvity': 3,
#  'european': 157,
#  'overanticoagulated': 3,
#  'adrenal': 4,
#  'system': 15,
#  'pneumonitis': 21,
#  'dehydration': 3,
#  'fumaric': 3,
#  'deceased': 6,
#  'market': 3,
#  'glucose': 49,
#  'idarubicin': 35,
#  'incidence': 51,
#  'methamphetamines': 9,
#  'adolescent': 12,
#  'fluorouracilother': 1,
#  'node': 3,
#  'intake': 7,
#  'along': 0,
#  'dihydropyridine': 6,
#  'varying': 17,
#  'distant': 6,
#  'normal': 30,
#  'compare': 7,
#  'sparteine': 0,
#  'slowly': 1,
#  'deleobuvir': 6,
#  'daclatasvir': 6,
#  'core': 3,
#  'subjective': 41,
#  'high': 66,
#  'schizophrenia': 408,
#  'scap': 3,
#  'samples': 1,
#  'excerbations': 4,
#  'labor': 3,
#  'part': 26,
#  'valproic': 115,
#  'experiencing': 187,
#  'melphalan': 6,
#  'responsible': 3,
#  'cardiomyopathies': 3,
#  'hypothalamic': 4,
#  'couple': 0,
#  'published': 3,
#  'phenylalanine': 21,
#  'torasemide': 11,
#  'ecg': 0,
#  'occurring': 3,
#  'immediate': 6,
#  'expiratory': 26,
#  'therapy': 310,
#  'reduced': 245,
#  'stronger': 2,
#  'frequency': 39,
#  'smallest': 1,
#  'cardiomyopathy': 3,
#  'studies': 433,
#  'cidofovir': 3,
#  'allows': 6,
#  'osteitis': 2,
#  'pr': 21,
#  'paper': 3,
#  'lupus': 6,
#  'radiotherapy': 63,
#  'promoter': 13,
#  'people': 679,
#  'ranibizumab': 27,
#  'trimethoprim': 3,
#  'hemolytic': 28,
#  'clopiodgrel': 3,
#  'certolizumab': 12,
#  'osteopenia': 3,
#  'cardiovascular': 136,
#  'thiopurine': 56,
#  'conclusive': 2,
#  'bone': 138,
#  'graft': 6,
#  'differences': 38,
#  'overload': 3,
#  'fluvoxamine': 27,
#  'atenolol': 161,
#  'discontinue': 30,
#  'clodronate': 4,
#  'pm': 0,
#  'dyskinesia': 19,
#  'count': 3,
#  'bisoprolol': 6,
#  'er': 18,
#  'include': 12,
#  'concentration': 64,
#  'ca': 21,
#  'injury': 54,
#  'eating': 3,
#  'dorsal': 3,
#  'null': 10,
#  'investigated': 3,
#  'antitubercular': 0,
#  'angiotensin': 3,
#  'haemoglobin': 3,
#  'actually': 2,
#  'spine': 9,
#  'repaglinide': 56,
#  'side': 122,
#  'alcohol': 159,
#  'amiloride': 0,
#  'carbamazepine': 106,
#  'pitrakinra': 18,
#  'leflunomide': 9,
#  'maraviroc': 0,
#  'difluorodeoxyuridine': 3,
#  'iron': 3,
#  'hematological': 27,
#  'births': 3,
#  'visual': 26,
#  'mental': 12,
#  'red': 56,
#  'thioridazine': 0,
#  'area': 33,
#  'changes': 54,
#  'fluid': 6,
#  'sulfinpyrazone': 3,
#  'mitotane': 0,
#  'hypertrophy': 15,
#  'dexmedetomidine': 15,
#  'antituberculosis': 3,
#  'gi': 32,
#  'interindividual': 3,
#  'fully': 0,
#  'snp': 106,
#  'heterozygous': 47,
#  'ketoprofen': 0,
#  'glioma': 2,
#  'nonhematological': 4,
#  'lumbar': 12,
#  'rheumatoid': 258,
#  'infliximab': 36,
#  'years': 6,
#  'overweight': 0,
#  'secretion': 8,
#  'apoe': 14,
#  'principal': 0,
#  'myelossuppression': 6,
#  'statin': 50,
#  'pump': 0,
#  'therefore': 27,
#  'montelukast': 64,
#  'contraindicated': 0,
#  'flow': 3,
#  'quality': 10,
#  'conjunction': 162,
#  'referred': 3,
#  'better': 466,
#  'impairment': 15,
#  'rise': 6,
#  'crohn': 6,
#  'osteonecrosis': 83,
#  'disease': 416,
#  'tolerability': 3,
#  'donors': 6,
#  'required': 66,
#  'activity': 221,
#  'found': 509,
#  'ghr': 2,
#  'vitamin': 6,
#  'analgesic': 51,
#  'performance': 6,
#  'analog': 3,
#  'life': 10,
#  'enzymatic': 23,
#  'sofosbuvir': 21,
#  'sleep': 18,
#  'sweat': 3,
#  'duplication': 0,
#  'gneotype': 1,
#  'amenorrhea': 3,
#  'acetaminophen': 148,
#  'lung': 565,
#  'arpiprazole': 3,
#  'candesartan': 6,
#  'euphoric': 3,
#  'sulfametopyrazine': 15,
#  'responders': 2,
#  'conflict': 6,
#  'sustained': 58,
#  'modification': 3,
#  'influences': 3,
#  'xelox': 3,
#  'depression': 264,
#  'dystonic': 0,
#  'indicates': 9,
#  'nrt': 11,
#  'analgesics': 18,
#  'soluble': 3,
#  'taken': 3,
#  'significantly': 32,
#  'experiments': 6,
#  'arthralgia': 6,
#  'hyperglycemia': 15,
#  'clavulanate': 3,
#  'likelihood': 1078,
#  'ratios': 9,
#  'seperate': 4,
#  'migraine': 21,
#  'waking': 3,
#  'urticaria': 24,
#  'three': 17,
#  'nonexpressers': 3,
#  'always': 38,
#  'hemoglobin': 3,
#  'axis': 4,
#  'citalopram': 153,
#  'phosphonate': 3,
#  'psoriatic': 9,
#  'thiazolidinediones': 3,
#  'dinitrate': 3,
#  'vincristine': 57,
#  'methamphetamine': 95,
#  'glucoronidation': 7,
#  'dextropropoxyphene': 0,
#  'exhibited': 0,
#  'subpopulation': 4,
#  'bearing': 8,
#  'health': 2,
#  'chlorproguanil': 7,
#  'deficient': 25,
#  'antibiotics': 3,
#  'combining': 9,
#  'tramadol': 67,
#  'randomized': 9,
#  'antithyroid': 28,
#  'stenosis': 3,
#  'remain': 15,
#  'conclusion': 1,
#  'plus': 69,
#  'relevance': 3,
#  'tissue': 9,
#  'ga': 44,
#  'despite': 3,
#  'postprandial': 9,
#  'worse': 109,
#  'caring': 0,
#  'migalastat': 49,
#  'ecitalopram': 3,
#  'constriction': 3,
#  'conversion': 18,
#  'skin': 43,
#  'regards': 3,
#  'failureas': 3,
#  'state': 4,
#  'lurasidone': 3,
#  'donepezil': 12,
#  'burden': 8,
#  'milnacipran': 24,
#  'disoproxil': 3,
#  'adefovir': 6,
#  'nelfinavir': 3,
#  'agonist': 3,
#  'illnesses': 3,
#  'tetrahydrocannabinol': 3,
#  'contradicted': 284,
#  'compound': 31,
#  'deep': 3,
#  'elevation': 9,
#  'palpitations': 4,
#  'anemia': 203,
#  'lead': 11,
#  'inhalational': 149,
#  'acquired': 6,
#  'cigarettes': 3,
#  'bioavailability': 10,
#  'subset': 3,
#  'patient': 238,
#  'recurrent': 6,
#  'conducted': 3,
#  'exacerbations': 35,
#  'assessed': 19,
#  'intermediate': 33,
#  'computational': 3,
#  'effects': 172,
#  'mm': 0,
#  'coronary': 231,
#  'alleles': 111,
#  'helicobacter': 6,
#  'regularly': 3,
#  'instead': 1,
#  'rating': 12,
#  'individual': 24,
#  'underlie': 5,
#  'successful': 3,
#  'probability': 4,
#  'tafenoquine': 3,
#  'docetaxel': 217,
#  'finding': 46,
#  'whites': 3,
#  'amodiaquine': 0,
#  'increased': 5125,
#  'aucs': 1,
#  'biochemical': 3,
#  'memory': 3,
#  'nevirapine': 81,
#  'pyschosis': 3,
#  'might': 11,
#  'ed': 1,
#  'main': 6,
#  'folinic': 3,
#  'adolescents': 12,
#  'estradiol': 14,
#  'flunisolide': 3,
#  'carry': 87,
#  'thiopurines': 47,
#  'four': 3,
#  'respond': 494,
#  'undetectable': 0,
#  'frequencies': 6,
#  'withstand': 3,
#  'pramipexole': 3,
#  'egfr': 33,
#  'mutations': 21,
#  'addicted': 24,
#  'antihypertensives': 18,
#  'differ': 2,
#  'testosterone': 2,
#  'sclerosis': 47,
#  'neurosurgery': 3,
#  'platelet': 104,
#  'curcumin': 3,
#  'influence': 8442,
#  'anxiety': 37,
#  'menopausal': 2,
#  'females': 8,
#  'everolimus': 15,
#  'pk': 6,
#  'prazosin': 9,
#  'environmental': 13,
#  'purine': 41,
#  'bonferroni': 18,
#  'polymorphism': 16,
#  'characterize': 15,
#  'influenza': 1,
#  'insufficient': 0,
#  'examined': 1,
#  'according': 24,
#  'cases': 1,
#  'also': 11152,
#  'globulin': 3,
#  'lack': 7,
#  'differential': 1,
#  'fexofenadine': 12,
#  'ejection': 6,
#  'biliary': 3,
#  'known': 28,
#  'cardiotoxocity': 3,
#  'hcv': 21,
#  'parental': 3,
#  'ethanol': 30,
#  'exclusively': 6,
#  'nsaid': 6,
#  'presence': 103,
#  'brivaracetam': 0,
#  'gum': 3,
#  'chloroquine': 16,
#  'american': 33,
#  'toxicities': 94,
#  'first': 53,
#  'eculizumab': 9,
#  'febuxostat': 12,
#  'developed': 5,
#  'recurrence': 31,
#  'rifampin': 30,
#  'participants': 2,
#  'tropisetron': 0,
#  'left': 30,
#  'nilotinib': 19,
#  'ulcerative': 30,
#  'ii': 29,
#  'factors': 11468,
#  'treatment': 1832,
#  'spliced': 5,
#  'azathioprine': 15,
#  'fumarate': 3,
#  'day': 3,
#  'pharmacokinetic': 9,
#  'discussed': 9,
#  'valve': 15,
#  'retinal': 12,
#  'expansion': 3,
#  'assayed': 3,
#  'cyclophosphamide': 106,
#  'duloxetine': 238,
#  'farglitazar': 3,
#  'mechanical': 3,
#  'nephrotic': 18,
#  'protective': 8,
#  'apnea': 16,
#  'esters': 3,
#  'genotyped': 2,
#  'degeneration': 32,
#  'medications': 6,
#  'rare': 0,
#  'sufficient': 0,
#  'versus': 13,
#  'shrinkage': 3,
#  'neovascularization': 6,
#  'number': 36,
#  'total': 78,
#  'derivatives': 21,
#  'transformation': 3,
#  'limited': 5,
#  'load': 3,
#  'common': 0,
#  'benazepril': 27,
#  'nausea': 166,
#  'gravis': 3,
#  'dcreased': 0,
#  'parkinson': 18,
#  'cholinesterase': 6,
#  'full': 2,
#  'fibrosis': 299,
#  'discontinuing': 18,
#  'valproate': 6,
#  'angiographic': 3,
#  'human': 32,
#  'partly': 0,
#  'confirm': 6,
#  'epileptic': 4,
#  'manifestations': 1,
#  'thiotepa': 6,
#  'descent': 6,
#  'optica': 3,
#  'regimen': 24,
#  'antiepileptics': 25,
#  'methylphenidate': 218,
#  'carvedilol': 15,
#  'demonstrated': 3,
#  'develop': 159,
#  'alfa': 12,
#  'myalgia': 31,
#  'menses': 12,
#  'engage': 3,
#  'manner': 46,
#  'pressure': 279,
#  'combination': 156,
#  'midazolam': 14,
#  'autistic': 5,
#  'enzyme': 23,
#  'decresed': 1,
#  'relative': 4,
#  'autoimmune': 6,
#  'hydrolysis': 2,
#  'ag': 2701,
#  'attempt': 4,
#  'simvastatin': 143,
#  'myeloid': 81,
#  'outcome': 40,
#  'artery': 100,
#  'cytarabine': 83,
#  'explained': 3,
#  'infuence': 2,
#  'regression': 15,
#  'observed': 21,
#  'marginally': 3,
#  'rectal': 6,
#  'alert': 0,
#  'reasons': 0,
#  'chemoradiotherapy': 6,
#  'corresponding': 12,
#  'protease': 3,
#  'although': 209,
#  'minocycline': 1,
#  'sunitinib': 55,
#  'diminished': 5,
#  'adhere': 4,
#  'experience': 270,
#  'tardive': 24,
#  'adult': 7,
#  'hamd': 31,
#  'prothrombin': 3,
#  'nonsteroidal': 1,
#  'provided': 1,
#  'quetiapine': 50,
#  'serotonin': 91,
#  'moderate': 6,
#  'gating': 3,
#  'caffeine': 18,
#  'demographic': 10,
#  'altered': 1,
#  'become': 3,
#  'utilization': 7,
#  'fungal': 0,
#  'scales': 12,
#  'cognitive': 24,
#  'exacerbationswhen': 1,
#  'tested': 4,
#  'vein': 6,
#  'tenoxicam': 0,
#  'greater': 219,
#  'consumed': 3,
#  'methylphenobarbital': 0,
#  'cancer': 1762,
#  'probenecid': 3,
#  'antihypertensive': 18,
#  'post': 34,
#  'dextromethorphan': 0,
#  'reduction': 244,
#  'including': 199,
#  'homozygous': 68,
#  'emerge': 0,
#  'adr': 3,
#  'substantially': 2,
#  'discuss': 3,
#  'antilymphocyte': 3,
#  'biomarkers': 6,
#  'clear': 3,
#  'rofecoxib': 3,
#  'resulting': 37,
#  'significant': 263,
#  'tumor': 67,
#  'cirrhosis': 12,
#  'musculoskeletal': 24,
#  'diastolic': 98,
#  'sarcoma': 3,
#  'trastuzamab': 1,
#  'hypokalemia': 3,
#  'annotation': 52,
#  'fractional': 6,
#  'substrate': 0,
#  'mononuclear': 6,
#  'pyrazinamide': 6,
#  'shows': 3,
#  'stop': 6,
#  'psychosis': 43,
#  'bronchodilator': 24,
#  'baseline': 13,
#  'order': 0,
#  'motor': 3,
#  'fasting': 49,
#  'rates': 54,
#  'ethnicity': 12,
#  'hemorrhagic': 6,
#  'autism': 31,
#  'mhs': 3,
#  'related': 105,
#  'olanzepine': 6,
#  'antipyretic': 12,
#  'sulfation': 297,
#  'highly': 21,
#  'sleepiness': 3,
#  'boosted': 3,
#  'administered': 238,
#  'maximum': 0,
#  'league': 3,
#  'social': 9,
#  'additional': 2,
#  'metformin': 140,
#  'larger': 17,
#  'pemetrexed': 33,
#  'several': 27,
#  'opposite': 65,
#  'oxidative': 7,
#  'tranilast': 3,
#  'fesoterodine': 0,
#  'autosomal': 49,
#  'diabetic': 6,
#  'shown': 23,
#  'risperidone': 195,
#  'zonisamide': 7,
#  'avoid': 0,
#  'clonal': 3,
#  'hormone': 24,
#  'substances': 63,
#  'nitrendipine': 3,
#  'blocking': 24,
#  'multiple': 135,
#  'rapid': 61,
#  'cluster': 3,
#  'cardiotox': 1,
#  'looked': 4,
#  'mentioned': 13,
#  'less': 455,
#  'logistic': 12,
#  'lithium': 183,
#  'ritonavir': 48,
#  'visits': 7,
#  'nephrolithiasis': 21,
#  'malignant': 515,
#  'oedema': 3,
#  'kidney': 208,
#  'lacking': 1,
#  'urofollitropin': 3,
#  'pack': 3,
#  'metabolizer': 3,
#  'gemcitabine': 298,
#  'see': 5,
#  'warfarin': 299,
#  'statistically': 36,
#  'bufuralol': 0,
#  'occurred': 3,
#  'thought': 1,
#  'made': 1,
#  'fibrinolytic': 3,
#  'tapentadol': 108,
#  'cerivastatin': 3,
#  'zafirlukast': 0,
#  'mutation': 161,
#  'maintained': 15,
#  'tianeptine': 3,
#  'paclitaxel': 99,
#  'without': 30,
#  'betterr': 1,
#  'imiquimod': 4,
#  'switch': 0,
#  'women': 276,
#  'defined': 13,
#  'locus': 4,
#  'neuropathic': 5,
#  'metabolites': 3,
#  'pyrazolones': 9,
#  'neutralizing': 3,
#  'caf': 3,
#  'icotinib': 0,
#  'elevations': 12,
#  'trichloroethylene': 1,
#  'subjects': 56,
#  'cravings': 14,
#  'change': 69,
#  'lonafarnib': 3,
#  'aromatase': 15,
#  'vasodilation': 8,
#  'evaluation': 10,
#  'decreases': 34,
#  'digoxin': 10,
#  'tyms': 6,
#  'diuretics': 24,
#  'type': 127,
#  'nortriptyline': 21,
#  'fludarabine': 0,
#  'aqueous': 0,
#  'del': 1,
#  'g': 55,
#  'considered': 61,
#  'rehospitalization': 3,
#  'terms': 6,
#  'auc': 35,
#  'calcium': 39,
#  'antiretrovirals': 3,
#  'conferring': 23,
#  'purified': 6,
#  'libido': 9,
#  'please': 219,
#  'nitrofurantoin': 5,
#  'check': 0,
#  'metabolize': 3,
#  'tamoxifen': 53,
#  'enter': 3,
#  'amiodarone': 10,
#  'pulse': 18,
#  'liothyronine': 3,
#  'overral': 3,
#  'affinity': 19,
#  'diagnosis': 9,
#  'binge': 0,
#  'muscle': 155,
#  'dementia': 3,
#  'acting': 9,
#  'pmid': 0,
#  'scoring': 3,
#  'abacavir': 4,
#  'another': 192,
#  'bupropion': 90,
#  'intracellular': 3,
#  'rasagiline': 6,
#  'extent': 6,
#  'k': 0,
#  'ketorolac': 3,
#  'lenalidomide': 9,
#  'delay': 12,
#  'irritable': 3,
#  'methimazole': 1,
#  'adhd': 31,
#  'opposing': 3,
#  'expressors': 3,
#  'chlorthalidone': 16,
#  'measured': 172,
#  'threshold': 0,
#  'concerning': 2,
#  'zidovudine': 9,
#  'anaesthesia': 0,
#  'heterzygous': 2,
#  'meloxicam': 0,
#  'blue': 9,
#  'polyglutamate': 6,
#  'supporting': 19,
#  'transfusion': 9,
#  'explanations': 0,
#  'patches': 3,
#  'commonly': 3,
#  'current': 8,
#  'cannot': 1,
#  'unfavorable': 5,
#  'benefit': 49,
#  'prolongation': 21,
#  'rifampicin': 21,
#  'cefotaxime': 3,
#  'svr': 9,
#  'function': 38,
#  'folfiri': 18,
#  'go': 3,
#  'loss': 88,
#  'corticosteroids': 45,
#  'lovastatin': 22,
#  'hemizygous': 22,
#  'arrythmias': 0,
#  'primarily': 3,
#  'ct': 2399,
#  'kidneys': 0,
#  'sickle': 6,
#  'simeprevir': 15,
#  'spent': 3,
#  'anaesthetics': 148,
#  'folfox': 39,
#  'asians': 6,
#  'elevated': 7,
#  'amitriptyline': 0,
#  'comapred': 1,
#  'osteoporosis': 15,
#  'exacerbationse': 1,
#  'infrequent': 1,
#  'electrophoresis': 5,
#  'mouth': 3,
#  'sevoflurane': 9,
#  'dermatitis': 13,
#  'peak': 8,
#  'affect': 3023,
#  'sufentanil': 18,
#  'sirolimus': 38,
#  'hyponatremia': 6,
#  'loading': 3,
#  'applied': 3,
#  'various': 3,
#  'vasculature': 3,
#  'indicating': 10,
#  'fluticasone': 12,
#  'drinking': 14,
#  'cardioselective': 3,
#  'pylori': 12,
#  'interval': 12,
#  'remains': 3,
#  'erlotinib': 23,
#  'expressers': 9,
#  'catalytically': 0,
#  'dexrazoxane': 13,
#  'invasive': 0,
#  'creatine': 25,
#  'verapamil': 43,
#  'depending': 4,
#  'asd': 1,
#  'parkinsonism': 3,
#  'phenobarbital': 9,
#  'ascites': 3,
#  'overgrowth': 3,
#  'gain': 212,
#  'ondansetron': 14,
#  'interferon': 66,
#  'dck': 3,
#  'atorvastatin': 165,
#  'cyclosporine': 57,
#  'exaggerated': 0,
#  'thickness': 3,
#  'chemotherapies': 3,
#  'mh': 48,
#  'annotations': 3,
#  'alfentanil': 21,
#  'serm': 12,
#  'suggesting': 4,
#  'thalassemia': 33,
#  'elderly': 3,
#  'chromosomal': 3,
#  'pulmonary': 26,
#  'secondhand': 6,
#  'trial': 4,
#  'sensitivity': 68,
#  'alternative': 1,
#  'b': 100,
#  'nasopharyngeal': 111,
#  'intronic': 1,
#  'effect': 111,
#  'since': 1,
#  'sympathomimetics': 3,
#  'daytime': 1,
#  'presented': 27,
#  'tg': 12,
#  'mycophenolic': 89,
#  'interferons': 21,
#  'recommend': 3,
#  'diarrhoea': 3,
#  'cure': 0,
#  'etravirine': 0,
#  'leucopenia': 0,
#  'metabolizers': 19,
#  'chronic': 155,
#  'combinations': 6,
#  'odds': 6,
#  'hematologic': 32,
#  'dicloxacillin': 6,
#  'subgroup': 9,
#  'vardenafil': 0,
#  'precursor': 104,
#  'covers': 9,
#  'inconsistencies': 3,
#  'results': 77,
#  'benefits': 1,
#  'telmisartan': 3,
#  'dobutamine': 3,
#  'subscale': 3,
#  'seems': 5,
#  'dvt': 10,
#  'old': 9,
#  'noncirrhotic': 24,
#  'dimercaprol': 5,
#  'together': 13,
#  'susceptibility': 4,
#  'inhaled': 12,
#  'hypercholesteremia': 36,
#  'exist': 42,
#  'mizolastine': 3,
#  'agitated': 6,
#  'female': 175,
#  'grouped': 0,
#  'prescription': 12,
#  'containing': 12,
#  'geneticc': 1,
#  'surgery': 18,
#  'akathisia': 6,
#  'associated': 391,
#  'ration': 0,
#  'maculopapular': 25,
#  'narcolepsy': 15,
#  'determined': 33,
#  'growth': 9,
#  'regard': 1,
#  'gastroesphageal': 2,
#  'conjunctival': 12,
#  'neurotoxicity': 45,
#  'esophagitis': 3,
#  'gemtuzumab': 24,
#  'bowel': 71,
#  'maprotiline': 0,
#  'per': 18,
#  'glucocorticoids': 3,
#  'long': 130,
#  'sulfamethoxazole': 11,
#  'tocilizumab': 26,
#  'metronidazole': 0,
#  'postmenopausal': 24,
#  'prochlorperazine': 6,
#  'rick': 4,
#  'dysphoria': 0,
#  'genotypes': 243,
#  'malay': 6,
#  'indicative': 9,
#  'pruritus': 3,
#  'aggregation': 54,
#  'mediterranean': 71,
#  'based': 148,
#  'reach': 25,
#  'healthy': 69,
#  'equivalent': 4,
#  'homozygotes': 6,
#  'drugs': 183,
#  'disorders': 108,
#  'adherence': 6,
#  'standard': 5,
#  'acamprosate': 6,
#  'barkley': 3,
#  'naltrexone': 18,
#  'decrease': 156,
#  'sexual': 72,
#  'fentanyl': 120,
#  'isoniazid': 71,
#  'started': 3,
#  'graves': 1,
#  'breast': 429,
#  'pronounced': 35,
#  'hemolysis': 58,
#  'fractures': 30,
#  'lamivudine': 3,
#  'acetaldehyde': 3,
#  'adiponectin': 4,
#  'modeling': 3,
#  'note': 91,
#  'doxorubcin': 1,
#  'hmgcr': 1,
#  'infants': 10,
#  'requirement': 14,
#  'response': 8768,
#  'hodgkin': 3,
#  'tpmt': 70,
#  'regimens': 58,
#  'remainder': 0,
#  'clindamycin': 2,
#  'mofetil': 52,
#  'serious': 2,
#  'monitor': 0,
#  'protein': 18,
#  'vascular': 6,
#  'inhalants': 4,
#  'anthracycline': 6,
#  'basal': 2,
#  'receive': 56,
#  'opioids': 98,
#  'inactive': 3,
#  'rasburicase': 8,
#  'stable': 25,
#  'ciprofloxacin': 5,
#  'cftr': 336,
#  'esophageal': 6,
#  'polycystic': 12,
#  'alopecia': 18,
#  'chemotherapy': 270,
#  'piroxicam': 0,
#  'galantamine': 4,
#  'pioglitazone': 11,
#  'sulindac': 6,
#  'turner': 3,
#  'jaw': 0,
#  'repeat': 6,
#  'tuberculosis': 73,
#  ...}

# %% [markdown]
# Now, we must have define a function that will compute the term frequencies of the words in our documents.
#
# This function will accepts as parametars - a dictionary with the counted words from a document, and a set of unique words, refered to us as 'bag of words'. Given these parameters the function will compute the term frequencies and will return a new dictionary with the frequencies of each unique word from the corpus.

# %%
def compute_tf(word_dict, bag_of_words):
    """
    Compute the term frequency of each word in a document.
    """
    tf_dict = {}
    bag_of_words_count = len(bag_of_words)
    
    #compute tf of each word
    for word, count in word_dict.items():
        tf_dict[word] = count / float(bag_of_words_count)
        
    return tf_dict

# %% [markdown]
# Now, let's compute the term frequencies of the words in our 'CYPs-related' document.

# %%
tf_cyps = compute_tf(number_of_words_cyps, unique_words)

# %% [markdown]
# We can see these frequencies.

# %%
tf_cyps
# Out:
# {'dolutegravir': 0.0,
#  'excerice': 0.0019083969465648854,
#  'normalized': 0.0026717557251908397,
#  'increases': 0.0,
#  'velpatasvir': 0.0,
#  'methylene': 0.0,
#  'recommended': 0.0,
#  'propionic': 0.0,
#  'extreme': 0.0,
#  'cilostazol': 0.0015267175572519084,
#  'drink': 0.0,
#  'separate': 0.0015267175572519084,
#  'consumption': 0.003816793893129771,
#  'propofol': 0.003435114503816794,
#  'perphanazine': 0.0,
#  'arteriosclerosis': 0.0011450381679389313,
#  'clarithromycin': 0.0022900763358778627,
#  'quinidine': 0.0003816793893129771,
#  'diabetes': 0.0030534351145038168,
#  'constipation': 0.0,
#  'reinforcement': 0.0,
#  'thalidomide': 0.0011450381679389313,
#  'atrasentan': 0.0,
#  'adalimumab': 0.0,
#  'dry': 0.0,
#  'discovery': 0.0,
#  'atrial': 0.004580152671755725,
#  'hdl': 0.011450381679389313,
#  'pharmacological': 0.0,
#  'insensitive': 0.0,
#  'e': 0.0057251908396946565,
#  'fatal': 0.0,
#  'entecavir': 0.0,
#  'leukopenia': 0.004961832061068702,
#  'remission': 0.016793893129770993,
#  'cystic': 0.0,
#  'record': 0.0022900763358778627,
#  'insulin': 0.0,
#  'fluorescently': 0.0,
#  'schizoaffective': 0.0,
#  'adjust': 0.0003816793893129771,
#  'hypertriglyceridemia': 0.0,
#  'eosinophilia': 0.0015267175572519084,
#  'hydrocodone': 0.008778625954198474,
#  'offered': 0.0015267175572519084,
#  'measure': 0.0,
#  'comparing': 0.0,
#  'withdrawn': 0.0,
#  'dosing': 0.0019083969465648854,
#  'metronomic': 0.0,
#  'tumours': 0.0,
#  'representing': 0.0,
#  'behaviors': 0.0,
#  'etanercept': 0.0,
#  'analogs': 0.0,
#  'hours': 0.0,
#  'antiepileptic': 0.0011450381679389313,
#  'myasthenia': 0.0,
#  'replicated': 0.0,
#  'tipiracil': 0.0,
#  'second': 0.0,
#  'success': 0.0,
#  'cohorts': 0.003816793893129771,
#  'dipyrone': 0.0,
#  'wt': 0.0003816793893129771,
#  'remained': 0.0,
#  'letermovir': 0.0,
#  'position': 0.0,
#  'hyperbilirubinemia': 0.0,
#  'distinguished': 0.0011450381679389313,
#  'list': 0.0,
#  'severity': 0.023282442748091603,
#  'acitvity': 0.0,
#  'european': 0.0022900763358778627,
#  'overanticoagulated': 0.0,
#  'adrenal': 0.0,
#  'system': 0.0,
#  'pneumonitis': 0.0,
#  'dehydration': 0.0,
#  'fumaric': 0.0,
#  'deceased': 0.0007633587786259542,
#  'market': 0.0,
#  'glucose': 0.003816793893129771,
#  'idarubicin': 0.0022900763358778627,
#  'incidence': 0.004580152671755725,
#  'methamphetamines': 0.0,
#  'adolescent': 0.0,
#  'fluorouracilother': 0.0,
#  'node': 0.0,
#  'intake': 0.0,
#  'along': 0.003435114503816794,
#  'dihydropyridine': 0.0,
#  'varying': 0.0,
#  'distant': 0.0,
#  'normal': 0.08511450381679389,
#  'compare': 0.030916030534351144,
#  'sparteine': 0.004198473282442748,
#  'slowly': 0.0026717557251908397,
#  'deleobuvir': 0.0,
#  'daclatasvir': 0.0,
#  'core': 0.0,
#  'subjective': 0.0,
#  'high': 0.0015267175572519084,
#  'schizophrenia': 0.013740458015267175,
#  'scap': 0.0,
#  'samples': 0.0,
#  'excerbations': 0.0,
#  'labor': 0.0,
#  'part': 0.0053435114503816794,
#  'valproic': 0.0053435114503816794,
#  'experiencing': 0.015267175572519083,
#  'melphalan': 0.0,
#  'responsible': 0.0,
#  'cardiomyopathies': 0.0,
#  'hypothalamic': 0.0,
#  'couple': 0.0011450381679389313,
#  'published': 0.0,
#  'phenylalanine': 0.0,
#  'torasemide': 0.0,
#  'ecg': 0.0003816793893129771,
#  'occurring': 0.0,
#  'immediate': 0.0,
#  'expiratory': 0.0,
#  'therapy': 0.007251908396946565,
#  'reduced': 0.04885496183206107,
#  'stronger': 0.0,
#  'frequency': 0.0030534351145038168,
#  'smallest': 0.0,
#  'cardiomyopathy': 0.0,
#  'studies': 0.1099236641221374,
#  'cidofovir': 0.0,
#  'allows': 0.0,
#  'osteitis': 0.0,
#  'pr': 0.0,
#  'paper': 0.0,
#  'lupus': 0.0022900763358778627,
#  'radiotherapy': 0.0,
#  'promoter': 0.0,
#  'people': 0.020229007633587787,
#  'ranibizumab': 0.0,
#  'trimethoprim': 0.0,
#  'hemolytic': 0.0,
#  'clopiodgrel': 0.0,
#  'certolizumab': 0.0,
#  'osteopenia': 0.0,
#  'cardiovascular': 0.014885496183206106,
#  'thiopurine': 0.0,
#  'conclusive': 0.0,
#  'bone': 0.0022900763358778627,
#  'graft': 0.0011450381679389313,
#  'differences': 0.011068702290076336,
#  'overload': 0.0,
#  'fluvoxamine': 0.0064885496183206106,
#  'atenolol': 0.0,
#  'discontinue': 0.0,
#  'clodronate': 0.0,
#  'pm': 0.004198473282442748,
#  'dyskinesia': 0.003816793893129771,
#  'count': 0.0,
#  'bisoprolol': 0.0,
#  'er': 0.0,
#  'include': 0.0316793893129771,
#  'concentration': 0.020610687022900764,
#  'ca': 0.0011450381679389313,
#  'injury': 0.0011450381679389313,
#  'eating': 0.0003816793893129771,
#  'dorsal': 0.0,
#  'null': 0.0,
#  'investigated': 0.0,
#  'antitubercular': 0.0022900763358778627,
#  'angiotensin': 0.0,
#  'haemoglobin': 0.0,
#  'actually': 0.0,
#  'spine': 0.0,
#  'repaglinide': 0.0026717557251908397,
#  'side': 0.0549618320610687,
#  'alcohol': 0.0,
#  'amiloride': 0.0022900763358778627,
#  'carbamazepine': 0.0057251908396946565,
#  'pitrakinra': 0.0,
#  'leflunomide': 0.0022900763358778627,
#  'maraviroc': 0.011450381679389313,
#  'difluorodeoxyuridine': 0.0,
#  'iron': 0.0,
#  'hematological': 0.0,
#  'births': 0.0,
#  'visual': 0.0,
#  'mental': 0.0011450381679389313,
#  'red': 0.0,
#  'thioridazine': 0.0022900763358778627,
#  'area': 0.0026717557251908397,
#  'changes': 0.0057251908396946565,
#  'fluid': 0.0,
#  'sulfinpyrazone': 0.0,
#  'mitotane': 0.0022900763358778627,
#  'hypertrophy': 0.0,
#  'dexmedetomidine': 0.0,
#  'antituberculosis': 0.0,
#  'gi': 0.0,
#  'interindividual': 0.0,
#  'fully': 0.0057251908396946565,
#  'snp': 0.0022900763358778627,
#  'heterozygous': 0.0064885496183206106,
#  'ketoprofen': 0.003816793893129771,
#  'glioma': 0.0,
#  'nonhematological': 0.0,
#  'lumbar': 0.0,
#  'rheumatoid': 0.0011450381679389313,
#  'infliximab': 0.0,
#  'years': 0.003816793893129771,
#  'overweight': 0.0015267175572519084,
#  'secretion': 0.0,
#  'apoe': 0.0,
#  'principal': 0.0022900763358778627,
#  'myelossuppression': 0.0,
#  'statin': 0.004198473282442748,
#  'pump': 0.0022900763358778627,
#  'therefore': 0.0,
#  'montelukast': 0.0011450381679389313,
#  'contraindicated': 0.0007633587786259542,
#  'flow': 0.0,
#  'quality': 0.0,
#  'conjunction': 0.0,
#  'referred': 0.0,
#  'better': 0.01870229007633588,
#  'impairment': 0.0,
#  'rise': 0.0,
#  'crohn': 0.0,
#  'osteonecrosis': 0.0011450381679389313,
#  'disease': 0.012977099236641221,
#  'tolerability': 0.0011450381679389313,
#  'donors': 0.00801526717557252,
#  'required': 0.024045801526717557,
#  'activity': 0.08396946564885496,
#  'found': 0.11870229007633588,
#  'ghr': 0.0,
#  'vitamin': 0.011450381679389313,
#  'analgesic': 0.008778625954198474,
#  'performance': 0.0,
#  'analog': 0.0,
#  'life': 0.0,
#  'enzymatic': 0.006870229007633588,
#  'sofosbuvir': 0.0,
#  'sleep': 0.0003816793893129771,
#  'sweat': 0.0,
#  'duplication': 0.004961832061068702,
#  'gneotype': 0.0,
#  'amenorrhea': 0.0,
#  'acetaminophen': 0.0,
#  'lung': 0.004580152671755725,
#  'arpiprazole': 0.0,
#  'candesartan': 0.0011450381679389313,
#  'euphoric': 0.0,
#  'sulfametopyrazine': 0.0,
#  'responders': 0.0,
#  'conflict': 0.0011450381679389313,
#  'sustained': 0.0022900763358778627,
#  'modification': 0.0,
#  'influences': 0.0,
#  'xelox': 0.0,
#  'depression': 0.01603053435114504,
#  'dystonic': 0.0022900763358778627,
#  'indicates': 0.0,
#  'nrt': 0.0,
#  'analgesics': 0.0026717557251908397,
#  'soluble': 0.0,
#  'taken': 0.008396946564885497,
#  'significantly': 0.012213740458015267,
#  'experiments': 0.0,
#  'arthralgia': 0.0022900763358778627,
#  'hyperglycemia': 0.0,
#  'clavulanate': 0.0,
#  'likelihood': 0.055725190839694655,
#  'ratios': 0.0030534351145038168,
#  'seperate': 0.0011450381679389313,
#  'migraine': 0.0,
#  'waking': 0.0,
#  'urticaria': 0.0,
#  'three': 0.004961832061068702,
#  'nonexpressers': 0.0,
#  'always': 0.0,
#  'hemoglobin': 0.0,
#  'axis': 0.0,
#  'citalopram': 0.015648854961832062,
#  'phosphonate': 0.0,
#  'psoriatic': 0.0,
#  'thiazolidinediones': 0.0,
#  'dinitrate': 0.0,
#  'vincristine': 0.0,
#  'methamphetamine': 0.0,
#  'glucoronidation': 0.0,
#  'dextropropoxyphene': 0.0007633587786259542,
#  'exhibited': 0.0015267175572519084,
#  'subpopulation': 0.0,
#  'bearing': 0.0,
#  'health': 0.0,
#  'chlorproguanil': 0.0,
#  'deficient': 0.0,
#  'antibiotics': 0.0,
#  'combining': 0.0,
#  'tramadol': 0.03206106870229008,
#  'randomized': 0.0,
#  'antithyroid': 0.0,
#  'stenosis': 0.0,
#  'remain': 0.0,
#  'conclusion': 0.0,
#  'plus': 0.0,
#  'relevance': 0.0011450381679389313,
#  'tissue': 0.0,
#  'ga': 0.0,
#  'despite': 0.0,
#  'postprandial': 0.0,
#  'worse': 0.0022900763358778627,
#  'caring': 0.0011450381679389313,
#  'migalastat': 0.0,
#  'ecitalopram': 0.0,
#  'constriction': 0.0,
#  'conversion': 0.0,
#  'skin': 0.0,
#  'regards': 0.003816793893129771,
#  'failureas': 0.0,
#  'state': 0.0,
#  'lurasidone': 0.0,
#  'donepezil': 0.007633587786259542,
#  'burden': 0.0,
#  'milnacipran': 0.0,
#  'disoproxil': 0.0022900763358778627,
#  'adefovir': 0.0,
#  'nelfinavir': 0.0011450381679389313,
#  'agonist': 0.0,
#  'illnesses': 0.0,
#  'tetrahydrocannabinol': 0.0,
#  'contradicted': 0.0183206106870229,
#  'compound': 0.0022900763358778627,
#  'deep': 0.0,
#  'elevation': 0.0,
#  'palpitations': 0.0,
#  'anemia': 0.0011450381679389313,
#  'lead': 0.0022900763358778627,
#  'inhalational': 0.0,
#  'acquired': 0.0,
#  'cigarettes': 0.0007633587786259542,
#  'bioavailability': 0.0019083969465648854,
#  'subset': 0.0,
#  'patient': 0.0053435114503816794,
#  'recurrent': 0.0,
#  'conducted': 0.0,
#  'exacerbations': 0.0,
#  'assessed': 0.003816793893129771,
#  'intermediate': 0.03778625954198473,
#  'computational': 0.0,
#  'effects': 0.05152671755725191,
#  'mm': 0.004580152671755725,
#  'coronary': 0.004961832061068702,
#  'alleles': 0.0816793893129771,
#  'helicobacter': 0.00916030534351145,
#  'regularly': 0.0,
#  'instead': 0.0,
#  'rating': 0.0,
#  'individual': 0.030916030534351144,
#  'underlie': 0.0,
#  'successful': 0.0,
#  'probability': 0.0,
#  'tafenoquine': 0.0,
#  'docetaxel': 0.004961832061068702,
#  'finding': 0.0053435114503816794,
#  'whites': 0.0,
#  'amodiaquine': 0.0026717557251908397,
#  'increased': 0.4263358778625954,
#  'aucs': 0.0,
#  'biochemical': 0.0,
#  'memory': 0.0,
#  'nevirapine': 0.012595419847328244,
#  'pyschosis': 0.0,
#  'might': 0.0,
#  'ed': 0.0,
#  'main': 0.0,
#  'folinic': 0.0,
#  'adolescents': 0.0,
#  'estradiol': 0.0,
#  'flunisolide': 0.0,
#  'carry': 0.035114503816793895,
#  'thiopurines': 0.0,
#  'four': 0.0,
#  'respond': 0.0026717557251908397,
#  'undetectable': 0.0022900763358778627,
#  'frequencies': 0.0022900763358778627,
#  'withstand': 0.0,
#  'pramipexole': 0.0,
#  'egfr': 0.0,
#  'mutations': 0.0,
#  'addicted': 0.0,
#  'antihypertensives': 0.0,
#  'differ': 0.0011450381679389313,
#  'testosterone': 0.0,
#  'sclerosis': 0.0,
#  'neurosurgery': 0.0,
#  'platelet': 0.0053435114503816794,
#  'curcumin': 0.0,
#  'influence': 0.7041984732824428,
#  'anxiety': 0.004961832061068702,
#  'menopausal': 0.0,
#  'females': 0.0,
#  'everolimus': 0.003435114503816794,
#  'pk': 0.0,
#  'prazosin': 0.0,
#  'environmental': 0.0,
#  'purine': 0.0,
#  'bonferroni': 0.0,
#  'polymorphism': 0.0,
#  'characterize': 0.0,
#  'influenza': 0.0,
#  'insufficient': 0.0015267175572519084,
#  'examined': 0.0003816793893129771,
#  'according': 0.0,
#  'cases': 0.0,
#  'also': 0.9064885496183206,
#  'globulin': 0.0,
#  'lack': 0.0057251908396946565,
#  'differential': 0.0,
#  'fexofenadine': 0.0,
#  'ejection': 0.0,
#  'biliary': 0.0,
#  'known': 0.0022900763358778627,
#  'cardiotoxocity': 0.0,
#  'hcv': 0.0,
#  'parental': 0.0,
#  'ethanol': 0.0,
#  'exclusively': 0.0011450381679389313,
#  'nsaid': 0.0,
#  'presence': 0.0,
#  'brivaracetam': 0.0011450381679389313,
#  'gum': 0.0,
#  'chloroquine': 0.0,
#  'american': 0.0022900763358778627,
#  'toxicities': 0.0011450381679389313,
#  'first': 0.0,
#  'eculizumab': 0.0,
#  'febuxostat': 0.0,
#  'developed': 0.0,
#  'recurrence': 0.003435114503816794,
#  'rifampin': 0.0022900763358778627,
#  'participants': 0.0,
#  'tropisetron': 0.0064885496183206106,
#  'left': 0.0,
#  'nilotinib': 0.0,
#  'ulcerative': 0.003435114503816794,
#  'ii': 0.0030534351145038168,
#  'factors': 0.866793893129771,
#  'treatment': 0.0450381679389313,
#  'spliced': 0.0,
#  'azathioprine': 0.0,
#  'fumarate': 0.0022900763358778627,
#  'day': 0.0,
#  'pharmacokinetic': 0.0583969465648855,
#  'discussed': 0.0,
#  'valve': 0.003435114503816794,
#  'retinal': 0.0,
#  'expansion': 0.0,
#  'assayed': 0.01450381679389313,
#  'cyclophosphamide': 0.02099236641221374,
#  'duloxetine': 0.0,
#  'farglitazar': 0.0,
#  'mechanical': 0.0022900763358778627,
#  'nephrotic': 0.0022900763358778627,
#  'protective': 0.0,
#  'apnea': 0.0,
#  'esters': 0.0,
#  'genotyped': 0.0,
#  'degeneration': 0.0,
#  'medications': 0.0,
#  'rare': 0.0011450381679389313,
#  'sufficient': 0.0003816793893129771,
#  'versus': 0.0,
#  'shrinkage': 0.0,
#  'neovascularization': 0.0,
#  'number': 0.025190839694656488,
#  'total': 0.003816793893129771,
#  'derivatives': 0.0,
#  'transformation': 0.0,
#  'limited': 0.0,
#  'load': 0.0,
#  'common': 0.0011450381679389313,
#  'benazepril': 0.0011450381679389313,
#  'nausea': 0.006870229007633588,
#  'gravis': 0.0,
#  'dcreased': 0.0003816793893129771,
#  'parkinson': 0.0,
#  'cholinesterase': 0.0,
#  'full': 0.0,
#  'fibrosis': 0.0,
#  'discontinuing': 0.0,
#  'valproate': 0.0,
#  'angiographic': 0.0,
#  'human': 0.0011450381679389313,
#  'partly': 0.0011450381679389313,
#  'confirm': 0.0,
#  'epileptic': 0.0,
#  'manifestations': 0.0,
#  'thiotepa': 0.0,
#  'descent': 0.0,
#  'optica': 0.0,
#  'regimen': 0.0,
#  'antiepileptics': 0.0,
#  'methylphenidate': 0.0003816793893129771,
#  'carvedilol': 0.0030534351145038168,
#  'demonstrated': 0.0,
#  'develop': 0.0,
#  'alfa': 0.0,
#  'myalgia': 0.0019083969465648854,
#  'menses': 0.0,
#  'engage': 0.0,
#  'manner': 0.0,
#  'pressure': 0.012977099236641221,
#  'combination': 0.08244274809160305,
#  'midazolam': 0.004580152671755725,
#  'autistic': 0.0,
#  'enzyme': 0.03816793893129771,
#  'decresed': 0.0,
#  'relative': 0.0,
#  'autoimmune': 0.0,
#  'hydrolysis': 0.0,
#  'ag': 0.07290076335877863,
#  'attempt': 0.0,
#  'simvastatin': 0.011450381679389313,
#  'myeloid': 0.0022900763358778627,
#  'outcome': 0.003435114503816794,
#  'artery': 0.0,
#  'cytarabine': 0.0,
#  'explained': 0.0,
#  'infuence': 0.0,
#  'regression': 0.0011450381679389313,
#  'observed': 0.0,
#  'marginally': 0.0,
#  'rectal': 0.0,
#  'alert': 0.0019083969465648854,
#  'reasons': 0.0011450381679389313,
#  'chemoradiotherapy': 0.0,
#  'corresponding': 0.0,
#  'protease': 0.0,
#  'although': 0.016412213740458016,
#  'minocycline': 0.0,
#  'sunitinib': 0.0011450381679389313,
#  'diminished': 0.0,
#  'adhere': 0.0,
#  'experience': 0.020229007633587787,
#  'tardive': 0.0064885496183206106,
#  'adult': 0.0,
#  'hamd': 0.0,
#  'prothrombin': 0.0,
#  'nonsteroidal': 0.0,
#  'provided': 0.0,
#  'quetiapine': 0.004961832061068702,
#  'serotonin': 0.0,
#  'moderate': 0.0,
#  'gating': 0.0,
#  'caffeine': 0.006870229007633588,
#  'demographic': 0.0,
#  'altered': 0.0,
#  'become': 0.0,
#  'utilization': 0.0,
#  'fungal': 0.0011450381679389313,
#  'scales': 0.0,
#  'cognitive': 0.0,
#  'exacerbationswhen': 0.0,
#  'tested': 0.0,
#  'vein': 0.0,
#  'tenoxicam': 0.003435114503816794,
#  'greater': 0.006870229007633588,
#  'consumed': 0.0,
#  'methylphenobarbital': 0.0007633587786259542,
#  'cancer': 0.055725190839694655,
#  'probenecid': 0.0,
#  'antihypertensive': 0.0,
#  'post': 0.0,
#  'dextromethorphan': 0.022137404580152672,
#  'reduction': 0.007633587786259542,
#  'including': 0.023282442748091603,
#  'homozygous': 0.01183206106870229,
#  'emerge': 0.0019083969465648854,
#  'adr': 0.0,
#  'substantially': 0.0,
#  'discuss': 0.0,
#  'antilymphocyte': 0.0,
#  'biomarkers': 0.0,
#  'clear': 0.0003816793893129771,
#  'rofecoxib': 0.0,
#  'resulting': 0.015648854961832062,
#  'significant': 0.03625954198473282,
#  'tumor': 0.0,
#  'cirrhosis': 0.0,
#  'musculoskeletal': 0.0,
#  'diastolic': 0.0061068702290076335,
#  'sarcoma': 0.0,
#  'trastuzamab': 0.0,
#  'hypokalemia': 0.0,
#  'annotation': 0.03282442748091603,
#  'fractional': 0.0,
#  'substrate': 0.0022900763358778627,
#  'mononuclear': 0.0,
#  'pyrazinamide': 0.003435114503816794,
#  'shows': 0.0003816793893129771,
#  'stop': 0.0,
#  'psychosis': 0.0,
#  'bronchodilator': 0.0,
#  'baseline': 0.0,
#  'order': 0.0007633587786259542,
#  'motor': 0.0,
#  'fasting': 0.0,
#  'rates': 0.0026717557251908397,
#  'ethnicity': 0.0,
#  'hemorrhagic': 0.0022900763358778627,
#  'autism': 0.0,
#  'mhs': 0.0,
#  'related': 0.0,
#  'olanzepine': 0.0,
#  'antipyretic': 0.0,
#  'sulfation': 0.0,
#  'highly': 0.0,
#  'sleepiness': 0.0,
#  'boosted': 0.0015267175572519084,
#  'administered': 0.024427480916030534,
#  'maximum': 0.0007633587786259542,
#  'league': 0.0,
#  'social': 0.0,
#  'additional': 0.0,
#  'metformin': 0.0,
#  'larger': 0.0015267175572519084,
#  'pemetrexed': 0.0,
#  'several': 0.00801526717557252,
#  'opposite': 0.003435114503816794,
#  'oxidative': 0.0,
#  'tranilast': 0.0,
#  'fesoterodine': 0.0030534351145038168,
#  'autosomal': 0.0,
#  'diabetic': 0.0,
#  'shown': 0.004961832061068702,
#  'risperidone': 0.0183206106870229,
#  'zonisamide': 0.0,
#  'avoid': 0.004580152671755725,
#  'clonal': 0.0,
#  'hormone': 0.0011450381679389313,
#  'substances': 0.0,
#  'nitrendipine': 0.0,
#  'blocking': 0.0003816793893129771,
#  'multiple': 0.013358778625954198,
#  'rapid': 0.0003816793893129771,
#  'cluster': 0.0,
#  'cardiotox': 0.0,
#  'looked': 0.0,
#  'mentioned': 0.0,
#  'less': 0.025572519083969465,
#  'logistic': 0.0011450381679389313,
#  'lithium': 0.0,
#  'ritonavir': 0.0,
#  'visits': 0.0,
#  'nephrolithiasis': 0.0,
#  'malignant': 0.0,
#  'oedema': 0.0,
#  'kidney': 0.03396946564885496,
#  'lacking': 0.0,
#  'urofollitropin': 0.0,
#  'pack': 0.003816793893129771,
#  'metabolizer': 0.04122137404580153,
#  'gemcitabine': 0.0022900763358778627,
#  'see': 0.022900763358778626,
#  'warfarin': 0.061068702290076333,
#  'statistically': 0.003435114503816794,
#  'bufuralol': 0.04198473282442748,
#  'occurred': 0.0,
#  'thought': 0.0,
#  'made': 0.0,
#  'fibrinolytic': 0.0,
#  'tapentadol': 0.0,
#  'cerivastatin': 0.0,
#  'zafirlukast': 0.0011450381679389313,
#  'mutation': 0.0,
#  'maintained': 0.0,
#  'tianeptine': 0.0,
#  'paclitaxel': 0.01603053435114504,
#  'without': 0.0057251908396946565,
#  'betterr': 0.0,
#  'imiquimod': 0.0,
#  'switch': 0.0011450381679389313,
#  'women': 0.06870229007633588,
#  'defined': 0.017938931297709924,
#  'locus': 0.0,
#  'neuropathic': 0.0,
#  'metabolites': 0.0003816793893129771,
#  'pyrazolones': 0.0,
#  'neutralizing': 0.0,
#  'caf': 0.0,
#  'icotinib': 0.0011450381679389313,
#  'elevations': 0.0,
#  'trichloroethylene': 0.0,
#  'subjects': 0.0064885496183206106,
#  'cravings': 0.0,
#  'change': 0.0015267175572519084,
#  'lonafarnib': 0.0,
#  'aromatase': 0.0022900763358778627,
#  'vasodilation': 0.0,
#  'evaluation': 0.0,
#  'decreases': 0.0015267175572519084,
#  'digoxin': 0.0,
#  'tyms': 0.0,
#  'diuretics': 0.0,
#  'type': 0.003816793893129771,
#  'nortriptyline': 0.02251908396946565,
#  'fludarabine': 0.0022900763358778627,
#  'aqueous': 0.003816793893129771,
#  'del': 0.0,
#  'g': 0.0019083969465648854,
#  'considered': 0.0015267175572519084,
#  'rehospitalization': 0.0,
#  'terms': 0.0,
#  'auc': 0.0030534351145038168,
#  'calcium': 0.0,
#  'antiretrovirals': 0.0,
#  'conferring': 0.0,
#  'purified': 0.0,
#  'libido': 0.0,
#  'please': 0.010687022900763359,
#  'nitrofurantoin': 0.0,
#  'check': 0.0022900763358778627,
#  'metabolize': 0.0064885496183206106,
#  'tamoxifen': 0.009541984732824428,
#  'enter': 0.0,
#  'amiodarone': 0.0,
#  'pulse': 0.0022900763358778627,
#  'liothyronine': 0.0,
#  'overral': 0.0,
#  'affinity': 0.0,
#  'diagnosis': 0.0,
#  'binge': 0.0003816793893129771,
#  'muscle': 0.0007633587786259542,
#  'dementia': 0.003816793893129771,
#  'acting': 0.0,
#  'pmid': 0.0003816793893129771,
#  'scoring': 0.0,
#  'abacavir': 0.0,
#  'another': 0.07022900763358779,
#  'bupropion': 0.01717557251908397,
#  'intracellular': 0.0,
#  'rasagiline': 0.0,
#  'extent': 0.0,
#  'k': 0.0011450381679389313,
#  'ketorolac': 0.0,
#  'lenalidomide': 0.0,
#  'delay': 0.0011450381679389313,
#  'irritable': 0.0,
#  'methimazole': 0.0,
#  'adhd': 0.0,
#  'opposing': 0.0,
#  'expressors': 0.0,
#  'chlorthalidone': 0.0,
#  'measured': 0.01183206106870229,
#  'threshold': 0.0003816793893129771,
#  'concerning': 0.0,
#  'zidovudine': 0.0,
#  'anaesthesia': 0.0011450381679389313,
#  'heterzygous': 0.0,
#  'meloxicam': 0.0022900763358778627,
#  'blue': 0.0,
#  'polyglutamate': 0.0,
#  'supporting': 0.0011450381679389313,
#  'transfusion': 0.0,
#  'explanations': 0.0007633587786259542,
#  'patches': 0.0,
#  'commonly': 0.0,
#  'current': 0.0011450381679389313,
#  'cannot': 0.0,
#  'unfavorable': 0.0,
#  'benefit': 0.0011450381679389313,
#  'prolongation': 0.0,
#  'rifampicin': 0.0,
#  'cefotaxime': 0.0,
#  'svr': 0.0,
#  'function': 0.16374045801526718,
#  'folfiri': 0.0,
#  'go': 0.0,
#  'loss': 0.0022900763358778627,
#  'corticosteroids': 0.0,
#  'lovastatin': 0.004198473282442748,
#  'hemizygous': 0.0,
#  'arrythmias': 0.0007633587786259542,
#  'primarily': 0.0,
#  'ct': 0.1301526717557252,
#  'kidneys': 0.007251908396946565,
#  'sickle': 0.0,
#  'simeprevir': 0.0,
#  'spent': 0.0011450381679389313,
#  'anaesthetics': 0.0,
#  'folfox': 0.0,
#  'asians': 0.0,
#  'elevated': 0.003435114503816794,
#  'amitriptyline': 0.020229007633587787,
#  'comapred': 0.0,
#  'osteoporosis': 0.0,
#  'exacerbationse': 0.0,
#  'infrequent': 0.0,
#  'electrophoresis': 0.0,
#  'mouth': 0.0,
#  'sevoflurane': 0.0,
#  'dermatitis': 0.0,
#  'peak': 0.0030534351145038168,
#  'affect': 0.18435114503816794,
#  'sufentanil': 0.00801526717557252,
#  'sirolimus': 0.004580152671755725,
#  'hyponatremia': 0.0,
#  'loading': 0.0,
#  'applied': 0.0,
#  'various': 0.0022900763358778627,
#  'vasculature': 0.0,
#  'indicating': 0.0011450381679389313,
#  'fluticasone': 0.0,
#  'drinking': 0.0,
#  'cardioselective': 0.0,
#  'pylori': 0.0183206106870229,
#  'interval': 0.003435114503816794,
#  'remains': 0.0,
#  'erlotinib': 0.0011450381679389313,
#  'expressers': 0.0003816793893129771,
#  'catalytically': 0.0007633587786259542,
#  'dexrazoxane': 0.0,
#  'invasive': 0.0011450381679389313,
#  'creatine': 0.0,
#  'verapamil': 0.0,
#  'depending': 0.0,
#  'asd': 0.0,
#  'parkinsonism': 0.0022900763358778627,
#  'phenobarbital': 0.0,
#  'ascites': 0.0,
#  'overgrowth': 0.0,
#  'gain': 0.0030534351145038168,
#  'ondansetron': 0.0019083969465648854,
#  'interferon': 0.0,
#  'dck': 0.0,
#  'atorvastatin': 0.01183206106870229,
#  'cyclosporine': 0.015648854961832062,
#  'exaggerated': 0.0003816793893129771,
#  'thickness': 0.0,
#  'chemotherapies': 0.0,
#  'mh': 0.0,
#  'annotations': 0.022900763358778626,
#  'alfentanil': 0.0,
#  'serm': 0.0,
#  'suggesting': 0.0,
#  'thalassemia': 0.0,
#  'elderly': 0.004580152671755725,
#  'chromosomal': 0.0022900763358778627,
#  'pulmonary': 0.0,
#  'secondhand': 0.0,
#  'trial': 0.0,
#  'sensitivity': 0.0,
#  'alternative': 0.004580152671755725,
#  'b': 0.0,
#  'nasopharyngeal': 0.0,
#  'intronic': 0.0,
#  'effect': 0.004580152671755725,
#  'since': 0.022900763358778626,
#  'sympathomimetics': 0.0,
#  'daytime': 0.0,
#  'presented': 0.0,
#  'tg': 0.0015267175572519084,
#  'mycophenolic': 0.0,
#  'interferons': 0.0,
#  'recommend': 0.0007633587786259542,
#  'diarrhoea': 0.0,
#  'cure': 0.0030534351145038168,
#  'etravirine': 0.003435114503816794,
#  'leucopenia': 0.0011450381679389313,
#  'metabolizers': 0.10610687022900764,
#  'chronic': 0.006870229007633588,
#  'combinations': 0.0,
#  'odds': 0.0011450381679389313,
#  'hematologic': 0.0,
#  'dicloxacillin': 0.0,
#  'subgroup': 0.0,
#  'vardenafil': 0.0011450381679389313,
#  'precursor': 0.0,
#  'covers': 0.0316793893129771,
#  'inconsistencies': 0.0,
#  'results': 0.0011450381679389313,
#  'benefits': 0.0,
#  'telmisartan': 0.0,
#  'dobutamine': 0.0,
#  'subscale': 0.0,
#  'seems': 0.0,
#  'dvt': 0.0,
#  'old': 0.0,
#  'noncirrhotic': 0.0,
#  'dimercaprol': 0.0,
#  'together': 0.03206106870229008,
#  'susceptibility': 0.0,
#  'inhaled': 0.0,
#  'hypercholesteremia': 0.0,
#  'exist': 0.0,
#  'mizolastine': 0.0,
#  'agitated': 0.0,
#  'female': 0.003435114503816794,
#  'grouped': 0.030916030534351144,
#  'prescription': 0.0,
#  'containing': 0.0011450381679389313,
#  'geneticc': 0.0,
#  'surgery': 0.0,
#  'akathisia': 0.0,
#  'associated': 0.019083969465648856,
#  'ration': 0.0007633587786259542,
#  'maculopapular': 0.004580152671755725,
#  'narcolepsy': 0.0,
#  'determined': 0.0,
#  'growth': 0.0,
#  'regard': 0.0,
#  'gastroesphageal': 0.0,
#  'conjunctival': 0.0,
#  'neurotoxicity': 0.007251908396946565,
#  'esophagitis': 0.0,
#  'gemtuzumab': 0.004580152671755725,
#  'bowel': 0.0,
#  'maprotiline': 0.0022900763358778627,
#  'per': 0.0007633587786259542,
#  'glucocorticoids': 0.0,
#  'long': 0.0,
#  'sulfamethoxazole': 0.0,
#  'tocilizumab': 0.0,
#  'metronidazole': 0.004580152671755725,
#  'postmenopausal': 0.010305343511450382,
#  'prochlorperazine': 0.0,
#  'rick': 0.0,
#  'dysphoria': 0.0007633587786259542,
#  'genotypes': 0.0648854961832061,
#  'malay': 0.0,
#  'indicative': 0.0,
#  'pruritus': 0.0,
#  'aggregation': 0.0011450381679389313,
#  'mediterranean': 0.0,
#  'based': 0.01183206106870229,
#  'reach': 0.0011450381679389313,
#  'healthy': 0.00801526717557252,
#  'equivalent': 0.0,
#  'homozygotes': 0.0,
#  'drugs': 0.0061068702290076335,
#  'disorders': 0.004961832061068702,
#  'adherence': 0.0,
#  'standard': 0.0,
#  'acamprosate': 0.0,
#  'barkley': 0.0,
#  'naltrexone': 0.0,
#  'decrease': 0.008396946564885497,
#  'sexual': 0.0,
#  'fentanyl': 0.01717557251908397,
#  'isoniazid': 0.0,
#  'started': 0.0,
#  'graves': 0.0,
#  'breast': 0.05725190839694656,
#  'pronounced': 0.0,
#  'hemolysis': 0.0,
#  'fractures': 0.0,
#  'lamivudine': 0.0,
#  'acetaldehyde': 0.0,
#  'adiponectin': 0.0,
#  'modeling': 0.0,
#  'note': 0.013740458015267175,
#  'doxorubcin': 0.0,
#  'hmgcr': 0.0,
#  'infants': 0.0,
#  'requirement': 0.0022900763358778627,
#  'response': 0.29465648854961835,
#  'hodgkin': 0.0,
#  'tpmt': 0.0,
#  'regimens': 0.0022900763358778627,
#  'remainder': 0.0022900763358778627,
#  'clindamycin': 0.0,
#  'mofetil': 0.0011450381679389313,
#  'serious': 0.0,
#  'monitor': 0.0019083969465648854,
#  'protein': 0.003435114503816794,
#  'vascular': 0.0,
#  'inhalants': 0.0,
#  'anthracycline': 0.0,
#  'basal': 0.0,
#  'receive': 0.0053435114503816794,
#  'opioids': 0.0,
#  'inactive': 0.0057251908396946565,
#  'rasburicase': 0.0,
#  'stable': 0.004580152671755725,
#  'ciprofloxacin': 0.0,
#  'cftr': 0.0,
#  'esophageal': 0.0,
#  'polycystic': 0.0,
#  'alopecia': 0.004580152671755725,
#  'chemotherapy': 0.0015267175572519084,
#  'piroxicam': 0.003435114503816794,
#  'galantamine': 0.003816793893129771,
#  'pioglitazone': 0.0011450381679389313,
#  'sulindac': 0.0,
#  'turner': 0.0,
#  'jaw': 0.0011450381679389313,
#  'repeat': 0.0,
#  'tuberculosis': 0.004580152671755725,
#  ...}

# %% [markdown]
# We must also compute the term frequencies of the words in our 'not-CYPs-related' document.

# %%
tf_phenotypes_without_cyps = compute_tf(number_of_words_phenotypes_without_cyps, unique_words)

# %%
tf_phenotypes_without_cyps
# Out:
# {'dolutegravir': 0.0011450381679389313,
#  'excerice': 0.0,
#  'normalized': 0.0022900763358778627,
#  'increases': 0.0057251908396946565,
#  'velpatasvir': 0.0011450381679389313,
#  'methylene': 0.003435114503816794,
#  'recommended': 0.0003816793893129771,
#  'propionic': 0.003435114503816794,
#  'extreme': 0.0022900763358778627,
#  'cilostazol': 0.0,
#  'drink': 0.0011450381679389313,
#  'separate': 0.0064885496183206106,
#  'consumption': 0.014122137404580152,
#  'propofol': 0.003435114503816794,
#  'perphanazine': 0.0011450381679389313,
#  'arteriosclerosis': 0.0011450381679389313,
#  'clarithromycin': 0.0,
#  'quinidine': 0.0022900763358778627,
#  'diabetes': 0.10076335877862595,
#  'constipation': 0.004580152671755725,
#  'reinforcement': 0.0011450381679389313,
#  'thalidomide': 0.029770992366412213,
#  'atrasentan': 0.0022900763358778627,
#  'adalimumab': 0.00801526717557252,
#  'dry': 0.0011450381679389313,
#  'discovery': 0.00916030534351145,
#  'atrial': 0.006870229007633588,
#  'hdl': 0.011450381679389313,
#  'pharmacological': 0.006870229007633588,
#  'insensitive': 0.0011450381679389313,
#  'e': 0.0,
#  'fatal': 0.0019083969465648854,
#  'entecavir': 0.0011450381679389313,
#  'leukopenia': 0.03931297709923664,
#  'remission': 0.03969465648854962,
#  'cystic': 0.11793893129770992,
#  'record': 0.0,
#  'insulin': 0.003435114503816794,
#  'fluorescently': 0.003435114503816794,
#  'schizoaffective': 0.0053435114503816794,
#  'adjust': 0.0,
#  'hypertriglyceridemia': 0.015267175572519083,
#  'eosinophilia': 0.0015267175572519084,
#  'hydrocodone': 0.0011450381679389313,
#  'offered': 0.0,
#  'measure': 0.0011450381679389313,
#  'comparing': 0.004580152671755725,
#  'withdrawn': 0.0011450381679389313,
#  'dosing': 0.0003816793893129771,
#  'metronomic': 0.0011450381679389313,
#  'tumours': 0.0011450381679389313,
#  'representing': 0.021374045801526718,
#  'behaviors': 0.0057251908396946565,
#  'etanercept': 0.012595419847328244,
#  'analogs': 0.0011450381679389313,
#  'hours': 0.0022900763358778627,
#  'antiepileptic': 0.011450381679389313,
#  'myasthenia': 0.0011450381679389313,
#  'replicated': 0.01450381679389313,
#  'tipiracil': 0.004580152671755725,
#  'second': 0.008396946564885497,
#  'success': 0.0022900763358778627,
#  'cohorts': 0.0057251908396946565,
#  'dipyrone': 0.0019083969465648854,
#  'wt': 0.0,
#  'remained': 0.0011450381679389313,
#  'letermovir': 0.003435114503816794,
#  'position': 0.003816793893129771,
#  'hyperbilirubinemia': 0.03282442748091603,
#  'distinguished': 0.004580152671755725,
#  'list': 0.07748091603053435,
#  'severity': 0.2099236641221374,
#  'acitvity': 0.0011450381679389313,
#  'european': 0.059923664122137406,
#  'overanticoagulated': 0.0011450381679389313,
#  'adrenal': 0.0015267175572519084,
#  'system': 0.0057251908396946565,
#  'pneumonitis': 0.00801526717557252,
#  'dehydration': 0.0011450381679389313,
#  'fumaric': 0.0011450381679389313,
#  'deceased': 0.0022900763358778627,
#  'market': 0.0011450381679389313,
#  'glucose': 0.01870229007633588,
#  'idarubicin': 0.013358778625954198,
#  'incidence': 0.019465648854961833,
#  'methamphetamines': 0.003435114503816794,
#  'adolescent': 0.004580152671755725,
#  'fluorouracilother': 0.0003816793893129771,
#  'node': 0.0011450381679389313,
#  'intake': 0.0026717557251908397,
#  'along': 0.0,
#  'dihydropyridine': 0.0022900763358778627,
#  'varying': 0.0064885496183206106,
#  'distant': 0.0022900763358778627,
#  'normal': 0.011450381679389313,
#  'compare': 0.0026717557251908397,
#  'sparteine': 0.0,
#  'slowly': 0.0003816793893129771,
#  'deleobuvir': 0.0022900763358778627,
#  'daclatasvir': 0.0022900763358778627,
#  'core': 0.0011450381679389313,
#  'subjective': 0.015648854961832062,
#  'high': 0.025190839694656488,
#  'schizophrenia': 0.15572519083969466,
#  'scap': 0.0011450381679389313,
#  'samples': 0.0003816793893129771,
#  'excerbations': 0.0015267175572519084,
#  'labor': 0.0011450381679389313,
#  'part': 0.009923664122137405,
#  'valproic': 0.04389312977099236,
#  'experiencing': 0.07137404580152672,
#  'melphalan': 0.0022900763358778627,
#  'responsible': 0.0011450381679389313,
#  'cardiomyopathies': 0.0011450381679389313,
#  'hypothalamic': 0.0015267175572519084,
#  'couple': 0.0,
#  'published': 0.0011450381679389313,
#  'phenylalanine': 0.00801526717557252,
#  'torasemide': 0.004198473282442748,
#  'ecg': 0.0,
#  'occurring': 0.0011450381679389313,
#  'immediate': 0.0022900763358778627,
#  'expiratory': 0.009923664122137405,
#  'therapy': 0.1183206106870229,
#  'reduced': 0.09351145038167939,
#  'stronger': 0.0007633587786259542,
#  'frequency': 0.014885496183206106,
#  'smallest': 0.0003816793893129771,
#  'cardiomyopathy': 0.0011450381679389313,
#  'studies': 0.16526717557251908,
#  'cidofovir': 0.0011450381679389313,
#  'allows': 0.0022900763358778627,
#  'osteitis': 0.0007633587786259542,
#  'pr': 0.00801526717557252,
#  'paper': 0.0011450381679389313,
#  'lupus': 0.0022900763358778627,
#  'radiotherapy': 0.024045801526717557,
#  'promoter': 0.004961832061068702,
#  'people': 0.2591603053435115,
#  'ranibizumab': 0.010305343511450382,
#  'trimethoprim': 0.0011450381679389313,
#  'hemolytic': 0.010687022900763359,
#  'clopiodgrel': 0.0011450381679389313,
#  'certolizumab': 0.004580152671755725,
#  'osteopenia': 0.0011450381679389313,
#  'cardiovascular': 0.051908396946564885,
#  'thiopurine': 0.021374045801526718,
#  'conclusive': 0.0007633587786259542,
#  'bone': 0.05267175572519084,
#  'graft': 0.0022900763358778627,
#  'differences': 0.01450381679389313,
#  'overload': 0.0011450381679389313,
#  'fluvoxamine': 0.010305343511450382,
#  'atenolol': 0.061450381679389314,
#  'discontinue': 0.011450381679389313,
#  'clodronate': 0.0015267175572519084,
#  'pm': 0.0,
#  'dyskinesia': 0.007251908396946565,
#  'count': 0.0011450381679389313,
#  'bisoprolol': 0.0022900763358778627,
#  'er': 0.006870229007633588,
#  'include': 0.004580152671755725,
#  'concentration': 0.024427480916030534,
#  'ca': 0.00801526717557252,
#  'injury': 0.020610687022900764,
#  'eating': 0.0011450381679389313,
#  'dorsal': 0.0011450381679389313,
#  'null': 0.003816793893129771,
#  'investigated': 0.0011450381679389313,
#  'antitubercular': 0.0,
#  'angiotensin': 0.0011450381679389313,
#  'haemoglobin': 0.0011450381679389313,
#  'actually': 0.0007633587786259542,
#  'spine': 0.003435114503816794,
#  'repaglinide': 0.021374045801526718,
#  'side': 0.046564885496183206,
#  'alcohol': 0.06068702290076336,
#  'amiloride': 0.0,
#  'carbamazepine': 0.04045801526717557,
#  'pitrakinra': 0.006870229007633588,
#  'leflunomide': 0.003435114503816794,
#  'maraviroc': 0.0,
#  'difluorodeoxyuridine': 0.0011450381679389313,
#  'iron': 0.0011450381679389313,
#  'hematological': 0.010305343511450382,
#  'births': 0.0011450381679389313,
#  'visual': 0.009923664122137405,
#  'mental': 0.004580152671755725,
#  'red': 0.021374045801526718,
#  'thioridazine': 0.0,
#  'area': 0.012595419847328244,
#  'changes': 0.020610687022900764,
#  'fluid': 0.0022900763358778627,
#  'sulfinpyrazone': 0.0011450381679389313,
#  'mitotane': 0.0,
#  'hypertrophy': 0.0057251908396946565,
#  'dexmedetomidine': 0.0057251908396946565,
#  'antituberculosis': 0.0011450381679389313,
#  'gi': 0.012213740458015267,
#  'interindividual': 0.0011450381679389313,
#  'fully': 0.0,
#  'snp': 0.04045801526717557,
#  'heterozygous': 0.017938931297709924,
#  'ketoprofen': 0.0,
#  'glioma': 0.0007633587786259542,
#  'nonhematological': 0.0015267175572519084,
#  'lumbar': 0.004580152671755725,
#  'rheumatoid': 0.0984732824427481,
#  'infliximab': 0.013740458015267175,
#  'years': 0.0022900763358778627,
#  'overweight': 0.0,
#  'secretion': 0.0030534351145038168,
#  'apoe': 0.0053435114503816794,
#  'principal': 0.0,
#  'myelossuppression': 0.0022900763358778627,
#  'statin': 0.019083969465648856,
#  'pump': 0.0,
#  'therefore': 0.010305343511450382,
#  'montelukast': 0.024427480916030534,
#  'contraindicated': 0.0,
#  'flow': 0.0011450381679389313,
#  'quality': 0.003816793893129771,
#  'conjunction': 0.06183206106870229,
#  'referred': 0.0011450381679389313,
#  'better': 0.17786259541984734,
#  'impairment': 0.0057251908396946565,
#  'rise': 0.0022900763358778627,
#  'crohn': 0.0022900763358778627,
#  'osteonecrosis': 0.0316793893129771,
#  'disease': 0.15877862595419848,
#  'tolerability': 0.0011450381679389313,
#  'donors': 0.0022900763358778627,
#  'required': 0.025190839694656488,
#  'activity': 0.08435114503816794,
#  'found': 0.19427480916030535,
#  'ghr': 0.0007633587786259542,
#  'vitamin': 0.0022900763358778627,
#  'analgesic': 0.019465648854961833,
#  'performance': 0.0022900763358778627,
#  'analog': 0.0011450381679389313,
#  'life': 0.003816793893129771,
#  'enzymatic': 0.008778625954198474,
#  'sofosbuvir': 0.00801526717557252,
#  'sleep': 0.006870229007633588,
#  'sweat': 0.0011450381679389313,
#  'duplication': 0.0,
#  'gneotype': 0.0003816793893129771,
#  'amenorrhea': 0.0011450381679389313,
#  'acetaminophen': 0.05648854961832061,
#  'lung': 0.21564885496183206,
#  'arpiprazole': 0.0011450381679389313,
#  'candesartan': 0.0022900763358778627,
#  'euphoric': 0.0011450381679389313,
#  'sulfametopyrazine': 0.0057251908396946565,
#  'responders': 0.0007633587786259542,
#  'conflict': 0.0022900763358778627,
#  'sustained': 0.022137404580152672,
#  'modification': 0.0011450381679389313,
#  'influences': 0.0011450381679389313,
#  'xelox': 0.0011450381679389313,
#  'depression': 0.10076335877862595,
#  'dystonic': 0.0,
#  'indicates': 0.003435114503816794,
#  'nrt': 0.004198473282442748,
#  'analgesics': 0.006870229007633588,
#  'soluble': 0.0011450381679389313,
#  'taken': 0.0011450381679389313,
#  'significantly': 0.012213740458015267,
#  'experiments': 0.0022900763358778627,
#  'arthralgia': 0.0022900763358778627,
#  'hyperglycemia': 0.0057251908396946565,
#  'clavulanate': 0.0011450381679389313,
#  'likelihood': 0.4114503816793893,
#  'ratios': 0.003435114503816794,
#  'seperate': 0.0015267175572519084,
#  'migraine': 0.00801526717557252,
#  'waking': 0.0011450381679389313,
#  'urticaria': 0.00916030534351145,
#  'three': 0.0064885496183206106,
#  'nonexpressers': 0.0011450381679389313,
#  'always': 0.01450381679389313,
#  'hemoglobin': 0.0011450381679389313,
#  'axis': 0.0015267175572519084,
#  'citalopram': 0.0583969465648855,
#  'phosphonate': 0.0011450381679389313,
#  'psoriatic': 0.003435114503816794,
#  'thiazolidinediones': 0.0011450381679389313,
#  'dinitrate': 0.0011450381679389313,
#  'vincristine': 0.021755725190839695,
#  'methamphetamine': 0.03625954198473282,
#  'glucoronidation': 0.0026717557251908397,
#  'dextropropoxyphene': 0.0,
#  'exhibited': 0.0,
#  'subpopulation': 0.0015267175572519084,
#  'bearing': 0.0030534351145038168,
#  'health': 0.0007633587786259542,
#  'chlorproguanil': 0.0026717557251908397,
#  'deficient': 0.009541984732824428,
#  'antibiotics': 0.0011450381679389313,
#  'combining': 0.003435114503816794,
#  'tramadol': 0.025572519083969465,
#  'randomized': 0.003435114503816794,
#  'antithyroid': 0.010687022900763359,
#  'stenosis': 0.0011450381679389313,
#  'remain': 0.0057251908396946565,
#  'conclusion': 0.0003816793893129771,
#  'plus': 0.02633587786259542,
#  'relevance': 0.0011450381679389313,
#  'tissue': 0.003435114503816794,
#  'ga': 0.016793893129770993,
#  'despite': 0.0011450381679389313,
#  'postprandial': 0.003435114503816794,
#  'worse': 0.0416030534351145,
#  'caring': 0.0,
#  'migalastat': 0.01870229007633588,
#  'ecitalopram': 0.0011450381679389313,
#  'constriction': 0.0011450381679389313,
#  'conversion': 0.006870229007633588,
#  'skin': 0.016412213740458016,
#  'regards': 0.0011450381679389313,
#  'failureas': 0.0011450381679389313,
#  'state': 0.0015267175572519084,
#  'lurasidone': 0.0011450381679389313,
#  'donepezil': 0.004580152671755725,
#  'burden': 0.0030534351145038168,
#  'milnacipran': 0.00916030534351145,
#  'disoproxil': 0.0011450381679389313,
#  'adefovir': 0.0022900763358778627,
#  'nelfinavir': 0.0011450381679389313,
#  'agonist': 0.0011450381679389313,
#  'illnesses': 0.0011450381679389313,
#  'tetrahydrocannabinol': 0.0011450381679389313,
#  'contradicted': 0.1083969465648855,
#  'compound': 0.01183206106870229,
#  'deep': 0.0011450381679389313,
#  'elevation': 0.003435114503816794,
#  'palpitations': 0.0015267175572519084,
#  'anemia': 0.07748091603053435,
#  'lead': 0.004198473282442748,
#  'inhalational': 0.05687022900763359,
#  'acquired': 0.0022900763358778627,
#  'cigarettes': 0.0011450381679389313,
#  'bioavailability': 0.003816793893129771,
#  'subset': 0.0011450381679389313,
#  'patient': 0.09083969465648854,
#  'recurrent': 0.0022900763358778627,
#  'conducted': 0.0011450381679389313,
#  'exacerbations': 0.013358778625954198,
#  'assessed': 0.007251908396946565,
#  'intermediate': 0.012595419847328244,
#  'computational': 0.0011450381679389313,
#  'effects': 0.06564885496183206,
#  'mm': 0.0,
#  'coronary': 0.0881679389312977,
#  'alleles': 0.042366412213740455,
#  'helicobacter': 0.0022900763358778627,
#  'regularly': 0.0011450381679389313,
#  'instead': 0.0003816793893129771,
#  'rating': 0.004580152671755725,
#  'individual': 0.00916030534351145,
#  'underlie': 0.0019083969465648854,
#  'successful': 0.0011450381679389313,
#  'probability': 0.0015267175572519084,
#  'tafenoquine': 0.0011450381679389313,
#  'docetaxel': 0.08282442748091604,
#  'finding': 0.017557251908396947,
#  'whites': 0.0011450381679389313,
#  'amodiaquine': 0.0,
#  'increased': 1.9561068702290076,
#  'aucs': 0.0003816793893129771,
#  'biochemical': 0.0011450381679389313,
#  'memory': 0.0011450381679389313,
#  'nevirapine': 0.030916030534351144,
#  'pyschosis': 0.0011450381679389313,
#  'might': 0.004198473282442748,
#  'ed': 0.0003816793893129771,
#  'main': 0.0022900763358778627,
#  'folinic': 0.0011450381679389313,
#  'adolescents': 0.004580152671755725,
#  'estradiol': 0.0053435114503816794,
#  'flunisolide': 0.0011450381679389313,
#  'carry': 0.033206106870229006,
#  'thiopurines': 0.017938931297709924,
#  'four': 0.0011450381679389313,
#  'respond': 0.18854961832061068,
#  'undetectable': 0.0,
#  'frequencies': 0.0022900763358778627,
#  'withstand': 0.0011450381679389313,
#  'pramipexole': 0.0011450381679389313,
#  'egfr': 0.012595419847328244,
#  'mutations': 0.00801526717557252,
#  'addicted': 0.00916030534351145,
#  'antihypertensives': 0.006870229007633588,
#  'differ': 0.0007633587786259542,
#  'testosterone': 0.0007633587786259542,
#  'sclerosis': 0.017938931297709924,
#  'neurosurgery': 0.0011450381679389313,
#  'platelet': 0.03969465648854962,
#  'curcumin': 0.0011450381679389313,
#  'influence': 3.2221374045801525,
#  'anxiety': 0.014122137404580152,
#  'menopausal': 0.0007633587786259542,
#  'females': 0.0030534351145038168,
#  'everolimus': 0.0057251908396946565,
#  'pk': 0.0022900763358778627,
#  'prazosin': 0.003435114503816794,
#  'environmental': 0.004961832061068702,
#  'purine': 0.015648854961832062,
#  'bonferroni': 0.006870229007633588,
#  'polymorphism': 0.0061068702290076335,
#  'characterize': 0.0057251908396946565,
#  'influenza': 0.0003816793893129771,
#  'insufficient': 0.0,
#  'examined': 0.0003816793893129771,
#  'according': 0.00916030534351145,
#  'cases': 0.0003816793893129771,
#  'also': 4.256488549618321,
#  'globulin': 0.0011450381679389313,
#  'lack': 0.0026717557251908397,
#  'differential': 0.0003816793893129771,
#  'fexofenadine': 0.004580152671755725,
#  'ejection': 0.0022900763358778627,
#  'biliary': 0.0011450381679389313,
#  'known': 0.010687022900763359,
#  'cardiotoxocity': 0.0011450381679389313,
#  'hcv': 0.00801526717557252,
#  'parental': 0.0011450381679389313,
#  'ethanol': 0.011450381679389313,
#  'exclusively': 0.0022900763358778627,
#  'nsaid': 0.0022900763358778627,
#  'presence': 0.03931297709923664,
#  'brivaracetam': 0.0,
#  'gum': 0.0011450381679389313,
#  'chloroquine': 0.0061068702290076335,
#  'american': 0.012595419847328244,
#  'toxicities': 0.03587786259541985,
#  'first': 0.020229007633587787,
#  'eculizumab': 0.003435114503816794,
#  'febuxostat': 0.004580152671755725,
#  'developed': 0.0019083969465648854,
#  'recurrence': 0.01183206106870229,
#  'rifampin': 0.011450381679389313,
#  'participants': 0.0007633587786259542,
#  'tropisetron': 0.0,
#  'left': 0.011450381679389313,
#  'nilotinib': 0.007251908396946565,
#  'ulcerative': 0.011450381679389313,
#  'ii': 0.011068702290076336,
#  'factors': 4.377099236641222,
#  'treatment': 0.6992366412213741,
#  'spliced': 0.0019083969465648854,
#  'azathioprine': 0.0057251908396946565,
#  'fumarate': 0.0011450381679389313,
#  'day': 0.0011450381679389313,
#  'pharmacokinetic': 0.003435114503816794,
#  'discussed': 0.003435114503816794,
#  'valve': 0.0057251908396946565,
#  'retinal': 0.004580152671755725,
#  'expansion': 0.0011450381679389313,
#  'assayed': 0.0011450381679389313,
#  'cyclophosphamide': 0.04045801526717557,
#  'duloxetine': 0.09083969465648854,
#  'farglitazar': 0.0011450381679389313,
#  'mechanical': 0.0011450381679389313,
#  'nephrotic': 0.006870229007633588,
#  'protective': 0.0030534351145038168,
#  'apnea': 0.0061068702290076335,
#  'esters': 0.0011450381679389313,
#  'genotyped': 0.0007633587786259542,
#  'degeneration': 0.012213740458015267,
#  'medications': 0.0022900763358778627,
#  'rare': 0.0,
#  'sufficient': 0.0,
#  'versus': 0.004961832061068702,
#  'shrinkage': 0.0011450381679389313,
#  'neovascularization': 0.0022900763358778627,
#  'number': 0.013740458015267175,
#  'total': 0.029770992366412213,
#  'derivatives': 0.00801526717557252,
#  'transformation': 0.0011450381679389313,
#  'limited': 0.0019083969465648854,
#  'load': 0.0011450381679389313,
#  'common': 0.0,
#  'benazepril': 0.010305343511450382,
#  'nausea': 0.0633587786259542,
#  'gravis': 0.0011450381679389313,
#  'dcreased': 0.0,
#  'parkinson': 0.006870229007633588,
#  'cholinesterase': 0.0022900763358778627,
#  'full': 0.0007633587786259542,
#  'fibrosis': 0.11412213740458016,
#  'discontinuing': 0.006870229007633588,
#  'valproate': 0.0022900763358778627,
#  'angiographic': 0.0011450381679389313,
#  'human': 0.012213740458015267,
#  'partly': 0.0,
#  'confirm': 0.0022900763358778627,
#  'epileptic': 0.0015267175572519084,
#  'manifestations': 0.0003816793893129771,
#  'thiotepa': 0.0022900763358778627,
#  'descent': 0.0022900763358778627,
#  'optica': 0.0011450381679389313,
#  'regimen': 0.00916030534351145,
#  'antiepileptics': 0.009541984732824428,
#  'methylphenidate': 0.083206106870229,
#  'carvedilol': 0.0057251908396946565,
#  'demonstrated': 0.0011450381679389313,
#  'develop': 0.06068702290076336,
#  'alfa': 0.004580152671755725,
#  'myalgia': 0.01183206106870229,
#  'menses': 0.004580152671755725,
#  'engage': 0.0011450381679389313,
#  'manner': 0.017557251908396947,
#  'pressure': 0.1064885496183206,
#  'combination': 0.059541984732824425,
#  'midazolam': 0.0053435114503816794,
#  'autistic': 0.0019083969465648854,
#  'enzyme': 0.008778625954198474,
#  'decresed': 0.0003816793893129771,
#  'relative': 0.0015267175572519084,
#  'autoimmune': 0.0022900763358778627,
#  'hydrolysis': 0.0007633587786259542,
#  'ag': 1.0309160305343512,
#  'attempt': 0.0015267175572519084,
#  'simvastatin': 0.05458015267175573,
#  'myeloid': 0.030916030534351144,
#  'outcome': 0.015267175572519083,
#  'artery': 0.03816793893129771,
#  'cytarabine': 0.0316793893129771,
#  'explained': 0.0011450381679389313,
#  'infuence': 0.0007633587786259542,
#  'regression': 0.0057251908396946565,
#  'observed': 0.00801526717557252,
#  'marginally': 0.0011450381679389313,
#  'rectal': 0.0022900763358778627,
#  'alert': 0.0,
#  'reasons': 0.0,
#  'chemoradiotherapy': 0.0022900763358778627,
#  'corresponding': 0.004580152671755725,
#  'protease': 0.0011450381679389313,
#  'although': 0.07977099236641222,
#  'minocycline': 0.0003816793893129771,
#  'sunitinib': 0.02099236641221374,
#  'diminished': 0.0019083969465648854,
#  'adhere': 0.0015267175572519084,
#  'experience': 0.10305343511450382,
#  'tardive': 0.00916030534351145,
#  'adult': 0.0026717557251908397,
#  'hamd': 0.01183206106870229,
#  'prothrombin': 0.0011450381679389313,
#  'nonsteroidal': 0.0003816793893129771,
#  'provided': 0.0003816793893129771,
#  'quetiapine': 0.019083969465648856,
#  'serotonin': 0.034732824427480914,
#  'moderate': 0.0022900763358778627,
#  'gating': 0.0011450381679389313,
#  'caffeine': 0.006870229007633588,
#  'demographic': 0.003816793893129771,
#  'altered': 0.0003816793893129771,
#  'become': 0.0011450381679389313,
#  'utilization': 0.0026717557251908397,
#  'fungal': 0.0,
#  'scales': 0.004580152671755725,
#  'cognitive': 0.00916030534351145,
#  'exacerbationswhen': 0.0003816793893129771,
#  'tested': 0.0015267175572519084,
#  'vein': 0.0022900763358778627,
#  'tenoxicam': 0.0,
#  'greater': 0.08358778625954198,
#  'consumed': 0.0011450381679389313,
#  'methylphenobarbital': 0.0,
#  'cancer': 0.6725190839694657,
#  'probenecid': 0.0011450381679389313,
#  'antihypertensive': 0.006870229007633588,
#  'post': 0.012977099236641221,
#  'dextromethorphan': 0.0,
#  'reduction': 0.09312977099236641,
#  'including': 0.07595419847328244,
#  'homozygous': 0.025954198473282442,
#  'emerge': 0.0,
#  'adr': 0.0011450381679389313,
#  'substantially': 0.0007633587786259542,
#  'discuss': 0.0011450381679389313,
#  'antilymphocyte': 0.0011450381679389313,
#  'biomarkers': 0.0022900763358778627,
#  'clear': 0.0011450381679389313,
#  'rofecoxib': 0.0011450381679389313,
#  'resulting': 0.014122137404580152,
#  'significant': 0.10038167938931297,
#  'tumor': 0.025572519083969465,
#  'cirrhosis': 0.004580152671755725,
#  'musculoskeletal': 0.00916030534351145,
#  'diastolic': 0.03740458015267176,
#  'sarcoma': 0.0011450381679389313,
#  'trastuzamab': 0.0003816793893129771,
#  'hypokalemia': 0.0011450381679389313,
#  'annotation': 0.01984732824427481,
#  'fractional': 0.0022900763358778627,
#  'substrate': 0.0,
#  'mononuclear': 0.0022900763358778627,
#  'pyrazinamide': 0.0022900763358778627,
#  'shows': 0.0011450381679389313,
#  'stop': 0.0022900763358778627,
#  'psychosis': 0.016412213740458016,
#  'bronchodilator': 0.00916030534351145,
#  'baseline': 0.004961832061068702,
#  'order': 0.0,
#  'motor': 0.0011450381679389313,
#  'fasting': 0.01870229007633588,
#  'rates': 0.020610687022900764,
#  'ethnicity': 0.004580152671755725,
#  'hemorrhagic': 0.0022900763358778627,
#  'autism': 0.01183206106870229,
#  'mhs': 0.0011450381679389313,
#  'related': 0.04007633587786259,
#  'olanzepine': 0.0022900763358778627,
#  'antipyretic': 0.004580152671755725,
#  'sulfation': 0.1133587786259542,
#  'highly': 0.00801526717557252,
#  'sleepiness': 0.0011450381679389313,
#  'boosted': 0.0011450381679389313,
#  'administered': 0.09083969465648854,
#  'maximum': 0.0,
#  'league': 0.0011450381679389313,
#  'social': 0.003435114503816794,
#  'additional': 0.0007633587786259542,
#  'metformin': 0.05343511450381679,
#  'larger': 0.0064885496183206106,
#  'pemetrexed': 0.012595419847328244,
#  'several': 0.010305343511450382,
#  'opposite': 0.02480916030534351,
#  'oxidative': 0.0026717557251908397,
#  'tranilast': 0.0011450381679389313,
#  'fesoterodine': 0.0,
#  'autosomal': 0.01870229007633588,
#  'diabetic': 0.0022900763358778627,
#  'shown': 0.008778625954198474,
#  'risperidone': 0.07442748091603053,
#  'zonisamide': 0.0026717557251908397,
#  'avoid': 0.0,
#  'clonal': 0.0011450381679389313,
#  'hormone': 0.00916030534351145,
#  'substances': 0.024045801526717557,
#  'nitrendipine': 0.0011450381679389313,
#  'blocking': 0.00916030534351145,
#  'multiple': 0.05152671755725191,
#  'rapid': 0.023282442748091603,
#  'cluster': 0.0011450381679389313,
#  'cardiotox': 0.0003816793893129771,
#  'looked': 0.0015267175572519084,
#  'mentioned': 0.004961832061068702,
#  'less': 0.1736641221374046,
#  'logistic': 0.004580152671755725,
#  'lithium': 0.06984732824427481,
#  'ritonavir': 0.0183206106870229,
#  'visits': 0.0026717557251908397,
#  'nephrolithiasis': 0.00801526717557252,
#  'malignant': 0.1965648854961832,
#  'oedema': 0.0011450381679389313,
#  'kidney': 0.07938931297709924,
#  'lacking': 0.0003816793893129771,
#  'urofollitropin': 0.0011450381679389313,
#  'pack': 0.0011450381679389313,
#  'metabolizer': 0.0011450381679389313,
#  'gemcitabine': 0.11374045801526718,
#  'see': 0.0019083969465648854,
#  'warfarin': 0.11412213740458016,
#  'statistically': 0.013740458015267175,
#  'bufuralol': 0.0,
#  'occurred': 0.0011450381679389313,
#  'thought': 0.0003816793893129771,
#  'made': 0.0003816793893129771,
#  'fibrinolytic': 0.0011450381679389313,
#  'tapentadol': 0.04122137404580153,
#  'cerivastatin': 0.0011450381679389313,
#  'zafirlukast': 0.0,
#  'mutation': 0.061450381679389314,
#  'maintained': 0.0057251908396946565,
#  'tianeptine': 0.0011450381679389313,
#  'paclitaxel': 0.03778625954198473,
#  'without': 0.011450381679389313,
#  'betterr': 0.0003816793893129771,
#  'imiquimod': 0.0015267175572519084,
#  'switch': 0.0,
#  'women': 0.10534351145038168,
#  'defined': 0.004961832061068702,
#  'locus': 0.0015267175572519084,
#  'neuropathic': 0.0019083969465648854,
#  'metabolites': 0.0011450381679389313,
#  'pyrazolones': 0.003435114503816794,
#  'neutralizing': 0.0011450381679389313,
#  'caf': 0.0011450381679389313,
#  'icotinib': 0.0,
#  'elevations': 0.004580152671755725,
#  'trichloroethylene': 0.0003816793893129771,
#  'subjects': 0.021374045801526718,
#  'cravings': 0.0053435114503816794,
#  'change': 0.02633587786259542,
#  'lonafarnib': 0.0011450381679389313,
#  'aromatase': 0.0057251908396946565,
#  'vasodilation': 0.0030534351145038168,
#  'evaluation': 0.003816793893129771,
#  'decreases': 0.012977099236641221,
#  'digoxin': 0.003816793893129771,
#  'tyms': 0.0022900763358778627,
#  'diuretics': 0.00916030534351145,
#  'type': 0.048473282442748095,
#  'nortriptyline': 0.00801526717557252,
#  'fludarabine': 0.0,
#  'aqueous': 0.0,
#  'del': 0.0003816793893129771,
#  'g': 0.02099236641221374,
#  'considered': 0.023282442748091603,
#  'rehospitalization': 0.0011450381679389313,
#  'terms': 0.0022900763358778627,
#  'auc': 0.013358778625954198,
#  'calcium': 0.014885496183206106,
#  'antiretrovirals': 0.0011450381679389313,
#  'conferring': 0.008778625954198474,
#  'purified': 0.0022900763358778627,
#  'libido': 0.003435114503816794,
#  'please': 0.08358778625954198,
#  'nitrofurantoin': 0.0019083969465648854,
#  'check': 0.0,
#  'metabolize': 0.0011450381679389313,
#  'tamoxifen': 0.020229007633587787,
#  'enter': 0.0011450381679389313,
#  'amiodarone': 0.003816793893129771,
#  'pulse': 0.006870229007633588,
#  'liothyronine': 0.0011450381679389313,
#  'overral': 0.0011450381679389313,
#  'affinity': 0.007251908396946565,
#  'diagnosis': 0.003435114503816794,
#  'binge': 0.0,
#  'muscle': 0.05916030534351145,
#  'dementia': 0.0011450381679389313,
#  'acting': 0.003435114503816794,
#  'pmid': 0.0,
#  'scoring': 0.0011450381679389313,
#  'abacavir': 0.0015267175572519084,
#  'another': 0.0732824427480916,
#  'bupropion': 0.03435114503816794,
#  'intracellular': 0.0011450381679389313,
#  'rasagiline': 0.0022900763358778627,
#  'extent': 0.0022900763358778627,
#  'k': 0.0,
#  'ketorolac': 0.0011450381679389313,
#  'lenalidomide': 0.003435114503816794,
#  'delay': 0.004580152671755725,
#  'irritable': 0.0011450381679389313,
#  'methimazole': 0.0003816793893129771,
#  'adhd': 0.01183206106870229,
#  'opposing': 0.0011450381679389313,
#  'expressors': 0.0011450381679389313,
#  'chlorthalidone': 0.0061068702290076335,
#  'measured': 0.06564885496183206,
#  'threshold': 0.0,
#  'concerning': 0.0007633587786259542,
#  'zidovudine': 0.003435114503816794,
#  'anaesthesia': 0.0,
#  'heterzygous': 0.0007633587786259542,
#  'meloxicam': 0.0,
#  'blue': 0.003435114503816794,
#  'polyglutamate': 0.0022900763358778627,
#  'supporting': 0.007251908396946565,
#  'transfusion': 0.003435114503816794,
#  'explanations': 0.0,
#  'patches': 0.0011450381679389313,
#  'commonly': 0.0011450381679389313,
#  'current': 0.0030534351145038168,
#  'cannot': 0.0003816793893129771,
#  'unfavorable': 0.0019083969465648854,
#  'benefit': 0.01870229007633588,
#  'prolongation': 0.00801526717557252,
#  'rifampicin': 0.00801526717557252,
#  'cefotaxime': 0.0011450381679389313,
#  'svr': 0.003435114503816794,
#  'function': 0.01450381679389313,
#  'folfiri': 0.006870229007633588,
#  'go': 0.0011450381679389313,
#  'loss': 0.03358778625954199,
#  'corticosteroids': 0.01717557251908397,
#  'lovastatin': 0.008396946564885497,
#  'hemizygous': 0.008396946564885497,
#  'arrythmias': 0.0,
#  'primarily': 0.0011450381679389313,
#  'ct': 0.915648854961832,
#  'kidneys': 0.0,
#  'sickle': 0.0022900763358778627,
#  'simeprevir': 0.0057251908396946565,
#  'spent': 0.0011450381679389313,
#  'anaesthetics': 0.05648854961832061,
#  'folfox': 0.014885496183206106,
#  'asians': 0.0022900763358778627,
#  'elevated': 0.0026717557251908397,
#  'amitriptyline': 0.0,
#  'comapred': 0.0003816793893129771,
#  'osteoporosis': 0.0057251908396946565,
#  'exacerbationse': 0.0003816793893129771,
#  'infrequent': 0.0003816793893129771,
#  'electrophoresis': 0.0019083969465648854,
#  'mouth': 0.0011450381679389313,
#  'sevoflurane': 0.003435114503816794,
#  'dermatitis': 0.004961832061068702,
#  'peak': 0.0030534351145038168,
#  'affect': 1.1538167938931299,
#  'sufentanil': 0.006870229007633588,
#  'sirolimus': 0.01450381679389313,
#  'hyponatremia': 0.0022900763358778627,
#  'loading': 0.0011450381679389313,
#  'applied': 0.0011450381679389313,
#  'various': 0.0011450381679389313,
#  'vasculature': 0.0011450381679389313,
#  'indicating': 0.003816793893129771,
#  'fluticasone': 0.004580152671755725,
#  'drinking': 0.0053435114503816794,
#  'cardioselective': 0.0011450381679389313,
#  'pylori': 0.004580152671755725,
#  'interval': 0.004580152671755725,
#  'remains': 0.0011450381679389313,
#  'erlotinib': 0.008778625954198474,
#  'expressers': 0.003435114503816794,
#  'catalytically': 0.0,
#  'dexrazoxane': 0.004961832061068702,
#  'invasive': 0.0,
#  'creatine': 0.009541984732824428,
#  'verapamil': 0.016412213740458016,
#  'depending': 0.0015267175572519084,
#  'asd': 0.0003816793893129771,
#  'parkinsonism': 0.0011450381679389313,
#  'phenobarbital': 0.003435114503816794,
#  'ascites': 0.0011450381679389313,
#  'overgrowth': 0.0011450381679389313,
#  'gain': 0.08091603053435115,
#  'ondansetron': 0.0053435114503816794,
#  'interferon': 0.025190839694656488,
#  'dck': 0.0011450381679389313,
#  'atorvastatin': 0.06297709923664122,
#  'cyclosporine': 0.021755725190839695,
#  'exaggerated': 0.0,
#  'thickness': 0.0011450381679389313,
#  'chemotherapies': 0.0011450381679389313,
#  'mh': 0.0183206106870229,
#  'annotations': 0.0011450381679389313,
#  'alfentanil': 0.00801526717557252,
#  'serm': 0.004580152671755725,
#  'suggesting': 0.0015267175572519084,
#  'thalassemia': 0.012595419847328244,
#  'elderly': 0.0011450381679389313,
#  'chromosomal': 0.0011450381679389313,
#  'pulmonary': 0.009923664122137405,
#  'secondhand': 0.0022900763358778627,
#  'trial': 0.0015267175572519084,
#  'sensitivity': 0.025954198473282442,
#  'alternative': 0.0003816793893129771,
#  'b': 0.03816793893129771,
#  'nasopharyngeal': 0.042366412213740455,
#  'intronic': 0.0003816793893129771,
#  'effect': 0.042366412213740455,
#  'since': 0.0003816793893129771,
#  'sympathomimetics': 0.0011450381679389313,
#  'daytime': 0.0003816793893129771,
#  'presented': 0.010305343511450382,
#  'tg': 0.004580152671755725,
#  'mycophenolic': 0.03396946564885496,
#  'interferons': 0.00801526717557252,
#  'recommend': 0.0011450381679389313,
#  'diarrhoea': 0.0011450381679389313,
#  'cure': 0.0,
#  'etravirine': 0.0,
#  'leucopenia': 0.0,
#  'metabolizers': 0.007251908396946565,
#  'chronic': 0.05916030534351145,
#  'combinations': 0.0022900763358778627,
#  'odds': 0.0022900763358778627,
#  'hematologic': 0.012213740458015267,
#  'dicloxacillin': 0.0022900763358778627,
#  'subgroup': 0.003435114503816794,
#  'vardenafil': 0.0,
#  'precursor': 0.03969465648854962,
#  'covers': 0.003435114503816794,
#  'inconsistencies': 0.0011450381679389313,
#  'results': 0.029389312977099236,
#  'benefits': 0.0003816793893129771,
#  'telmisartan': 0.0011450381679389313,
#  'dobutamine': 0.0011450381679389313,
#  'subscale': 0.0011450381679389313,
#  'seems': 0.0019083969465648854,
#  'dvt': 0.003816793893129771,
#  'old': 0.003435114503816794,
#  'noncirrhotic': 0.00916030534351145,
#  'dimercaprol': 0.0019083969465648854,
#  'together': 0.004961832061068702,
#  'susceptibility': 0.0015267175572519084,
#  'inhaled': 0.004580152671755725,
#  'hypercholesteremia': 0.013740458015267175,
#  'exist': 0.01603053435114504,
#  'mizolastine': 0.0011450381679389313,
#  'agitated': 0.0022900763358778627,
#  'female': 0.06679389312977099,
#  'grouped': 0.0,
#  'prescription': 0.004580152671755725,
#  'containing': 0.004580152671755725,
#  'geneticc': 0.0003816793893129771,
#  'surgery': 0.006870229007633588,
#  'akathisia': 0.0022900763358778627,
#  'associated': 0.14923664122137403,
#  'ration': 0.0,
#  'maculopapular': 0.009541984732824428,
#  'narcolepsy': 0.0057251908396946565,
#  'determined': 0.012595419847328244,
#  'growth': 0.003435114503816794,
#  'regard': 0.0003816793893129771,
#  'gastroesphageal': 0.0007633587786259542,
#  'conjunctival': 0.004580152671755725,
#  'neurotoxicity': 0.01717557251908397,
#  'esophagitis': 0.0011450381679389313,
#  'gemtuzumab': 0.00916030534351145,
#  'bowel': 0.027099236641221373,
#  'maprotiline': 0.0,
#  'per': 0.006870229007633588,
#  'glucocorticoids': 0.0011450381679389313,
#  'long': 0.04961832061068702,
#  'sulfamethoxazole': 0.004198473282442748,
#  'tocilizumab': 0.009923664122137405,
#  'metronidazole': 0.0,
#  'postmenopausal': 0.00916030534351145,
#  'prochlorperazine': 0.0022900763358778627,
#  'rick': 0.0015267175572519084,
#  'dysphoria': 0.0,
#  'genotypes': 0.09274809160305343,
#  'malay': 0.0022900763358778627,
#  'indicative': 0.003435114503816794,
#  'pruritus': 0.0011450381679389313,
#  'aggregation': 0.020610687022900764,
#  'mediterranean': 0.027099236641221373,
#  'based': 0.05648854961832061,
#  'reach': 0.009541984732824428,
#  'healthy': 0.02633587786259542,
#  'equivalent': 0.0015267175572519084,
#  'homozygotes': 0.0022900763358778627,
#  'drugs': 0.06984732824427481,
#  'disorders': 0.04122137404580153,
#  'adherence': 0.0022900763358778627,
#  'standard': 0.0019083969465648854,
#  'acamprosate': 0.0022900763358778627,
#  'barkley': 0.0011450381679389313,
#  'naltrexone': 0.006870229007633588,
#  'decrease': 0.059541984732824425,
#  'sexual': 0.02748091603053435,
#  'fentanyl': 0.04580152671755725,
#  'isoniazid': 0.027099236641221373,
#  'started': 0.0011450381679389313,
#  'graves': 0.0003816793893129771,
#  'breast': 0.16374045801526718,
#  'pronounced': 0.013358778625954198,
#  'hemolysis': 0.022137404580152672,
#  'fractures': 0.011450381679389313,
#  'lamivudine': 0.0011450381679389313,
#  'acetaldehyde': 0.0011450381679389313,
#  'adiponectin': 0.0015267175572519084,
#  'modeling': 0.0011450381679389313,
#  'note': 0.034732824427480914,
#  'doxorubcin': 0.0003816793893129771,
#  'hmgcr': 0.0003816793893129771,
#  'infants': 0.003816793893129771,
#  'requirement': 0.0053435114503816794,
#  'response': 3.3465648854961834,
#  'hodgkin': 0.0011450381679389313,
#  'tpmt': 0.026717557251908396,
#  'regimens': 0.022137404580152672,
#  'remainder': 0.0,
#  'clindamycin': 0.0007633587786259542,
#  'mofetil': 0.01984732824427481,
#  'serious': 0.0007633587786259542,
#  'monitor': 0.0,
#  'protein': 0.006870229007633588,
#  'vascular': 0.0022900763358778627,
#  'inhalants': 0.0015267175572519084,
#  'anthracycline': 0.0022900763358778627,
#  'basal': 0.0007633587786259542,
#  'receive': 0.021374045801526718,
#  'opioids': 0.03740458015267176,
#  'inactive': 0.0011450381679389313,
#  'rasburicase': 0.0030534351145038168,
#  'stable': 0.009541984732824428,
#  'ciprofloxacin': 0.0019083969465648854,
#  'cftr': 0.1282442748091603,
#  'esophageal': 0.0022900763358778627,
#  'polycystic': 0.004580152671755725,
#  'alopecia': 0.006870229007633588,
#  'chemotherapy': 0.10305343511450382,
#  'piroxicam': 0.0,
#  'galantamine': 0.0015267175572519084,
#  'pioglitazone': 0.004198473282442748,
#  'sulindac': 0.0022900763358778627,
#  'turner': 0.0011450381679389313,
#  'jaw': 0.0,
#  'repeat': 0.0022900763358778627,
#  'tuberculosis': 0.027862595419847327,
#  ...}

# %% [markdown]
# We must now difine another function that will compute the inverse document frequencies of the words in our 'CYPs-related' and 'not-CYPs-related' documents.
#
# As we already said the inverse document frequency determines the weights of common and rare words across all documents in the corpus. The rare terms are more informative than frequent term, since they might be used as discriminating factors for these document that they appear in. Hence, we wants low positive weights for frequent terms and high weights for rare terms. That provides for us _idf_. For example, if we have 10 million documents and a given word appears in 1000 of them, then _idf_ is calculated as $IDF = log(10,000,000 / 1,000) = 4$, however if the word appear in only 100 documents, then _idf_ will be equal to 5, which will increase the wight of that word.
#
# Now, this function will accept all documents as parameter, and will return a dictionary with the calculated _idf_ weights for each word.
#
# Let's define it.

# %%
def compute_idf(documents):
    """
    Compute the inverse document frequency weight for each word from the provided documents.
    """
    N = len(documents)
    
    # count the number of documents that contain a word
    idf_dict = dict.fromkeys(documents[0].keys(), 0)
    for document in documents:
        for word, value in document.items():
            if value > 0:
                idf_dict[word] += 1
    
    # compute idf weights for each word
    for word, value in idf_dict.items():
        idf_dict[word] = np.log(N / float(value))
        
    return idf_dict

# %% [markdown]
# The _idf_ is computed once for all documents.

# %%
idfs = compute_idf([number_of_words_cyps, number_of_words_phenotypes_without_cyps])

# %% [markdown]
# We can now see the weights of all words in the corpus.

# %%
idfs
# Out:
# {'dolutegravir': 0.6931471805599453,
#  'excerice': 0.6931471805599453,
#  'normalized': 0.0,
#  'increases': 0.6931471805599453,
#  'velpatasvir': 0.6931471805599453,
#  'methylene': 0.6931471805599453,
#  'recommended': 0.6931471805599453,
#  'propionic': 0.6931471805599453,
#  'extreme': 0.6931471805599453,
#  'cilostazol': 0.6931471805599453,
#  'drink': 0.6931471805599453,
#  'separate': 0.0,
#  'consumption': 0.0,
#  'propofol': 0.0,
#  'perphanazine': 0.6931471805599453,
#  'arteriosclerosis': 0.0,
#  'clarithromycin': 0.6931471805599453,
#  'quinidine': 0.0,
#  'diabetes': 0.0,
#  'constipation': 0.6931471805599453,
#  'reinforcement': 0.6931471805599453,
#  'thalidomide': 0.0,
#  'atrasentan': 0.6931471805599453,
#  'adalimumab': 0.6931471805599453,
#  'dry': 0.6931471805599453,
#  'discovery': 0.6931471805599453,
#  'atrial': 0.0,
#  'hdl': 0.0,
#  'pharmacological': 0.6931471805599453,
#  'insensitive': 0.6931471805599453,
#  'e': 0.6931471805599453,
#  'fatal': 0.6931471805599453,
#  'entecavir': 0.6931471805599453,
#  'leukopenia': 0.0,
#  'remission': 0.0,
#  'cystic': 0.6931471805599453,
#  'record': 0.6931471805599453,
#  'insulin': 0.6931471805599453,
#  'fluorescently': 0.6931471805599453,
#  'schizoaffective': 0.6931471805599453,
#  'adjust': 0.6931471805599453,
#  'hypertriglyceridemia': 0.6931471805599453,
#  'eosinophilia': 0.0,
#  'hydrocodone': 0.0,
#  'offered': 0.6931471805599453,
#  'measure': 0.6931471805599453,
#  'comparing': 0.6931471805599453,
#  'withdrawn': 0.6931471805599453,
#  'dosing': 0.0,
#  'metronomic': 0.6931471805599453,
#  'tumours': 0.6931471805599453,
#  'representing': 0.6931471805599453,
#  'behaviors': 0.6931471805599453,
#  'etanercept': 0.6931471805599453,
#  'analogs': 0.6931471805599453,
#  'hours': 0.6931471805599453,
#  'antiepileptic': 0.0,
#  'myasthenia': 0.6931471805599453,
#  'replicated': 0.6931471805599453,
#  'tipiracil': 0.6931471805599453,
#  'second': 0.6931471805599453,
#  'success': 0.6931471805599453,
#  'cohorts': 0.0,
#  'dipyrone': 0.6931471805599453,
#  'wt': 0.6931471805599453,
#  'remained': 0.6931471805599453,
#  'letermovir': 0.6931471805599453,
#  'position': 0.6931471805599453,
#  'hyperbilirubinemia': 0.6931471805599453,
#  'distinguished': 0.0,
#  'list': 0.6931471805599453,
#  'severity': 0.0,
#  'acitvity': 0.6931471805599453,
#  'european': 0.0,
#  'overanticoagulated': 0.6931471805599453,
#  'adrenal': 0.6931471805599453,
#  'system': 0.6931471805599453,
#  'pneumonitis': 0.6931471805599453,
#  'dehydration': 0.6931471805599453,
#  'fumaric': 0.6931471805599453,
#  'deceased': 0.0,
#  'market': 0.6931471805599453,
#  'glucose': 0.0,
#  'idarubicin': 0.0,
#  'incidence': 0.0,
#  'methamphetamines': 0.6931471805599453,
#  'adolescent': 0.6931471805599453,
#  'fluorouracilother': 0.6931471805599453,
#  'node': 0.6931471805599453,
#  'intake': 0.6931471805599453,
#  'along': 0.6931471805599453,
#  'dihydropyridine': 0.6931471805599453,
#  'varying': 0.6931471805599453,
#  'distant': 0.6931471805599453,
#  'normal': 0.0,
#  'compare': 0.0,
#  'sparteine': 0.6931471805599453,
#  'slowly': 0.0,
#  'deleobuvir': 0.6931471805599453,
#  'daclatasvir': 0.6931471805599453,
#  'core': 0.6931471805599453,
#  'subjective': 0.6931471805599453,
#  'high': 0.0,
#  'schizophrenia': 0.0,
#  'scap': 0.6931471805599453,
#  'samples': 0.6931471805599453,
#  'excerbations': 0.6931471805599453,
#  'labor': 0.6931471805599453,
#  'part': 0.0,
#  'valproic': 0.0,
#  'experiencing': 0.0,
#  'melphalan': 0.6931471805599453,
#  'responsible': 0.6931471805599453,
#  'cardiomyopathies': 0.6931471805599453,
#  'hypothalamic': 0.6931471805599453,
#  'couple': 0.6931471805599453,
#  'published': 0.6931471805599453,
#  'phenylalanine': 0.6931471805599453,
#  'torasemide': 0.6931471805599453,
#  'ecg': 0.6931471805599453,
#  'occurring': 0.6931471805599453,
#  'immediate': 0.6931471805599453,
#  'expiratory': 0.6931471805599453,
#  'therapy': 0.0,
#  'reduced': 0.0,
#  'stronger': 0.6931471805599453,
#  'frequency': 0.0,
#  'smallest': 0.6931471805599453,
#  'cardiomyopathy': 0.6931471805599453,
#  'studies': 0.0,
#  'cidofovir': 0.6931471805599453,
#  'allows': 0.6931471805599453,
#  'osteitis': 0.6931471805599453,
#  'pr': 0.6931471805599453,
#  'paper': 0.6931471805599453,
#  'lupus': 0.0,
#  'radiotherapy': 0.6931471805599453,
#  'promoter': 0.6931471805599453,
#  'people': 0.0,
#  'ranibizumab': 0.6931471805599453,
#  'trimethoprim': 0.6931471805599453,
#  'hemolytic': 0.6931471805599453,
#  'clopiodgrel': 0.6931471805599453,
#  'certolizumab': 0.6931471805599453,
#  'osteopenia': 0.6931471805599453,
#  'cardiovascular': 0.0,
#  'thiopurine': 0.6931471805599453,
#  'conclusive': 0.6931471805599453,
#  'bone': 0.0,
#  'graft': 0.0,
#  'differences': 0.0,
#  'overload': 0.6931471805599453,
#  'fluvoxamine': 0.0,
#  'atenolol': 0.6931471805599453,
#  'discontinue': 0.6931471805599453,
#  'clodronate': 0.6931471805599453,
#  'pm': 0.6931471805599453,
#  'dyskinesia': 0.0,
#  'count': 0.6931471805599453,
#  'bisoprolol': 0.6931471805599453,
#  'er': 0.6931471805599453,
#  'include': 0.0,
#  'concentration': 0.0,
#  'ca': 0.0,
#  'injury': 0.0,
#  'eating': 0.0,
#  'dorsal': 0.6931471805599453,
#  'null': 0.6931471805599453,
#  'investigated': 0.6931471805599453,
#  'antitubercular': 0.6931471805599453,
#  'angiotensin': 0.6931471805599453,
#  'haemoglobin': 0.6931471805599453,
#  'actually': 0.6931471805599453,
#  'spine': 0.6931471805599453,
#  'repaglinide': 0.0,
#  'side': 0.0,
#  'alcohol': 0.6931471805599453,
#  'amiloride': 0.6931471805599453,
#  'carbamazepine': 0.0,
#  'pitrakinra': 0.6931471805599453,
#  'leflunomide': 0.0,
#  'maraviroc': 0.6931471805599453,
#  'difluorodeoxyuridine': 0.6931471805599453,
#  'iron': 0.6931471805599453,
#  'hematological': 0.6931471805599453,
#  'births': 0.6931471805599453,
#  'visual': 0.6931471805599453,
#  'mental': 0.0,
#  'red': 0.6931471805599453,
#  'thioridazine': 0.6931471805599453,
#  'area': 0.0,
#  'changes': 0.0,
#  'fluid': 0.6931471805599453,
#  'sulfinpyrazone': 0.6931471805599453,
#  'mitotane': 0.6931471805599453,
#  'hypertrophy': 0.6931471805599453,
#  'dexmedetomidine': 0.6931471805599453,
#  'antituberculosis': 0.6931471805599453,
#  'gi': 0.6931471805599453,
#  'interindividual': 0.6931471805599453,
#  'fully': 0.6931471805599453,
#  'snp': 0.0,
#  'heterozygous': 0.0,
#  'ketoprofen': 0.6931471805599453,
#  'glioma': 0.6931471805599453,
#  'nonhematological': 0.6931471805599453,
#  'lumbar': 0.6931471805599453,
#  'rheumatoid': 0.0,
#  'infliximab': 0.6931471805599453,
#  'years': 0.0,
#  'overweight': 0.6931471805599453,
#  'secretion': 0.6931471805599453,
#  'apoe': 0.6931471805599453,
#  'principal': 0.6931471805599453,
#  'myelossuppression': 0.6931471805599453,
#  'statin': 0.0,
#  'pump': 0.6931471805599453,
#  'therefore': 0.6931471805599453,
#  'montelukast': 0.0,
#  'contraindicated': 0.6931471805599453,
#  'flow': 0.6931471805599453,
#  'quality': 0.6931471805599453,
#  'conjunction': 0.6931471805599453,
#  'referred': 0.6931471805599453,
#  'better': 0.0,
#  'impairment': 0.6931471805599453,
#  'rise': 0.6931471805599453,
#  'crohn': 0.6931471805599453,
#  'osteonecrosis': 0.0,
#  'disease': 0.0,
#  'tolerability': 0.0,
#  'donors': 0.0,
#  'required': 0.0,
#  'activity': 0.0,
#  'found': 0.0,
#  'ghr': 0.6931471805599453,
#  'vitamin': 0.0,
#  'analgesic': 0.0,
#  'performance': 0.6931471805599453,
#  'analog': 0.6931471805599453,
#  'life': 0.6931471805599453,
#  'enzymatic': 0.0,
#  'sofosbuvir': 0.6931471805599453,
#  'sleep': 0.0,
#  'sweat': 0.6931471805599453,
#  'duplication': 0.6931471805599453,
#  'gneotype': 0.6931471805599453,
#  'amenorrhea': 0.6931471805599453,
#  'acetaminophen': 0.6931471805599453,
#  'lung': 0.0,
#  'arpiprazole': 0.6931471805599453,
#  'candesartan': 0.0,
#  'euphoric': 0.6931471805599453,
#  'sulfametopyrazine': 0.6931471805599453,
#  'responders': 0.6931471805599453,
#  'conflict': 0.0,
#  'sustained': 0.0,
#  'modification': 0.6931471805599453,
#  'influences': 0.6931471805599453,
#  'xelox': 0.6931471805599453,
#  'depression': 0.0,
#  'dystonic': 0.6931471805599453,
#  'indicates': 0.6931471805599453,
#  'nrt': 0.6931471805599453,
#  'analgesics': 0.0,
#  'soluble': 0.6931471805599453,
#  'taken': 0.0,
#  'significantly': 0.0,
#  'experiments': 0.6931471805599453,
#  'arthralgia': 0.0,
#  'hyperglycemia': 0.6931471805599453,
#  'clavulanate': 0.6931471805599453,
#  'likelihood': 0.0,
#  'ratios': 0.0,
#  'seperate': 0.0,
#  'migraine': 0.6931471805599453,
#  'waking': 0.6931471805599453,
#  'urticaria': 0.6931471805599453,
#  'three': 0.0,
#  'nonexpressers': 0.6931471805599453,
#  'always': 0.6931471805599453,
#  'hemoglobin': 0.6931471805599453,
#  'axis': 0.6931471805599453,
#  'citalopram': 0.0,
#  'phosphonate': 0.6931471805599453,
#  'psoriatic': 0.6931471805599453,
#  'thiazolidinediones': 0.6931471805599453,
#  'dinitrate': 0.6931471805599453,
#  'vincristine': 0.6931471805599453,
#  'methamphetamine': 0.6931471805599453,
#  'glucoronidation': 0.6931471805599453,
#  'dextropropoxyphene': 0.6931471805599453,
#  'exhibited': 0.6931471805599453,
#  'subpopulation': 0.6931471805599453,
#  'bearing': 0.6931471805599453,
#  'health': 0.6931471805599453,
#  'chlorproguanil': 0.6931471805599453,
#  'deficient': 0.6931471805599453,
#  'antibiotics': 0.6931471805599453,
#  'combining': 0.6931471805599453,
#  'tramadol': 0.0,
#  'randomized': 0.6931471805599453,
#  'antithyroid': 0.6931471805599453,
#  'stenosis': 0.6931471805599453,
#  'remain': 0.6931471805599453,
#  'conclusion': 0.6931471805599453,
#  'plus': 0.6931471805599453,
#  'relevance': 0.0,
#  'tissue': 0.6931471805599453,
#  'ga': 0.6931471805599453,
#  'despite': 0.6931471805599453,
#  'postprandial': 0.6931471805599453,
#  'worse': 0.0,
#  'caring': 0.6931471805599453,
#  'migalastat': 0.6931471805599453,
#  'ecitalopram': 0.6931471805599453,
#  'constriction': 0.6931471805599453,
#  'conversion': 0.6931471805599453,
#  'skin': 0.6931471805599453,
#  'regards': 0.0,
#  'failureas': 0.6931471805599453,
#  'state': 0.6931471805599453,
#  'lurasidone': 0.6931471805599453,
#  'donepezil': 0.0,
#  'burden': 0.6931471805599453,
#  'milnacipran': 0.6931471805599453,
#  'disoproxil': 0.0,
#  'adefovir': 0.6931471805599453,
#  'nelfinavir': 0.0,
#  'agonist': 0.6931471805599453,
#  'illnesses': 0.6931471805599453,
#  'tetrahydrocannabinol': 0.6931471805599453,
#  'contradicted': 0.0,
#  'compound': 0.0,
#  'deep': 0.6931471805599453,
#  'elevation': 0.6931471805599453,
#  'palpitations': 0.6931471805599453,
#  'anemia': 0.0,
#  'lead': 0.0,
#  'inhalational': 0.6931471805599453,
#  'acquired': 0.6931471805599453,
#  'cigarettes': 0.0,
#  'bioavailability': 0.0,
#  'subset': 0.6931471805599453,
#  'patient': 0.0,
#  'recurrent': 0.6931471805599453,
#  'conducted': 0.6931471805599453,
#  'exacerbations': 0.6931471805599453,
#  'assessed': 0.0,
#  'intermediate': 0.0,
#  'computational': 0.6931471805599453,
#  'effects': 0.0,
#  'mm': 0.6931471805599453,
#  'coronary': 0.0,
#  'alleles': 0.0,
#  'helicobacter': 0.0,
#  'regularly': 0.6931471805599453,
#  'instead': 0.6931471805599453,
#  'rating': 0.6931471805599453,
#  'individual': 0.0,
#  'underlie': 0.6931471805599453,
#  'successful': 0.6931471805599453,
#  'probability': 0.6931471805599453,
#  'tafenoquine': 0.6931471805599453,
#  'docetaxel': 0.0,
#  'finding': 0.0,
#  'whites': 0.6931471805599453,
#  'amodiaquine': 0.6931471805599453,
#  'increased': 0.0,
#  'aucs': 0.6931471805599453,
#  'biochemical': 0.6931471805599453,
#  'memory': 0.6931471805599453,
#  'nevirapine': 0.0,
#  'pyschosis': 0.6931471805599453,
#  'might': 0.6931471805599453,
#  'ed': 0.6931471805599453,
#  'main': 0.6931471805599453,
#  'folinic': 0.6931471805599453,
#  'adolescents': 0.6931471805599453,
#  'estradiol': 0.6931471805599453,
#  'flunisolide': 0.6931471805599453,
#  'carry': 0.0,
#  'thiopurines': 0.6931471805599453,
#  'four': 0.6931471805599453,
#  'respond': 0.0,
#  'undetectable': 0.6931471805599453,
#  'frequencies': 0.0,
#  'withstand': 0.6931471805599453,
#  'pramipexole': 0.6931471805599453,
#  'egfr': 0.6931471805599453,
#  'mutations': 0.6931471805599453,
#  'addicted': 0.6931471805599453,
#  'antihypertensives': 0.6931471805599453,
#  'differ': 0.0,
#  'testosterone': 0.6931471805599453,
#  'sclerosis': 0.6931471805599453,
#  'neurosurgery': 0.6931471805599453,
#  'platelet': 0.0,
#  'curcumin': 0.6931471805599453,
#  'influence': 0.0,
#  'anxiety': 0.0,
#  'menopausal': 0.6931471805599453,
#  'females': 0.6931471805599453,
#  'everolimus': 0.0,
#  'pk': 0.6931471805599453,
#  'prazosin': 0.6931471805599453,
#  'environmental': 0.6931471805599453,
#  'purine': 0.6931471805599453,
#  'bonferroni': 0.6931471805599453,
#  'polymorphism': 0.6931471805599453,
#  'characterize': 0.6931471805599453,
#  'influenza': 0.6931471805599453,
#  'insufficient': 0.6931471805599453,
#  'examined': 0.0,
#  'according': 0.6931471805599453,
#  'cases': 0.6931471805599453,
#  'also': 0.0,
#  'globulin': 0.6931471805599453,
#  'lack': 0.0,
#  'differential': 0.6931471805599453,
#  'fexofenadine': 0.6931471805599453,
#  'ejection': 0.6931471805599453,
#  'biliary': 0.6931471805599453,
#  'known': 0.0,
#  'cardiotoxocity': 0.6931471805599453,
#  'hcv': 0.6931471805599453,
#  'parental': 0.6931471805599453,
#  'ethanol': 0.6931471805599453,
#  'exclusively': 0.0,
#  'nsaid': 0.6931471805599453,
#  'presence': 0.6931471805599453,
#  'brivaracetam': 0.6931471805599453,
#  'gum': 0.6931471805599453,
#  'chloroquine': 0.6931471805599453,
#  'american': 0.0,
#  'toxicities': 0.0,
#  'first': 0.6931471805599453,
#  'eculizumab': 0.6931471805599453,
#  'febuxostat': 0.6931471805599453,
#  'developed': 0.6931471805599453,
#  'recurrence': 0.0,
#  'rifampin': 0.0,
#  'participants': 0.6931471805599453,
#  'tropisetron': 0.6931471805599453,
#  'left': 0.6931471805599453,
#  'nilotinib': 0.6931471805599453,
#  'ulcerative': 0.0,
#  'ii': 0.0,
#  'factors': 0.0,
#  'treatment': 0.0,
#  'spliced': 0.6931471805599453,
#  'azathioprine': 0.6931471805599453,
#  'fumarate': 0.0,
#  'day': 0.6931471805599453,
#  'pharmacokinetic': 0.0,
#  'discussed': 0.6931471805599453,
#  'valve': 0.0,
#  'retinal': 0.6931471805599453,
#  'expansion': 0.6931471805599453,
#  'assayed': 0.0,
#  'cyclophosphamide': 0.0,
#  'duloxetine': 0.6931471805599453,
#  'farglitazar': 0.6931471805599453,
#  'mechanical': 0.0,
#  'nephrotic': 0.0,
#  'protective': 0.6931471805599453,
#  'apnea': 0.6931471805599453,
#  'esters': 0.6931471805599453,
#  'genotyped': 0.6931471805599453,
#  'degeneration': 0.6931471805599453,
#  'medications': 0.6931471805599453,
#  'rare': 0.6931471805599453,
#  'sufficient': 0.6931471805599453,
#  'versus': 0.6931471805599453,
#  'shrinkage': 0.6931471805599453,
#  'neovascularization': 0.6931471805599453,
#  'number': 0.0,
#  'total': 0.0,
#  'derivatives': 0.6931471805599453,
#  'transformation': 0.6931471805599453,
#  'limited': 0.6931471805599453,
#  'load': 0.6931471805599453,
#  'common': 0.6931471805599453,
#  'benazepril': 0.0,
#  'nausea': 0.0,
#  'gravis': 0.6931471805599453,
#  'dcreased': 0.6931471805599453,
#  'parkinson': 0.6931471805599453,
#  'cholinesterase': 0.6931471805599453,
#  'full': 0.6931471805599453,
#  'fibrosis': 0.6931471805599453,
#  'discontinuing': 0.6931471805599453,
#  'valproate': 0.6931471805599453,
#  'angiographic': 0.6931471805599453,
#  'human': 0.0,
#  'partly': 0.6931471805599453,
#  'confirm': 0.6931471805599453,
#  'epileptic': 0.6931471805599453,
#  'manifestations': 0.6931471805599453,
#  'thiotepa': 0.6931471805599453,
#  'descent': 0.6931471805599453,
#  'optica': 0.6931471805599453,
#  'regimen': 0.6931471805599453,
#  'antiepileptics': 0.6931471805599453,
#  'methylphenidate': 0.0,
#  'carvedilol': 0.0,
#  'demonstrated': 0.6931471805599453,
#  'develop': 0.6931471805599453,
#  'alfa': 0.6931471805599453,
#  'myalgia': 0.0,
#  'menses': 0.6931471805599453,
#  'engage': 0.6931471805599453,
#  'manner': 0.6931471805599453,
#  'pressure': 0.0,
#  'combination': 0.0,
#  'midazolam': 0.0,
#  'autistic': 0.6931471805599453,
#  'enzyme': 0.0,
#  'decresed': 0.6931471805599453,
#  'relative': 0.6931471805599453,
#  'autoimmune': 0.6931471805599453,
#  'hydrolysis': 0.6931471805599453,
#  'ag': 0.0,
#  'attempt': 0.6931471805599453,
#  'simvastatin': 0.0,
#  'myeloid': 0.0,
#  'outcome': 0.0,
#  'artery': 0.6931471805599453,
#  'cytarabine': 0.6931471805599453,
#  'explained': 0.6931471805599453,
#  'infuence': 0.6931471805599453,
#  'regression': 0.0,
#  'observed': 0.6931471805599453,
#  'marginally': 0.6931471805599453,
#  'rectal': 0.6931471805599453,
#  'alert': 0.6931471805599453,
#  'reasons': 0.6931471805599453,
#  'chemoradiotherapy': 0.6931471805599453,
#  'corresponding': 0.6931471805599453,
#  'protease': 0.6931471805599453,
#  'although': 0.0,
#  'minocycline': 0.6931471805599453,
#  'sunitinib': 0.0,
#  'diminished': 0.6931471805599453,
#  'adhere': 0.6931471805599453,
#  'experience': 0.0,
#  'tardive': 0.0,
#  'adult': 0.6931471805599453,
#  'hamd': 0.6931471805599453,
#  'prothrombin': 0.6931471805599453,
#  'nonsteroidal': 0.6931471805599453,
#  'provided': 0.6931471805599453,
#  'quetiapine': 0.0,
#  'serotonin': 0.6931471805599453,
#  'moderate': 0.6931471805599453,
#  'gating': 0.6931471805599453,
#  'caffeine': 0.0,
#  'demographic': 0.6931471805599453,
#  'altered': 0.6931471805599453,
#  'become': 0.6931471805599453,
#  'utilization': 0.6931471805599453,
#  'fungal': 0.6931471805599453,
#  'scales': 0.6931471805599453,
#  'cognitive': 0.6931471805599453,
#  'exacerbationswhen': 0.6931471805599453,
#  'tested': 0.6931471805599453,
#  'vein': 0.6931471805599453,
#  'tenoxicam': 0.6931471805599453,
#  'greater': 0.0,
#  'consumed': 0.6931471805599453,
#  'methylphenobarbital': 0.6931471805599453,
#  'cancer': 0.0,
#  'probenecid': 0.6931471805599453,
#  'antihypertensive': 0.6931471805599453,
#  'post': 0.6931471805599453,
#  'dextromethorphan': 0.6931471805599453,
#  'reduction': 0.0,
#  'including': 0.0,
#  'homozygous': 0.0,
#  'emerge': 0.6931471805599453,
#  'adr': 0.6931471805599453,
#  'substantially': 0.6931471805599453,
#  'discuss': 0.6931471805599453,
#  'antilymphocyte': 0.6931471805599453,
#  'biomarkers': 0.6931471805599453,
#  'clear': 0.0,
#  'rofecoxib': 0.6931471805599453,
#  'resulting': 0.0,
#  'significant': 0.0,
#  'tumor': 0.6931471805599453,
#  'cirrhosis': 0.6931471805599453,
#  'musculoskeletal': 0.6931471805599453,
#  'diastolic': 0.0,
#  'sarcoma': 0.6931471805599453,
#  'trastuzamab': 0.6931471805599453,
#  'hypokalemia': 0.6931471805599453,
#  'annotation': 0.0,
#  'fractional': 0.6931471805599453,
#  'substrate': 0.6931471805599453,
#  'mononuclear': 0.6931471805599453,
#  'pyrazinamide': 0.0,
#  'shows': 0.0,
#  'stop': 0.6931471805599453,
#  'psychosis': 0.6931471805599453,
#  'bronchodilator': 0.6931471805599453,
#  'baseline': 0.6931471805599453,
#  'order': 0.6931471805599453,
#  'motor': 0.6931471805599453,
#  'fasting': 0.6931471805599453,
#  'rates': 0.0,
#  'ethnicity': 0.6931471805599453,
#  'hemorrhagic': 0.0,
#  'autism': 0.6931471805599453,
#  'mhs': 0.6931471805599453,
#  'related': 0.6931471805599453,
#  'olanzepine': 0.6931471805599453,
#  'antipyretic': 0.6931471805599453,
#  'sulfation': 0.6931471805599453,
#  'highly': 0.6931471805599453,
#  'sleepiness': 0.6931471805599453,
#  'boosted': 0.0,
#  'administered': 0.0,
#  'maximum': 0.6931471805599453,
#  'league': 0.6931471805599453,
#  'social': 0.6931471805599453,
#  'additional': 0.6931471805599453,
#  'metformin': 0.6931471805599453,
#  'larger': 0.0,
#  'pemetrexed': 0.6931471805599453,
#  'several': 0.0,
#  'opposite': 0.0,
#  'oxidative': 0.6931471805599453,
#  'tranilast': 0.6931471805599453,
#  'fesoterodine': 0.6931471805599453,
#  'autosomal': 0.6931471805599453,
#  'diabetic': 0.6931471805599453,
#  'shown': 0.0,
#  'risperidone': 0.0,
#  'zonisamide': 0.6931471805599453,
#  'avoid': 0.6931471805599453,
#  'clonal': 0.6931471805599453,
#  'hormone': 0.0,
#  'substances': 0.6931471805599453,
#  'nitrendipine': 0.6931471805599453,
#  'blocking': 0.0,
#  'multiple': 0.0,
#  'rapid': 0.0,
#  'cluster': 0.6931471805599453,
#  'cardiotox': 0.6931471805599453,
#  'looked': 0.6931471805599453,
#  'mentioned': 0.6931471805599453,
#  'less': 0.0,
#  'logistic': 0.0,
#  'lithium': 0.6931471805599453,
#  'ritonavir': 0.6931471805599453,
#  'visits': 0.6931471805599453,
#  'nephrolithiasis': 0.6931471805599453,
#  'malignant': 0.6931471805599453,
#  'oedema': 0.6931471805599453,
#  'kidney': 0.0,
#  'lacking': 0.6931471805599453,
#  'urofollitropin': 0.6931471805599453,
#  'pack': 0.0,
#  'metabolizer': 0.0,
#  'gemcitabine': 0.0,
#  'see': 0.0,
#  'warfarin': 0.0,
#  'statistically': 0.0,
#  'bufuralol': 0.6931471805599453,
#  'occurred': 0.6931471805599453,
#  'thought': 0.6931471805599453,
#  'made': 0.6931471805599453,
#  'fibrinolytic': 0.6931471805599453,
#  'tapentadol': 0.6931471805599453,
#  'cerivastatin': 0.6931471805599453,
#  'zafirlukast': 0.6931471805599453,
#  'mutation': 0.6931471805599453,
#  'maintained': 0.6931471805599453,
#  'tianeptine': 0.6931471805599453,
#  'paclitaxel': 0.0,
#  'without': 0.0,
#  'betterr': 0.6931471805599453,
#  'imiquimod': 0.6931471805599453,
#  'switch': 0.6931471805599453,
#  'women': 0.0,
#  'defined': 0.0,
#  'locus': 0.6931471805599453,
#  'neuropathic': 0.6931471805599453,
#  'metabolites': 0.0,
#  'pyrazolones': 0.6931471805599453,
#  'neutralizing': 0.6931471805599453,
#  'caf': 0.6931471805599453,
#  'icotinib': 0.6931471805599453,
#  'elevations': 0.6931471805599453,
#  'trichloroethylene': 0.6931471805599453,
#  'subjects': 0.0,
#  'cravings': 0.6931471805599453,
#  'change': 0.0,
#  'lonafarnib': 0.6931471805599453,
#  'aromatase': 0.0,
#  'vasodilation': 0.6931471805599453,
#  'evaluation': 0.6931471805599453,
#  'decreases': 0.0,
#  'digoxin': 0.6931471805599453,
#  'tyms': 0.6931471805599453,
#  'diuretics': 0.6931471805599453,
#  'type': 0.0,
#  'nortriptyline': 0.0,
#  'fludarabine': 0.6931471805599453,
#  'aqueous': 0.6931471805599453,
#  'del': 0.6931471805599453,
#  'g': 0.0,
#  'considered': 0.0,
#  'rehospitalization': 0.6931471805599453,
#  'terms': 0.6931471805599453,
#  'auc': 0.0,
#  'calcium': 0.6931471805599453,
#  'antiretrovirals': 0.6931471805599453,
#  'conferring': 0.6931471805599453,
#  'purified': 0.6931471805599453,
#  'libido': 0.6931471805599453,
#  'please': 0.0,
#  'nitrofurantoin': 0.6931471805599453,
#  'check': 0.6931471805599453,
#  'metabolize': 0.0,
#  'tamoxifen': 0.0,
#  'enter': 0.6931471805599453,
#  'amiodarone': 0.6931471805599453,
#  'pulse': 0.0,
#  'liothyronine': 0.6931471805599453,
#  'overral': 0.6931471805599453,
#  'affinity': 0.6931471805599453,
#  'diagnosis': 0.6931471805599453,
#  'binge': 0.6931471805599453,
#  'muscle': 0.0,
#  'dementia': 0.0,
#  'acting': 0.6931471805599453,
#  'pmid': 0.6931471805599453,
#  'scoring': 0.6931471805599453,
#  'abacavir': 0.6931471805599453,
#  'another': 0.0,
#  'bupropion': 0.0,
#  'intracellular': 0.6931471805599453,
#  'rasagiline': 0.6931471805599453,
#  'extent': 0.6931471805599453,
#  'k': 0.6931471805599453,
#  'ketorolac': 0.6931471805599453,
#  'lenalidomide': 0.6931471805599453,
#  'delay': 0.0,
#  'irritable': 0.6931471805599453,
#  'methimazole': 0.6931471805599453,
#  'adhd': 0.6931471805599453,
#  'opposing': 0.6931471805599453,
#  'expressors': 0.6931471805599453,
#  'chlorthalidone': 0.6931471805599453,
#  'measured': 0.0,
#  'threshold': 0.6931471805599453,
#  'concerning': 0.6931471805599453,
#  'zidovudine': 0.6931471805599453,
#  'anaesthesia': 0.6931471805599453,
#  'heterzygous': 0.6931471805599453,
#  'meloxicam': 0.6931471805599453,
#  'blue': 0.6931471805599453,
#  'polyglutamate': 0.6931471805599453,
#  'supporting': 0.0,
#  'transfusion': 0.6931471805599453,
#  'explanations': 0.6931471805599453,
#  'patches': 0.6931471805599453,
#  'commonly': 0.6931471805599453,
#  'current': 0.0,
#  'cannot': 0.6931471805599453,
#  'unfavorable': 0.6931471805599453,
#  'benefit': 0.0,
#  'prolongation': 0.6931471805599453,
#  'rifampicin': 0.6931471805599453,
#  'cefotaxime': 0.6931471805599453,
#  'svr': 0.6931471805599453,
#  'function': 0.0,
#  'folfiri': 0.6931471805599453,
#  'go': 0.6931471805599453,
#  'loss': 0.0,
#  'corticosteroids': 0.6931471805599453,
#  'lovastatin': 0.0,
#  'hemizygous': 0.6931471805599453,
#  'arrythmias': 0.6931471805599453,
#  'primarily': 0.6931471805599453,
#  'ct': 0.0,
#  'kidneys': 0.6931471805599453,
#  'sickle': 0.6931471805599453,
#  'simeprevir': 0.6931471805599453,
#  'spent': 0.0,
#  'anaesthetics': 0.6931471805599453,
#  'folfox': 0.6931471805599453,
#  'asians': 0.6931471805599453,
#  'elevated': 0.0,
#  'amitriptyline': 0.6931471805599453,
#  'comapred': 0.6931471805599453,
#  'osteoporosis': 0.6931471805599453,
#  'exacerbationse': 0.6931471805599453,
#  'infrequent': 0.6931471805599453,
#  'electrophoresis': 0.6931471805599453,
#  'mouth': 0.6931471805599453,
#  'sevoflurane': 0.6931471805599453,
#  'dermatitis': 0.6931471805599453,
#  'peak': 0.0,
#  'affect': 0.0,
#  'sufentanil': 0.0,
#  'sirolimus': 0.0,
#  'hyponatremia': 0.6931471805599453,
#  'loading': 0.6931471805599453,
#  'applied': 0.6931471805599453,
#  'various': 0.0,
#  'vasculature': 0.6931471805599453,
#  'indicating': 0.0,
#  'fluticasone': 0.6931471805599453,
#  'drinking': 0.6931471805599453,
#  'cardioselective': 0.6931471805599453,
#  'pylori': 0.0,
#  'interval': 0.0,
#  'remains': 0.6931471805599453,
#  'erlotinib': 0.0,
#  'expressers': 0.0,
#  'catalytically': 0.6931471805599453,
#  'dexrazoxane': 0.6931471805599453,
#  'invasive': 0.6931471805599453,
#  'creatine': 0.6931471805599453,
#  'verapamil': 0.6931471805599453,
#  'depending': 0.6931471805599453,
#  'asd': 0.6931471805599453,
#  'parkinsonism': 0.0,
#  'phenobarbital': 0.6931471805599453,
#  'ascites': 0.6931471805599453,
#  'overgrowth': 0.6931471805599453,
#  'gain': 0.0,
#  'ondansetron': 0.0,
#  'interferon': 0.6931471805599453,
#  'dck': 0.6931471805599453,
#  'atorvastatin': 0.0,
#  'cyclosporine': 0.0,
#  'exaggerated': 0.6931471805599453,
#  'thickness': 0.6931471805599453,
#  'chemotherapies': 0.6931471805599453,
#  'mh': 0.6931471805599453,
#  'annotations': 0.0,
#  'alfentanil': 0.6931471805599453,
#  'serm': 0.6931471805599453,
#  'suggesting': 0.6931471805599453,
#  'thalassemia': 0.6931471805599453,
#  'elderly': 0.0,
#  'chromosomal': 0.0,
#  'pulmonary': 0.6931471805599453,
#  'secondhand': 0.6931471805599453,
#  'trial': 0.6931471805599453,
#  'sensitivity': 0.6931471805599453,
#  'alternative': 0.0,
#  'b': 0.6931471805599453,
#  'nasopharyngeal': 0.6931471805599453,
#  'intronic': 0.6931471805599453,
#  'effect': 0.0,
#  'since': 0.0,
#  'sympathomimetics': 0.6931471805599453,
#  'daytime': 0.6931471805599453,
#  'presented': 0.6931471805599453,
#  'tg': 0.0,
#  'mycophenolic': 0.6931471805599453,
#  'interferons': 0.6931471805599453,
#  'recommend': 0.0,
#  'diarrhoea': 0.6931471805599453,
#  'cure': 0.6931471805599453,
#  'etravirine': 0.6931471805599453,
#  'leucopenia': 0.6931471805599453,
#  'metabolizers': 0.0,
#  'chronic': 0.0,
#  'combinations': 0.6931471805599453,
#  'odds': 0.0,
#  'hematologic': 0.6931471805599453,
#  'dicloxacillin': 0.6931471805599453,
#  'subgroup': 0.6931471805599453,
#  'vardenafil': 0.6931471805599453,
#  'precursor': 0.6931471805599453,
#  'covers': 0.0,
#  'inconsistencies': 0.6931471805599453,
#  'results': 0.0,
#  'benefits': 0.6931471805599453,
#  'telmisartan': 0.6931471805599453,
#  'dobutamine': 0.6931471805599453,
#  'subscale': 0.6931471805599453,
#  'seems': 0.6931471805599453,
#  'dvt': 0.6931471805599453,
#  'old': 0.6931471805599453,
#  'noncirrhotic': 0.6931471805599453,
#  'dimercaprol': 0.6931471805599453,
#  'together': 0.0,
#  'susceptibility': 0.6931471805599453,
#  'inhaled': 0.6931471805599453,
#  'hypercholesteremia': 0.6931471805599453,
#  'exist': 0.6931471805599453,
#  'mizolastine': 0.6931471805599453,
#  'agitated': 0.6931471805599453,
#  'female': 0.0,
#  'grouped': 0.6931471805599453,
#  'prescription': 0.6931471805599453,
#  'containing': 0.0,
#  'geneticc': 0.6931471805599453,
#  'surgery': 0.6931471805599453,
#  'akathisia': 0.6931471805599453,
#  'associated': 0.0,
#  'ration': 0.6931471805599453,
#  'maculopapular': 0.0,
#  'narcolepsy': 0.6931471805599453,
#  'determined': 0.6931471805599453,
#  'growth': 0.6931471805599453,
#  'regard': 0.6931471805599453,
#  'gastroesphageal': 0.6931471805599453,
#  'conjunctival': 0.6931471805599453,
#  'neurotoxicity': 0.0,
#  'esophagitis': 0.6931471805599453,
#  'gemtuzumab': 0.0,
#  'bowel': 0.6931471805599453,
#  'maprotiline': 0.6931471805599453,
#  'per': 0.0,
#  'glucocorticoids': 0.6931471805599453,
#  'long': 0.6931471805599453,
#  'sulfamethoxazole': 0.6931471805599453,
#  'tocilizumab': 0.6931471805599453,
#  'metronidazole': 0.6931471805599453,
#  'postmenopausal': 0.0,
#  'prochlorperazine': 0.6931471805599453,
#  'rick': 0.6931471805599453,
#  'dysphoria': 0.6931471805599453,
#  'genotypes': 0.0,
#  'malay': 0.6931471805599453,
#  'indicative': 0.6931471805599453,
#  'pruritus': 0.6931471805599453,
#  'aggregation': 0.0,
#  'mediterranean': 0.6931471805599453,
#  'based': 0.0,
#  'reach': 0.0,
#  'healthy': 0.0,
#  'equivalent': 0.6931471805599453,
#  'homozygotes': 0.6931471805599453,
#  'drugs': 0.0,
#  'disorders': 0.0,
#  'adherence': 0.6931471805599453,
#  'standard': 0.6931471805599453,
#  'acamprosate': 0.6931471805599453,
#  'barkley': 0.6931471805599453,
#  'naltrexone': 0.6931471805599453,
#  'decrease': 0.0,
#  'sexual': 0.6931471805599453,
#  'fentanyl': 0.0,
#  'isoniazid': 0.6931471805599453,
#  'started': 0.6931471805599453,
#  'graves': 0.6931471805599453,
#  'breast': 0.0,
#  'pronounced': 0.6931471805599453,
#  'hemolysis': 0.6931471805599453,
#  'fractures': 0.6931471805599453,
#  'lamivudine': 0.6931471805599453,
#  'acetaldehyde': 0.6931471805599453,
#  'adiponectin': 0.6931471805599453,
#  'modeling': 0.6931471805599453,
#  'note': 0.0,
#  'doxorubcin': 0.6931471805599453,
#  'hmgcr': 0.6931471805599453,
#  'infants': 0.6931471805599453,
#  'requirement': 0.0,
#  'response': 0.0,
#  'hodgkin': 0.6931471805599453,
#  'tpmt': 0.6931471805599453,
#  'regimens': 0.0,
#  'remainder': 0.6931471805599453,
#  'clindamycin': 0.6931471805599453,
#  'mofetil': 0.0,
#  'serious': 0.6931471805599453,
#  'monitor': 0.6931471805599453,
#  'protein': 0.0,
#  'vascular': 0.6931471805599453,
#  'inhalants': 0.6931471805599453,
#  'anthracycline': 0.6931471805599453,
#  'basal': 0.6931471805599453,
#  'receive': 0.0,
#  'opioids': 0.6931471805599453,
#  'inactive': 0.0,
#  'rasburicase': 0.6931471805599453,
#  'stable': 0.0,
#  'ciprofloxacin': 0.6931471805599453,
#  'cftr': 0.6931471805599453,
#  'esophageal': 0.6931471805599453,
#  'polycystic': 0.6931471805599453,
#  'alopecia': 0.0,
#  'chemotherapy': 0.0,
#  'piroxicam': 0.6931471805599453,
#  'galantamine': 0.0,
#  'pioglitazone': 0.0,
#  'sulindac': 0.6931471805599453,
#  'turner': 0.6931471805599453,
#  'jaw': 0.6931471805599453,
#  'repeat': 0.6931471805599453,
#  'tuberculosis': 0.0,
#  ...}

# %% [markdown]
# As we can note clearly, the _idf_ weights are either 0 or 0.693147... This is so, because we have only 2 documents, hence words that are common for both documents have weight of 0, and those words that appear in only one of the two documents - have weight of 0.693147...
#
# Now, we have to compute the entire _tf-idf_ score. This is a straightworfard task, we just have to multiply the term frequency of each word in our 'CYPs-related' and 'not-CYPs-related' ducuments by the _idf_ weight of the same word.
#
# We must now define a function that will do these computations. The function will recieve the term frequenices and the _idf_ weights for each word, and will return the calculated _tf-idf_ score.
#
# Let's do that.

# %%
def compute_tfidf(tf_bag_of_words, idfs):
    """
    Compute tf-idf score. 
    """
    tf_idf = {}
    for word, value in tf_bag_of_words.items():
        tf_idf[word] = value * idfs[word]
        
    return tf_idf

# %% [markdown]
# Let's now compute these _tf-idf_ scores for our 'CYPs-related' and 'not-CYPs-related' documents.

# %%
tfidf_cyps = compute_tfidf(tf_cyps, idfs)
tfidf_phenotypes_without_cyps = compute_tfidf(tf_phenotypes_without_cyps, idfs)

# %% [markdown]
# We can now make a DataFrame with our _tf-idf_ scores for better presentation of the results.

# %%
tfidf_scores = pd.DataFrame([tfidf_cyps, tfidf_phenotypes_without_cyps], index = ['tfidf_cyps', 'tfidf_phenotypes_without_cyps'])

# %% [markdown]
# Let's see these scores.

# %%
tfidf_scores
# Out:
#                                dolutegravir  excerice  normalized  increases  \
# tfidf_cyps                         0.000000  0.001323         0.0   0.000000
# tfidf_phenotypes_without_cyps      0.000794  0.000000         0.0   0.003968
#
#                                velpatasvir  methylene  recommended  propionic  \
# tfidf_cyps                        0.000000   0.000000     0.000000   0.000000
# tfidf_phenotypes_without_cyps     0.000794   0.002381     0.000265   0.002381
#
#                                 extreme  cilostazol  ...  evaluated     birth  \
# tfidf_cyps                     0.000000    0.001058  ...   0.000000  0.000000
# tfidf_phenotypes_without_cyps  0.001587    0.000000  ...   0.002116  0.000794
#
#                                impact        ld  analyses  associations  \
# tfidf_cyps                        0.0  0.000000  0.000794           0.0
# tfidf_phenotypes_without_cyps     0.0  0.003175  0.000000           0.0
#
#                                consequence  heterozygosity  platinum  \
# tfidf_cyps                             0.0        0.000000  0.000000
# tfidf_phenotypes_without_cyps          0.0        0.003439  0.071431
#
#                                diplotypes
# tfidf_cyps                       0.005556
# tfidf_phenotypes_without_cyps    0.000000
#
# [2 rows x 2620 columns]

# %% [markdown]
# Since the words are present as columns while the documents are set as indices, it is a good idea to transpose the DataFrame - it will be more readable.

# %%
tfidf_scores = tfidf_scores.T

# %%
tfidf_scores
# Out:
#                 tfidf_cyps  tfidf_phenotypes_without_cyps
# dolutegravir      0.000000                       0.000794
# excerice          0.001323                       0.000000
# normalized        0.000000                       0.000000
# increases         0.000000                       0.003968
# velpatasvir       0.000000                       0.000794
# ...                    ...                            ...
# associations      0.000000                       0.000000
# consequence       0.000000                       0.000000
# heterozygosity    0.000000                       0.003439
# platinum          0.000000                       0.071431
# diplotypes        0.005556                       0.000000
#
# [2620 rows x 2 columns]

# %% [markdown]
# Now, we can explore more thoroughly those words that are specific for the CYPs phenotypes, yet that is our primary goal  this section. These are the words that have score higher than 0. On the other hand, words with score 0 are either specific for the phenotypes associated with the rest of the genes (if this score is positive in the column `tfidf_phenotypes_without_cyps`) or are common for all phenotypes (if the score is 0 in both column).
#
# Let's examine which are these words specific for the CYPs genes.

# %%
tfidf_scores[tfidf_scores['tfidf_cyps'] > 0]
# Out:
#                 tfidf_cyps  tfidf_phenotypes_without_cyps
# excerice          0.001323                            0.0
# cilostazol        0.001058                            0.0
# clarithromycin    0.001587                            0.0
# e                 0.003968                            0.0
# record            0.001587                            0.0
# ...                    ...                            ...
# diazepam          0.002646                            0.0
# propafenone       0.000529                            0.0
# fast              0.000265                            0.0
# analyses          0.000794                            0.0
# diplotypes        0.005556                            0.0
#
# [235 rows x 2 columns]

# %% [markdown]
# 235 words out of 2620 unique words for the entire corpus are relevant only for the the CYPs.
#
# We can even display the first, let's say, 25 terms by rank, in order to see if there is something interesting.

# %%
tfidf_scores['tfidf_cyps'].nlargest(25)
# Out:
# functional          0.046827
# characterization    0.044446
# bufuralol           0.029102
# intrinsic           0.026456
# grouped             0.021429
# mephenytoin         0.017461
# trimipramine        0.016932
# pharmacogenomics    0.015874
# properties          0.015874
# comparable          0.015874
# dextromethorphan    0.015344
# intragastric        0.015344
# doxepin             0.014286
# amitriptyline       0.014022
# ph                  0.013757
# tricyclics          0.012170
# imipramine          0.011905
# maraviroc           0.007937
# ultrarapid          0.007937
# construct           0.007408
# tricyclic           0.006879
# lumefantrine        0.006085
# flurbiprofen        0.005556
# rabeprazole         0.005556
# diplotypes          0.005556
# Name: tfidf_cyps, dtype: float64

# %% [markdown]
# What do we observe here?
#
# We can see that there are words like $functional$, $characterization$, $construct$, and $properties$, that are difficult for interpretation in the light of phenotypes concerning the most important human pharmacogenes. In contrast, we have many names of drugs like $bufuralol$, $mephenytoin$, $trimipramine$, $doxepin$, $dextromethorphan$, $amitriptyline$, $imipramine$, $lumefantrine$, $flurbiprofen$, and $rabeprazole$ - most of which belong to the group of tricyclic antidepressants. Plus, if we take into account that we have 2 words - $tricyclic$, and $tricyclics$ in our top 25 ranked words, which conceivable also refer to the group of tricyclic antidepressant, we might indeed infer that tricyclic antidepressant are amidst the most studied medicines with reference to the genetic variability in the Cytochrome P450 enzyme family. This is not so surprising, because we already saw in the previous section that tricyclic antidepressants are metabolized by one of the major CYP enzymes - CYP2D6.

# %% [markdown]
# ### V. Conclusion

# %% [markdown]
# In this project so far, we walked through comprehensive exploratary data analysis of the Cytochrome P450 gene family. Our main source of data was the Pharmacogenomics Knowledge Base. We explored the six most frequently researched Cytochrome P450 genes - CYP2D6, CYP2C19, CYP2C9, CYP3A4, CYP3A5, and CYP2B6 in terms of their variant - drug associations. We found out that CYP2D6 is the gene with most variant - drug association in the literature curated by PharmGKB, followed by CYP2C19 and CYP2C9. In addition, we examined the biogeographical distribution of the variants of these 6 most common CYPs, as we found that there is no substantial difference in the number of variant - drug associations annotated in distinct racial group.
#
# In relation to the drugs associated with the genetic variants of the CYPs we discovered the antitussive - dextrometorphan as the drug with most variants linked to it - 62. From the point of view of the genetic variants, CYP2D6\*1 is the variant associated with most drug annotation - 12. We further extended our analysis to exploring the adverse drug reactions of these medicines, as our statistical analysis concluded that between the setrons - tropisetron and ondansetron, as well as between the opioids - codeine and tramadol, there is statistically significant differences in the severity of the adverse reactions in each group.
#
# We completed our project with demonstrating the power of _tf-idf_ while analysing clinical phenotypes associated with CYPs. We found out that amongst the top ranked terms are drugs part of the class of tricyclic antidepressants which backed up the findings in section III. Something more, if we reflect about the score obtained in the last section we may extend our knowledge beyond the Cytochrome P450 enzyme family, because all of the tricyclic antidepressants, which are top ranked in the 'CYP-related' document, are with _tf-idf_ score 0 in the rest of phenotype annotations. Hence, we may infer that this drug class is not a subject of genetic studies, for instance, concerning their target molecules (pharmacodynamic perspective), but rather the interests of pharmacogenetists is constrained only to their metabolism, at least according to the data we dealt with.

# %% [markdown]
# ### VI. References

# %% [markdown]
# 1. Dan M Roden, Howard L McLeod, Mary V Relling _et al._ 2019. Genomic Medicine: Pharmacogenomics. Publisher: The Lancet. http://dx.doi.org/10.1016/S0140-6736(19)31276-0
#
#
# 2. Liewei Wang, 2014. Pharmacogenomics: a systems approach. Wiley Interdiscip Rev Syst Biol Med. doi: 10.1002/wsbm.42
#
#
# 3. Chittaranjan Andrade, 2015. Understanding Relative Risk, Odds Ration, and Related Terms. Clinical and Practical Psychopharmacology. J Clin Psychiatry 2015; doi: 10.4088/JCP.15f10150
#
#
# 4. Matthew J. Lavin, 2019. Analyzing Documents with TF-IDF. https://programminghistorian.org/en/lessons/analyzing-documents-with-tfidf
#
#
# 5. Cory Maklin, 2019. TF IDF | TFIDF Python Example. https://towardsdatascience.com/natural-language-processing-feature-engineering-using-tf-idf-e8b9d00e7e76
